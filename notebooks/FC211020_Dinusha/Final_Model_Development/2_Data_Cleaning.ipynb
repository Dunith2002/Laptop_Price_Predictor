# %% [markdown]
# #  **Data Cleaning**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../../data/raw/laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    Brand                                               Name  \
# 0           0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...
# 1           1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....
# 2           3     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...
# 3           4       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...
# 4           6  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...
#
#    Price            Processor_Name Processor_Brand     RAM_Expandable  \
# 0  22990        MediaTek Octa-core        MediaTek     Not Expandable
# 1  36289     AMD Hexa-Core Ryzen 5             AMD   12 GB Expandable
# 2  78500  Intel Core i5 (12th Gen)           Intel   32 GB Expandable
# 3  55490  Intel Core i5 (12th Gen)           Intel    8 GB Expandable
# 4  21990  Intel Core i3 (11th Gen)           Intel     Not Expandable
#
#        RAM      RAM_TYPE                 Ghz Display_type Display  \
# 0    4 GB       DDR4 RAM   2.0 Ghz Processor          LED   11.6
# 1    8 GB      DDR4 RAM    4.0 Ghz Processor          LCD   15.6
# 2   16 GB      DDR5 RAM    3.3 Ghz Processor          LCD   15.6
# 3    8 GB      DDR4 RAM    4.2 Ghz Processor          LCD   15.6
# 4  8 GB LP   LPDDR4X RAM   1.7 Ghz Processor          LCD   15.6
#
#                           GPU GPU_Brand                 SSD     HDD Adapter  \
# 0         Integrated Graphics  MediaTek   64 GB SSD Storage  No HDD      45
# 1                      Radeon       AMD  512 GB SSD Storage  No HDD      65
# 2  GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD Storage  No HDD      56
# 3                     Iris Xe     Intel  512 GB SSD Storage  No HDD      no
# 4                         UHD     Intel  512 GB SSD Storage  No HDD      45
#
#                  Battery_Life
# 0    Upto 12 Hrs Battery Life
# 1    Upto 11 Hrs Battery Life
# 2    Upto 10 Hrs Battery Life
# 3  Upto 7.30 Hrs Battery Life
# 4     Upto 8 Hrs Battery Life

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3976 entries, 0 to 3975
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       3976 non-null   int64
#  1   Brand            3976 non-null   object
#  2   Name             3976 non-null   object
#  3   Price            3976 non-null   int64
#  4   Processor_Name   3976 non-null   object
#  5   Processor_Brand  3976 non-null   object
#  6   RAM_Expandable   3976 non-null   object
#  7   RAM              3976 non-null   object
#  8   RAM_TYPE         3976 non-null   object
#  9   Ghz              3976 non-null   object
#  10  Display_type     3976 non-null   object
#  11  Display          3976 non-null   object
#  12  GPU              3968 non-null   object
#  13  GPU_Brand        3972 non-null   object
#  14  SSD              3976 non-null   object
#  15  HDD              3976 non-null   object
#  16  Adapter          3976 non-null   object
#  17  Battery_Life     3558 non-null   object
# dtypes: int64(2), object(16)
# memory usage: 559.3+ KB

# %%
df.isnull().sum() #Check sum of null values
# Out:
# Unnamed: 0           0
# Brand                0
# Name                 0
# Price                0
# Processor_Name       0
# Processor_Brand      0
# RAM_Expandable       0
# RAM                  0
# RAM_TYPE             0
# Ghz                  0
# Display_type         0
# Display              0
# GPU                  8
# GPU_Brand            4
# SSD                  0
# HDD                  0
# Adapter              0
# Battery_Life       418
# dtype: int64

# %%
df.shape
# Out:
# (3976, 18)

# %%
df = df.drop(columns=['Unnamed: 0'])#Remove Unnamed column

# %%
df[df.duplicated()]
# Out:
#        Brand                                               Name  Price  \
# 2867  Lenovo  Lenovo Ideapad 3 15ITL6 (82H801L7IN) Laptop (1...  33900
# 3018      HP  HP 15s-du1044tu (18N71PA) Laptop (15.6 Inch | ...  22071
# 3104    Acer  Acer Aspire 5 A514-53 (NX.HZ6SI.001) Laptop (1...  27775
# 3321  Lenovo  Lenovo Ideapad Gaming 3 15ACH6 (82K200X3IN) La...  81990
#
#                 Processor_Name Processor_Brand     RAM_Expandable     RAM  \
# 2867  Intel Core i3 (11th Gen)           Intel   12 GB Expandable   8 GB
# 3018   Intel Celeron Dual-Core           Intel     Not Expandable   4 GB
# 3104  Intel Core i3 (10th Gen)           Intel   12 GB Expandable   4 GB
# 3321     AMD Octa-Core Ryzen 7             AMD   16 GB Expandable  16 GB
#
#         RAM_TYPE                 Ghz Display_type Display  \
# 2867   DDR4 RAM    4.0 Ghz Processor          LCD   15.6
# 3018    DDR4 RAM   1.1 Ghz Processor          LED   15.6
# 3104   DDR4 RAM    1.2 Ghz Processor          LED     14
# 3321   DDR4 RAM    3.1 Ghz Processor          LCD   15.6
#
#                              GPU GPU_Brand                 SSD  \
# 2867                         UHD     Intel  512 GB SSD Storage
# 3018                     UHD 600     Intel              NO SSD
# 3104                         UHD     Intel  512 GB SSD Storage
# 3321  GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD Storage
#
#                       HDD Adapter               Battery_Life
# 2867               No HDD      45   Upto 12 Hrs Battery Life
# 3018  1024 GB HDD Storage      46                46W Adapter
# 3104               No HDD      48   Upto 11 Hrs Battery Life
# 3321               No HDD      65    Upto 5 Hrs Battery Life

# %%
df = df.drop_duplicates() #Remove duplicates columns

# %%
df.shape
# Out:
# (3972, 17)

# %%
print(f"Number of unique Brands: {df['Brand'].nunique()}\n") 
print(f"Unique Values: {df['Brand'].unique()}\n")
print(f"Value count for each unique Brand type: {df['Brand'].value_counts()}")
# Out:
# Number of unique Brands: 31
#
# Unique Values: ['HP' 'Lenovo' 'Dell' 'Infinix' 'Acer' 'ASUS' 'Tecno' 'Xiaomi' 'MSI'
#  'Samsung' 'Apple' 'Realme' 'AVITA' 'Zebronics' 'Honor' 'Fujitsu' 'Wings'
#  'LG' 'Gigabyte' 'Microsoft' 'Razer' 'Coconics' 'Huawei' 'Micromax'
#  'iball' 'Lava' 'VAIO' 'Smartron' 'Colorful' 'Nokia' 'RDP']
#
# Value count for each unique Brand type: Brand
# ASUS         989
# Lenovo       809
# HP           802
# Dell         420
# Acer         321
# MSI          316
# Samsung       61
# Apple         49
# Infinix       39
# Microsoft     34
# AVITA         23
# Gigabyte      17
# LG            15
# Honor         14
# iball         11
# Xiaomi        10
# Fujitsu        8
# Zebronics      8
# Wings          4
# Colorful       3
# Realme         3
# Micromax       3
# Coconics       3
# Tecno          2
# Smartron       2
# Huawei         1
# Razer          1
# VAIO           1
# Lava           1
# Nokia          1
# RDP            1
# Name: count, dtype: int64

# %% [markdown]
# ## **Clean each feature**

# %% [markdown]
# ### Brand

# %%
#Clean Brand column
df['Brand'] = df['Brand'].astype('category')
brand_counts = df['Brand'].value_counts()
rare_brands = brand_counts[brand_counts < 40].index
df["Brand"] = df["Brand"].replace(rare_brands, "Other")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14052\1398493072.py:5: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df["Brand"] = df["Brand"].replace(rare_brands, "Other")

# %%
print(f"Unique Values: {df['Brand'].unique()}\n")
print(f"Value count for each unique Brand type: {df['Brand'].value_counts()}")
# Out:
# Unique Values: ['HP', 'Lenovo', 'Dell', 'Other', 'Acer', 'ASUS', 'MSI', 'Samsung', 'Apple']
# Categories (9, object): ['ASUS', 'Other', 'Acer', 'Apple', ..., 'HP', 'Lenovo', 'MSI', 'Samsung']
#
# Value count for each unique Brand type: Brand
# ASUS       989
# Lenovo     809
# HP         802
# Dell       420
# Acer       321
# MSI        316
# Other      205
# Samsung     61
# Apple       49
# Name: count, dtype: int64

# %%
avg_price = df.groupby('Brand')['Price'].mean().sort_values()

plt.figure(figsize=(18,5))
plt.barh(avg_price.index, avg_price.values)   # horizontal bar chart
plt.xlabel("Average Price")
plt.ylabel("Processor Seies")
plt.title("Average Laptop Price by Processor Category")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14052\3943692356.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_price = df.groupby('Brand')['Price'].mean().sort_values()

# %% [markdown]
# ### RAM Expandable

# %%
#Clean RAM_Expandable column
df['RAM_Expandable'] = df['RAM_Expandable'].str.rstrip('GB Expandable') # Remove unwanted characters
print(f"Unique Values: {df['RAM_Expandable'].unique()}\n")
df['RAM_Expandable'].value_counts()
# Out:
# Unique Values: ['Not' ' 12' ' 32' ' 8' ' 16' ' 4' ' 64' ' 48' ' 2' ' 10']
# RAM_Expandable
# Not    2156
#  16     756
#  32     537
#  8      186
#  12     158
#  64     158
#  4        9
#  48       9
#  2        2
#  10       1
# Name: count, dtype: int64

# %%
df['RAM_Expandable'] = df['RAM_Expandable'].apply(lambda x: 'No' if 'Not' in x else 'Yes')
df['RAM_Expandable'].value_counts()
# Out:
# RAM_Expandable
# No     2156
# Yes    1816
# Name: count, dtype: int64

# %% [markdown]
# ### RAM Size

# %%
#Clean RAM column
df['RAM'] = df['RAM'].str.extract('(\d+)').astype(int)
df.rename(columns={'RAM': 'RAM_Size (GB)'}, inplace=True)
print(f"Unique Values: {df['RAM_Size (GB)'].unique()}\n")
# Out:
# Unique Values: [ 4  8 16 32 18 64 12 36  2 24  6  3]
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\USER\AppData\Local\Temp\ipykernel_14052\1427822852.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df['RAM'] = df['RAM'].str.extract('(\d+)').astype(int)

# %%
print(f"Value count for each unique RAM sizes: {df['RAM_Size (GB)'].value_counts()}")
# Out:
# Value count for each unique RAM sizes: RAM_Size (GB)
# 8     1803
# 16    1407
# 4      581
# 32     139
# 2       24
# 64       6
# 12       6
# 3        2
# 36       1
# 18       1
# 24       1
# 6        1
# Name: count, dtype: int64

# %%
standard_ram_sizes = [4, 8, 16, 32]
df = df[df["RAM_Size (GB)"].isin(standard_ram_sizes)].reset_index(drop=True)

print(df["RAM_Size (GB)"].value_counts())
# Out:
# RAM_Size (GB)
# 8     1803
# 16    1407
# 4      581
# 32     139
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3930, 17)

# %% [markdown]
# ### Processor Brand

# %%
apple_df = df[df['Brand'] == 'Apple'][['Name','Brand', 'Processor_Brand','Ghz', 'Processor_Name']]
print(apple_df)

print(apple_df['Ghz'].value_counts())
# Out:
#                                                    Name  Brand  \
# 80    Apple MacBook Air M1 MGND3HN/A Ultrabook (13.3...  Apple
# 82    Apple MacBook Air MQD32HN/A Ultrabook (13.3 In...  Apple
# 96    Apple MacBook Air M2 MLXY3HN/A Ultrabook (13.6...  Apple
# 160   Apple MacBook Pro M1 Pro MKGQ3HN/A Ultrabook (...  Apple
# 227   Apple MacBook Pro M2 MNEJ3HN/A Ultrabook (13.3...  Apple
# 366   Apple MacBook Pro MV972HN/A Ultrabook (13.3 In...  Apple
# 371   Apple MacBook Air M2 MLY43HN/A Ultrabook (13.6...  Apple
# 698   Apple MacBook Pro M2 Max MNWA3HN/A Ultrabook (...  Apple
# 1342  Apple MacBook Air MREE2HN/A Ultrabook (13.3 In...  Apple
# 1348  Apple MacBook Air MVFM2HN/A Ultrabook (13.3 In...  Apple
# 1349  Apple MacBook Air MVFH2HN/A Ultrabook (13.3 In...  Apple
# 1351  Apple MacBook Air MRE82HN/A Ultrabook (13.3 In...  Apple
# 1352  Apple MacBook Air MREA2HN/A Ultrabook (13.3 In...  Apple
# 1417  Apple MacBook MRQN2HN/A Ultrabook (12 Inch | C...  Apple
# 1441  Apple MacBook Air MMGF2HN/A Ultrabook (13.3 In...  Apple
# 1547  Apple MacBook Air M1 Z124J001KD Laptop (13.3 I...  Apple
# 1564  Apple MacBook Air MVFK2HN/A Ultrabook (13.3 In...  Apple
# 1573  Apple MacBook Air MWTJ2HN/A Ultrabook (13.3 In...  Apple
# 1674  Apple MacBook Air MVFJ2HN/A Ultrabook (13.3 In...  Apple
# 1679  Apple MacBook Air MVH22HN/A Ultrabook (13.3 In...  Apple
# 1701  Apple MacBook Air MRE92HN/A Ultrabook (13.3 In...  Apple
# 1715  Apple MacBook Air MREC2HN/A Ultrabook (13.3 In...  Apple
# 1768  Apple MacBook Air MVH42HN/A Ultrabook (13.3 In...  Apple
# 1930  Apple MacBook Pro M2 MNEH3HN/A Ultrabook (13.3...  Apple
# 1958  Apple MacBook Air M2 MQKV3HN/A Ultrabook (15.3...  Apple
# 1964  Apple MacBook Air M2 MQKQ3HN/A Ultrabook (15.3...  Apple
# 1966  Apple MacBook Air M2 MQKX3HN/A Laptop (15.3 In...  Apple
# 1967  Apple MacBook Air M2 MQKP3HN/A Ultrabook (15.3...  Apple
# 1968  Apple MacBook Air M2 MQKR3HN/A Ultrabook (15.3...  Apple
# 1969  Apple MacBook Air M2 MQKU3HN/A Ultrabook (15.3...  Apple
# 2189  Apple MacBook Pro M2 Pro MPHH3HN/A Ultrabook (...  Apple
# 2218  Apple MacBook Pro M2 Pro MNW93HN/A Ultrabook (...  Apple
# 2232  Apple MacBook Pro M2 Max MPHG3HN/A Ultrabook (...  Apple
# 2305  Apple MacBook Pro M2 Pro MPHJ3HN/A Ultrabook (...  Apple
# 3044  Apple MacBook Pro M1 Pro MK193HN/A Ultrabook (...  Apple
# 3123  Apple MacBook Pro MWP52HN/A Ultrabook (13 Inch...  Apple
# 3156  Apple MacBook Air MVFN2HN/A Ultrabook (13.3 In...  Apple
# 3181  Apple MacBook Air MVFL2HN/A Ultrabook (13.3 In...  Apple
# 3191  Apple MacBook Air MREF2HN/A Ultrabook (13.3 In...  Apple
# 3215  Apple MacBook Pro MWP42HN/A Ultrabook (13 Inch...  Apple
# 3288  Apple MacBook Pro MUHN2HN/A Ultrabook (13.3 In...  Apple
# 3306  Apple MacBook Pro MV992HN/A Ultrabook (13.3 In...  Apple
# 3341  Apple MacBook Pro MVVK2HN/A Ultrabook (16 Inch...  Apple
# 3407  Apple MacBook Pro MR9R2HN/A Ultrabook (13.3 In...  Apple
# 3456  Apple MacBook Pro MLH32HN/A Ultrabook (15.4 In...  Apple
# 3558  Apple MacBook Pro MR932HN/A Ultrabook (15.4 In...  Apple
# 3656  Apple MacBook Pro MR962HN/A Ultrabook (15.4 In...  Apple
#
#      Processor_Brand                 Ghz                      Processor_Name
# 80             Apple   2.9 Ghz Processor                            Apple M1
# 82             Intel   1.8 Ghz Processor             Intel Core i5 (5th Gen)
# 96             Apple                   0                  Apple M2 Processor
# 160              2.3                   0                   2.3 Ghz Processor
# 227            Apple                   0                  Apple M2 Processor
# 366            Intel   2.4 Ghz Processor             Intel Core i5 (8th Gen)
# 371            Apple                   0                  Apple M2 Processor
# 698            Apple                   0              Apple M2 Max Processor
# 1342           Intel   1.6 Ghz Processor             Intel Core i5 (8th Gen)
# 1348           Intel   1.6 Ghz Processor             Intel Core i5 (8th Gen)
# 1349           Intel   1.6 Ghz Processor             Intel Core i5 (8th Gen)
# 1351           Intel   1.6 Ghz Processor             Intel Core i5 (8th Gen)
# 1352             1.6                   0                   1.6 Ghz Processor
# 1417           Intel   1.1 Ghz Processor             Intel Core M3 (7th Gen)
# 1441           Intel   1.6 Ghz Processor             Intel Core i5 (5th Gen)
# 1547           Apple                   0                  Apple M1 Processor
# 1564           Intel   1.6 Ghz Processor             Intel Core i5 (8th Gen)
# 1573           Intel                   0  Intel Core i3 (10th Gen) Processor
# 1674           Intel   1.6 Ghz Processor             Intel Core i5 (8th Gen)
# 1679           Intel   1.1 Ghz Processor            Intel Core i5 (10th Gen)
# 1701           Intel   1.6 Ghz Processor             Intel Core i5 (8th Gen)
# 1715           Intel   1.6 Ghz Processor             Intel Core i5 (8th Gen)
# 1768           Intel   1.1 Ghz Processor            Intel Core i5 (10th Gen)
# 1930           Apple                   0                  Apple M2 Processor
# 1958           Apple                   0                  Apple M2 Processor
# 1964           Apple                   0                  Apple M2 Processor
# 1966           Apple                   0                  Apple M2 Processor
# 1967           Apple                   0                  Apple M2 Processor
# 1968           Apple                   0                  Apple M2 Processor
# 1969           Apple                   0                  Apple M2 Processor
# 2189           Apple   3.4 Ghz Processor                        Apple M2 Pro
# 2218           Apple   3.4 Ghz Processor                        Apple M2 Pro
# 2232           Apple   3.4 Ghz Processor                        Apple M2 Max
# 2305           Apple   3.4 Ghz Processor                        Apple M2 Pro
# 3044           Apple   2.3 Ghz Processor                        Apple M1 Pro
# 3123           Intel   2.0 Ghz Processor            Intel Core i5 (10th Gen)
# 3156           Intel   1.6 Ghz Processor             Intel Core i5 (8th Gen)
# 3181           Intel   1.6 Ghz Processor             Intel Core i5 (8th Gen)
# 3191           Intel   1.6 Ghz Processor             Intel Core i5 (8th Gen)
# 3215           Intel   2.0 Ghz Processor            Intel Core i5 (10th Gen)
# 3288           Intel   1.4 Ghz Processor             Intel Core i5 (8th Gen)
# 3306           Intel   2.4 Ghz Processor             Intel Core i5 (8th Gen)
# 3341           Intel   2.3 Ghz Processor             Intel Core i9 (9th Gen)
# 3407           Intel   2.3 Ghz Processor             Intel Core i5 (8th Gen)
# 3456           Intel   2.6 Ghz Processor             Intel Core i7 (6th Gen)
# 3558           Intel   2.2 Ghz Processor             Intel Core i7 (8th Gen)
# 3656           Intel   2.2 Ghz Processor             Intel Core i7 (8th Gen)
# Ghz
# 0                     15
#  1.6 Ghz Processor    12
#  3.4 Ghz Processor     4
#  1.1 Ghz Processor     3
#  2.3 Ghz Processor     3
#  2.0 Ghz Processor     2
#  2.4 Ghz Processor     2
#  2.2 Ghz Processor     2
#  2.9 Ghz Processor     1
#  1.8 Ghz Processor     1
#  1.4 Ghz Processor     1
#  2.6 Ghz Processor     1
# Name: count, dtype: int64

# %%
# def split_processor_details(value):
#     if pd.isna(value) or str(value).strip() == "":
#         return ("Unknown", "Unknown")
    
#     text = value.strip()

#     # Extract brand (first word before space)
#     brand = text.split()[0]

#     # Remove everything inside parentheses and after it
#     text_before_parenthesis = re.split(r'\(', text)[0].strip()

#     # Remove the brand name from the start
#     series = re.sub(rf'^{brand}\s*', '', text_before_parenthesis, flags=re.IGNORECASE).strip()

#     return (brand, series)

# # Apply to DataFrame
# df[["Processor_Brand_Extracted", "Processor_Series"]] = df["Processor_Name"].apply(lambda x: pd.Series(split_processor_details(x)))

# %%
# print(f"Unique Values: {df['Processor_Series'].unique()}\n")
# print(f"Value count for each unique processor type: {df['Processor_Series'].value_counts()}")

# %%
print(f"Unique Values: {df['Processor_Brand'].unique()}\n")
print(f"Value count for each unique processor type: {df['Processor_Brand'].value_counts()}")
# Out:
# Unique Values: ['MediaTek' 'AMD' 'Intel' 'Apple' '2.3' '3.4' 'Qualcomm' '3.3' '1.6' '2.4'
#  '3.0' '2.2' '1.7' '2.0' '2.1' 'Microsoft' '1.9' '2.6']
#
# Value count for each unique processor type: Processor_Brand
# Intel        2968
# AMD           919
# Apple          18
# MediaTek        4
# 1.7             4
# 3.4             2
# 3.0             2
# 2.0             2
# 2.4             2
# 2.3             1
# 1.6             1
# 3.3             1
# Qualcomm        1
# 2.2             1
# 2.1             1
# Microsoft       1
# 1.9             1
# 2.6             1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3930, 17)

# %%
# Keep only the major processor brands
valid_brands = ["AMD", "Apple", "Intel"]

df = df[df["Processor_Brand"].isin(valid_brands)].reset_index(drop=True)
df.shape
# Out:
# (3905, 17)

# %%
print(f"Unique Values: {df['Processor_Brand'].unique()}\n")
print(f"Value count for each unique processor type: {df['Processor_Brand'].value_counts()}")
# Out:
# Unique Values: ['AMD' 'Intel' 'Apple']
#
# Value count for each unique processor type: Processor_Brand
# Intel    2968
# AMD       919
# Apple      18
# Name: count, dtype: int64

# %%
# Calculate mean price by Processor_Brand
avg_price_tier = df.groupby('Processor_Brand')['Price'].mean().sort_values()

# Plot horizontal bar chart
plt.figure(figsize=(18,3))
plt.barh(avg_price_tier.index, avg_price_tier.values, color='skyblue')
plt.xlabel("Average Price")
plt.ylabel("Processor Brand")
plt.title("Average Laptop Price by Processor Brand")
plt.tight_layout()
plt.show()

# %%
print(f"Unique Values: {df['Brand'].unique()}\n")
print(f"Value count for each unique processor type: {df['Brand'].value_counts()}")
# Out:
# Unique Values: ['Lenovo', 'Dell', 'HP', 'Other', 'Acer', 'ASUS', 'MSI', 'Samsung', 'Apple']
# Categories (9, object): ['ASUS', 'Other', 'Acer', 'Apple', ..., 'HP', 'Lenovo', 'MSI', 'Samsung']
#
# Value count for each unique processor type: Brand
# ASUS       977
# Lenovo     803
# HP         784
# Dell       420
# Acer       317
# MSI        309
# Other      191
# Samsung     59
# Apple       45
# Name: count, dtype: int64

# %%
# print(f"Unique Values: {df['Processor_Series'].unique()}\n")
# print(f"Value count for each unique processor type: {df['Processor_Series'].value_counts()}")

# %% [markdown]
# ### Processor speed

# %%
#Clean processr speed column (Ghz)
df['Ghz'] = df['Ghz'].str.rstrip('Ghz Processor').astype(float)
df.rename(columns={'Ghz': 'Processer_speed'}, inplace=True)
print(f"Unique Values: {df['Processer_speed'].unique()}\n")
df['Processer_speed'].value_counts()
# Out:
# Unique Values: [4.  3.3 4.2 1.7 0.  2.5 2.2 2.9 3.4 2.6 3.  4.7 3.1 2.7 2.8 2.4 2.1 4.8
#  1.2 1.  1.8 2.  1.1 2.3 1.6 0.8 1.3 1.5 1.9 5.5 1.4]
# Processer_speed
# 4.2    331
# 2.4    249
# 4.7    244
# 1.6    233
# 2.3    212
# 0.0    202
# 3.3    197
# 4.8    181
# 2.1    176
# 2.6    175
# 2.5    163
# 2.0    157
# 1.2    148
# 3.0    138
# 3.4    137
# 4.0    106
# 1.1    103
# 1.8     98
# 2.2     96
# 2.8     89
# 1.0     81
# 3.1     80
# 1.7     74
# 2.7     56
# 1.3     44
# 2.9     34
# 1.4     26
# 1.5     24
# 0.8     20
# 5.5     16
# 1.9     15
# Name: count, dtype: int64

# %%
df[df['Processer_speed']==0]
# Out:
#      Brand                                               Name   Price  \
# 4     Acer  Acer One 14 Z8-415 (UN.599SI.020) Laptop (14 I...   34990
# 11    Acer  Acer Predator Helios Neo 16 PHN16-71 (NH.QLTSI...  104990
# 13    Acer  Acer Predator Helios Neo 16 PHN16-71 (NH.QLTSI...  112980
# 17    Acer  Acer Nitro V ANV15-51 (UN.QN8SI.001) Laptop (1...   77860
# 46      HP  HP 15s-du3564TU (5R7P5PA) Laptop (15.6 Inch | ...   49999
# ...    ...                                                ...     ...
# 3791  Acer  Acer Aspire 5 A515-45 (NX.A84SI.007) Laptop (1...   49990
# 3800  ASUS  ASUS VivoBook 15 X515EA-BR391TS Laptop (15.6 I...   29990
# 3812  ASUS  ASUS VivoBook 14 X415EA-EK678TS Laptop (14 Inc...   49990
# 3862  ASUS  ASUS TUF Dash F15 FX516PR-AZ108TS Laptop (15.6...  146000
# 3877  ASUS  ASUS TUF Dash F15 FX516PR-AZ107TS Laptop (15.6...  146990
#
#                           Processor_Name Processor_Brand RAM_Expandable  \
# 4     Intel Core i5 (11th Gen) Processor           Intel            Yes
# 11    Intel Core i7 (13th Gen) Processor           Intel            Yes
# 13    Intel Core i7 (13th Gen) Processor           Intel            Yes
# 17    Intel Core i5 (13th Gen) Processor           Intel            Yes
# 46    Intel Core i3 (11th Gen) Processor           Intel             No
# ...                                  ...             ...            ...
# 3791     AMD Hexa-Core Ryzen 5 Processor             AMD             No
# 3800  Intel Core i3 (11th Gen) Processor           Intel             No
# 3812  Intel Core i5 (11th Gen) Processor           Intel             No
# 3862  Intel Core i7 (11th Gen) Processor           Intel            Yes
# 3877  Intel Core i7 (11th Gen) Processor           Intel            Yes
#
#       RAM_Size (GB)    RAM_TYPE  Processer_speed Display_type Display  \
# 4                16   DDR4 RAM               0.0          LCD     14
# 11               16   DDR5 RAM               0.0          LCD     16
# 13               16   DDR5 RAM               0.0          LCD     16
# 17               16   DDR5 RAM               0.0          LCD   15.6
# 46                8    DDR4 RAM              0.0          LED   15.6
# ...             ...         ...              ...          ...     ...
# 3791              8    DDR4 RAM              0.0          LED   15.6
# 3800              8    DDR4 RAM              0.0          LED   15.6
# 3812              8    DDR4 RAM              0.0          LED     14
# 3862             16   DDR4 RAM               0.0          LED   15.6
# 3877             16   DDR4 RAM               0.0          LED   15.6
#
#                              GPU GPU_Brand                  SSD  \
# 4                        Iris Xe     Intel   512 GB SSD Storage
# 11    GeForce RTX 4050 GPU, 6 GB    NVIDIA  1024 GB SSD Storage
# 13    GeForce RTX 4050 GPU, 6 GB    NVIDIA  1024 GB SSD Storage
# 17    GeForce RTX 4050 GPU, 6 GB    NVIDIA   512 GB SSD Storage
# 46                           UHD     Intel   512 GB SSD Storage
# ...                          ...       ...                  ...
# 3791                      Radeon       AMD   512 GB SSD Storage
# 3800                         UHD     Intel               NO SSD
# 3812                         UHD     Intel   256 GB SSD Storage
# 3862  GeForce RTX 3070 GPU, 8 GB    NVIDIA  1024 GB SSD Storage
# 3877  GeForce RTX 3070 GPU, 8 GB    NVIDIA  1024 GB SSD Storage
#
#                       HDD Adapter  Battery_Life
# 4                  No HDD      45   45W Adapter
# 11                 No HDD     230  230W Adapter
# 13                 No HDD     230  230W Adapter
# 17                 No HDD     135  135W Adapter
# 46                 No HDD      65   65W Adapter
# ...                   ...     ...           ...
# 3791               No HDD      48   48W Adapter
# 3800  1024 GB HDD Storage      no           NaN
# 3812               No HDD      45   45W Adapter
# 3862               No HDD     200  200W Adapter
# 3877               No HDD     200  200W Adapter
#
# [202 rows x 17 columns]

# %%
apple_df = df[df['Brand'] == 'Apple'][['Brand', 'Processor_Brand', 'Processer_speed']]
print(apple_df)

print(apple_df['Processor_Brand'].value_counts())
# Out:
#       Brand Processor_Brand  Processer_speed
# 79    Apple           Apple              2.9
# 81    Apple           Intel              1.8
# 95    Apple           Apple              0.0
# 225   Apple           Apple              0.0
# 362   Apple           Intel              2.4
# 367   Apple           Apple              0.0
# 693   Apple           Apple              0.0
# 1336  Apple           Intel              1.6
# 1342  Apple           Intel              1.6
# 1343  Apple           Intel              1.6
# 1345  Apple           Intel              1.6
# 1410  Apple           Intel              1.1
# 1434  Apple           Intel              1.6
# 1539  Apple           Apple              0.0
# 1556  Apple           Intel              1.6
# 1565  Apple           Intel              0.0
# 1666  Apple           Intel              1.6
# 1671  Apple           Intel              1.1
# 1693  Apple           Intel              1.6
# 1707  Apple           Intel              1.6
# 1760  Apple           Intel              1.1
# 1921  Apple           Apple              0.0
# 1949  Apple           Apple              0.0
# 1955  Apple           Apple              0.0
# 1957  Apple           Apple              0.0
# 1958  Apple           Apple              0.0
# 1959  Apple           Apple              0.0
# 1960  Apple           Apple              0.0
# 2179  Apple           Apple              3.4
# 2207  Apple           Apple              3.4
# 2221  Apple           Apple              3.4
# 2294  Apple           Apple              3.4
# 3032  Apple           Apple              2.3
# 3111  Apple           Intel              2.0
# 3142  Apple           Intel              1.6
# 3167  Apple           Intel              1.6
# 3177  Apple           Intel              1.6
# 3201  Apple           Intel              2.0
# 3272  Apple           Intel              1.4
# 3290  Apple           Intel              2.4
# 3325  Apple           Intel              2.3
# 3391  Apple           Intel              2.3
# 3439  Apple           Intel              2.6
# 3538  Apple           Intel              2.2
# 3635  Apple           Intel              2.2
# Processor_Brand
# Intel    27
# Apple    18
# Name: count, dtype: int64

# %%
import re

def fix_processor_speed(row):
    if row["Processer_speed"] == 0 or pd.isna(row["Processer_speed"]):
        match = re.search(r"\d+(\.\d+)?", str(row["Processor_Brand"]))
        if match:
            return float(match.group(0))
    return row["Processer_speed"]

df["Processer_speed"] = df.apply(fix_processor_speed, axis=1)
df["Processer_speed"].value_counts()
# Out:
# Processer_speed
# 4.2    331
# 2.4    249
# 4.7    244
# 1.6    233
# 2.3    212
# 0.0    202
# 3.3    197
# 4.8    181
# 2.1    176
# 2.6    175
# 2.5    163
# 2.0    157
# 1.2    148
# 3.0    138
# 3.4    137
# 4.0    106
# 1.1    103
# 1.8     98
# 2.2     96
# 2.8     89
# 1.0     81
# 3.1     80
# 1.7     74
# 2.7     56
# 1.3     44
# 2.9     34
# 1.4     26
# 1.5     24
# 0.8     20
# 5.5     16
# 1.9     15
# Name: count, dtype: int64

# %%
df[df['Processer_speed']==0]
# Out:
#      Brand                                               Name   Price  \
# 4     Acer  Acer One 14 Z8-415 (UN.599SI.020) Laptop (14 I...   34990
# 11    Acer  Acer Predator Helios Neo 16 PHN16-71 (NH.QLTSI...  104990
# 13    Acer  Acer Predator Helios Neo 16 PHN16-71 (NH.QLTSI...  112980
# 17    Acer  Acer Nitro V ANV15-51 (UN.QN8SI.001) Laptop (1...   77860
# 46      HP  HP 15s-du3564TU (5R7P5PA) Laptop (15.6 Inch | ...   49999
# ...    ...                                                ...     ...
# 3791  Acer  Acer Aspire 5 A515-45 (NX.A84SI.007) Laptop (1...   49990
# 3800  ASUS  ASUS VivoBook 15 X515EA-BR391TS Laptop (15.6 I...   29990
# 3812  ASUS  ASUS VivoBook 14 X415EA-EK678TS Laptop (14 Inc...   49990
# 3862  ASUS  ASUS TUF Dash F15 FX516PR-AZ108TS Laptop (15.6...  146000
# 3877  ASUS  ASUS TUF Dash F15 FX516PR-AZ107TS Laptop (15.6...  146990
#
#                           Processor_Name Processor_Brand RAM_Expandable  \
# 4     Intel Core i5 (11th Gen) Processor           Intel            Yes
# 11    Intel Core i7 (13th Gen) Processor           Intel            Yes
# 13    Intel Core i7 (13th Gen) Processor           Intel            Yes
# 17    Intel Core i5 (13th Gen) Processor           Intel            Yes
# 46    Intel Core i3 (11th Gen) Processor           Intel             No
# ...                                  ...             ...            ...
# 3791     AMD Hexa-Core Ryzen 5 Processor             AMD             No
# 3800  Intel Core i3 (11th Gen) Processor           Intel             No
# 3812  Intel Core i5 (11th Gen) Processor           Intel             No
# 3862  Intel Core i7 (11th Gen) Processor           Intel            Yes
# 3877  Intel Core i7 (11th Gen) Processor           Intel            Yes
#
#       RAM_Size (GB)    RAM_TYPE  Processer_speed Display_type Display  \
# 4                16   DDR4 RAM               0.0          LCD     14
# 11               16   DDR5 RAM               0.0          LCD     16
# 13               16   DDR5 RAM               0.0          LCD     16
# 17               16   DDR5 RAM               0.0          LCD   15.6
# 46                8    DDR4 RAM              0.0          LED   15.6
# ...             ...         ...              ...          ...     ...
# 3791              8    DDR4 RAM              0.0          LED   15.6
# 3800              8    DDR4 RAM              0.0          LED   15.6
# 3812              8    DDR4 RAM              0.0          LED     14
# 3862             16   DDR4 RAM               0.0          LED   15.6
# 3877             16   DDR4 RAM               0.0          LED   15.6
#
#                              GPU GPU_Brand                  SSD  \
# 4                        Iris Xe     Intel   512 GB SSD Storage
# 11    GeForce RTX 4050 GPU, 6 GB    NVIDIA  1024 GB SSD Storage
# 13    GeForce RTX 4050 GPU, 6 GB    NVIDIA  1024 GB SSD Storage
# 17    GeForce RTX 4050 GPU, 6 GB    NVIDIA   512 GB SSD Storage
# 46                           UHD     Intel   512 GB SSD Storage
# ...                          ...       ...                  ...
# 3791                      Radeon       AMD   512 GB SSD Storage
# 3800                         UHD     Intel               NO SSD
# 3812                         UHD     Intel   256 GB SSD Storage
# 3862  GeForce RTX 3070 GPU, 8 GB    NVIDIA  1024 GB SSD Storage
# 3877  GeForce RTX 3070 GPU, 8 GB    NVIDIA  1024 GB SSD Storage
#
#                       HDD Adapter  Battery_Life
# 4                  No HDD      45   45W Adapter
# 11                 No HDD     230  230W Adapter
# 13                 No HDD     230  230W Adapter
# 17                 No HDD     135  135W Adapter
# 46                 No HDD      65   65W Adapter
# ...                   ...     ...           ...
# 3791               No HDD      48   48W Adapter
# 3800  1024 GB HDD Storage      no           NaN
# 3812               No HDD      45   45W Adapter
# 3862               No HDD     200  200W Adapter
# 3877               No HDD     200  200W Adapter
#
# [202 rows x 17 columns]

# %%
def fix_apple_processor_name(row):
    if row["Brand"] == "Apple" and row["Processor_Brand"] == "Apple":
        # Extract the part between the first and second '|'
        match = re.search(r'\|\s*([^|]+?)\s*\|', row["Name"])
        if match:
            return match.group(1).strip()
    return row["Processor_Name"]

# Update the column directly
df["Processor_Name"] = df.apply(fix_apple_processor_name, axis=1)

# %%
# Filter rows where Processor_Brand is Apple
apple_df = df[df['Processor_Brand'] == 'Apple'][['Processor_Name', 'Processor_Brand', 'Processer_speed']]

# View the resulting DataFrame
print(apple_df)
# Out:
#      Processor_Name Processor_Brand  Processer_speed
# 79         Apple M1           Apple              2.9
# 95         Apple M2           Apple              0.0
# 225        Apple M2           Apple              0.0
# 367        Apple M2           Apple              0.0
# 693    Apple M2 Max           Apple              0.0
# 1539       Apple M1           Apple              0.0
# 1921       Apple M2           Apple              0.0
# 1949       Apple M2           Apple              0.0
# 1955       Apple M2           Apple              0.0
# 1957       Apple M2           Apple              0.0
# 1958       Apple M2           Apple              0.0
# 1959       Apple M2           Apple              0.0
# 1960       Apple M2           Apple              0.0
# 2179   Apple M2 Pro           Apple              3.4
# 2207   Apple M2 Pro           Apple              3.4
# 2221   Apple M2 Max           Apple              3.4
# 2294   Apple M2 Pro           Apple              3.4
# 3032   Apple M1 Pro           Apple              2.3

# %%
# Define typical Apple processor speeds (in GHz)
apple_speed_map = {
    "Apple M1": 3.2,
    "Apple M1 Pro": 3.2,
    "Apple M2": 3.5,
    "Apple M2 Pro": 3.5,
    "Apple M2 Max": 3.5,
}

# Update Processer_speed for Apple processors
df.loc[
    (df["Processor_Brand"] == "Apple") & (df["Processor_Name"].isin(apple_speed_map.keys())),
    "Processer_speed"
] = df["Processor_Name"].map(apple_speed_map)

# %%
# Filter rows where Processor_Brand is Apple
apple_df = df[df['Processor_Brand'] == 'Apple'][['Processor_Name', 'Processor_Brand', 'Processer_speed']]

# View the resulting DataFrame
print(apple_df)
# Out:
#      Processor_Name Processor_Brand  Processer_speed
# 79         Apple M1           Apple              3.2
# 95         Apple M2           Apple              3.5
# 225        Apple M2           Apple              3.5
# 367        Apple M2           Apple              3.5
# 693    Apple M2 Max           Apple              3.5
# 1539       Apple M1           Apple              3.2
# 1921       Apple M2           Apple              3.5
# 1949       Apple M2           Apple              3.5
# 1955       Apple M2           Apple              3.5
# 1957       Apple M2           Apple              3.5
# 1958       Apple M2           Apple              3.5
# 1959       Apple M2           Apple              3.5
# 1960       Apple M2           Apple              3.5
# 2179   Apple M2 Pro           Apple              3.5
# 2207   Apple M2 Pro           Apple              3.5
# 2221   Apple M2 Max           Apple              3.5
# 2294   Apple M2 Pro           Apple              3.5
# 3032   Apple M1 Pro           Apple              3.2

# %%
print(f"Unique Values: {df['Processor_Name'].unique()}\n")
print(f"Value count for each unique processor type: {df['Processor_Name'].value_counts()}")
# Out:
# Unique Values: ['AMD Hexa-Core Ryzen 5' 'Intel Core i5 (12th Gen)'
#  'Intel Core i3 (11th Gen)' 'Intel Core i5 (11th Gen) Processor'
#  'Intel Core i5 (11th Gen)' 'Intel Core i3 (8th Gen)'
#  'AMD Octa-Core Ryzen 7' 'AMD Dual-Core Ryzen 3'
#  'Intel Core i7 (13th Gen) Processor' 'Intel Core i5 (13th Gen) Processor'
#  'Intel Core Ultra 5' 'Intel Celeron Dual-Core' 'AMD Quad-Core Ryzen 3'
#  'Intel Core i5 (10th Gen)' 'Intel Core i3 (12th Gen)'
#  'Intel Pentium Quad-Core' 'Intel Core i5 (13th Gen)'
#  'Intel Core i9 (12th Gen)' 'Intel Core i3 (11th Gen) Processor'
#  'Intel Core i9 (11th Gen)' 'Intel Core i7 (10th Gen)'
#  'Intel Core i3 (10th Gen)' 'Intel Core i7 (13th Gen)'
#  'Intel Core i3 (12th Gen) Processor' 'AMD Quad-Core Ryzen 5' 'Apple M1'
#  'Intel Core i5 (5th Gen)' 'Apple M2' 'AMD Hexa-Core Ryzen 5 Processor'
#  'Intel Core i3 (7th Gen)' 'Intel Core i5 (8th Gen)'
#  'Intel Pentium Dual-Core' 'Intel Core i5 (9th Gen)'
#  'Intel Core i3 (6th Gen)' 'AMD Dual-Core Athlon'
#  'Intel Core i7 (11th Gen)' 'Intel Core i7 (12th Gen)'
#  'Intel Core i7 (7th Gen)' 'Intel Core i7 (10th Gen) Processor'
#  'Intel Core i5 (10th Gen) Processor' 'Intel Core i5 (7th Gen)'
#  'AMD Quad-Core APU' 'Intel Core i3 (13th Gen)' 'AMD Dual-Core A6 APU'
#  'AMD Octa-Core Ryzen 9' 'Intel Core i5 (12th Gen) Processor'
#  'AMD Dual-Core A9 APU' 'Intel Core i7 (8th Gen)'
#  'Intel Core i7 (12th Gen) Processor' 'Intel Core i7 (11th Gen) Processor'
#  'Intel Core 7 (Series 1)' 'Intel Celeron Dual-Core Processor'
#  'Intel Pentium Gold' 'Intel Core i9 (13th Gen)' 'Apple M2 Max'
#  'AMD Hexadeca-Core Ryzen 9' 'AMD Octa-Core Ryzen 7 Processor'
#  'Intel Core i5 (6th Gen)' 'Intel Core i7 (14th Gen)' 'Intel Core Ultra 7'
#  'Intel Core i9 (14th Gen)' 'Intel Core 5 (Series 1)' 'Intel Core Ultra 9'
#  'Intel Core i9 (14th Gen) Processor' 'Intel Core i3 (13th Gen) Processor'
#  'Intel Core i9 (13th Gen) Processor' 'Intel Core i3 (10th Gen) Processor'
#  'Intel Core M3 (7th Gen)' 'AMD Quad-Core Ryzen 7'
#  'Intel Core i7 (9th Gen)' 'Intel Pentium Quad-Core Processor'
#  'Intel Celeron Quad-Core' 'AMD Quad-Core A8 APU' 'AMD Dual-Core A4 APU'
#  'Intel Core i3 (5th Gen)' 'AMD Dual-Core E1 APU'
#  'AMD Quad-Core Ryzen 5 Processor' 'AMD Quad-Core E2 APU'
#  'Intel Core i5 (1st Gen)' 'AMD Dual-Core APU'
#  'AMD Quad-Core Ryzen 3 Processor' 'AMD Dual-Core Ryzen 3 Processor'
#  'Apple M2 Pro' 'AMD Octa-Core Ryzen 7 Pro' 'Intel Core 3 (Series 1)'
#  'Intel Core i9 (8th Gen)' 'AMD Quad-Core Ryzen 7 Processor'
#  'Intel Atom Quad-Core' 'AMD Quad-Core A12 APU' 'Apple M1 Pro'
#  'AMD Dual-Core Athlon Processor' 'Intel Core i7 (6th Gen)'
#  'Intel Core i5 (9th Gen) Processor' 'AMD Quad-Core A6 APU'
#  'Intel Core M5 (6th Gen)' 'Intel Core i9 (9th Gen)'
#  'AMD Quad-Core A10 APU' 'Intel Core M3 (6th Gen)'
#  'Intel Core i3 (4th Gen)' 'Intel Core i5 (4th Gen)'
#  'Intel Core i3 (3rd Gen)' 'Intel Core i7 (5th Gen)'
#  'AMD Dual-Core A9 APU Processor' 'AMD Octa-Core Ryzen 9 Processor'
#  'Intel Core i9 (10th Gen)']
#
# Value count for each unique processor type: Processor_Name
# Intel Core i5 (11th Gen)             316
# Intel Core i5 (12th Gen)             291
# AMD Hexa-Core Ryzen 5                245
# AMD Octa-Core Ryzen 7                238
# Intel Core i3 (11th Gen)             188
#                                     ...
# Intel Core i5 (9th Gen) Processor      1
# Intel Core M3 (6th Gen)                1
# Intel Core i7 (5th Gen)                1
# AMD Dual-Core A9 APU Processor         1
# AMD Octa-Core Ryzen 9 Processor        1
# Name: count, Length: 105, dtype: int64

# %%
df
# Out:
#        Brand                                               Name  Price  \
# 0     Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  36289
# 1       Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  78500
# 2         HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  55490
# 3      Other  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...  21990
# 4       Acer  Acer One 14 Z8-415 (UN.599SI.020) Laptop (14 I...  34990
# ...      ...                                                ...    ...
# 3900    ASUS  ASUS Zenbook UX430UN-GV022T Laptop (14 Inch | ...  84990
# 3901    ASUS  ASUS Vivobook K15 OLED K513EA-L301WS Laptop (1...  40031
# 3902    ASUS  ASUS VivoBook Pro 15 OLED M3500QC-L1711WS Lapt...  75990
# 3903    ASUS  ASUS TUF FX505DT-AL118T Laptop (15.6 Inch | AM...  71909
# 3904  Lenovo  Lenovo Legion 5i (82AU00CFIN) Laptop (15.6 Inc...  69990
#
#                           Processor_Name Processor_Brand RAM_Expandable  \
# 0                  AMD Hexa-Core Ryzen 5             AMD            Yes
# 1               Intel Core i5 (12th Gen)           Intel            Yes
# 2               Intel Core i5 (12th Gen)           Intel            Yes
# 3               Intel Core i3 (11th Gen)           Intel             No
# 4     Intel Core i5 (11th Gen) Processor           Intel            Yes
# ...                                  ...             ...            ...
# 3900             Intel Core i5 (8th Gen)           Intel            Yes
# 3901            Intel Core i3 (11th Gen)           Intel             No
# 3902               AMD Octa-Core Ryzen 7             AMD             No
# 3903               AMD Quad-Core Ryzen 5             AMD            Yes
# 3904            Intel Core i5 (10th Gen)           Intel             No
#
#       RAM_Size (GB)      RAM_TYPE  Processer_speed Display_type Display  \
# 0                 8     DDR4 RAM               4.0          LCD   15.6
# 1                16     DDR5 RAM               3.3          LCD   15.6
# 2                 8     DDR4 RAM               4.2          LCD   15.6
# 3                 8   LPDDR4X RAM              1.7          LCD   15.6
# 4                16     DDR4 RAM               0.0          LCD     14
# ...             ...           ...              ...          ...     ...
# 3900              8     DDR4 RAM               1.6          LED     14
# 3901              8      DDR4 RAM              4.0          LED   15.6
# 3902             16      DDR4 RAM              3.1          LED   15.6
# 3903              8     DDR4 RAM               2.1          LED   15.6
# 3904              8      DDR4 RAM              2.5          LED   15.6
#
#                              GPU GPU_Brand                  SSD     HDD  \
# 0                         Radeon       AMD   512 GB SSD Storage  No HDD
# 1     GeForce RTX 3050 GPU, 4 GB    NVIDIA   512 GB SSD Storage  No HDD
# 2                        Iris Xe     Intel   512 GB SSD Storage  No HDD
# 3                            UHD     Intel   512 GB SSD Storage  No HDD
# 4                        Iris Xe     Intel   512 GB SSD Storage  No HDD
# ...                          ...       ...                  ...     ...
# 3900     Geforce MX150 GPU, 2 GB    NVIDIA   512 GB SSD Storage  No HDD
# 3901                         UHD     Intel   256 GB SSD Storage  No HDD
# 3902  GeForce RTX 3050 GPU, 4 GB    NVIDIA  1024 GB SSD Storage  No HDD
# 3903  GeForce GTX 1650 GPU, 4 GB    NVIDIA   512 GB SSD Storage  No HDD
# 3904  Geforce GTX 1650 GPU, 4 GB    NVIDIA   512 GB SSD Storage  No HDD
#
#      Adapter                Battery_Life
# 0         65    Upto 11 Hrs Battery Life
# 1         56    Upto 10 Hrs Battery Life
# 2         no  Upto 7.30 Hrs Battery Life
# 3         45     Upto 8 Hrs Battery Life
# 4         45                 45W Adapter
# ...      ...                         ...
# 3900      65     Upto 9 Hrs Battery Life
# 3901      65     Upto 3 Hrs Battery Life
# 3902     120     Upto 3 Hrs Battery Life
# 3903     150                150W Adapter
# 3904      60                 60W Adapter
#
# [3905 rows x 17 columns]

# %%
df['Processer_speed'].value_counts()
# Out:
# Processer_speed
# 4.2    331
# 2.4    249
# 4.7    244
# 1.6    233
# 2.3    211
# 3.3    197
# 0.0    190
# 4.8    181
# 2.1    176
# 2.6    175
# 2.5    163
# 2.0    157
# 1.2    148
# 3.0    138
# 3.4    133
# 4.0    106
# 1.1    103
# 1.8     98
# 2.2     96
# 2.8     89
# 1.0     81
# 3.1     80
# 1.7     74
# 2.7     56
# 1.3     44
# 2.9     33
# 1.4     26
# 1.5     24
# 0.8     20
# 5.5     16
# 3.5     15
# 1.9     15
# 3.2      3
# Name: count, dtype: int64

# %%
# df.drop(df[df['Processer_speed']==0].index, inplace=True) #Remove rows with 0 Ghz

# %%
df.shape
# Out:
# (3905, 17)

# %%
df['Brand'].value_counts()
# Out:
# Brand
# ASUS       977
# Lenovo     803
# HP         784
# Dell       420
# Acer       317
# MSI        309
# Other      191
# Samsung     59
# Apple       45
# Name: count, dtype: int64

# %% [markdown]
# ### Processor Series

# %%
# apple_df = df[df['Brand'] == 'Apple'][['Name','Brand', 'Processor_Brand','Processer_speed', 'Processor_Name']]
# print(apple_df)

# print(apple_df['Processer_speed'].value_counts())

# %%
def split_processor_details(value):
    if pd.isna(value) or str(value).strip() == "":
        return ("Unknown", "Unknown")
    
    text = value.strip()

    # Extract brand (first word before space)
    brand = text.split()[0]

    # Remove everything inside parentheses and after it
    text_before_parenthesis = re.split(r'\(', text)[0].strip()

    # Remove the brand name from the start
    series = re.sub(rf'^{brand}\s*', '', text_before_parenthesis, flags=re.IGNORECASE).strip()

    return (brand, series)

# Apply to DataFrame
df[["Processor_Brand_Extracted", "Processor_Series"]] = df["Processor_Name"].apply(lambda x: pd.Series(split_processor_details(x)))

# %%
print(f"Unique Values: {df['Processor_Brand_Extracted'].unique()}\n")
print(f"Value count for each unique processor type: {df['Processor_Brand_Extracted'].value_counts()}")
# Out:
# Unique Values: ['AMD' 'Intel' 'Apple']
#
# Value count for each unique processor type: Processor_Brand_Extracted
# Intel    2968
# AMD       919
# Apple      18
# Name: count, dtype: int64

# %%
intel_df = df[df['Processor_Brand'] == 'Intel'][['Brand', 'Processor_Brand', "Processor_Series"]]
print(intel_df)

print(intel_df['Processor_Series'].value_counts())
# Out:
#        Brand Processor_Brand Processor_Series
# 1       Dell           Intel          Core i5
# 2         HP           Intel          Core i5
# 3      Other           Intel          Core i3
# 4       Acer           Intel          Core i5
# 6       Acer           Intel          Core i5
# ...      ...             ...              ...
# 3898    ASUS           Intel          Core i9
# 3899     MSI           Intel          Core i7
# 3900    ASUS           Intel          Core i5
# 3901    ASUS           Intel          Core i3
# 3904  Lenovo           Intel          Core i5
#
# [2968 rows x 3 columns]
# Processor_Series
# Core i5                        1282
# Core i3                         682
# Core i7                         642
# Celeron Dual-Core                92
# Core i9                          87
# Core Ultra 7                     52
# Pentium Quad-Core                43
# Core Ultra 5                     24
# Core Ultra 9                     16
# Core 5                           11
# Pentium Dual-Core                 8
# Pentium Gold                      6
# Core M3                           5
# Core 7                            5
# Celeron Quad-Core                 5
# Celeron Dual-Core Processor       3
# Atom Quad-Core                    2
# Pentium Quad-Core Processor       1
# Core 3                            1
# Core M5                           1
# Name: count, dtype: int64

# %%
amd_df = df[df['Processor_Brand'] == 'AMD'][['Brand', 'Processor_Brand', "Processor_Series"]]
print(amd_df)

print(amd_df['Processor_Series'].value_counts())
# Out:
#        Brand Processor_Brand   Processor_Series
# 0     Lenovo             AMD  Hexa-Core Ryzen 5
# 5         HP             AMD  Hexa-Core Ryzen 5
# 9     Lenovo             AMD  Octa-Core Ryzen 7
# 10        HP             AMD  Dual-Core Ryzen 3
# 22        HP             AMD  Octa-Core Ryzen 7
# ...      ...             ...                ...
# 3873    Dell             AMD  Octa-Core Ryzen 7
# 3879    ASUS             AMD  Quad-Core Ryzen 5
# 3896      HP             AMD  Octa-Core Ryzen 7
# 3902    ASUS             AMD  Octa-Core Ryzen 7
# 3903    ASUS             AMD  Quad-Core Ryzen 5
#
# [919 rows x 3 columns]
# Processor_Series
# Hexa-Core Ryzen 5              245
# Octa-Core Ryzen 7              238
# Quad-Core Ryzen 5              108
# Dual-Core Ryzen 3               67
# Quad-Core Ryzen 3               46
# Octa-Core Ryzen 9               45
# Dual-Core Athlon                34
# Dual-Core A6 APU                21
# Dual-Core A9 APU                20
# Hexa-Core Ryzen 5 Processor     16
# Octa-Core Ryzen 7 Processor     16
# Quad-Core Ryzen 7               11
# Dual-Core APU                    8
# Quad-Core A8 APU                 7
# Dual-Core A4 APU                 6
# Quad-Core APU                    4
# Dual-Core E1 APU                 4
# Quad-Core Ryzen 5 Processor      3
# Quad-Core A12 APU                3
# Quad-Core Ryzen 3 Processor      3
# Dual-Core Ryzen 3 Processor      2
# Quad-Core E2 APU                 2
# Quad-Core A10 APU                2
# Quad-Core A6 APU                 2
# Hexadeca-Core Ryzen 9            1
# Octa-Core Ryzen 7 Pro            1
# Dual-Core Athlon Processor       1
# Quad-Core Ryzen 7 Processor      1
# Dual-Core A9 APU Processor       1
# Octa-Core Ryzen 9 Processor      1
# Name: count, dtype: int64

# %%
# apu = df[df['Processor_Series']=='Quad-Core APU'][['Name']]
# apu

# %%
# import re

# def categorize_processor(row):
#     name = row['Processor_Series']
#     brand = row['Processor_Brand']
    
#     if brand == 'Intel':
#         # Capture i3/i5/i7/i9 or Core Ultra, Core series, etc.
#         match = re.search(r'(i[3579]|core\s*[3579])', name, re.I)
#         if match:
#             # Standardize naming: convert "core 5" → "i5"
#             text = match.group(0).lower()
#             if "core" in text:
#                 # Extract the number after "core"
#                 num = re.search(r'[3579]', text).group(0)
#                 return f"Intel Core I{num}"
#             else:
#                 return f"Intel Core {text.upper()}"
#         elif re.search(r'Ultra\s*5', name, re.I):
#             return "Intel Core Ultra 5"
#         elif re.search(r'Ultra\s*7', name, re.I):
#             return "Intel Core Ultra 7"
#         elif re.search(r'Ultra\s*9', name, re.I):
#             return "Intel Core Ultra 9"
#         elif re.search(r'Pentium', name, re.I):
#             return "Intel Pentium"
#         elif re.search(r'Celeron', name, re.I):
#             return "Intel Celeron"
#         else:
#             return "Intel Other"
    
#     elif brand == 'AMD':
#         # Ryzen families or Athlon/A-series
#         match = re.search(r'Ryzen\s*[3579]', name, re.I)
#         if match:
#             return f"AMD {match.group(0).title()}"
#         elif re.search(r'Athlon', name, re.I):
#             return "Athlon"
#         elif re.search(r'A\d', name, re.I):
#             # e.g., A6, A8, A10, A12
#             a_match = re.search(r'A\d+', name, re.I)
#             return "AMD A-Series"
#         else:
#             return "AMD Other"
    
#     elif brand == 'Apple':
#         # All M-series grouped together
#         return "Apple M-series"
    
#     else:
#         return "Other"

# # Apply to DataFrame
# df['Processor_Series'] = df.apply(categorize_processor, axis=1)

# # Quick look at the result
# print(df['Processor_Series'].value_counts())

# %%
import re

def categorize_processor(row):
    name = row['Processor_Series']
    brand = row['Processor_Brand']
    
    if brand == 'Intel':
        # Capture i3/i5/i7/i9 or Core Ultra, Core series, etc.
        match = re.search(r'(i[3579]|core\s*[3579])', name, re.I)
        if match:
            # Standardize naming: convert "core 5" → "i5"
            text = match.group(0).lower()
            if "core" in text:
                # Extract the number after "core"
                num = re.search(r'[3579]', text).group(0)
                return f"Intel Core I{num}"
            else:
                return f"Intel Core {text.upper()}"
        elif re.search(r'Ultra\s*5', name, re.I):
            return "Intel Ultra 5"
        elif re.search(r'Ultra\s*7', name, re.I):
            return "Intel Ultra 7"
        elif re.search(r'Ultra\s*9', name, re.I):
            return "Intel Ultra 9"
        elif re.search(r'Pentium', name, re.I):
            return "Intel Pentium"
        elif re.search(r'Celeron', name, re.I):
            return "Intel Celeron"
        else:
            return "Intel Other"
    
    elif brand == 'AMD':
        # Ryzen families or Athlon/A-series
        match = re.search(r'Ryzen\s*[3579]', name, re.I)
        if match:
            return f"AMD {match.group(0).title()}"
        elif re.search(r'Athlon', name, re.I):
            return "AMD Athlon"
        elif re.search(r'A\d', name, re.I):
            # e.g., A6, A8, A10, A12
            a_match = re.search(r'A\d+', name, re.I)
            return "AMD A-Series"
        else:
            return "AMD Other"
    
    elif brand == 'Apple':
        # All M-series grouped together
        return "Apple M-series"
    
    else:
        return "Other"

# Apply to DataFrame
df['Processor_Series'] = df.apply(categorize_processor, axis=1)

# Quick look at the result
print(df['Processor_Series'].value_counts())
# Out:
# Processor_Series
# Intel Core I5     1293
# Intel Core I3      683
# Intel Core I7      647
# AMD Ryzen 5        372
# AMD Ryzen 7        267
# AMD Ryzen 3        118
# Intel Celeron      100
# Intel Core I9       87
# AMD A-Series        62
# Intel Pentium       58
# Intel Ultra 7       52
# AMD Ryzen 9         47
# AMD Athlon          35
# Intel Ultra 5       24
# AMD Other           18
# Apple M-series      18
# Intel Ultra 9       16
# Intel Other          8
# Name: count, dtype: int64

# %%
df['Processor_Series'] = df['Processor_Series'].replace({
    'Intel Core I5': 'Intel I5',
    'Intel Core I3': 'Intel I3',
    'Intel Core I7': 'Intel I7',
    'Intel Core I9': 'Intel I9'
})
print(df['Processor_Series'].value_counts())
# Out:
# Processor_Series
# Intel I5          1293
# Intel I3           683
# Intel I7           647
# AMD Ryzen 5        372
# AMD Ryzen 7        267
# AMD Ryzen 3        118
# Intel Celeron      100
# Intel I9            87
# AMD A-Series        62
# Intel Pentium       58
# Intel Ultra 7       52
# AMD Ryzen 9         47
# AMD Athlon          35
# Intel Ultra 5       24
# AMD Other           18
# Apple M-series      18
# Intel Ultra 9       16
# Intel Other          8
# Name: count, dtype: int64

# %%
print(f"Unique Values: {df['Brand'].unique()}\n")
print(f"Value count for each unique Brand type: {df['Brand'].value_counts()}")
# Out:
# Unique Values: ['Lenovo', 'Dell', 'HP', 'Other', 'Acer', 'ASUS', 'MSI', 'Samsung', 'Apple']
# Categories (9, object): ['ASUS', 'Other', 'Acer', 'Apple', ..., 'HP', 'Lenovo', 'MSI', 'Samsung']
#
# Value count for each unique Brand type: Brand
# ASUS       977
# Lenovo     803
# HP         784
# Dell       420
# Acer       317
# MSI        309
# Other      191
# Samsung     59
# Apple       45
# Name: count, dtype: int64

# %%
avg_price = df.groupby('Processor_Series')['Price'].mean().sort_values()

plt.figure(figsize=(18,5))
plt.barh(avg_price.index, avg_price.values)   
plt.xlabel("Average Price")
plt.ylabel("Processor Seies")
plt.title("Average Laptop Price by Processor Category")
plt.tight_layout()
plt.show()

# %%
print(f"Unique Values: {df['Processor_Series'].unique()}\n")
print(f"Value count for each unique processor series type: {df['Processor_Series'].value_counts()}")
# Out:
# Unique Values: ['AMD Ryzen 5' 'Intel I5' 'Intel I3' 'AMD Ryzen 7' 'AMD Ryzen 3'
#  'Intel I7' 'Intel Ultra 5' 'Intel Celeron' 'Intel Pentium' 'Intel I9'
#  'Apple M-series' 'AMD Athlon' 'AMD Other' 'AMD A-Series' 'AMD Ryzen 9'
#  'Intel Ultra 7' 'Intel Ultra 9' 'Intel Other']
#
# Value count for each unique processor series type: Processor_Series
# Intel I5          1293
# Intel I3           683
# Intel I7           647
# AMD Ryzen 5        372
# AMD Ryzen 7        267
# AMD Ryzen 3        118
# Intel Celeron      100
# Intel I9            87
# AMD A-Series        62
# Intel Pentium       58
# Intel Ultra 7       52
# AMD Ryzen 9         47
# AMD Athlon          35
# Intel Ultra 5       24
# AMD Other           18
# Apple M-series      18
# Intel Ultra 9       16
# Intel Other          8
# Name: count, dtype: int64

# %%
# def map_processor_performance(row):
#     brand = row['Processor_Brand']
#     series   = row['Processor_Series']

#     if brand == 'Intel':
#         if series in ['Intel Core Ultra 9', 'Intel Core I9', 'Intel Core Ultra 7']:
#             return 'High-End'
#         elif series in ['Intel Core I5', 'Intel Core I7', 'Intel Core Ultra 5']:
#             return 'Mid-End'
#         elif series in ['Intel Core I3', 'Intel Celeron', 'Intel Pentium', 'Intel Other']:
#             return 'Low-End'

#     elif brand == 'AMD':
#         if series in ['AMD Ryzen 9', 'AMD Ryzen 7']:
#             return 'High-End'
#         elif series in ['AMD Ryzen 5']:
#             return 'Mid-End'
#         elif series in [
#             'AMD Ryzen 3', 'Athlon', 'AMD A-Series', 'AMD Other'
#         ]:
#             return 'Low-End'

#     elif brand == 'Apple':
#         return 'Apple M-series'  

#     return 'Other'

# %%
def map_processor_performance(row):
    brand = row['Processor_Brand']
    series   = row['Processor_Series']

    if brand == 'Intel':
        if series in ['Intel Core Ultra 9', 'Intel Core I9']:
            return 'High-End'
        elif series in ['Intel Core I7',  'Intel Core Ultra 7']:
            return 'Upper Mid-End'
        elif series in ['Intel Core I5', 'Intel Core Ultra 5']:
            return 'Mid-End'
        elif series in ['Intel Core I3', 'Intel Celeron', 'Intel Pentium', 'Intel Other']:
            return 'Low-End'

    elif brand == 'AMD':
        if series in ['AMD Ryzen 9']:
            return 'High-End'
        elif series in ['AMD Ryzen 7']:
            return 'Upper Mid-End'
        elif series in ['AMD Ryzen 5']:
            return 'Mid-End'
        elif series in [
            'AMD Ryzen 3', 'Athlon', 'AMD A-Series', 'AMD Other'
        ]:
            return 'Low-End'

    elif brand == 'Apple':
        return 'Apple M-series'  

    return 'Other'

# %%
df['Processor_Tier'] = df.apply(map_processor_performance, axis=1)
print(df['Processor_Tier'].value_counts())
# Out:
# Processor_Tier
# Other             2837
# Mid-End            372
# Low-End            364
# Upper Mid-End      267
# High-End            47
# Apple M-series      18
# Name: count, dtype: int64

# %%
# Calculate mean price by Processor_Tier
avg_price_tier = df.groupby('Processor_Tier')['Price'].mean().sort_values()

# Plot horizontal bar chart
plt.figure(figsize=(18,3))
plt.barh(avg_price_tier.index, avg_price_tier.values, color='skyblue')
plt.xlabel("Average Price")
plt.ylabel("Processor Tier")
plt.title("Average Laptop Price by Processor Tier")
plt.tight_layout()
plt.show()

# %%
# df.shape

# %%
# # Keep only the major processor brands
# valid_brands = ["AMD", "Apple", "Intel"]

# df = df[df["Processor_Brand"].isin(valid_brands)].reset_index(drop=True)
# df.shape

# %%
# print(f"Unique Values: {df['Processor_Brand'].unique()}\n")
# print(f"Value count for each unique processor type: {df['Processor_Brand'].value_counts()}")

# %%
print(f"Unique Values: {df['Brand'].unique()}\n")
print(f"Value count for each unique processor type: {df['Brand'].value_counts()}")
# Out:
# Unique Values: ['Lenovo', 'Dell', 'HP', 'Other', 'Acer', 'ASUS', 'MSI', 'Samsung', 'Apple']
# Categories (9, object): ['ASUS', 'Other', 'Acer', 'Apple', ..., 'HP', 'Lenovo', 'MSI', 'Samsung']
#
# Value count for each unique processor type: Brand
# ASUS       977
# Lenovo     803
# HP         784
# Dell       420
# Acer       317
# MSI        309
# Other      191
# Samsung     59
# Apple       45
# Name: count, dtype: int64

# %%
# print(f"Unique Values: {df['Processor_Series'].unique()}\n")
# print(f"Value count for each unique processor type: {df['Processor_Series'].value_counts()}")

# %%
# apple_df = df[df['Brand'] == 'Apple'][['Brand', 'Processor_Brand_Extracted']]
# print(apple_df)

# print(apple_df['Processor_Brand_Extracted'].value_counts())

# %% [markdown]
# ### Generation

# %%
# def gen(text):
#     if 'Intel' in text:
#         if 'i3' in text or 'i5' in text or 'i7' in text or 'i9' in text:
#             if text.split()[3][-2:]=='th':
#                 return int(text.split('th')[0].split('(')[-1])
#             elif text.split()[3][-2:]=='st':
#                 return int(text.split('st')[0].split('(')[-1])
#             elif text.split()[3][-2:]=='nd':
#                 return int(text.split('nd')[0].split('(')[-1])
#             elif text.split()[3][-2:]=='rd':
#                 return int(text.split('rd')[0].split('(')[-1])
#             else:
#                 return 0
                
#         else:
#             return 0
#     else:
#         return 0
    


# df['Generation']=df['Processor_Name'].apply(gen)  
# df['Generation']=df['Generation'].astype(np.int16)
# df['Generation'].value_counts()

# %%
df['Processer_speed'].dtype
# Out:
# dtype('float64')

# %%
df['Processer_speed'].value_counts()
# Out:
# Processer_speed
# 4.2    331
# 2.4    249
# 4.7    244
# 1.6    233
# 2.3    211
# 3.3    197
# 0.0    190
# 4.8    181
# 2.1    176
# 2.6    175
# 2.5    163
# 2.0    157
# 1.2    148
# 3.0    138
# 3.4    133
# 4.0    106
# 1.1    103
# 1.8     98
# 2.2     96
# 2.8     89
# 1.0     81
# 3.1     80
# 1.7     74
# 2.7     56
# 1.3     44
# 2.9     33
# 1.4     26
# 1.5     24
# 0.8     20
# 5.5     16
# 3.5     15
# 1.9     15
# 3.2      3
# Name: count, dtype: int64

# %%
mean_ghz = (
    df[df['Processer_speed'] != 0.0]                       # exclude zeros from mean calc
      .groupby(['Processor_Brand', 'Processor_Tier'])['Processer_speed']
      .mean()
      .reset_index()
      .rename(columns={'Processer_speed': 'Mean_Ghz'})
)

#Merge the mean values back to df
df = df.merge(mean_ghz, on=['Processor_Brand', 'Processor_Tier'], how='left')

#Replace 0.0 with the corresponding mean
df['Processer_speed'] = df.apply(
    lambda row: row['Mean_Ghz'] if row['Processor_Brand'] in ['Intel','AMD'] 
                and row['Processer_speed'] == 0.0 else row['Processer_speed'],
    axis=1
)

df = df.drop(columns=['Mean_Ghz'])

print(df['Processer_speed'].value_counts().head())
# Out:
# Processer_speed
# 4.2    331
# 2.4    249
# 4.7    244
# 1.6    233
# 2.3    211
# Name: count, dtype: int64

# %%
df['Processer_speed'] = (df['Processer_speed'] * 2).round() / 2

# %%
df['Processer_speed'].value_counts()
# Out:
# Processer_speed
# 2.5    1003
# 2.0     542
# 4.0     438
# 1.5     405
# 3.5     362
# 3.0     362
# 1.0     352
# 4.5     244
# 5.0     181
# 5.5      16
# Name: count, dtype: int64

# %% [markdown]
# ### Operating System

# %%
def gen(text):
    if ('Windows 11' in text.split('|')[3]) or 'Windows 10' in text.split('|')[3] or ('Windows 8.1' in text.split('|')[3]) or ('DOS' in text.split('|')[3]) or ('Linux' in text.split('|')[3]) or ('Ubuntu' in text.split('|')[3]) :
        return text.split('|')[3].strip()
    elif 'macOS' in text.split('|')[3]:
        return 'macOS'
    else:
        return 'Others'
    
df['Operating_System'] = df['Name'].apply(gen)
df['Operating_System'].value_counts()
# Out:
# Operating_System
# Windows 11     2120
# Windows 10     1482
# DOS             185
# macOS            45
# Others           26
# Linux            22
# Windows 8.1      18
# Ubuntu            7
# Name: count, dtype: int64

# %% [markdown]
# ### Display Size

# %%
#Clean Display size column
df[df['Display']=='OLED Display With Touchscreen']
# Out:
#     Brand                                               Name   Price  \
# 768    HP  HP ENVY 15 ep1087TX (54B88PA) Laptop (| Core i...  189400
#
#                Processor_Name Processor_Brand RAM_Expandable  RAM_Size (GB)  \
# 768  Intel Core i9 (11th Gen)           Intel             No             32
#
#       RAM_TYPE  Processer_speed Display_type  ...                         GPU  \
# 768   DDR4 RAM              5.0          LED  ...  GeForce RTX 3060 GPU, 6 GB
#
#     GPU_Brand                  SSD     HDD Adapter  \
# 768    NVIDIA  1024 GB SSD Storage  No HDD      83
#
#                     Battery_Life Processor_Brand_Extracted Processor_Series  \
# 768   Upto 7.15 Hrs Battery Life                     Intel         Intel I9
#
#     Processor_Tier Operating_System
# 768          Other       Windows 11
#
# [1 rows x 21 columns]

# %%
df = df[df['Display'] != 'OLED Display With Touchscreen'] #Remove rows with non-numeric display sizes
# df['Display']=df['Display'].astype(np.float32)
df['Display'] = pd.to_numeric(df['Display'], errors='coerce')
df.rename(columns={'Display': 'Display_size(inch)'}, inplace=True)
print(f"Unique Values: {df['Display_size(inch)'].unique()}\n")
# Out:
# Unique Values: [15.6 14.  16.  17.3 11.6 13.3 16.1 13.6 14.1 15.3 13.4 15.  10.5 13.5
#  13.  12.4 16.2 17.  18.  14.5 12.  14.9 11.  12.3 16.6 14.2 12.2 10.1
#  12.5 15.4]

# %%
def display_category(x):
    if x <= 15.6:
        return 'Small'
    else:
        return 'Large'
df['Display_Category'] = df['Display_size(inch)'].apply(display_category)
df['Display_Category'].value_counts()
# Out:
# Display_Category
# Small    3496
# Large     408
# Name: count, dtype: int64

# %%
# Calculate mean price by Processor_Tier
avg_price_tier = df.groupby('Display_Category')['Price'].mean().sort_values()

# Plot horizontal bar chart
plt.figure(figsize=(18,3))
plt.barh(avg_price_tier.index, avg_price_tier.values, color='skyblue')
plt.xlabel("Average Price")
plt.ylabel("Display Category")
plt.title("Average Laptop Price by Display Category")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### SSD

# %%
#Clean SSD column
df['SSD'] = df['SSD'].str.extract(r"(\d+)").fillna(0).astype(int) 
df.rename(columns={'SSD': 'SSD(GB)'}, inplace=True)
print(f"Unique Values: {df['SSD(GB)'].unique()}\n")
# Out:
# Unique Values: [ 512    0 1024  256   64  128 2048    1    8   16   32 4098]

# %%
standard_sizes = [0, 128, 256, 512, 1024]

# Keep only these values
df = df[df['SSD(GB)'].isin(standard_sizes)]

# Check results
print(df['SSD(GB)'].value_counts())
# Out:
# SSD(GB)
# 512     1936
# 0        644
# 1024     586
# 256      562
# 128      100
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3828, 22)

# %% [markdown]
# ### HDD

# %%
#Clean HDD column
df['HDD'] = df['HDD'].str.extract(r"(\d+)").fillna(0).astype(int)
df.rename(columns={'HDD': 'HDD(GB)'}, inplace=True)
print(f"Unique Values: {df['HDD(GB)'].unique()}\n")
# df['HDD(GB)'].value_counts()
# Out:
# Unique Values: [   0 1024 2048  500    1]

# %%
standard_hdd = [0, 500, 1024]

# Keep only these values
df = df[df['HDD(GB)'].isin(standard_hdd)]

# Check results
print(df['HDD(GB)'].value_counts())
# Out:
# HDD(GB)
# 0       2906
# 1024     867
# 500       35
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3808, 22)

# %%
# df['Processor_Brand'] = df['Processor_Brand'].astype('category')
# print(f"Unique Values: {df['Processor_Brand'].unique()}\n")
# print(f"Value count for each unique Processor_Brand type: {df['Processor_Brand'].value_counts()}\n")

# %%
df.head()
# Out:
#     Brand                                               Name  Price  \
# 0  Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  36289
# 1    Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  78500
# 2      HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  55490
# 3   Other  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...  21990
# 4    Acer  Acer One 14 Z8-415 (UN.599SI.020) Laptop (14 I...  34990
#
#                        Processor_Name Processor_Brand RAM_Expandable  \
# 0               AMD Hexa-Core Ryzen 5             AMD            Yes
# 1            Intel Core i5 (12th Gen)           Intel            Yes
# 2            Intel Core i5 (12th Gen)           Intel            Yes
# 3            Intel Core i3 (11th Gen)           Intel             No
# 4  Intel Core i5 (11th Gen) Processor           Intel            Yes
#
#    RAM_Size (GB)      RAM_TYPE  Processer_speed Display_type  ...  GPU_Brand  \
# 0              8     DDR4 RAM               4.0          LCD  ...        AMD
# 1             16     DDR5 RAM               3.5          LCD  ...     NVIDIA
# 2              8     DDR4 RAM               4.0          LCD  ...      Intel
# 3              8   LPDDR4X RAM              1.5          LCD  ...      Intel
# 4             16     DDR4 RAM               2.5          LCD  ...      Intel
#
#   SSD(GB) HDD(GB)  Adapter                Battery_Life  \
# 0     512       0       65    Upto 11 Hrs Battery Life
# 1     512       0       56    Upto 10 Hrs Battery Life
# 2     512       0       no  Upto 7.30 Hrs Battery Life
# 3     512       0       45     Upto 8 Hrs Battery Life
# 4     512       0       45                 45W Adapter
#
#   Processor_Brand_Extracted Processor_Series Processor_Tier Operating_System  \
# 0                       AMD      AMD Ryzen 5        Mid-End       Windows 11
# 1                     Intel         Intel I5          Other       Windows 11
# 2                     Intel         Intel I5          Other       Windows 11
# 3                     Intel         Intel I3          Other       Windows 11
# 4                     Intel         Intel I5          Other       Windows 11
#
#   Display_Category
# 0            Small
# 1            Small
# 2            Small
# 3            Small
# 4            Small
#
# [5 rows x 22 columns]

# %% [markdown]
# ### RAM Type

# %%
#Clean RAM_TYPE column
   
df['RAM_TYPE'] = df['RAM_TYPE'].str.strip().str.upper()
mapping = {
    'DDR4 RAM': 'DDR4',
    'DDR5 RAM': 'DDR5',
    'DDR3 RAM': 'DDR3',
    'DDR2 RAM': 'DDR2',
    'LPDDR3 RAM' : 'LPDDR3',
    'LPDDR4 RAM': 'LPDDR4',
    'LPDDR4X RAM': 'LPDDR4X',
    'LPDDR5 RAM': 'LPDDR5',
    'LPDDR5X RAM': 'LPDDR5X'
}
df['RAM_TYPE'] = df['RAM_TYPE'].replace(mapping)
# df['RAM_TYPE'] = df['RAM_TYPE'].replace({'RAM': 'Other'})
df['RAM_TYPE'] = df['RAM_TYPE'].astype('category')

# %%
print(f"Unique Values: {df['RAM_TYPE'].unique()}\n") 
print(f"Value count for each unique RAM_TYPE type: {df['RAM_TYPE'].value_counts()}\n")
# Out:
# Unique Values: ['DDR4', 'DDR5', 'LPDDR4X', 'LPDDR5X', 'LPDDR5', 'LPDDR3', 'RAM', 'LPDDR4', 'DDR3', 'DDR2']
# Categories (10, object): ['DDR2', 'DDR3', 'DDR4', 'DDR5', ..., 'LPDDR4X', 'LPDDR5', 'LPDDR5X', 'RAM']
#
# Value count for each unique RAM_TYPE type: RAM_TYPE
# DDR4       2760
# DDR5        361
# LPDDR5      241
# LPDDR4X     148
# DDR3        113
# LPDDR5X      77
# LPDDR3       47
# RAM          37
# LPDDR4       23
# DDR2          1
# Name: count, dtype: int64

# %%
df = df[df['RAM_TYPE'] != 'DDR2']

# %%
ram = df[df['RAM_TYPE']== 'RAM']
ram
# Out:
#         Brand                                               Name   Price  \
# 90       ASUS  ASUS VivoBook 15 X515EA-EJ322WS Laptop (15.6 I...   33990
# 95      Apple  Apple MacBook Air M2 MLXY3HN/A Ultrabook (13.6...   92990
# 220     Other  Tecno MEGABOOK T1 Laptop (15.6 Inch | Core i3 ...   37999
# 281     Other  Honor MagicBook X 14 Laptop (14 Inch | Core i3...   39990
# 354      Dell  Dell Vostro 14 3400 (D552217WIN9D) Laptop (14 ...   39275
# 367     Apple  Apple MacBook Air M2 MLY43HN/A Ultrabook (13.6...  108990
# 562   Samsung  Samsung Galaxy Book 3 360 NP750QFG-KA1IN Lapto...  122990
# 563   Samsung  Samsung Galaxy Book 3 360 NP730QFG-KA1IN Lapto...  109990
# 565   Samsung  Samsung Galaxy Book 3 360 NP730QFG-KA2IN Lapto...  109990
# 567   Samsung  Samsung Galaxy Book 3 360 NP750QFG-KA2IN Lapto...  109990
# 568   Samsung  Samsung Galaxy Book 3 360 NP750QFG-KA3IN Lapto...  107000
# 571   Samsung  Samsung Galaxy Book Pro 360 Intel Evo NP960QFG...  119990
# 583   Samsung  Samsung Galaxy Book 3 Pro 360 NP960QFG-KA1IN L...  163990
# 586   Samsung  Samsung Galaxy Book 3 Pro 360 NP960QFG-KA2IN L...  155990
# 651   Samsung  Samsung Galaxy Book 3 Pro NP960XFG-KC1IN Lapto...   96990
# 652   Samsung  Samsung Galaxy Book 3 Pro NP940XFG-KC4IN Lapto...  139990
# 653   Samsung  Samsung Galaxy Book 3 Pro NP960XFG-KC2IN Lapto...  165990
# 654   Samsung  Samsung Galaxy Book 3 Pro NP940XFG-KC1IN Lapto...   94980
# 655   Samsung  Samsung Galaxy Book Pro Intel Evo NP940XFG-KC5...  155990
# 693     Apple  Apple MacBook Pro M2 Max MNWA3HN/A Ultrabook (...  349900
# 1189     ASUS  ASUS Vivobook 16X K3605ZV-MBN741WS Laptop (16 ...  126054
# 1213  Samsung  Samsung Galaxy Book 3 Ultra NP960XFH-XA1IN Lap...  281990
# 1563    Other  Honor MagicBook X 15 Laptop (15.6 Inch | Core ...   35865
# 1949    Apple  Apple MacBook Air M2 MQKV3HN/A Ultrabook (15.3...  149900
# 1955    Apple  Apple MacBook Air M2 MQKQ3HN/A Ultrabook (15.3...  154900
# 1957    Apple  Apple MacBook Air M2 MQKX3HN/A Laptop (15.3 In...  149890
# 1958    Apple  Apple MacBook Air M2 MQKP3HN/A Ultrabook (15.3...  133254
# 1959    Apple  Apple MacBook Air M2 MQKR3HN/A Ultrabook (15.3...  134900
# 1960    Apple  Apple MacBook Air M2 MQKU3HN/A Ultrabook (15.3...  131521
# 2179    Apple  Apple MacBook Pro M2 Pro MPHH3HN/A Ultrabook (...  199900
# 2207    Apple  Apple MacBook Pro M2 Pro MNW93HN/A Ultrabook (...  269900
# 2221    Apple  Apple MacBook Pro M2 Max MPHG3HN/A Ultrabook (...  309900
# 2266  Samsung  Samsung Galaxy Book Pro Intel Evo NP940XFG-KC5...   99999
# 2267  Samsung  Samsung Galaxy Book 3 Pro NP940XFG-KC1IN Lapto...  112990
# 2294    Apple  Apple MacBook Pro M2 Pro MPHJ3HN/A Ultrabook (...  249900
# 3032    Apple  Apple MacBook Pro M1 Pro MK193HN/A Ultrabook (...  170990
# 3268     ASUS  ASUS VivoBook Flip 14 TP470EA-EC311WS Laptop (...   46999
#
#                           Processor_Name Processor_Brand RAM_Expandable  \
# 90              Intel Core i3 (11th Gen)           Intel             No
# 95                              Apple M2           Apple             No
# 220             Intel Core i3 (11th Gen)           Intel             No
# 281             Intel Core i3 (10th Gen)           Intel             No
# 354             Intel Core i3 (11th Gen)           Intel             No
# 367                             Apple M2           Apple             No
# 562             Intel Core i7 (13th Gen)           Intel             No
# 563             Intel Core i5 (13th Gen)           Intel             No
# 565             Intel Core i7 (13th Gen)           Intel            Yes
# 567             Intel Core i5 (13th Gen)           Intel             No
# 568             Intel Core i7 (13th Gen)           Intel             No
# 571             Intel Core i7 (13th Gen)           Intel             No
# 583             Intel Core i7 (13th Gen)           Intel             No
# 586             Intel Core i5 (13th Gen)           Intel             No
# 651   Intel Core i7 (13th Gen) Processor           Intel             No
# 652             Intel Core i7 (13th Gen)           Intel             No
# 653             Intel Core i7 (13th Gen)           Intel             No
# 654             Intel Core i5 (13th Gen)           Intel             No
# 655             Intel Core i7 (13th Gen)           Intel             No
# 693                         Apple M2 Max           Apple             No
# 1189            Intel Core i7 (12th Gen)           Intel            Yes
# 1213  Intel Core i9 (13th Gen) Processor           Intel             No
# 1563            Intel Core i3 (10th Gen)           Intel             No
# 1949                            Apple M2           Apple             No
# 1955                            Apple M2           Apple             No
# 1957                            Apple M2           Apple             No
# 1958                            Apple M2           Apple             No
# 1959                            Apple M2           Apple             No
# 1960                            Apple M2           Apple             No
# 2179                        Apple M2 Pro           Apple             No
# 2207                        Apple M2 Pro           Apple            Yes
# 2221                        Apple M2 Max           Apple             No
# 2266            Intel Core i7 (13th Gen)           Intel             No
# 2267            Intel Core i5 (13th Gen)           Intel             No
# 2294                        Apple M2 Pro           Apple            Yes
# 3032                        Apple M1 Pro           Apple             No
# 3268            Intel Core i3 (11th Gen)           Intel             No
#
#       RAM_Size (GB) RAM_TYPE  Processer_speed Display_type  ...  GPU_Brand  \
# 90                8      RAM              3.0          LCD  ...      Intel
# 95                8      RAM              3.5          LCD  ...      Apple
# 220               8      RAM              1.5          LCD  ...      Intel
# 281               8      RAM              4.0          LCD  ...      Intel
# 354               8      RAM              4.0          LCD  ...      Intel
# 367               8      RAM              3.5          LCD  ...      Apple
# 562              16      RAM              2.0          LED  ...      Intel
# 563              16      RAM              2.0          LED  ...      Intel
# 565              16      RAM              2.0          LED  ...      Intel
# 567              16      RAM              2.0          LED  ...      Intel
# 568              16      RAM              2.0          LED  ...      Intel
# 571              16      RAM              2.0          LED  ...      Intel
# 583              16      RAM              2.0          LED  ...      Intel
# 586              16      RAM              2.0          LED  ...      Intel
# 651              16      RAM              2.5          LED  ...      Intel
# 652              16      RAM              2.0          LED  ...      Intel
# 653              16      RAM              2.0          LED  ...      Intel
# 654              16      RAM              2.0          LED  ...      Intel
# 655              16      RAM              2.0          LED  ...      Intel
# 693              32      RAM              3.5          LCD  ...      Apple
# 1189             16      RAM              2.5          LCD  ...     NVIDIA
# 1213             32      RAM              2.5          LED  ...     NVIDIA
# 1563              8      RAM              4.0          LCD  ...      Intel
# 1949              8      RAM              3.5          LCD  ...      Apple
# 1955              8      RAM              3.5          LCD  ...      Apple
# 1957              8      RAM              3.5          LCD  ...      Apple
# 1958              8      RAM              3.5          LCD  ...      Apple
# 1959              8      RAM              3.5          LCD  ...      Apple
# 1960              8      RAM              3.5          LCD  ...      Apple
# 2179             16      RAM              3.5          LCD  ...      Apple
# 2207             16      RAM              3.5          LCD  ...      Apple
# 2221             32      RAM              3.5          LCD  ...      Apple
# 2266             16      RAM              2.0          LED  ...      Intel
# 2267             16      RAM              2.0          LED  ...      Intel
# 2294             16      RAM              3.5          LCD  ...      Apple
# 3032             16      RAM              3.0          LCD  ...      Apple
# 3268              8      RAM              4.0          LED  ...      Intel
#
#      SSD(GB) HDD(GB)  Adapter                 Battery_Life  \
# 90       512       0       65      Upto 5 Hrs Battery Life
# 95       256       0       65     Upto 18 Hrs Battery Life
# 220      512       0       65   Upto 17.5 Hrs Battery Life
# 281      256       0       56   Upto 13.2 Hrs Battery Life
# 354      256       0       65     Upto 10 Hrs Battery Life
# 367      512       0       65     Upto 18 Hrs Battery Life
# 562      512       0       65                  65W Adapter
# 563      512       0       65                  65W Adapter
# 565      512       0       65                  65W Adapter
# 567      512       0       65                  65W Adapter
# 568     1024       0       65                  65W Adapter
# 571     1024       0       65                  65W Adapter
# 583      512       0       76     Upto 19 Hrs Battery Life
# 586      512       0       65                  65W Adapter
# 651      512       0       65                  65W Adapter
# 652      512       0       65                  65W Adapter
# 653     1024       0       65                  65W Adapter
# 654      512       0       65                  65W Adapter
# 655     1024       0       63     Upto 16 Hrs Battery Life
# 693     1024       0      140     Upto 22 Hrs Battery Life
# 1189     512       0       no                          NaN
# 1213    1024       0       76   Upto 17.5 Hrs Battery Life
# 1563     256       0       42    Upto 7.8 Hrs Battery Life
# 1949     512       0       35     Upto 18 Hrs Battery Life
# 1955     512       0       35     Upto 18 Hrs Battery Life
# 1957     512       0       35     Upto 18 Hrs Battery Life
# 1958     256       0       35     Upto 18 Hrs Battery Life
# 1959     256       0       35     Upto 18 Hrs Battery Life
# 1960     256       0       35     Upto 18 Hrs Battery Life
# 2179     512       0       67     Upto 18 Hrs Battery Life
# 2207    1024       0      140     Upto 22 Hrs Battery Life
# 2221    1024       0       67                  67W Adapter
# 2266    1024       0       63     Upto 16 Hrs Battery Life
# 2267     512       0       65                  65W Adapter
# 2294    1024       0       no                69.6W Adapter
# 3032    1024       0      140     Upto 21 Hrs Battery Life
# 3268     512       0       65      Upto 6 Hrs Battery Life
#
#      Processor_Brand_Extracted Processor_Series  Processor_Tier  \
# 90                       Intel         Intel I3           Other
# 95                       Apple   Apple M-series  Apple M-series
# 220                      Intel         Intel I3           Other
# 281                      Intel         Intel I3           Other
# 354                      Intel         Intel I3           Other
# 367                      Apple   Apple M-series  Apple M-series
# 562                      Intel         Intel I7           Other
# 563                      Intel         Intel I5           Other
# 565                      Intel         Intel I7           Other
# 567                      Intel         Intel I5           Other
# 568                      Intel         Intel I7           Other
# 571                      Intel         Intel I7           Other
# 583                      Intel         Intel I7           Other
# 586                      Intel         Intel I5           Other
# 651                      Intel         Intel I7           Other
# 652                      Intel         Intel I7           Other
# 653                      Intel         Intel I7           Other
# 654                      Intel         Intel I5           Other
# 655                      Intel         Intel I7           Other
# 693                      Apple   Apple M-series  Apple M-series
# 1189                     Intel         Intel I7           Other
# 1213                     Intel         Intel I9           Other
# 1563                     Intel         Intel I3           Other
# 1949                     Apple   Apple M-series  Apple M-series
# 1955                     Apple   Apple M-series  Apple M-series
# 1957                     Apple   Apple M-series  Apple M-series
# 1958                     Apple   Apple M-series  Apple M-series
# 1959                     Apple   Apple M-series  Apple M-series
# 1960                     Apple   Apple M-series  Apple M-series
# 2179                     Apple   Apple M-series  Apple M-series
# 2207                     Apple   Apple M-series  Apple M-series
# 2221                     Apple   Apple M-series  Apple M-series
# 2266                     Intel         Intel I7           Other
# 2267                     Intel         Intel I5           Other
# 2294                     Apple   Apple M-series  Apple M-series
# 3032                     Apple   Apple M-series  Apple M-series
# 3268                     Intel         Intel I3           Other
#
#      Operating_System Display_Category
# 90         Windows 11            Small
# 95              macOS            Small
# 220        Windows 11            Small
# 281        Windows 11            Small
# 354        Windows 11            Small
# 367             macOS            Small
# 562        Windows 11            Small
# 563        Windows 11            Small
# 565        Windows 11            Small
# 567        Windows 11            Small
# 568        Windows 11            Small
# 571        Windows 11            Large
# 583        Windows 11            Large
# 586        Windows 11            Large
# 651        Windows 11            Large
# 652        Windows 11            Small
# 653        Windows 11            Large
# 654        Windows 11            Small
# 655        Windows 11            Small
# 693             macOS            Large
# 1189       Windows 11            Large
# 1213       Windows 11            Large
# 1563       Windows 10            Small
# 1949            macOS            Small
# 1955            macOS            Small
# 1957            macOS            Small
# 1958            macOS            Small
# 1959            macOS            Small
# 1960            macOS            Small
# 2179            macOS            Small
# 2207            macOS            Large
# 2221            macOS            Small
# 2266       Windows 11            Small
# 2267       Windows 11            Small
# 2294            macOS            Small
# 3032            macOS            Large
# 3268       Windows 11            Small
#
# [37 rows x 22 columns]

# %%
df[(df['Brand'] == 'Apple') & (df['RAM_TYPE'] == 'RAM')][['Processer_speed', 'RAM_TYPE', 'Processor_Name','Processor_Tier']].head(40)
# Out:
#       Processer_speed RAM_TYPE Processor_Name  Processor_Tier
# 95                3.5      RAM       Apple M2  Apple M-series
# 367               3.5      RAM       Apple M2  Apple M-series
# 693               3.5      RAM   Apple M2 Max  Apple M-series
# 1949              3.5      RAM       Apple M2  Apple M-series
# 1955              3.5      RAM       Apple M2  Apple M-series
# 1957              3.5      RAM       Apple M2  Apple M-series
# 1958              3.5      RAM       Apple M2  Apple M-series
# 1959              3.5      RAM       Apple M2  Apple M-series
# 1960              3.5      RAM       Apple M2  Apple M-series
# 2179              3.5      RAM   Apple M2 Pro  Apple M-series
# 2207              3.5      RAM   Apple M2 Pro  Apple M-series
# 2221              3.5      RAM   Apple M2 Max  Apple M-series
# 2294              3.5      RAM   Apple M2 Pro  Apple M-series
# 3032              3.0      RAM   Apple M1 Pro  Apple M-series

# %%
# df[(df['Brand'] == 'Apple')][['Processer_speed', 'RAM_TYPE', 'Processor_Name','Processor_Tier']].head(44)

# %%
# Apple M2 rows: set RAM_TYPE='LPDDR5 RAM'
df.loc[
    (df['Brand'] == 'Apple') &
    (df['Processor_Brand'] == 'Apple') &
    ((df['RAM_TYPE'] == 'RAM')) &
    df['Processor_Name'].str.contains('M2', na=False),
    ['RAM_TYPE']
] = ['LPDDR5'] # Values inserted manually by search in web

# Apple M1 rows: set RAM_TYPE='DDR4 RAM'
df.loc[
    (df['Brand'] == 'Apple') &
    (df['Processor_Brand'] == 'Apple') &
    ((df['RAM_TYPE'] == 'RAM')) &
    df['Processor_Name'].str.contains('M1', na=False),
    ['RAM_TYPE']
] = ['DDR4']

# %%
most_freq_ram = (
    df[df['RAM_TYPE'] != 'RAM']  # exclude placeholder 'RAM'
      .groupby(['Processor_Brand', 'Processor_Tier'])['RAM_TYPE']
      .agg(lambda x: x.mode()[0] if not x.mode().empty else None)
      .reset_index()
      .rename(columns={'RAM_TYPE': 'Most_Freq_RAM'})
)

#Merge back to the original dataframe
df = df.merge(most_freq_ram, on=['Processor_Brand', 'Processor_Tier'], how='left')

#Replace 'RAM' with the most frequent RAM_TYPE
df['RAM_TYPE'] = df.apply(
    lambda row: row['Most_Freq_RAM'] if row['RAM_TYPE'] == 'RAM' else row['RAM_TYPE'],
    axis=1
)

df = df.drop(columns=['Most_Freq_RAM'])

df['RAM_TYPE'].value_counts()
# Out:
# RAM_TYPE
# DDR4       2784
# DDR5        361
# LPDDR5      254
# LPDDR4X     148
# DDR3        113
# LPDDR5X      77
# LPDDR3       47
# LPDDR4       23
# Name: count, dtype: int64

# %%
print(f"Unique Values: {df['RAM_TYPE'].unique()}\n") 
print(f"Value count for each unique RAM_TYPE type: {df['RAM_TYPE'].value_counts()}\n")
# Out:
# Unique Values: ['DDR4' 'DDR5' 'LPDDR4X' 'LPDDR5X' 'LPDDR5' 'LPDDR3' 'LPDDR4' 'DDR3']
#
# Value count for each unique RAM_TYPE type: RAM_TYPE
# DDR4       2784
# DDR5        361
# LPDDR5      254
# LPDDR4X     148
# DDR3        113
# LPDDR5X      77
# LPDDR3       47
# LPDDR4       23
# Name: count, dtype: int64

# %%
df[(df['Brand'] == 'Apple')][['Processer_speed', 'RAM_TYPE', 'Processor_Name','Processor_Tier']].head(44)
# Out:
#       Processer_speed RAM_TYPE                      Processor_Name  \
# 78                3.0     DDR4                            Apple M1
# 80                2.0   LPDDR3             Intel Core i5 (5th Gen)
# 94                3.5   LPDDR5                            Apple M2
# 223               3.5   LPDDR5                            Apple M2
# 360               2.5   LPDDR3             Intel Core i5 (8th Gen)
# 365               3.5   LPDDR5                            Apple M2
# 691               3.5   LPDDR5                        Apple M2 Max
# 1316              1.5   LPDDR3             Intel Core i5 (8th Gen)
# 1321              1.5   LPDDR3             Intel Core i5 (8th Gen)
# 1322              1.5   LPDDR3             Intel Core i5 (8th Gen)
# 1324              1.5   LPDDR3             Intel Core i5 (8th Gen)
# 1384              1.0   LPDDR3             Intel Core M3 (7th Gen)
# 1407              1.5     DDR3             Intel Core i5 (5th Gen)
# 1510              3.0     DDR4                            Apple M1
# 1525              1.5   LPDDR3             Intel Core i5 (8th Gen)
# 1534              2.5  LPDDR4X  Intel Core i3 (10th Gen) Processor
# 1631              1.5   LPDDR3             Intel Core i5 (8th Gen)
# 1635              1.0  LPDDR4X            Intel Core i5 (10th Gen)
# 1657              1.5   LPDDR3             Intel Core i5 (8th Gen)
# 1671              1.5   LPDDR3             Intel Core i5 (8th Gen)
# 1722              1.0  LPDDR4X            Intel Core i5 (10th Gen)
# 1880              3.5   LPDDR5                            Apple M2
# 1908              3.5   LPDDR5                            Apple M2
# 1914              3.5   LPDDR5                            Apple M2
# 1916              3.5   LPDDR5                            Apple M2
# 1917              3.5   LPDDR5                            Apple M2
# 1918              3.5   LPDDR5                            Apple M2
# 1919              3.5   LPDDR5                            Apple M2
# 2136              3.5   LPDDR5                        Apple M2 Pro
# 2164              3.5   LPDDR5                        Apple M2 Pro
# 2178              3.5   LPDDR5                        Apple M2 Max
# 2251              3.5   LPDDR5                        Apple M2 Pro
# 2970              3.0     DDR4                        Apple M1 Pro
# 3044              2.0  LPDDR4X            Intel Core i5 (10th Gen)
# 3073              1.5   LPDDR3             Intel Core i5 (8th Gen)
# 3096              1.5   LPDDR3             Intel Core i5 (8th Gen)
# 3106              1.5   LPDDR3             Intel Core i5 (8th Gen)
# 3130              2.0  LPDDR4X            Intel Core i5 (10th Gen)
# 3197              1.5   LPDDR3             Intel Core i5 (8th Gen)
# 3214              2.5   LPDDR3             Intel Core i5 (8th Gen)
# 3247              2.5     DDR4             Intel Core i9 (9th Gen)
# 3311              2.5   LPDDR3             Intel Core i5 (8th Gen)
# 3359              2.5   LPDDR3             Intel Core i7 (6th Gen)
# 3453              2.0     DDR4             Intel Core i7 (8th Gen)
#
#       Processor_Tier
# 78    Apple M-series
# 80             Other
# 94    Apple M-series
# 223   Apple M-series
# 360            Other
# 365   Apple M-series
# 691   Apple M-series
# 1316           Other
# 1321           Other
# 1322           Other
# 1324           Other
# 1384         Low-End
# 1407           Other
# 1510  Apple M-series
# 1525           Other
# 1534           Other
# 1631           Other
# 1635           Other
# 1657           Other
# 1671           Other
# 1722           Other
# 1880  Apple M-series
# 1908  Apple M-series
# 1914  Apple M-series
# 1916  Apple M-series
# 1917  Apple M-series
# 1918  Apple M-series
# 1919  Apple M-series
# 2136  Apple M-series
# 2164  Apple M-series
# 2178  Apple M-series
# 2251  Apple M-series
# 2970  Apple M-series
# 3044           Other
# 3073           Other
# 3096           Other
# 3106           Other
# 3130           Other
# 3197           Other
# 3214           Other
# 3247           Other
# 3311           Other
# 3359           Other
# 3453           Other

# %%
# Calculate mean price by RAM_TYPE
avg_price_tier = df.groupby('RAM_TYPE')['Price'].mean().sort_values()

# Plot horizontal bar chart
plt.figure(figsize=(18,3))
plt.barh(avg_price_tier.index, avg_price_tier.values, color='skyblue')
plt.xlabel("Average Price")
plt.ylabel("RAM Type")
plt.title("Average Laptop Price by RAM Type")
plt.tight_layout()
plt.show()

# %%
# df['RAM_TYPE'] = df['RAM_TYPE'].replace({
#     'DDR4': 'DDR4',
#     'LPDDR4': 'DDR4',
#     'LPDDR4X': 'DDR4',

#     'DDR5': 'DDR5',
#     'LPDDR5': 'DDR5',
#     'LPDDR5X': 'DDR5',

#     'DDR3': 'DDR3',
#     'LPDDR3': 'DDR3',
# })

# %%
df['RAM_TYPE'] = df['RAM_TYPE'].replace({
    # DDR4 family
    # 'DDR4': 'DDR4',
    # 'LPDDR4': 'LPDDR4',
    'LPDDR4X': 'LPDDR4',

    # DDR5 family
    # 'DDR5': 'DDR5',
    # 'LPDDR5': 'LPDDR5',
    'LPDDR5X': 'LPDDR5',

    # DDR3 family
    # 'DDR3': 'DDR3',
    'LPDDR3': 'LPDDR3',

    # DDR2 family (remove)
    # 'DDR2 RAM': 'DDR2'
})

df['RAM_TYPE'].value_counts()
# Out:
# RAM_TYPE
# DDR4      2784
# DDR5       361
# LPDDR5     331
# LPDDR4     171
# DDR3       113
# LPDDR3      47
# Name: count, dtype: int64

# %%
import re

# Remove only 'DDR' text, keep 'LP' and other parts
df['RAM_TYPE'] = df['RAM_TYPE'].str.replace(r'DDR', '', regex=True).str.strip()

# Rename the column (optional)
df = df.rename(columns={'RAM_TYPE': 'RAM_TYPE(DDR)'})

# View unique categories or counts
df['RAM_TYPE(DDR)'].value_counts()
# Out:
# RAM_TYPE(DDR)
# 4      2784
# 5       361
# LP5     331
# LP4     171
# 3       113
# LP3      47
# Name: count, dtype: int64

# %%
# most_freq_ram = (
#     df[df['RAM_TYPE'] != 'RAM']  # exclude placeholder 'RAM'
#       .groupby(['Processor_Brand', 'Processor_Tier'])['RAM_TYPE']
#       .agg(lambda x: x.mode()[0] if not x.mode().empty else None)
#       .reset_index()
#       .rename(columns={'RAM_TYPE': 'Most_Freq_RAM'})
# )

# #Merge back to the original dataframe
# df = df.merge(most_freq_ram, on=['Processor_Brand', 'Processor_Tier'], how='left')

# #Replace 'RAM' with the most frequent RAM_TYPE
# df['RAM_TYPE'] = df.apply(
#     lambda row: row['Most_Freq_RAM'] if row['RAM_TYPE'] == 'RAM' else row['RAM_TYPE'],
#     axis=1
# )

# df = df.drop(columns=['Most_Freq_RAM'])

# df['RAM_TYPE'].value_counts()

# %%
# # Calculate mean price by RAM_TYPE
# avg_price_tier = df.groupby('RAM_TYPE')['Price'].mean().sort_values()

# # Plot horizontal bar chart
# plt.figure(figsize=(18,3))
# plt.barh(avg_price_tier.index, avg_price_tier.values, color='skyblue')
# plt.xlabel("Average Price")
# plt.ylabel("RAM Type")
# plt.title("Average Laptop Price by RAM Type")
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### Display Type

# %%
df['Display_type'] = df['Display_type'].astype('category')
print(f"Unique Values: {df['Display_type'].unique()}\n")
# Out:
# Unique Values: ['LCD', 'LED']
# Categories (2, object): ['LCD', 'LED']

# %%
# import re

# def clean_gpu(value):
#     if pd.isna(value):
#         return ("Unknown", 0)
    
#     text = value.strip()

#     # Extract memory size
#     mem_match = re.search(r"(\d+)\s*GB", text)
#     vram = int(mem_match.group(1)) if mem_match else 0

#     # Normalize brand/type keywords
#     if "RTX" in text.upper():
#         gpu_type = "NVIDIA RTX"
#     elif "GTX" in text.upper():
#         gpu_type = "NVIDIA GTX"
#     elif "MX" in text.upper():
#         gpu_type = "NVIDIA MX"
#     elif "RADEON" in text.upper():
#         gpu_type = "AMD Radeon"
#     elif "IRIS" in text.upper():
#         gpu_type = "Intel Iris"
#     elif "UHD" in text.upper() or "HD" in text.upper():
#         gpu_type = "Intel UHD/HD"
#     elif "M1" in text.upper() or "M2" in text.upper():
#         gpu_type = "Apple Silicon"
#     elif "QUADRO" in text.upper():
#         gpu_type = "NVIDIA Workstation"
#     elif "INTEGRATED" in text.upper():
#         gpu_type = "Integrated"
#     else:
#         gpu_type = "Other"

#     return (gpu_type, vram)

# # Apply cleaning
# df[["GPU_Type", "GPU_VRAM"]] = df["GPU"].apply(lambda x: pd.Series(clean_gpu(x)))

# %% [markdown]
# ### GPU

# %%
df.dropna(subset=['GPU'], inplace=True)

# %%
print(f"Unique Values: {df['GPU'].unique()}\n")
print(f"Value count for each unique processor type: {df['GPU'].value_counts()}")
# Out:
# Unique Values: ['Radeon' 'GeForce RTX 3050 GPU, 4 GB' 'Iris Xe' 'UHD' 'UHD 620'
#  'GeForce RTX 2050 GPU, 4 GB' 'GeForce RTX 4050 GPU, 6 GB' 'Arc'
#  'GeForce GTX 1650 GPU, 4 GB' 'UHD 605' 'GeForce RTX 3060 GPU, 6 GB'
#  'GeForce GTX 1650 Max Q GPU, 4 GB' 'GeForce RTX 3050 Ti GPU, 4 GB'
#  'Integrated' 'Geforce GTX 1650 GPU, 4 GB' 'Radeon Vega 3' 'UHD Graphics'
#  'UHD GPU, 128 MB' 'M1' 'HD 6000' 'UHD 600' 'Radeon Vega 6'
#  'M2 Integrated' 'HD 620' 'Geforce MX150 GPU, 2 GB' 'Radeon Vega 8'
#  'Geforce GTX 1650 Max-Q GPU, 4 GB' 'GeForce GTX 1650 Ti GPU, 4 GB'
#  'Radeon RX Vega 10' 'HD 520' 'Radeon RX 5500M GPU, 4 GB'
#  'GeForce GTX 3050 GPU, 4 GB' 'Radeon 610M' 'Radeon RX6500M GPU, 4 GB'
#  'GeForce GTX 1650 MAX Q GPU, 4 GB' 'GeForce RTX 2050' 'Radeon Graphics'
#  'GeForce RTX 3070 Ti GPU, 8 GB' 'GeForce GTX 1050 GPU, 4 GB'
#  'Geforce RTX 3050 GPU, 4 GB' 'M2' 'Radeon RX 6500M GPU, 4 GB'
#  'Radeon RX 5600M GPU, 6 GB' 'GeForce MX450 GPU, 2 GB'
#  'GeForce RTX 4060 GPU, 8 GB' 'GeForce GTX 1060 GPU, 6 GB'
#  'GeForce MX330 GPU, 2 GB' 'Radeon R2' 'Iris X' 'Radeon Vega 7'
#  'Radeon R4' 'Integrated UHD' 'Iris Xe Graphics' 'Iris Plus 655'
#  'GeForce RTX 3050 Ti  GPU, 4 GB' 'GeForce RTX 3050 GPU, 6 GB'
#  'GeForce MX350 GPU, 2 GB' 'Radeon RX 6800M GPU, 12 GB' 'Iris Plus'
#  'GeForce MX250 GPU, 2 GB' 'GeForce RTX 3070 GPU, 8 GB'
#  'GeForce RTX 3050 GPU, 4 ' 'Radeon R5' 'GeForce RTX 3050'
#  'MX350 GPU, 2 GB' 'GeForce MX550 GPU, 2 GB' 'Integrated Iris Xe'
#  'Geforce GTX 1650 Ti GPU, 4 GB' 'Radeon 610M Vega 2' 'UHD Graphics 600'
#  'GEFORCE RTX 3050 Ti GPU, 4 GB' 'Radeon RX 6700S GPU, 8 GB' 'M2 Max' 'HD'
#  'UHD ' 'GeForce RTX 3050Ti GPU, 4 GB' 'GeForce MX570 GPU, 2 GB'
#  'GeForce 940MX GPU, 2 GB' 'Radeon RX 6700S GPU, 8 '
#  'GeForce GTX 1650Ti GPU, 4 GB' 'Intel Iris Xe'
#  'GeForce RTX 4070 GPU, 8 GB' 'GeForce MX250' 'GeForce RTX 2070 GPU, 8 GB'
#  'HD 615' 'GeForce MX550  GPU, 2 GB' 'GeForce N16V-GMR1 GPU, 2 GB'
#  'Arc A370M GPU, 4 GB' 'UMA' 'Radeon RX6550M GPU, 4 GB'
#  'GeForce RTX 3080 GPU, 8 GB' 'GeForce RTX 3080 Ti GPU, 16 GB'
#  'Radeon GPU, 6 GB' 'Radeon 680M GPU, 6 GB' 'Radeon 780M'
#  'GeForce RTX 4060 GPU, 6 GB' 'GeForce RTX 4090 GPU, 16 GB' 'Radeon 760M'
#  'GeForce RTX 4060 GPU, 8 ' 'GeForce RTX 4080 GPU, 8 GB'
#  'RTX A500 GPU, 4 GB' 'Integrated Arc' 'Radeon 680M' 'Graphics'
#  'GeForce RTX 4050 GPU, 8 GB' 'GeForce RTX 4070' 'T1200 GPU, 4 GB'
#  'GeForce RTX 2080 GPU, 8 GB' 'GeForce RTX 3070 Ti GPU, 8 '
#  'Quadro T2000  GPU, 4 GB' 'Integrated HD' 'GeForce RTX 3070 GPU, 8 '
#  'UHD Graphics 620' 'Geoforce RTX3050 GPU, 4 GB' 'Quadro T50 GPU, 4 GB'
#  'RTX 3050 Ti GPU, 4 GB' 'GeForce P620 GPU, 4 GB' 'Quadro T1200 GPU, 4 GB'
#  'UHD 617' 'Geforce MX250 GPU, 2 GB' 'Geforce GTX 1050Ti GPU, 4 GB'
#  'Geforce MX150 GPU, 4 GB' 'GeForce GTX 1050 Ti  GPU, 4 GB'
#  'GeForce GTX 1050Ti GPU, 4 GB' 'Geforce GTX 1060 GPU, 6 GB'
#  'Geforce GTX 1650 Ti GPU, 6 GB' 'Radeon RX Vega 8' 'HD 405'
#  'Radeon R16M-M1-30 GPU, 2 GB' 'GeForce GTX 1050T GPU, 4 GB'
#  'Radeon 520 GPU, 2 GB' 'HD 400' 'Radeon 530 GPU, 2 GB'
#  'Geforce GTX 1650Ti GPU, 6 GB' 'R17M-M1-70 GPU, 2 GB'
#  'Geforce MX130 GPU, 2 GB' 'GeForce MX150 GPU, 2 GB'
#  'Radeon HD 520 GPU, 2 GB' 'GeForce GTX 1660 Ti GPU, 6 GB'
#  'GeForce 920MX GPU, 2 GB' 'HD 610' 'Radeon HD 8210 GPU, 2 GB'
#  'Geforce GTX 1050Ti GPU, 8 GB' 'Radeon RX 560X GPU, 4 GB' 'HD 505'
#  'GeForce GTX 1050 GPU, 3 GB' 'Geforce GTX 1050 GPU, 3 GB' 'Radeon R3'
#  'Geforce GTX 1050 Ti GPU, 4 GB' 'Geforce RTX 2060 GPU, 6 GB'
#  'M1 Integrated' 'Geforce 940MX GPU, 4 GB' 'Geforce GTX 1660 Ti GPU, 6 GB'
#  'GeForce GTX 1050 GPU, 2 GB' 'Geforce MX350 GPU, 2 GB'
#  'GeForce MX110 GPU, 2 GB' 'Radeon Vega' 'HD 5500' 'HD 500'
#  'GeForce GTX 1650 Ti GPU, 6 GB' 'Radeon R5 M430 GPU, 2 GB'
#  'GeForce GTX 1050 Ti GPU, 4 GB' 'Geforce MX330 GPU, 2 GB'
#  'GeForce 940MX  GPU, 4 GB' 'Geforce GTX 1050 GPU, 2 GB'
#  'GeForce MX130 GPU, 2 GB' 'Geforce RTX 2070 GPU, 8 GB'
#  'GeForce GPU, 2 GB' 'Radeon R5 M430  GPU, 2 GB' 'Radeon RX 5500M'
#  'Radeon RX 6500M  GPU, 4 GB' 'RTX 3050 GPU, 4 GB' 'Radeon Vega 8 Mobile'
#  'GeForce RTX 1650 GPU, 4 GB' 'GeForce MX 450 GPU, 2 GB' 'GeForce MX550'
#  'M2 Pro' 'Geforce MX230 GPU, 2 GB' 'Radeon Athlon 3000G'
#  'Radeon RX 6600M GPU, 8 GB' 'Radeon RX6700M'
#  'GeForce RTX 3070 GPU, 16 GB' 'Arc A530M GPU, 4 GB'
#  'Quadro T550 GPU, 4 GB' 'UHD GPU, 2 GB' 'Integrated GPU, 512 MB'
#  'Radeon RX 6650M GPU, 8 GB' 'GeForce RTX 3060 GPU GPU, 6 GB'
#  'GeForce RTX 3060 GPU, 6 ' 'Quadro T600 GPU, 4 GB'
#  'GeForce RTX 4080 GPU, 12 GB' 'GeForce GTX 1070 GPU, 8 GB'
#  'Radeon RX 7600S GPU, 8 GB' 'RTX A1000 GPU, 6 GB'
#  'GeForce MX 350 GPU, 2 GB' 'GeForce MX550 GPU, 2 '
#  'GeForce RTX A2000 GPU, 8 GB' 'MX450 GPU, 2 GB' 'Geforce MX110 GPU, 2 GB'
#  'T600 GPU, 4 GB' 'HD Graphics' 'GeForce MX230 GPU, 2 GB'
#  'Geforce 940MX GPU, 2 GB' 'GeForce GTX 940MX GPU, 4 GB' 'Radeon R7'
#  'Radeon R4 ' 'GeForce GT 940MX GPU, 4 GB'
#  'Geforce GTX 1650 Ti` GPU, 4 GB' 'Radeon R5 M430 GPU, 4 GB' 'Iris Pro'
#  'GeForce GT 940MX GPU, 2 GB' 'GeForce RTX 2060 GPU, 6 GB'
#  'Integrated Graphics' 'Geforce MX 150 GPU, 2 GB'
#  'GeForce GTX 1650 Ti Max Q GPU, 4 GB' 'GeForce RTX 3060 GPU, 4 GB'
#  'Radeon R7 M260 GPU, 2 GB' 'Geforce GTX 1650 Ti with Max-Q GPU, 4 GB'
#  'GeForce GTX 940MX GPU, 2 GB' 'Geforce GTX 1650Ti GPU, 4 GB'
#  'GeForce GTX 960M GPU, 2 GB' 'GeForce 940MX GPU, 4 GB'
#  'GeForce MX150  GPU, 2 GB' 'Geforce GTX 1050 GPU, 4 GB' 'GeForce 920M'
#  'Iris Plus Graphics 645' 'Iris Plus 640' 'Radeon Pro 5500M GPU, 4 GB'
#  'GeForce GTX 1050  GPU, 2 GB' 'GeForce GTX 960M GPU, 4 GB' 'UHD 605 '
#  'Radeon RX Vega 6' 'Iris Plus Graphics 655' 'Radeon R7 M440 GPU, 2 GB'
#  'Geforce 940M GPU, 2 GB' 'GeForce 930M GPU, 2 GB'
#  'GeForce 920M GPU, 2 GB' 'Iris graphics' 'R5' 'Radeon Pro 450 GPU, 2 GB'
#  'Radeon HD 8670M GPU, 2 GB' 'GeForce 820M GPU, 2 GB'
#  'Radeon HD R7 M265 GPU, 2 GB' 'GeForce 830M GPU, 2 GB'
#  'Radeon HD 8670M GPU, 1 GB' 'HD 4000' 'GeForce 940M GPU, 4 GB'
#  'GeForce 930MX GPU, 2 GB' 'GeForce GT 740M GPU, 2 GB'
#  'GeForce GTX 850M GPU, 4 GB' 'HD 4400' 'GeForce GT 820M GPU, 1 GB'
#  'GeForce RTX 3080 GPU, 16 GB' 'Radeon RX 580 GPU, 4 GB'
#  'Pro 555X GPU, 4 GB' 'Iris Xe Max GPU, 4 GB'
#  'GeForce GTX 1050TI GPU, 4 GB' 'GeForce 920MX  GPU, 2 GB'
#  'GeForce 1650 Ti GPU, 4 GB' 'GeForce 940 MX GPU, 2 GB'
#  'Iris Xe GPU, 4 GB' 'GeForce RTX 2060 GPU, 8 GB'
#  'GeForce RTX A1000 GPU, 4 GB' 'Geforce GTX 1070 GPU, 8 GB'
#  'Geforce RTX 2070 Super GPU, 8 GB' 'Radeon R5 M330 GPU, 2 GB'
#  'HD Graphics 620' 'Radeon 535 GPU, 2 GB' 'GeForce GTX 1660 GPU, 6 GB'
#  'Geforce GT 940MX GPU, 2 GB' 'Geforce GTX MX330 GPU, 2 GB'
#  'Geforce RTX 2080 with Max-Q GPU, 8 GB' 'Radeon RX640 GPU, 2 GB'
#  'Radeon RX 640 GPU, 2 GB' 'Radeon RX Vega 5' 'Geforce RTX 2080 GPU, 8 GB'
#  'Radeon RX Vega 7 ' 'EXO PRO R5 M330 GPU, 2 GB' 'GeForce MX230'
#  'Geforce Gt 940MX GPU, 2 GB' 'Geforce RTX 2080 Super GPU, 8 GB']
#
# Value count for each unique processor type: GPU
# UHD                                 647
# Iris Xe                             571
# Radeon                              313
# GeForce RTX 3050 GPU, 4 GB          202
# Integrated                          155
#                                    ...
# Radeon RX Vega 7                      1
# EXO PRO R5 M330 GPU, 2 GB             1
# GeForce MX230                         1
# Geforce Gt 940MX GPU, 2 GB            1
# Geforce RTX 2080 Super GPU, 8 GB      1
# Name: count, Length: 281, dtype: int64

# %%
# import re
# import pandas as pd

# def clean_gpu_series(value):
#     if pd.isna(value):
#         return "Other"
    
#     text = str(value).strip().upper()

#     if "RTX" in text:
#         return "RTX"
#     elif "GTX" in text:
#         return "GTX"
#     elif "MX" in text:
#         return "MX"
#     elif "RADEON" in text:
#         return "Radeon"
#     elif "IRIS" in text:
#         return "Iris"
#     elif "UHD" in text or "HD" in text:
#         return "UHD/HD"
#     elif "ARC" in text:
#         return "Arc"
#     elif "M1" in text:
#         return "Apple M1"
#     elif "M2" in text:
#         return "Apple M2"
#     elif "ADRENO" in text:
#         return "Adreno"
#     elif "MALI" in text:
#         return "Mali"
#     elif "INTEGRATED" in text:
#         return "Integrated"
#     else:
#         return "Other"

# # --- Apply to your dataframe ---
# df["GPU_Series"] = df["GPU"].apply(clean_gpu_series)

# %%
def categorize_gpu_tier(gpu):
    if pd.isna(gpu):
        return 'Unknown'
    
    gpu = str(gpu).lower()

    # Entry-level (Integrated / Basic)
    if any(x in gpu for x in [
        'uhd', 'hd', 'integrated', 'r2', 'r3', 'r4', 'r5', 'r7', 
        '520', '530', '535', '610m', 'vega 3', 'vega 2', 'intel hd graphics',
        'vega 3', 'vega 6', 'vega 8', 'graphics', 'iris', '820m', 
        '830m', '920m', '930m', '940m', 'gt 740m', 'gt 820m', 'uma'
    
    ]):
        return 'Entry-level'

    # Low-end (Budget Discrete)
    elif any(x in gpu for x in [
        'mx', 'arc', 'vega 5', 'vega 6', 'vega 7', 'vega 8',
        'vega 10', 'rx640', 'rx 640', 'rx 5500m', 'rx5500', 'rx 5500', 'rx vega',
        'iris xe', 'iris plus', 'iris pro', 'rx 640 gpu', 'rx 640m', 'rx 640 ', 'rx640 ', 'iris x', 'radeon'
    ]):
        return 'Low-end'

    # Mid-end (Mainstream Gaming / Productivity)
    elif any(x in gpu for x in [
        'gtx 1050', 'gtx 1060', 'gtx 1650', 'gtx 1660',
        'rtx 2050', 'rtx 3050', 'rtx 3050 ti', 'rtx 3060',
        't550', 't600', 't1200', 'p620', 'a1000',
        'rx 5600', 'rx 6500', 'rx 6600', 'rx 6650', 'rx 6700s',
        '680m', '760m', '780m', 'iris xe max', 'gtx 850m', 'gtx 960m', 'gtx 1070', 'gtx 3050', 'rtx 1650', 
    'rx 560x', 'rx6500', 'rx6550', 'rx6700', 'pro 555x'
    ]):
        return 'Mid-end'

    # High-end (Performance / Workstation / Enthusiast)
    elif any(x in gpu for x in [
        'rtx 2060', 'rtx 2070', 'rtx 2080', 'rtx 3050 ti', 'rtx 3060',
        'rtx 3070', 'rtx 3070 ti', 'rtx 3080', 'rtx 3080 ti',
        'rtx 4060', 'rtx 4070', 'rtx 4080', 'rtx 4090',
        'rtx a2000', 'rtx a500', 'rtx a1000',
        'quadro t2000', 'quadro t600', 'quadro t550',
        'rx 6700m', 'rx 6700s', 'rx 6800m', 'rx 7600s',
        'rx 6650m', 'rx 580', 'pro 5500m',
        'm2 max', 'm3 max','rtx 4050', 'radeon pro 450', 'radeon gpu, 6', 'm2', 'm1'
    ]):
        return 'High-end'

    else:
        return 'Unknown'


# Apply to your DataFrame
df['GPU_Tier'] = df['GPU'].apply(categorize_gpu_tier)
print(df['GPU_Tier'].value_counts())
# Out:
# GPU_Tier
# Entry-level    2082
# Mid-end         806
# Low-end         599
# High-end        306
# Unknown           6
# Name: count, dtype: int64

# %%
df.drop(df[df['GPU_Tier']=='Unknown'].index, inplace=True)

# %%
print(df['GPU_Tier'].value_counts())
# Out:
# GPU_Tier
# Entry-level    2082
# Mid-end         806
# Low-end         599
# High-end        306
# Name: count, dtype: int64

# %%
# def categorize_gpu_tier(gpu):
#     if pd.isna(gpu):
#         return 'Unknown'
#     gpu = gpu.upper()
#     if any(x in gpu for x in ['RTX 4090', 'RTX 4080', 'RX 7900', 'M2 MAX', 'M3 MAX']):
#         return 'High-end'
#     elif any(x in gpu for x in ['ARC A530M', 'ARC A370M', 'IRIS XE MAX','RTX 3060', 'RTX 3070', 'RX 6600', 'RX 6700', 'M2 PRO']):
#         return 'Mid-end'
#     elif any(x in gpu for x in ['GTX 1650', 'MX450', 'RX 5500']):
#         return 'Low-end'
#     elif any(x in gpu for x in ['UHD', 'IRIS', 'VEGA 3', 'R5', 'R4']):
#         return 'Entry-level'
#     else:
#         return 'Other'

# df['GPU_Tier'] = df['GPU'].apply(categorize_gpu_tier)
# print(f"Unique Values: {df['GPU_Tier'].unique()}\n")
# print(f"Value count for each unique GPU_Tier type: {df['GPU_Tier'].value_counts()}\n")

# %%
# print(f"Number of unique GPU types : {df['GPU_Series'].nunique()}\n")
# print(f"Unique Values: {df['GPU_Series'].unique()}\n")
# print(f"Value count for each unique GPU Series: {df['GPU_Series'].value_counts()}\n")
# df = df.drop(columns=['GPU'])

# %% [markdown]
# ### GPU Brand

# %%
df.dropna(subset=['GPU_Brand'], inplace=True)

# %%
print(f"Unique Values: {df['GPU_Brand'].unique()}\n")
print(f"Value count for each unique GPU_Brand type: {df['GPU_Brand'].value_counts()}\n")
# Out:
# Unique Values: ['AMD' 'NVIDIA' 'Intel' 'Apple' 'NIVIDIA' 'Nvidia' 'ATI']
#
# Value count for each unique GPU_Brand type: GPU_Brand
# Intel      1855
# NVIDIA     1301
# AMD         606
# Apple        18
# Nvidia        8
# NIVIDIA       1
# ATI           1
# Name: count, dtype: int64

# %%
df.drop(df[df['GPU_Brand']=='ATI'].index, inplace=True)
df['GPU_Brand'] = df['GPU_Brand'].astype('category')

def clean_gpu_brand(value):
    if 'Intel' in value:
        return 'Intel'
    elif 'NVIDIA' in value or 'Nvidia' in value or 'NIVIDIA' in value:
        return 'NVIDIA'
    elif 'AMD' in value:
        return 'AMD'
    elif 'Apple' in value:
        return 'Apple'
    else:
        return 'Other'

df['GPU_Brand'] = df['GPU_Brand'].apply(clean_gpu_brand)

# %%
df.shape
# Out:
# (3789, 23)

# %%
print(f"Unique Values: {df['GPU_Brand'].unique()}\n")
print(f"Value count for each unique GPU_Brand type: {df['GPU_Brand'].value_counts()}\n")
# Out:
# Unique Values: ['AMD' 'NVIDIA' 'Intel' 'Apple']
#
# Value count for each unique GPU_Brand type: GPU_Brand
# Intel     1855
# NVIDIA    1310
# AMD        606
# Apple       18
# Name: count, dtype: int64

# %% [markdown]
# ### Adapter & Battery life

# %%
print(f"Number of unique Adapters: {df['Adapter'].nunique()}\n")
print(f"Unique Values: {df['Adapter'].unique()}\n")
print(f"Value count for each unique Adapters: {df['Adapter'].value_counts()}")
# Out:
# Number of unique Adapters: 65
#
# Unique Values: ['65' '56' 'no' '45' '150' '170' '230' '135' '41' '100' '90' '120' '96'
#  '180' '63' '30' '54' '33' '46' '57' '43' '48' '70' '37' '24' '67' '42'
#  '330' '200' '58' '240' '50' '280' '60' '80' '35' '51' '61' '76' '38' '86'
#  '66' '210' '39' '97' '140' '83' '59' '53' '71' '75' '74' '49' '300' '68'
#  '52' '40' '36' '32' '64' '130' '87' '72' '95' '69']
#
# Value count for each unique Adapters: Adapter
# 65     1423
# no      733
# 45      433
# 41      146
# 150      90
#        ...
# 24        1
# 46        1
# 97        1
# 130       1
# 69        1
# Name: count, Length: 65, dtype: int64

# %%
print(f"Number of unique Battery life: {df['Battery_Life'].nunique()}\n")
print(f"Unique Values: {df['Adapter'].unique()}\n")
print(f"Value count for each unique Battery_Life: {df['Battery_Life'].value_counts()}")
# Out:
# Number of unique Battery life: 186
#
# Unique Values: ['65' '56' 'no' '45' '150' '170' '230' '135' '41' '100' '90' '120' '96'
#  '180' '63' '30' '54' '33' '46' '57' '43' '48' '70' '37' '24' '67' '42'
#  '330' '200' '58' '240' '50' '280' '60' '80' '35' '51' '61' '76' '38' '86'
#  '66' '210' '39' '97' '140' '83' '59' '53' '71' '75' '74' '49' '300' '68'
#  '52' '40' '36' '32' '64' '130' '87' '72' '95' '69']
#
# Value count for each unique Battery_Life: Battery_Life
# 65W Adapter                    787
# 45W Adapter                    266
#  Upto 6 Hrs Battery Life       193
#  Upto 8 Hrs Battery Life       144
#  Upto 10 Hrs Battery Life      138
#                               ...
#  Upto 12.5 Hrs Battery Life      1
#  Upto 10.5 Hrs Battery Life      1
# 60.7W Adapter                    1
# 69W Adapter                      1
# 71W Adapter                      1
# Name: count, Length: 186, dtype: int64

# %% [markdown]
# Remove Adapter column and Battery_life column because,
#     Adupter column have lot of unknown (no) values and Battery_life column data mixed with adupter column values.

# %% [markdown]
# ### Price

# %%
print("Missing Price values:", df['Price'].isna().sum())
print((df['Price'] == 0).any())  
# print(df['Price'].value_counts())
# Out:
# Missing Price values: 0
# False

# %%
df['Price'] = df['Price'] * 3.5 # Get Average Exchange Rate INR to LKR

# %%
plt.figure(figsize=(18,6))

plt.subplot(1, 2, 1)
sns.histplot(df['Price'], kde=True)
plt.title('Laptop Price Distribution')
plt.xlabel('Price')
plt.ylabel('Count')


plt.subplot(1, 2, 2)
sns.boxplot(data=df, y='Price')
plt.title('Laptop Price Boxplot')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## **Remove unnessary Colums**

# %%
cols_to_drop = [
    'Name','Processor_Name', 'Display_size(inch)','GPU',
    'Adapter', 'Battery_Life', 'Processor_Brand_Extracted', 'Operating_System', 'Processor_Tier' 
]
# Drop columns
df = df.drop(columns=cols_to_drop)
# Check the updated DataFrame
df.head()
# Out:
#     Brand     Price Processor_Brand RAM_Expandable  RAM_Size (GB)  \
# 0  Lenovo  127011.5             AMD            Yes              8
# 1    Dell  274750.0           Intel            Yes             16
# 2      HP  194215.0           Intel            Yes              8
# 3   Other   76965.0           Intel             No              8
# 4    Acer  122465.0           Intel            Yes             16
#
#   RAM_TYPE(DDR)  Processer_speed Display_type GPU_Brand  SSD(GB)  HDD(GB)  \
# 0             4              4.0          LCD       AMD      512        0
# 1             5              3.5          LCD    NVIDIA      512        0
# 2             4              4.0          LCD     Intel      512        0
# 3           LP4              1.5          LCD     Intel      512        0
# 4             4              2.5          LCD     Intel      512        0
#
#   Processor_Series Display_Category     GPU_Tier
# 0      AMD Ryzen 5            Small      Low-end
# 1         Intel I5            Small      Mid-end
# 2         Intel I5            Small  Entry-level
# 3         Intel I3            Small  Entry-level
# 4         Intel I5            Small  Entry-level

# %%
df[df.duplicated()].shape
# Out:
# (70, 14)

# %%
df = df.drop_duplicates()

# %%
df[df.duplicated()].shape
# Out:
# (0, 14)

# %%
df.shape
# Out:
# (3719, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3719 entries, 0 to 3806
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             3719 non-null   category
#  1   Price             3719 non-null   float64
#  2   Processor_Brand   3719 non-null   object
#  3   RAM_Expandable    3719 non-null   object
#  4   RAM_Size (GB)     3719 non-null   int64
#  5   RAM_TYPE(DDR)     3719 non-null   object
#  6   Processer_speed   3719 non-null   float64
#  7   Display_type      3719 non-null   category
#  8   GPU_Brand         3719 non-null   object
#  9   SSD(GB)           3719 non-null   int64
#  10  HDD(GB)           3719 non-null   int64
#  11  Processor_Series  3719 non-null   object
#  12  Display_Category  3719 non-null   object
#  13  GPU_Tier          3719 non-null   object
# dtypes: category(2), float64(2), int64(3), object(7)
# memory usage: 385.5+ KB

# %%
df = df.rename(columns={"Processor_Series": "Processor_Category"})
df = df.rename(columns={"Display_Category": "Display_Tier"})
df = df.rename(columns={"Processer_speed": "Processor_Speed(Ghz)"})
df = df.rename(columns={"RAM_Size (GB)": "RAM_Capacity"})

# %%
df.to_csv('cleaned_laptop_dataset_2.csv', index=False)

# %%
# Categorical columns
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
print("Categorical columns:", list(categorical_cols))

# Numerical columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
print("Numerical columns:", list(numerical_cols))
# Out:
# Categorical columns: ['Brand', 'Processor_Brand', 'RAM_Expandable', 'RAM_TYPE(DDR)', 'Display_type', 'GPU_Brand', 'Processor_Category', 'Display_Tier', 'GPU_Tier']
# Numerical columns: ['Price', 'RAM_Capacity', 'Processor_Speed(Ghz)', 'SSD(GB)', 'HDD(GB)']

# %%
for col in categorical_cols:
    print(f"{col}: {df[col].nunique()} unique values")
    print(df[col].value_counts().head(30))
# Out:
# Brand: 9 unique values
# Brand
# ASUS       920
# Lenovo     762
# HP         750
# Dell       413
# Acer       301
# MSI        296
# Other      186
# Samsung     51
# Apple       40
# Name: count, dtype: int64
# Processor_Brand: 3 unique values
# Processor_Brand
# Intel    2805
# AMD       897
# Apple      17
# Name: count, dtype: int64
# RAM_Expandable: 2 unique values
# RAM_Expandable
# No     2008
# Yes    1711
# Name: count, dtype: int64
# RAM_TYPE(DDR): 6 unique values
# RAM_TYPE(DDR)
# 4      2726
# 5       350
# LP5     322
# LP4     166
# 3       110
# LP3      45
# Name: count, dtype: int64
# Display_type: 2 unique values
# Display_type
# LCD    1937
# LED    1782
# Name: count, dtype: int64
# GPU_Brand: 4 unique values
# GPU_Brand
# Intel     1811
# NVIDIA    1292
# AMD        599
# Apple       17
# Name: count, dtype: int64
# Processor_Category: 18 unique values
# Processor_Category
# Intel I5          1236
# Intel I3           654
# Intel I7           626
# AMD Ryzen 5        369
# AMD Ryzen 7        261
# AMD Ryzen 3        116
# Intel Celeron       75
# Intel I9            67
# AMD A-Series        57
# Intel Pentium       56
# Intel Ultra 7       48
# AMD Ryzen 9         43
# AMD Athlon          35
# Intel Ultra 5       23
# Apple M-series      17
# AMD Other           16
# Intel Ultra 9       14
# Intel Other          6
# Name: count, dtype: int64
# Display_Tier: 2 unique values
# Display_Tier
# Small    3345
# Large     374
# Name: count, dtype: int64
# GPU_Tier: 4 unique values
# GPU_Tier
# Entry-level    2033
# Mid-end         793
# Low-end         593
# High-end        300
# Name: count, dtype: int64

# %%
df['Processor_Speed(Ghz)'].value_counts()
# Out:
# Processor_Speed(Ghz)
# 2.5    965
# 2.0    508
# 4.0    434
# 1.5    367
# 3.5    359
# 3.0    349
# 1.0    325
# 4.5    236
# 5.0    163
# 5.5     13
# Name: count, dtype: int64
