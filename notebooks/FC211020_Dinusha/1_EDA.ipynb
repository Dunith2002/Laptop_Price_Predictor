# %% [markdown]
# # **Exploratory Data Analysis**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../data/raw/laptop_data.csv')

# %%
df.shape
# Out:
# (3976, 18)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Brand', 'Name', 'Price', 'Processor_Name',
#        'Processor_Brand', 'RAM_Expandable', 'RAM', 'RAM_TYPE', 'Ghz',
#        'Display_type', 'Display', 'GPU', 'GPU_Brand', 'SSD', 'HDD', 'Adapter',
#        'Battery_Life'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0    Brand                                               Name  \
# 0           0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...
# 1           1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....
# 2           3     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...
# 3           4       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...
# 4           6  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...
#
#    Price            Processor_Name Processor_Brand     RAM_Expandable  \
# 0  22990        MediaTek Octa-core        MediaTek     Not Expandable
# 1  36289     AMD Hexa-Core Ryzen 5             AMD   12 GB Expandable
# 2  78500  Intel Core i5 (12th Gen)           Intel   32 GB Expandable
# 3  55490  Intel Core i5 (12th Gen)           Intel    8 GB Expandable
# 4  21990  Intel Core i3 (11th Gen)           Intel     Not Expandable
#
#        RAM      RAM_TYPE                 Ghz Display_type Display  \
# 0    4 GB       DDR4 RAM   2.0 Ghz Processor          LED   11.6
# 1    8 GB      DDR4 RAM    4.0 Ghz Processor          LCD   15.6
# 2   16 GB      DDR5 RAM    3.3 Ghz Processor          LCD   15.6
# 3    8 GB      DDR4 RAM    4.2 Ghz Processor          LCD   15.6
# 4  8 GB LP   LPDDR4X RAM   1.7 Ghz Processor          LCD   15.6
#
#                           GPU GPU_Brand                 SSD     HDD Adapter  \
# 0         Integrated Graphics  MediaTek   64 GB SSD Storage  No HDD      45
# 1                      Radeon       AMD  512 GB SSD Storage  No HDD      65
# 2  GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD Storage  No HDD      56
# 3                     Iris Xe     Intel  512 GB SSD Storage  No HDD      no
# 4                         UHD     Intel  512 GB SSD Storage  No HDD      45
#
#                  Battery_Life
# 0    Upto 12 Hrs Battery Life
# 1    Upto 11 Hrs Battery Life
# 2    Upto 10 Hrs Battery Life
# 3  Upto 7.30 Hrs Battery Life
# 4     Upto 8 Hrs Battery Life

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3976 entries, 0 to 3975
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       3976 non-null   int64
#  1   Brand            3976 non-null   object
#  2   Name             3976 non-null   object
#  3   Price            3976 non-null   int64
#  4   Processor_Name   3976 non-null   object
#  5   Processor_Brand  3976 non-null   object
#  6   RAM_Expandable   3976 non-null   object
#  7   RAM              3976 non-null   object
#  8   RAM_TYPE         3976 non-null   object
#  9   Ghz              3976 non-null   object
#  10  Display_type     3976 non-null   object
#  11  Display          3976 non-null   object
#  12  GPU              3968 non-null   object
#  13  GPU_Brand        3972 non-null   object
#  14  SSD              3976 non-null   object
#  15  HDD              3976 non-null   object
#  16  Adapter          3976 non-null   object
#  17  Battery_Life     3558 non-null   object
# dtypes: int64(2), object(16)
# memory usage: 559.3+ KB

# %%
print("Null value counts\n")
df.isnull().sum()
# Out:
# Null value counts
# Unnamed: 0           0
# Brand                0
# Name                 0
# Price                0
# Processor_Name       0
# Processor_Brand      0
# RAM_Expandable       0
# RAM                  0
# RAM_TYPE             0
# Ghz                  0
# Display_type         0
# Display              0
# GPU                  8
# GPU_Brand            4
# SSD                  0
# HDD                  0
# Adapter              0
# Battery_Life       418
# dtype: int64

# %%
df = df.drop(['Unnamed: 0', 'Name'], axis=1)

# %%
print(f"Duplicated rows count: {df.duplicated().sum()}")
df = df.drop_duplicates() #Remove duplicates columns
# Out:
# Duplicated rows count: 27

# %%
df.describe(include='all')
# Out:
#        Brand          Price            Processor_Name Processor_Brand  \
# count   3949    3949.000000                      3949            3949
# unique    31            NaN                       125              19
# top     ASUS            NaN  Intel Core i5 (11th Gen)           Intel
# freq     976            NaN                       316            2986
# mean     NaN   72437.915422                       NaN             NaN
# std      NaN   52285.617467                       NaN             NaN
# min      NaN    7990.000000                       NaN             NaN
# 25%      NaN   39853.000000                       NaN             NaN
# 50%      NaN   58990.000000                       NaN             NaN
# 75%      NaN   84990.000000                       NaN             NaN
# max      NaN  503890.000000                       NaN             NaN
#
#         RAM_Expandable    RAM   RAM_TYPE                 Ghz Display_type  \
# count             3949   3949       3949                3949         3949
# unique              10     20         19                  31            2
# top     Not Expandable  8 GB    DDR4 RAM   4.2 Ghz Processor          LCD
# freq              2141   1601       1495                 330         2016
# mean               NaN    NaN        NaN                 NaN          NaN
# std                NaN    NaN        NaN                 NaN          NaN
# min                NaN    NaN        NaN                 NaN          NaN
# 25%                NaN    NaN        NaN                 NaN          NaN
# 50%                NaN    NaN        NaN                 NaN          NaN
# 75%                NaN    NaN        NaN                 NaN          NaN
# max                NaN    NaN        NaN                 NaN          NaN
#
#        Display   GPU GPU_Brand                 SSD     HDD Adapter  \
# count     3949  3941      3945                3949    3949    3949
# unique      34   300        11                  19       8      68
# top      15.6    UHD     Intel  512 GB SSD Storage  No HDD      65
# freq      2189   644      1922                1915    2993    1451
# mean       NaN   NaN       NaN                 NaN     NaN     NaN
# std        NaN   NaN       NaN                 NaN     NaN     NaN
# min        NaN   NaN       NaN                 NaN     NaN     NaN
# 25%        NaN   NaN       NaN                 NaN     NaN     NaN
# 50%        NaN   NaN       NaN                 NaN     NaN     NaN
# 75%        NaN   NaN       NaN                 NaN     NaN     NaN
# max        NaN   NaN       NaN                 NaN     NaN     NaN
#
#        Battery_Life
# count          3531
# unique          191
# top     65W Adapter
# freq            799
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %%
df.dtypes #Explain data types
# Out:
# Brand              object
# Price               int64
# Processor_Name     object
# Processor_Brand    object
# RAM_Expandable     object
# RAM                object
# RAM_TYPE           object
# Ghz                object
# Display_type       object
# Display            object
# GPU                object
# GPU_Brand          object
# SSD                object
# HDD                object
# Adapter            object
# Battery_Life       object
# dtype: object

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Price'], kde=True)
plt.title('Laptop Price Distribution')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #####  **Visualization of each column**

# %% [markdown]
# ##### *1. Visualization of Brand*

# %%
print(f"Number of unique Brands: {df['Brand'].nunique()}\n") 
print(f"Unique Values: {df['Brand'].unique()}\n")
print(f"Value count for each unique Brand type: {df['Brand'].value_counts()}")

plt.figure(figsize=(10,10))
sns.countplot(x='Brand',data=df, palette='Set2')
plt.title("Laptop Brand Distribution")
plt.xticks(rotation=90)
plt.show()
# Out:
# Number of unique Brands: 31
#
# Unique Values: ['HP' 'Lenovo' 'Dell' 'Infinix' 'Acer' 'ASUS' 'Tecno' 'Xiaomi' 'MSI'
#  'Samsung' 'Apple' 'Realme' 'AVITA' 'Zebronics' 'Honor' 'Fujitsu' 'Wings'
#  'LG' 'Gigabyte' 'Microsoft' 'Razer' 'Coconics' 'Huawei' 'Micromax'
#  'iball' 'Lava' 'VAIO' 'Smartron' 'Colorful' 'Nokia' 'RDP']
#
# Value count for each unique Brand type: Brand
# ASUS         976
# Lenovo       808
# HP           799
# Dell         420
# Acer         317
# MSI          316
# Samsung       61
# Apple         48
# Infinix       39
# Microsoft     33
# AVITA         23
# Gigabyte      17
# LG            15
# Honor         14
# iball         11
# Xiaomi        10
# Fujitsu        8
# Zebronics      8
# Wings          4
# Colorful       3
# Realme         3
# Micromax       3
# Coconics       3
# Tecno          2
# Smartron       2
# Huawei         1
# Razer          1
# VAIO           1
# Lava           1
# Nokia          1
# RDP            1
# Name: count, dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_2988\2657073020.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Brand',data=df, palette='Set2')

# %% [markdown]
# ##### *2. Visualization of Processor Brand*

# %%
print(f"Number of unique processor brands: {df['Processor_Brand'].nunique()}\n")
print(f"Unique Values: {df['Processor_Brand'].unique()}\n")
print(f"Value count for each unique processor brand type: {df['Processor_Brand'].value_counts()}")

plt.figure(figsize=(10,10))
sns.countplot(x='Processor_Brand',data=df, palette='Set2')
plt.title("Processor brand Distribution")
plt.xticks(rotation=90)
plt.show()
# Out:
# Number of unique processor brands: 19
#
# Unique Values: ['MediaTek' 'AMD' 'Intel' 'Apple' '2.3' '3.4' 'Qualcomm' '3.3' '1.6' '2.4'
#  '3.0' '2.2' '1.7' '2.0' '2.1' '1.8' 'Microsoft' '1.9' '2.6']
#
# Value count for each unique processor brand type: Processor_Brand
# Intel        2986
# AMD           916
# Apple          20
# MediaTek        4
# 1.7             4
# 2.4             2
# 3.4             2
# 2.0             2
# 2.1             2
# 3.0             2
# Qualcomm        1
# 3.3             1
# 1.6             1
# 2.3             1
# 2.2             1
# 1.8             1
# Microsoft       1
# 1.9             1
# 2.6             1
# Name: count, dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_2988\1454627382.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Processor_Brand',data=df, palette='Set2')

# %% [markdown]
# Include both string and numerical values

# %% [markdown]
# ##### *3. Visualization of RAM*

# %%
print(f"Number of unique RAM sizes: {df['RAM'].nunique()}\n")
print(f"Unique Values: {df['RAM'].unique()}\n")
print(f"Value count for each unique RAM sizes: {df['RAM'].value_counts()}")


plt.figure(figsize=(15, 6))
sns.countplot(data=df, x='RAM', hue='RAM', palette='Set2')
plt.xticks(rotation=90)
plt.title("RAM Size Distribution")
plt.show()
# Out:
# Number of unique RAM sizes: 20
#
# Unique Values: ['4 GB ' '8 GB ' '16 GB ' '8 GB LP' '16 GB LP' '4 GB LP' '32 GB LP'
#  '8 GB RAM' '16 GB RAM ' '32 GB ' '16 GB RAM' '18 GB RAM' '32 GB RAM'
#  '64 GB ' '12 GB ' '36 GB RAM' '2 GB ' '24 GB ' '6 GB ' '3 GB ']
#
# Value count for each unique RAM sizes: RAM
# 8 GB          1601
# 16 GB         1077
# 4 GB           544
# 16 GB LP       297
# 8 GB LP        178
# 32 GB           88
# 32 GB LP        48
# 4 GB LP         36
# 2 GB            24
# 16 GB RAM       16
# 8 GB RAM        14
# 64 GB            6
# 12 GB            6
# 16 GB RAM        5
# 32 GB RAM        3
# 3 GB             2
# 18 GB RAM        1
# 36 GB RAM        1
# 24 GB            1
# 6 GB             1
# Name: count, dtype: int64

# %% [markdown]
# ##### *4.Visualization of RAM types*

# %%
print(f"Number of unique RAM types: {df['RAM_TYPE'].nunique()}\n")
print(f"Unique Values: {df['RAM_TYPE'].unique()}\n")
print(f"Value count for each unique RAM type: {df['RAM_TYPE'].value_counts()}")


plt.figure(figsize=(7,7))
sns.countplot(x='RAM_TYPE',data=df, palette='Set2')
plt.title("RAM Type Distribution")
plt.xticks(rotation=90)
plt.show()
# Out:
# Number of unique RAM types: 19
#
# Unique Values: [' DDR4 RAM' ' DDR4 RAM ' ' DDR5 RAM ' ' LPDDR4X RAM' ' LPDDR5X RAM '
#  ' LPDDR5 RAM' ' LPDDR4 RAM' ' DDR5 RAM' ' LPDDR5X RAM' ' LPDDR5 RAM '
#  ' LPDDR4X RAM ' ' LPDDR3 RAM' ' RAM' ' RAM ' ' LPDDR4 RAM ' ' DDR3 RAM'
#  ' DDR3 RAM ' ' LPDDR3 RAM ' ' DDR2 RAM']
#
# Value count for each unique RAM type: RAM_TYPE
# DDR4 RAM        1495
# DDR4 RAM        1311
# DDR5 RAM         244
# DDR5 RAM         144
# LPDDR5 RAM       140
# LPDDR4X RAM      121
# LPDDR5 RAM        97
# DDR3 RAM          87
# DDR3 RAM          68
# LPDDR3 RAM        48
# LPDDR5X RAM       42
# LPDDR4X RAM       37
# LPDDR5X RAM       36
# RAM               35
# LPDDR4 RAM        28
# LPDDR4 RAM         8
# RAM                5
# LPDDR3 RAM         2
# DDR2 RAM           1
# Name: count, dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_2988\4131829469.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='RAM_TYPE',data=df, palette='Set2')

# %% [markdown]
# * There is 19 unique values but they are acually not unique .There are some same values unique names with different spaces. so there are only 9 actual unique values.
#
#         DDR4 RAM, DDR3 RAM, DDR5 RAM, DDR2, LPDDR3, LPDDR4, LPDDR5, LPDDR4X, LPDDR5X
#
# * There are some values without RAM type('RAM')

# %% [markdown]
# ##### *5. Visualization Ram Expandable column*

# %%
print(f"Number of unique RAM Expandable sizes: {df['RAM_Expandable'].nunique()}\n")
print(f"Unique Values: {df['RAM_Expandable'].unique()}\n")
print(f"Value count for each unique RAM expandable sizes: {df['RAM_Expandable'].value_counts()}")


plt.figure(figsize=(7,7))
sns.countplot(x='RAM_Expandable',data=df, palette='Set2')
plt.xticks(rotation=90)
plt.title("RAM Expandable sizes Distribution")
plt.show()
# Out:
# Number of unique RAM Expandable sizes: 10
#
# Unique Values: ['Not Expandable' ' 12 GB Expandable' ' 32 GB Expandable'
#  ' 8 GB Expandable' ' 16 GB Expandable' ' 4 GB Expandable'
#  ' 64 GB Expandable' ' 48 GB Expandable' ' 2 GB Expandable'
#  ' 10 GB Expandable']
#
# Value count for each unique RAM expandable sizes: RAM_Expandable
# Not Expandable       2141
#  16 GB Expandable     752
#  32 GB Expandable     535
#  8 GB Expandable      185
#  64 GB Expandable     158
#  12 GB Expandable     157
#  4 GB Expandable        9
#  48 GB Expandable       9
#  2 GB Expandable        2
#  10 GB Expandable       1
# Name: count, dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_2988\3874031958.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='RAM_Expandable',data=df, palette='Set2')

# %% [markdown]
# ##### *6. Visualization of Display type*

# %%
print(f"Number of unique Display types: {df['Display_type'].nunique()}\n")
print(f"Unique Values: {df['Display_type'].unique()}\n")
print(f"Value count for each unique Display type: {df['Display_type'].value_counts()}")

sns.countplot(x='Display_type',data=df, palette='Set2')
plt.title("Display Type Distribution")
plt.show()
# Out:
# Number of unique Display types: 2
#
# Unique Values: ['LED' 'LCD']
#
# Value count for each unique Display type: Display_type
# LCD    2016
# LED    1933
# Name: count, dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_2988\1368649046.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Display_type',data=df, palette='Set2')

# %% [markdown]
# ##### *7. Visualization of processor speed*

# %%
print(f"Number of unique Processor speed values: {df['Ghz'].nunique()}\n")
print(f"Unique Values: {df['Ghz'].unique()}\n")
print(f"Value count for each unique Processor speeds: {df['Ghz'].value_counts()}")

plt.figure(figsize=(10,10))
sns.countplot(x='Ghz',data=df, palette='Set2')
plt.title("Processor speed Distribution")
plt.xticks(rotation=90)
plt.show()
# Out:
# Number of unique Processor speed values: 31
#
# Unique Values: [' 2.0 Ghz Processor' ' 4.0 Ghz Processor' ' 3.3 Ghz Processor'
#  ' 4.2 Ghz Processor' ' 1.7 Ghz Processor' '0' ' 2.5 Ghz Processor'
#  ' 2.2 Ghz Processor' ' 2.9 Ghz Processor' ' 3.4 Ghz Processor'
#  ' 2.6 Ghz Processor' ' 3.0 Ghz Processor' ' 4.7 Ghz Processor'
#  ' 3.1 Ghz Processor' ' 2.7 Ghz Processor' ' 2.8 Ghz Processor'
#  ' 2.4 Ghz Processor' ' 2.1 Ghz Processor' ' 4.8 Ghz Processor'
#  ' 1.2 Ghz Processor' ' 1.0 Ghz Processor' ' 1.8 Ghz Processor'
#  ' 1.1 Ghz Processor' ' 2.3 Ghz Processor' ' 1.6 Ghz Processor'
#  ' 0.8 Ghz Processor' ' 1.3 Ghz Processor' ' 1.5 Ghz Processor'
#  ' 1.9 Ghz Processor' ' 5.5 Ghz Processor' ' 1.4 Ghz Processor']
#
# Value count for each unique Processor speeds: Ghz
#  4.2 Ghz Processor    330
#  2.4 Ghz Processor    251
#  4.7 Ghz Processor    243
#  1.6 Ghz Processor    233
# 0                     220
#  2.3 Ghz Processor    210
#  3.3 Ghz Processor    196
#  4.8 Ghz Processor    182
#  2.6 Ghz Processor    177
#  2.1 Ghz Processor    176
#  2.5 Ghz Processor    164
#  2.0 Ghz Processor    163
#  1.2 Ghz Processor    146
#  3.0 Ghz Processor    138
#  3.4 Ghz Processor    137
#  1.1 Ghz Processor    109
#  4.0 Ghz Processor    106
#  1.8 Ghz Processor    100
#  2.2 Ghz Processor     96
#  2.8 Ghz Processor     89
#  1.0 Ghz Processor     84
#  3.1 Ghz Processor     80
#  1.7 Ghz Processor     73
#  2.7 Ghz Processor     56
#  1.3 Ghz Processor     48
#  2.9 Ghz Processor     34
#  1.4 Ghz Processor     31
#  1.5 Ghz Processor     24
#  0.8 Ghz Processor     20
#  5.5 Ghz Processor     17
#  1.9 Ghz Processor     16
# Name: count, dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_2988\867873960.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Ghz',data=df, palette='Set2')

# %% [markdown]
# ##### *8. Visualization of Display sizes*

# %%
print(f"Number of unique Display sizes: {df['Display'].nunique()}\n")
print(f"Unique Values: {df['Display'].unique()}\n")
print(f"Value count for each unique Display sizes: {df['Display'].value_counts()}")

plt.figure(figsize=(10,10))
sns.countplot(x='Display',data=df, palette='Set2')
plt.title("Processor speed Distribution")
plt.xticks(rotation=90)
plt.show()
# Out:
# Number of unique Display sizes: 34
#
# Unique Values: ['11.6 ' '15.6 ' '14 ' '16 ' '17.3 ' '13.3 ' '16.1 ' '13.6 ' '14.2 '
#  '14.1 ' '15.3 ' '13.4 ' '15 ' '10.5 ' '13.5 ' '13 ' '12.4 ' '16.2 '
#  'OLED Display With Touchscreen' '14.0 ' '17 ' '18 ' '14.5 ' '12 ' '10.1 '
#  '15. ' '14.9 ' '11 ' '12.3 ' '16.6 ' '12.2 ' '12.5 ' '15.4 ' '12.0 ']
#
# Value count for each unique Display sizes: Display
# 15.6                             2189
# 14                                991
# 16                                227
# 13.3                              162
# 17.3                               99
# 16.1                               63
# 11.6                               41
# 15                                 23
# 13.4                               19
# 13                                 16
# 13.5                               15
# 17                                 13
# 14.1                               12
# 14.0                                9
# 12.3                                8
# 10.1                                8
# 15.3                                7
# 14.5                                6
# 18                                  6
# 14.2                                5
# 12.4                                5
# 16.2                                5
# 15.4                                3
# 13.6                                3
# 15.                                 3
# 12.2                                2
# 12                                  2
# 10.5                                1
# OLED Display With Touchscreen       1
# 14.9                                1
# 16.6                                1
# 11                                  1
# 12.5                                1
# 12.0                                1
# Name: count, dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_2988\3078500943.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Display',data=df, palette='Set2')

# %% [markdown]
# ##### *9. Visualization of GPU*

# %%
print(f"Number of unique GPUs: {df['GPU'].nunique()}\n")
print(f"Unique Values: {df['GPU'].unique()}\n")
print(f"Value count for each unique GPU s: {df['GPU'].value_counts()}")
# Out:
# Number of unique GPUs: 300
#
# Unique Values: ['Integrated Graphics' 'Radeon' 'GeForce RTX 3050 GPU, 4 GB' 'Iris Xe'
#  'UHD' 'UHD 620' 'GeForce RTX 2050 GPU, 4 GB' 'GeForce RTX 4050 GPU, 6 GB'
#  'Arc' 'GeForce GTX 1650 GPU, 4 GB' 'UHD 605' 'GeForce RTX 3060 GPU, 6 GB'
#  'GeForce GTX 1650 Max Q GPU, 4 GB' 'GeForce RTX 3050 Ti GPU, 4 GB'
#  'Integrated' 'Geforce GTX 1650 GPU, 4 GB' 'Radeon Vega 3' 'UHD Graphics'
#  'UHD GPU, 128 MB' 'M1' 'HD 6000' 'UHD 600' 'Radeon Vega 6'
#  'M2 Integrated' 'HD 620' 'Geforce MX150 GPU, 2 GB' 'Radeon Vega 8'
#  'Geforce GTX 1650 Max-Q GPU, 4 GB' 'GeForce GTX 1650 Ti GPU, 4 GB'
#  'Radeon RX Vega 10' 'HD 520' 'Radeon RX 5500M GPU, 4 GB'
#  'GeForce GTX 3050 GPU, 4 GB' 'Radeon 610M' 'Radeon RX6500M GPU, 4 GB'
#  'GeForce GTX 1650 MAX Q GPU, 4 GB' 'GeForce RTX 2050' 'HD 500'
#  'Radeon Graphics' 'GeForce RTX 3070 Ti GPU, 8 GB'
#  'GeForce GTX 1050 GPU, 4 GB' 'Geforce RTX 3050 GPU, 4 GB' 'M2'
#  'Radeon RX 6500M GPU, 4 GB' 'Radeon RX 5600M GPU, 6 GB'
#  'GeForce MX450 GPU, 2 GB' 'GeForce RTX 4060 GPU, 8 GB' 'Adreno'
#  'GeForce GTX 1060 GPU, 6 GB' 'GeForce MX330 GPU, 2 GB' 'Radeon R2'
#  'Iris X' 'Radeon Vega 7' 'Radeon R4' 'Integrated UHD' 'Iris Xe Graphics'
#  'Iris Plus 655' 'GeForce RTX 3050 Ti  GPU, 4 GB'
#  'GeForce RTX 3050 GPU, 6 GB' 'GeForce MX350 GPU, 2 GB'
#  'Radeon RX 6800M GPU, 12 GB' 'Iris Plus' 'GeForce MX250 GPU, 2 GB'
#  'GeForce RTX 3070 GPU, 8 GB' 'GeForce RTX 3050 GPU, 4 ' 'Radeon R5'
#  'GeForce RTX 3050' 'MX350 GPU, 2 GB' 'GeForce MX550 GPU, 2 GB'
#  'Integrated Arm Mali' 'Integrated Iris Xe'
#  'Geforce GTX 1650 Ti GPU, 4 GB' 'Radeon 610M Vega 2' '18-core GPU'
#  'UHD Graphics 600' 'GEFORCE RTX 3050 Ti GPU, 4 GB'
#  'Radeon RX 6700S GPU, 8 GB' 'M2 Max' 'HD' 'UHD '
#  'GeForce RTX 3080 GPU, 16 GB' 'GeForce RTX 3050Ti GPU, 4 GB'
#  'GeForce MX570 GPU, 2 GB' 'GeForce 940MX GPU, 2 GB'
#  'Radeon RX 6700S GPU, 8 ' 'GeForce RTX 4080 GPU, 12 GB'
#  'GeForce GTX 1650Ti GPU, 4 GB' 'Intel Iris Xe'
#  'GeForce RTX 4070 GPU, 8 GB' 'GeForce MX250' 'GeForce RTX 2070 GPU, 8 GB'
#  'HD 615' 'GeForce MX550  GPU, 2 GB' 'GeForce N16V-GMR1 GPU, 2 GB'
#  'Arc A370M GPU, 4 GB' 'UMA' 'Radeon RX6550M GPU, 4 GB'
#  'GeForce RTX 3080 GPU, 8 GB' 'GeForce RTX 3080 Ti GPU, 16 GB'
#  'Radeon GPU, 6 GB' 'Radeon 680M GPU, 6 GB' 'GeForce RTX 4090 GPU, 16 GB'
#  'Radeon 780M' 'GeForce RTX 4060 GPU, 6 GB' nan 'Radeon 760M'
#  'GeForce RTX 4060 GPU, 8 ' 'GeForce RTX 4080 GPU, 8 GB'
#  'RTX A500 GPU, 4 GB' 'Integrated Arc' 'Radeon 680M' 'Graphics'
#  'GeForce RTX 4050 GPU, 8 GB' 'GeForce RTX 4070' 'T1200 GPU, 4 GB'
#  'GeForce RTX 2080 GPU, 8 GB' 'GeForce RTX 3070 Ti GPU, 8 '
#  'Quadro T2000  GPU, 4 GB' 'Integrated HD' 'GeForce RTX 3070 GPU, 8 '
#  'UHD Graphics 620' 'Geoforce RTX3050 GPU, 4 GB' 'Quadro T50 GPU, 4 GB'
#  'RTX 3050 Ti GPU, 4 GB' 'GeForce P620 GPU, 4 GB' 'Quadro T1200 GPU, 4 GB'
#  'UHD 617' 'Geforce MX250 GPU, 2 GB' 'GeForce GT 940MX GPU, 4 GB'
#  'Geforce GTX 1050Ti GPU, 4 GB' 'Geforce MX150 GPU, 4 GB'
#  'GeForce GTX 1050 Ti  GPU, 4 GB' 'GeForce GTX 1050Ti GPU, 4 GB'
#  'Geforce GTX 1060 GPU, 6 GB' 'Geforce GTX 1650 Ti GPU, 6 GB'
#  'Radeon RX Vega 8' 'HD 405' 'Radeon R16M-M1-30 GPU, 2 GB'
#  'GeForce GTX 1050T GPU, 4 GB' 'Radeon 520 GPU, 2 GB'
#  'GeForce MX130 GPU, 2 GB' 'HD 400' 'Radeon 530 GPU, 2 GB'
#  'Geforce GTX 1650Ti GPU, 6 GB' 'R17M-M1-70 GPU, 2 GB'
#  'Geforce MX130 GPU, 2 GB' 'GeForce MX150 GPU, 2 GB'
#  'Radeon HD 520 GPU, 2 GB' 'GeForce GTX 1660 Ti GPU, 6 GB'
#  'GeForce 920MX GPU, 2 GB' 'HD 610' 'Radeon HD 8210 GPU, 2 GB'
#  'Geforce GTX 1050Ti GPU, 8 GB' 'Radeon RX 560X GPU, 4 GB' 'HD 505'
#  'GeForce GTX 1050 GPU, 3 GB' 'Geforce GTX 1050 GPU, 3 GB' 'Radeon R3'
#  'Geforce GTX 1050 Ti GPU, 4 GB' 'Geforce RTX 2060 GPU, 6 GB'
#  'M1 Integrated' 'Geforce 940MX GPU, 4 GB' 'Geforce GTX 1660 Ti GPU, 6 GB'
#  'GeForce GTX 1050 GPU, 2 GB' 'Geforce MX350 GPU, 2 GB'
#  'GeForce MX110 GPU, 2 GB' 'Radeon Vega' 'HD 5500'
#  'GeForce GTX 1650 Ti GPU, 6 GB' 'Radeon R5 M430 GPU, 2 GB'
#  'GeForce GTX 1050 Ti GPU, 4 GB' 'Geforce MX330 GPU, 2 GB'
#  'GeForce 940MX  GPU, 4 GB' 'Geforce GTX 1050 GPU, 2 GB'
#  'Geforce RTX 2070 GPU, 8 GB' 'HD Graphics' 'GeForce GPU, 2 GB'
#  'Radeon R5 M430  GPU, 2 GB' 'Radeon RX 5500M'
#  'Radeon RX 6500M  GPU, 4 GB' 'RTX 3050 GPU, 4 GB' 'Radeon Vega 8 Mobile'
#  'GeForce RTX 1650 GPU, 4 GB' 'GeForce MX 450 GPU, 2 GB' 'GeForce MX550'
#  'M2 Pro' 'Geforce RTX 2060 with Max-Q Design GPU, 6 GB'
#  'Geforce MX230 GPU, 2 GB' 'Radeon Athlon 3000G'
#  'Radeon RX 6600M GPU, 8 GB' 'Radeon RX6700M'
#  'GeForce RTX 3070 GPU, 16 GB' 'Arc A530M GPU, 4 GB'
#  'Quadro T550 GPU, 4 GB' 'UHD GPU, 2 GB' 'Integrated GPU, 512 MB'
#  'Radeon RX 6650M GPU, 8 GB' 'GeForce RTX 3060 GPU GPU, 6 GB'
#  'GeForce RTX 3060 GPU, 6 ' 'Quadro T600 GPU, 4 GB'
#  'GeForce GTX 1070 GPU, 8 GB' 'Radeon RX 7600S GPU, 8 GB'
#  'GeForce RTX 4080 GPU, 16 GB' 'RTX 3000 Ada GPU, 8 GB'
#  'RTX A1000 GPU, 6 GB' 'GeForce MX 350 GPU, 2 GB' 'GeForce MX550 GPU, 2 '
#  'GeForce RTX A2000 GPU, 8 GB' 'MX450 GPU, 2 GB' 'Mali-G72'
#  'Geforce MX110 GPU, 2 GB' 'T600 GPU, 4 GB' 'GeForce MX230 GPU, 2 GB'
#  'Geforce 940MX GPU, 2 GB' 'GeForce GTX 940MX GPU, 4 GB' 'Radeon R7'
#  'Radeon R4 ' 'GeForce MX150 GPU, 4 GB' 'Geforce GTX 1650 Ti` GPU, 4 GB'
#  'Radeon R5 M430 GPU, 4 GB' 'Iris Pro' 'GeForce GT 940MX GPU, 2 GB'
#  'GeForce RTX 2060 GPU, 6 GB' 'Geforce MX 150 GPU, 2 GB'
#  'Radeon 530 GPU, 4 GB' 'GeForce GTX 1650 Ti Max Q GPU, 4 GB'
#  'GeForce RTX 3060 GPU, 4 GB' 'GeForce 820M GPU, 2 GB'
#  'GeForce 940MX GPU, 4 GB' 'Radeon R7 M260 GPU, 2 GB'
#  'Geforce GTX 1650 Ti with Max-Q GPU, 4 GB' 'GeForce GTX 940MX GPU, 2 GB'
#  'Geforce GTX 1650Ti GPU, 4 GB' 'GeForce GTX 960M GPU, 2 GB'
#  'Geforce GT 820M GPU, 2 GB' 'R5 M230 GPU, 2 GB'
#  'GeForce MX150  GPU, 2 GB' 'Geforce GTX 1050 GPU, 4 GB' 'GeForce 920M'
#  'HD 515' 'Iris Plus Graphics 645' 'Iris Plus 640'
#  'Radeon Pro 5500M GPU, 4 GB' 'GeForce GTX 1050  GPU, 2 GB'
#  'GeForce GTX 960M GPU, 4 GB' 'HD 5300' 'UHD 605 ' 'Radeon RX Vega 6'
#  'Iris Plus Graphics 655' 'HD ' 'Radeon R7 M440 GPU, 2 GB'
#  'Geforce 940M GPU, 2 GB' 'GeForce 930M GPU, 2 GB'
#  'GeForce 920M GPU, 2 GB' 'Iris graphics' 'Radeon HD 8570M GPU, 2 GB' 'R5'
#  'Radeon Pro 450 GPU, 2 GB' 'Radeon HD 8670M GPU, 2 GB'
#  'GeForce 840M GPU, 2 GB' 'HD 4400' 'Radeon HD R7 M265 GPU, 2 GB'
#  'GeForce 830M GPU, 2 GB' 'Radeon HD 8670M GPU, 1 GB' 'HD 4000'
#  'GeForce 940M GPU, 4 GB' 'GeForce 930MX GPU, 2 GB'
#  'GeForce GT 740M GPU, 2 GB' 'GeForce GTX 850M GPU, 4 GB'
#  'GeForce GT 820M GPU, 1 GB' 'Radeon RX 580 GPU, 4 GB'
#  'Pro 555X GPU, 4 GB' 'Iris Xe Max GPU, 4 GB'
#  'GeForce GTX 1050TI GPU, 4 GB' 'GeForce 920MX  GPU, 2 GB'
#  'GeForce 1650 Ti GPU, 4 GB' 'GeForce 940 MX GPU, 2 GB'
#  'SQ1 Adreno 685 GPU' 'Geforce GTX 860M GPU, 2 GB' 'Iris Xe GPU, 4 GB'
#  'GeForce MX130 GPU, 4 GB' 'GeForce RTX 2060 GPU, 8 GB'
#  'GeForce RTX A1000 GPU, 4 GB' 'Geforce GTX 1070 GPU, 8 GB'
#  'Geforce RTX 2070 Super GPU, 8 GB' 'Radeon R5 M330 GPU, 2 GB'
#  'HD Graphics 620' 'Radeon 535 GPU, 2 GB' 'GeForce GTX 1660 GPU, 6 GB'
#  'Geforce GT 940MX GPU, 2 GB' 'Geforce GTX MX330 GPU, 2 GB'
#  'Geforce RTX 2080 with Max-Q GPU, 8 GB' 'Radeon RX640 GPU, 2 GB'
#  'Radeon RX 640 GPU, 2 GB' 'Radeon RX Vega 5' 'Geforce RTX 2080 GPU, 8 GB'
#  'Radeon RX Vega 7 ' 'EXO PRO R5 M330 GPU, 2 GB' 'GeForce MX230'
#  'Geforce Gt 940MX GPU, 2 GB' 'Geforce RTX 2080 Super GPU, 8 GB']
#
# Value count for each unique GPU s: GPU
# UHD                           644
# Iris Xe                       571
# Radeon                        313
# GeForce RTX 3050 GPU, 4 GB    200
# Integrated                    155
#                              ...
# Radeon RX Vega 5                1
# Radeon RX Vega 7                1
# EXO PRO R5 M330 GPU, 2 GB       1
# GeForce MX230                   1
# Geforce Gt 940MX GPU, 2 GB      1
# Name: count, Length: 300, dtype: int64

# %% [markdown]
# * Hard to visualize beacuse there are 300 unique values

# %% [markdown]
# ##### *10. Visualization of GPU Brand*

# %%
print(f"Number of unique GPUs: {df['GPU_Brand'].nunique()}\n")
print(f"Unique Values: {df['GPU_Brand'].unique()}\n")
print(f"Value count for each unique GPU brandss: {df['GPU_Brand'].value_counts()}")

plt.figure(figsize=(10,10))
sns.countplot(x='GPU_Brand',data=df, palette='Set2')
plt.title("GPU Brands Distribution")
plt.xticks(rotation=90)
plt.show()
# Out:
# Number of unique GPUs: 11
#
# Unique Values: ['MediaTek' 'AMD' 'NVIDIA' 'Intel' 'Apple' 'Qualcomm' 'NIVIDIA' 'Nvidia'
#  'ARM' nan 'Microsoft' 'ATI']
#
# Value count for each unique GPU brandss: GPU_Brand
# Intel        1922
# NVIDIA       1370
# AMD           616
# Apple          21
# Nvidia          8
# MediaTek        3
# Qualcomm        1
# NIVIDIA         1
# ARM             1
# Microsoft       1
# ATI             1
# Name: count, dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_2988\3032397825.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='GPU_Brand',data=df, palette='Set2')

# %% [markdown]
# ##### *11. Visualization of SSD*

# %%
print(f"Number of unique SSDs: {df['SSD'].nunique()}\n")
print(f"Unique Values: {df['SSD'].unique()}\n")
print(f"Value count for each unique SSDs: {df['SSD'].value_counts()}")

plt.figure(figsize=(10,10))
sns.countplot(x='SSD',data=df, palette='Set2')
plt.title("SSD Distribution")
plt.xticks(rotation=90)
plt.show()
# Out:
# Number of unique SSDs: 19
#
# Unique Values: ['64 GB SSD Storage' '512 GB SSD Storage' 'NO SSD' '1024 GB SSD Storage'
#  '256 GB SSD Storage' '256 GB SSD Storage ' '128 GB SSD Storage'
#  '128 GB SSD Storage ' '512 GB SSD Storage ' '512  SSD Storage'
#  '2048 GB SSD Storage' '1 GB SSD Storage' '8 GB SSD Storage '
#  '16 GB SSD Storage ' '32 GB SSD Storage' '16 GB SSD Storage'
#  '256  SSD Storage ' '4098 GB SSD Storage' '32 GB SSD Storage ']
#
# Value count for each unique SSDs: SSD
# 512 GB SSD Storage     1915
# NO SSD                  662
# 1024 GB SSD Storage     589
# 256 GB SSD Storage      353
# 256 GB SSD Storage      201
# 128 GB SSD Storage       57
# 128 GB SSD Storage       48
# 2048 GB SSD Storage      34
# 32 GB SSD Storage        25
# 64 GB SSD Storage        23
# 512 GB SSD Storage       16
# 16 GB SSD Storage        12
# 8 GB SSD Storage          5
# 512  SSD Storage          2
# 16 GB SSD Storage         2
# 256  SSD Storage          2
# 1 GB SSD Storage          1
# 4098 GB SSD Storage       1
# 32 GB SSD Storage         1
# Name: count, dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_2988\2472465190.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='SSD',data=df, palette='Set2')

# %% [markdown]
# ##### *12. Visualization of HDD*

# %%
print(f"Number of unique HDDs: {df['HDD'].nunique()}\n")
print(f"Unique Values: {df['HDD'].unique()}\n")
print(f"Value count for each unique HDDs: {df['HDD'].value_counts()}")

plt.figure(figsize=(10,10))
sns.countplot(x='HDD',data=df, palette='Set2')
plt.title("HDD Distribution")
plt.xticks(rotation=90)
plt.show()
# Out:
# Number of unique HDDs: 8
#
# Unique Values: ['No HDD' '1024 GB HDD Storage' ' 1024 GB HDD Storage'
#  '2048 GB HDD Storage' '500 GB HDD Storage' ' 2048 GB HDD Storage'
#  ' 500 GB HDD Storage' '1 GB HDD Storage']
#
# Value count for each unique HDDs: HDD
# No HDD                  2993
# 1024 GB HDD Storage      601
#  1024 GB HDD Storage     290
# 500 GB HDD Storage        42
# 2048 GB HDD Storage       18
#  500 GB HDD Storage        3
#  2048 GB HDD Storage       1
# 1 GB HDD Storage           1
# Name: count, dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_2988\3161223420.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='HDD',data=df, palette='Set2')

# %% [markdown]
# ##### *13. Visualization of Adapter Column*

# %%
print(f"Number of unique Adapters: {df['Adapter'].nunique()}\n")
print(f"Unique Values: {df['Adapter'].unique()}\n")
print(f"Value count for each unique Adapters: {df['Adapter'].value_counts()}")
# Out:
# Number of unique Adapters: 68
#
# Unique Values: ['45' '65' '56' 'no' '150' '170' '230' '135' '41' '100' '90' '120' '96'
#  '180' '63' '30' '54' '33' '46' '67' '57' '43' '48' '70' '37' '24' '42'
#  '330' '200' '58' '240' '50' '280' '60' '80' '35' '51' '61' '76' '38' '86'
#  '66' '210' '39' '97' '140' '83' '59' '53' '71' '75' '74' '49' '300' '68'
#  '52' '40' '36' '32' '15' '26' '47' '64' '130' '87' '72' '95' '69']
#
# Value count for each unique Adapters: Adapter
# 65     1451
# no      775
# 45      458
# 41      156
# 150      90
#        ...
# 97        1
# 15        1
# 47        1
# 26        1
# 69        1
# Name: count, Length: 68, dtype: int64

# %% [markdown]
# ##### *14. Visualization of Batter life column*

# %%
print(f"Number of unique Battery life: {df['Battery_Life'].nunique()}\n")
print(f"Unique Values: {df['Battery_Life'].unique()}\n")
print(f"Value count for each unique Battery life values: {df['Battery_Life'].value_counts()}")
# Out:
# Number of unique Battery life: 191
#
# Unique Values: [' Upto 12 Hrs Battery Life' ' Upto 11 Hrs Battery Life'
#  ' Upto 10 Hrs Battery Life' 'Upto 7.30 Hrs Battery Life'
#  ' Upto 8 Hrs Battery Life' '45W Adapter' ' Upto 9 Hrs Battery Life'
#  '150W Adapter' ' Upto 9.5 Hrs Battery Life' ' Upto 7 Hrs Battery Life'
#  '230W Adapter' ' Upto 9.45 Hrs Battery Life' 'Upto 7 Hrs Battery Life'
#  ' Upto 6 Hrs Battery Life' ' Upto 17.5 Hrs Battery Life' '135W Adapter'
#  'Upto 6.5 Hrs Battery Life' nan '65W Adapter' 'Upto 5 Hrs Battery Life'
#  'Upto 10 Hrs Battery Life' ' Upto 4 Hrs Battery Life'
#  ' Upto 6.5 Hrs Battery Life' ' Upto 5 Hrs Battery Life' '90W Adapter'
#  ' Upto 21 Hrs Battery Life' 'Upto 6 Hrs Battery Life'
#  ' Upto 14.7 Hrs Battery Life' ' Upto 13 Hrs Battery Life' '52.5W Adapter'
#  '180W Adapter' '41W Adapter' '45 / 65W Adapter'
#  ' Upto 15 Hrs Battery Life' '120W Adapter' ' Upto 18 Hrs Battery Life'
#  ' Upto 9.15 Hrs Battery Life' ' Upto 11.5 Hrs Battery Life'
#  'Upto 8 Hrs Battery Life' '36.7W Adapter' 'Upto 12 Hrs Battery Life'
#  ' Upto 8.5 Hrs Battery Life' '46W Adapter' ' Upto 17 Hrs Battery Life'
#  ' Upto 7.15 Hrs Battery Life' '43W Adapter' '70W Adapter'
#  ' Upto 9.50 Hrs Battery Life' ' Upto 10.15 Hrs Battery Life'
#  ' Upto 14 Hrs Battery Life' ' Upto 7.5 Hrs Battery Life'
#  ' Upto 20 Hrs Battery Life' '100W Adapter' ' Upto 9.2 Hrs Battery Life'
#  ' Upto 13.2 Hrs Battery Life' '42W Adapter' 'Upto 4.5 Hrs Battery Life'
#  ' Upto 3 Hrs Battery Life' ' Upto 6.7 Hrs Battery Life'
#  ' Upto 5.32 Hrs Battery Life' '240W Adapter' '200W Adapter'
#  ' Upto 4.5 Hrs Battery Life' '57.5W Adapter' '280W Adapter' '60W Adapter'
#  ' Upto 15.5 Hrs Battery Life' '80W Adapter' ' Upto 10.8 Hrs Battery Life'
#  '51W Adapter' '63W Adapter' ' Upto 22 Hrs Battery Life'
#  ' Upto 9.29 Hrs Battery Life' '61W Adapter' '48W Adapter' '330W Adapter'
#  ' Upto 8.45 Hrs Battery Life' ' Upto 19 Hrs Battery Life'
#  ' Upto 11.9 Hrs Battery Life' '56W Adapter' 'Upto 11 Hrs Battery Life'
#  ' Upto 9.4 Hrs Battery Life' 'Upto 5.5 Hrs Battery Life'
#  ' Upto 12.8 Hrs Battery Life' '38W Adapter'
#  ' Upto 13.30 Hrs Battery Life' '86W Adapter' '30W Adapter' '67W Adapter'
#  ' Upto 11.45 Hrs Battery Life' '210W Adapter' ' Upto 16 Hrs Battery Life'
#  '83W Adapter' '53W Adapter' '74W Adapter' '33W Adapter'
#  'Upto 10.15 Hrs Battery Life' ' Upto 7.45 Hrs Battery Life'
#  'Upto 9.86 Hrs Battery Life' 'Upto 8.8 Hrs Battery Life'
#  'Upto 3 Hrs Battery Life' '37W Adapter' ' Upto 12.30 Hrs Battery Life'
#  'Upto 4 Hrs Battery Life' '170W Adapter' '39W Adapter'
#  ' Upto 13.45 Hrs Battery Life' ' Upto 2.25 Hrs Battery Life'
#  ' Upto 7.30 Hrs Battery Life' ' Upto 5.5 Hrs Battery Life'
#  'Upto 6.15 Hrs Battery Life' ' Upto 6.30 Hrs Battery Life'
#  ' Upto 8.8 Hrs Battery Life' ' Upto 5.8 Hrs Battery Life' '300W Adapter'
#  ' Upto 8.7 Hrs Battery Life' ' Upto 10.4 Hrs Battery Life' '140W Adapter'
#  'Upto 13 Hrs Battery Life' ' Upto 9.3 Hrs Battery Life' '76W Adapter'
#  'Upto 14 Hrs Battery Life' '68W Adapter' '52W Adapter'
#  ' Upto 13.5 Hrs Battery Life' '35W Adapter' 'Upto 12.5 Hrs Battery Life'
#  '40W Adapter' ' Upto 10.5 Hrs Battery Life' '65wW Adapter' '36W Adapter'
#  '32W Adapter' '15W Adapter' ' Upto 15.45 Hrs Battery Life' '57W Adapter'
#  'Upto 8.5 Hrs Battery Life' '47W Adapter' ' Upto 7.8 Hrs Battery Life'
#  'Upto 5.3 Hrs Battery Life' '64W Adapter' '50W Adapter'
#  'Upto 10.5 Hrs Battery Life' '66W Adapter' ' Upto 7.1 Hrs Battery Life'
#  'Upto 7.8 Hrs Battery Life' ' Upto 9.9 Hrs Battery Life'
#  ' Upto 5.9 Hrs Battery Life' ' Upto 9.30 Hrs Battery Life'
#  'Upto 9 Hrs Battery Life' '37.24W Adapter' ' Upto 8.9 Hrs Battery Life'
#  '39.3W Adapter' ' Upto 10.30 Hrs Battery Life'
#  ' Upto 9.7 Hrs Battery Life' ' Upto 14.30 Hrs Battery Life'
#  '69.6W Adapter' ' Upto 10.9 Hrs Battery Life'
#  'Upto 10.8 Hrs Battery Life' ' Upto 16.30 Hrs Battery Life'
#  'Upto 15 Hrs Battery Life' '75W Adapter' '87W Adapter'
#  'Upto 6.30 Hrs Battery Life' 'Upto 12.38 Hrs Battery Life'
#  ' Upto 2.5 Hrs Battery Life' ' Upto 9.22 Hrs Battery Life'
#  ' Upto 13.6 Hrs Battery Life' 'Upto 9.4 Hrs Battery Life'
#  'Upto 11.15 Hrs Battery Life' '72W Adapter' ' Upto 10.7 Hrs Battery Life'
#  ' Upto 12.1 Hrs Battery Life' 'Upto 7.45 Hrs Battery Life'
#  'Upto 8.50 Hrs Battery Life' ' Upto 10.45 Hrs Battery Life'
#  ' Upto 21.5 Hrs Battery Life' 'Upto 17 Hrs Battery Life'
#  ' Upto 11.1 Hrs Battery Life' ' Upto 7.3 Hrs Battery Life' '130W Adapter'
#  'Upto 7.5 Hrs Battery Life' '56.5W Adapter' 'Upto 18.5 Hrs Battery Life'
#  ' Upto 23.5 Hrs Battery Life' '63.3W Adapter'
#  ' Upto 12.5 Hrs Battery Life' '53.6W Adapter'
#  ' Upto 3.5 Hrs Battery Life' '60.7W Adapter' '69W Adapter' '59W Adapter'
#  '71W Adapter']
#
# Value count for each unique Battery life values: Battery_Life
# 65W Adapter                    799
# 45W Adapter                    286
#  Upto 6 Hrs Battery Life       196
#  Upto 8 Hrs Battery Life       151
#  Upto 10 Hrs Battery Life      144
#                               ...
#  Upto 12.5 Hrs Battery Life      1
#  Upto 3.5 Hrs Battery Life       1
# 60.7W Adapter                    1
# 69W Adapter                      1
# 71W Adapter                      1
# Name: count, Length: 191, dtype: int64

# %% [markdown]
# ##### Comparing categorical variables against Price

# %%
#To show the plots, converting all the object data types into categorical datatypes. 
# But these datatypes can be changed in Data cleaning part.

for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].astype('category')

# %% [markdown]
# *1. Brand Vs Price*

# %%
plt.figure(figsize=(18, 6))
plt.subplot(1, 2, 1)
sns.lineplot(data=df,x='Brand',y='Price')
plt.xticks(rotation=90)
plt.title('The relationship between Brand and Price ')

plt.subplot(1, 2, 2)
sns.boxplot(data=df,x='Brand',y='Price')
plt.xticks(rotation=90)
plt.title('The relationship between Brand and Price ')
# Out:
# Text(0.5, 1.0, 'The relationship between Brand and Price ')

# %% [markdown]
# *2. Processor Brand Vs Price*

# %%
plt.figure(figsize=(18, 6))
plt.subplot(1, 2, 1)
sns.lineplot(data=df,x='Processor_Brand',y='Price')
plt.xticks(rotation=90)
plt.title('The relationship between Brand and Price ')

plt.subplot(1, 2, 2)
sns.boxplot(data=df,x='Processor_Brand',y='Price')
plt.xticks(rotation=90)
plt.title('The relationship between Processor Brand and Price ')
# Out:
# Text(0.5, 1.0, 'The relationship between Processor Brand and Price ')

# %% [markdown]
# *3. RAM Type Vs Price*

# %%
plt.figure(figsize=(18, 6))
plt.subplot(1, 2, 1)
sns.lineplot(data=df,x='RAM_TYPE',y='Price')
plt.xticks(rotation=90)
plt.title('The relationship between RAM Type and Price ')

plt.subplot(1, 2, 2)
sns.boxplot(data=df,x='RAM_TYPE',y='Price')
plt.xticks(rotation=90)
plt.title('The relationship between RAM Type and Price ')
# Out:
# Text(0.5, 1.0, 'The relationship between RAM Type and Price ')

# %% [markdown]
# *4. Display Type Vs Price*

# %%
plt.figure(figsize=(18, 6))
plt.subplot(1, 2, 1)
sns.lineplot(data=df,x='Display_type',y='Price')
plt.xticks(rotation=90)
plt.title('The relationship between Display Type and Price ')

plt.subplot(1, 2, 2)
sns.boxplot(data=df,x='Display_type',y='Price')
plt.xticks(rotation=90)
plt.title('The relationship between Display Type and Price ')
# Out:
# Text(0.5, 1.0, 'The relationship between Display Type and Price ')

# %% [markdown]
# *5. RAM Expandable size Vs Price*

# %%
plt.figure(figsize=(18, 6))
plt.subplot(1, 2, 1)
sns.lineplot(data=df,x='RAM_Expandable',y='Price')
plt.xticks(rotation=90)
plt.title('The relationship between RAM Expandable size and Price ')

plt.subplot(1, 2, 2)
sns.boxplot(data=df,x='RAM_Expandable',y='Price')
plt.xticks(rotation=90)
plt.title('The relationship between RAM Expandable size and Price ')
# Out:
# Text(0.5, 1.0, 'The relationship between RAM Expandable size and Price ')

# %% [markdown]
# *6. Processor_Speed Vs Price*

# %%
plt.figure(figsize=(16,9))
df_sorted = df.sort_values(by='Ghz')
sns.lineplot(data=df_sorted,x='Ghz',y='Price')
plt.xticks(rotation=90)
plt.title('The relationship between Processor speed and Price ')
# Out:
# Text(0.5, 1.0, 'The relationship between Processor speed and Price ')
