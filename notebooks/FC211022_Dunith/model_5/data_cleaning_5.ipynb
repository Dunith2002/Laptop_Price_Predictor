# %% [markdown]
# # Data Cleaning and Preprocessing

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('../../../data/raw/laptop_data.csv')

# %%
data.head(10)
# Out:
#    Unnamed: 0    Brand                                               Name  \
# 0           0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...
# 1           1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....
# 2           3     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...
# 3           4       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...
# 4           6  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...
# 5           7     Acer  Acer One 14 Z8-415 (UN.599SI.020) Laptop (14 I...
# 6           8       HP  HP 14s-fq1092AU (50M60PA) Laptop (14 Inch | AM...
# 7           9     Acer  Acer One 14 Z8-415 (UN.599SI.018) Laptop (14 I...
# 8          10   Lenovo  Lenovo Ideapad S145 (81VD008PIN) Laptop (15.6 ...
# 9          11     ASUS  ASUS TUF Gaming F15 FX506HF-HN075W Laptop (15....
#
#    Price                      Processor_Name Processor_Brand  \
# 0  22990                  MediaTek Octa-core        MediaTek
# 1  36289               AMD Hexa-Core Ryzen 5             AMD
# 2  78500            Intel Core i5 (12th Gen)           Intel
# 3  55490            Intel Core i5 (12th Gen)           Intel
# 4  21990            Intel Core i3 (11th Gen)           Intel
# 5  34990  Intel Core i5 (11th Gen) Processor           Intel
# 6  49599               AMD Hexa-Core Ryzen 5             AMD
# 7  39990            Intel Core i5 (11th Gen)           Intel
# 8  33111             Intel Core i3 (8th Gen)           Intel
# 9  48990            Intel Core i5 (11th Gen)           Intel
#
#       RAM_Expandable      RAM      RAM_TYPE                 Ghz Display_type  \
# 0     Not Expandable    4 GB       DDR4 RAM   2.0 Ghz Processor          LED
# 1   12 GB Expandable    8 GB      DDR4 RAM    4.0 Ghz Processor          LCD
# 2   32 GB Expandable   16 GB      DDR5 RAM    3.3 Ghz Processor          LCD
# 3    8 GB Expandable    8 GB      DDR4 RAM    4.2 Ghz Processor          LCD
# 4     Not Expandable  8 GB LP   LPDDR4X RAM   1.7 Ghz Processor          LCD
# 5   32 GB Expandable   16 GB      DDR4 RAM                    0          LCD
# 6   16 GB Expandable    8 GB      DDR4 RAM    4.0 Ghz Processor          LCD
# 7   32 GB Expandable    8 GB      DDR4 RAM    2.5 Ghz Processor          LCD
# 8   12 GB Expandable    4 GB      DDR4 RAM    2.2 Ghz Processor          LED
# 9     Not Expandable    8 GB       DDR4 RAM   2.9 Ghz Processor          LCD
#
#   Display                         GPU GPU_Brand                 SSD  \
# 0   11.6          Integrated Graphics  MediaTek   64 GB SSD Storage
# 1   15.6                       Radeon       AMD  512 GB SSD Storage
# 2   15.6   GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD Storage
# 3   15.6                      Iris Xe     Intel  512 GB SSD Storage
# 4   15.6                          UHD     Intel  512 GB SSD Storage
# 5     14                      Iris Xe     Intel  512 GB SSD Storage
# 6     14                       Radeon       AMD  512 GB SSD Storage
# 7     14                      Iris Xe     Intel  512 GB SSD Storage
# 8   15.6                      UHD 620     Intel              NO SSD
# 9   15.6   GeForce RTX 2050 GPU, 4 GB    NVIDIA  512 GB SSD Storage
#
#                    HDD Adapter                Battery_Life
# 0               No HDD      45    Upto 12 Hrs Battery Life
# 1               No HDD      65    Upto 11 Hrs Battery Life
# 2               No HDD      56    Upto 10 Hrs Battery Life
# 3               No HDD      no  Upto 7.30 Hrs Battery Life
# 4               No HDD      45     Upto 8 Hrs Battery Life
# 5               No HDD      45                 45W Adapter
# 6               No HDD      65     Upto 9 Hrs Battery Life
# 7               No HDD      45                 45W Adapter
# 8  1024 GB HDD Storage      45                 45W Adapter
# 9               No HDD     150                150W Adapter

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3976 entries, 0 to 3975
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       3976 non-null   int64
#  1   Brand            3976 non-null   object
#  2   Name             3976 non-null   object
#  3   Price            3976 non-null   int64
#  4   Processor_Name   3976 non-null   object
#  5   Processor_Brand  3976 non-null   object
#  6   RAM_Expandable   3976 non-null   object
#  7   RAM              3976 non-null   object
#  8   RAM_TYPE         3976 non-null   object
#  9   Ghz              3976 non-null   object
#  10  Display_type     3976 non-null   object
#  11  Display          3976 non-null   object
#  12  GPU              3968 non-null   object
#  13  GPU_Brand        3972 non-null   object
#  14  SSD              3976 non-null   object
#  15  HDD              3976 non-null   object
#  16  Adapter          3976 non-null   object
#  17  Battery_Life     3558 non-null   object
# dtypes: int64(2), object(16)
# memory usage: 559.3+ KB

# %%
#Creating copy of data frame
df = data.copy()

# %% [markdown]
# ### Remove unnecessary coulmns

# %%
df.shape
# Out:
# (3976, 18)

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.head()
# Out:
#      Brand                                               Name  Price  \
# 0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...  22990
# 1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  36289
# 2     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  78500
# 3       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  55490
# 4  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...  21990
#
#              Processor_Name Processor_Brand     RAM_Expandable      RAM  \
# 0        MediaTek Octa-core        MediaTek     Not Expandable    4 GB
# 1     AMD Hexa-Core Ryzen 5             AMD   12 GB Expandable    8 GB
# 2  Intel Core i5 (12th Gen)           Intel   32 GB Expandable   16 GB
# 3  Intel Core i5 (12th Gen)           Intel    8 GB Expandable    8 GB
# 4  Intel Core i3 (11th Gen)           Intel     Not Expandable  8 GB LP
#
#        RAM_TYPE                 Ghz Display_type Display  \
# 0      DDR4 RAM   2.0 Ghz Processor          LED   11.6
# 1     DDR4 RAM    4.0 Ghz Processor          LCD   15.6
# 2     DDR5 RAM    3.3 Ghz Processor          LCD   15.6
# 3     DDR4 RAM    4.2 Ghz Processor          LCD   15.6
# 4   LPDDR4X RAM   1.7 Ghz Processor          LCD   15.6
#
#                           GPU GPU_Brand                 SSD     HDD Adapter  \
# 0         Integrated Graphics  MediaTek   64 GB SSD Storage  No HDD      45
# 1                      Radeon       AMD  512 GB SSD Storage  No HDD      65
# 2  GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD Storage  No HDD      56
# 3                     Iris Xe     Intel  512 GB SSD Storage  No HDD      no
# 4                         UHD     Intel  512 GB SSD Storage  No HDD      45
#
#                  Battery_Life
# 0    Upto 12 Hrs Battery Life
# 1    Upto 11 Hrs Battery Life
# 2    Upto 10 Hrs Battery Life
# 3  Upto 7.30 Hrs Battery Life
# 4     Upto 8 Hrs Battery Life

# %%
df.shape
# Out:
# (3976, 17)

# %%
df['Brand'].value_counts()
# Out:
# Brand
# ASUS         989
# Lenovo       811
# HP           803
# Dell         420
# Acer         322
# MSI          316
# Samsung       61
# Apple         49
# Infinix       39
# Microsoft     34
# AVITA         23
# Gigabyte      17
# LG            15
# Honor         14
# iball         11
# Xiaomi        10
# Fujitsu        8
# Zebronics      8
# Wings          4
# Colorful       3
# Realme         3
# Micromax       3
# Coconics       3
# Tecno          2
# Smartron       2
# Huawei         1
# Razer          1
# VAIO           1
# Lava           1
# Nokia          1
# RDP            1
# Name: count, dtype: int64

# %% [markdown]
# ### Drop Duplicate Rows

# %%
df[df.duplicated()]
# Out:
#        Brand                                               Name  Price  \
# 2867  Lenovo  Lenovo Ideapad 3 15ITL6 (82H801L7IN) Laptop (1...  33900
# 3018      HP  HP 15s-du1044tu (18N71PA) Laptop (15.6 Inch | ...  22071
# 3104    Acer  Acer Aspire 5 A514-53 (NX.HZ6SI.001) Laptop (1...  27775
# 3321  Lenovo  Lenovo Ideapad Gaming 3 15ACH6 (82K200X3IN) La...  81990
#
#                 Processor_Name Processor_Brand     RAM_Expandable     RAM  \
# 2867  Intel Core i3 (11th Gen)           Intel   12 GB Expandable   8 GB
# 3018   Intel Celeron Dual-Core           Intel     Not Expandable   4 GB
# 3104  Intel Core i3 (10th Gen)           Intel   12 GB Expandable   4 GB
# 3321     AMD Octa-Core Ryzen 7             AMD   16 GB Expandable  16 GB
#
#         RAM_TYPE                 Ghz Display_type Display  \
# 2867   DDR4 RAM    4.0 Ghz Processor          LCD   15.6
# 3018    DDR4 RAM   1.1 Ghz Processor          LED   15.6
# 3104   DDR4 RAM    1.2 Ghz Processor          LED     14
# 3321   DDR4 RAM    3.1 Ghz Processor          LCD   15.6
#
#                              GPU GPU_Brand                 SSD  \
# 2867                         UHD     Intel  512 GB SSD Storage
# 3018                     UHD 600     Intel              NO SSD
# 3104                         UHD     Intel  512 GB SSD Storage
# 3321  GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD Storage
#
#                       HDD Adapter               Battery_Life
# 2867               No HDD      45   Upto 12 Hrs Battery Life
# 3018  1024 GB HDD Storage      46                46W Adapter
# 3104               No HDD      48   Upto 11 Hrs Battery Life
# 3321               No HDD      65    Upto 5 Hrs Battery Life

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Brand, Name, Price, Processor_Name, Processor_Brand, RAM_Expandable, RAM, RAM_TYPE, Ghz, Display_type, Display, GPU, GPU_Brand, SSD, HDD, Adapter, Battery_Life]
# Index: []

# %%
df['Brand'].value_counts()
# Out:
# Brand
# ASUS         989
# Lenovo       809
# HP           802
# Dell         420
# Acer         321
# MSI          316
# Samsung       61
# Apple         49
# Infinix       39
# Microsoft     34
# AVITA         23
# Gigabyte      17
# LG            15
# Honor         14
# iball         11
# Xiaomi        10
# Fujitsu        8
# Zebronics      8
# Wings          4
# Colorful       3
# Realme         3
# Micromax       3
# Coconics       3
# Tecno          2
# Smartron       2
# Huawei         1
# Razer          1
# VAIO           1
# Lava           1
# Nokia          1
# RDP            1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3972, 17)

# %%
# For every column
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# Brand                0
# Name                 0
# Price                0
# Processor_Name       0
# Processor_Brand      0
# RAM_Expandable       0
# RAM                  0
# RAM_TYPE             0
# Ghz                  0
# Display_type         0
# Display              0
# GPU                  8
# GPU_Brand            4
# SSD                  0
# HDD                  0
# Adapter              0
# Battery_Life       418
# dtype: int64

# %%
print(df.dtypes)
# Out:
# Brand              object
# Name               object
# Price               int64
# Processor_Name     object
# Processor_Brand    object
# RAM_Expandable     object
# RAM                object
# RAM_TYPE           object
# Ghz                object
# Display_type       object
# Display            object
# GPU                object
# GPU_Brand          object
# SSD                object
# HDD                object
# Adapter            object
# Battery_Life       object
# dtype: object

# %% [markdown]
# ### Clean by Feature

# %%
df.head(10)
# Out:
#      Brand                                               Name  Price  \
# 0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...  22990
# 1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  36289
# 2     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  78500
# 3       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  55490
# 4  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...  21990
# 5     Acer  Acer One 14 Z8-415 (UN.599SI.020) Laptop (14 I...  34990
# 6       HP  HP 14s-fq1092AU (50M60PA) Laptop (14 Inch | AM...  49599
# 7     Acer  Acer One 14 Z8-415 (UN.599SI.018) Laptop (14 I...  39990
# 8   Lenovo  Lenovo Ideapad S145 (81VD008PIN) Laptop (15.6 ...  33111
# 9     ASUS  ASUS TUF Gaming F15 FX506HF-HN075W Laptop (15....  48990
#
#                        Processor_Name Processor_Brand     RAM_Expandable  \
# 0                  MediaTek Octa-core        MediaTek     Not Expandable
# 1               AMD Hexa-Core Ryzen 5             AMD   12 GB Expandable
# 2            Intel Core i5 (12th Gen)           Intel   32 GB Expandable
# 3            Intel Core i5 (12th Gen)           Intel    8 GB Expandable
# 4            Intel Core i3 (11th Gen)           Intel     Not Expandable
# 5  Intel Core i5 (11th Gen) Processor           Intel   32 GB Expandable
# 6               AMD Hexa-Core Ryzen 5             AMD   16 GB Expandable
# 7            Intel Core i5 (11th Gen)           Intel   32 GB Expandable
# 8             Intel Core i3 (8th Gen)           Intel   12 GB Expandable
# 9            Intel Core i5 (11th Gen)           Intel     Not Expandable
#
#        RAM      RAM_TYPE                 Ghz Display_type Display  \
# 0    4 GB       DDR4 RAM   2.0 Ghz Processor          LED   11.6
# 1    8 GB      DDR4 RAM    4.0 Ghz Processor          LCD   15.6
# 2   16 GB      DDR5 RAM    3.3 Ghz Processor          LCD   15.6
# 3    8 GB      DDR4 RAM    4.2 Ghz Processor          LCD   15.6
# 4  8 GB LP   LPDDR4X RAM   1.7 Ghz Processor          LCD   15.6
# 5   16 GB      DDR4 RAM                    0          LCD     14
# 6    8 GB      DDR4 RAM    4.0 Ghz Processor          LCD     14
# 7    8 GB      DDR4 RAM    2.5 Ghz Processor          LCD     14
# 8    4 GB      DDR4 RAM    2.2 Ghz Processor          LED   15.6
# 9    8 GB       DDR4 RAM   2.9 Ghz Processor          LCD   15.6
#
#                           GPU GPU_Brand                 SSD  \
# 0         Integrated Graphics  MediaTek   64 GB SSD Storage
# 1                      Radeon       AMD  512 GB SSD Storage
# 2  GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD Storage
# 3                     Iris Xe     Intel  512 GB SSD Storage
# 4                         UHD     Intel  512 GB SSD Storage
# 5                     Iris Xe     Intel  512 GB SSD Storage
# 6                      Radeon       AMD  512 GB SSD Storage
# 7                     Iris Xe     Intel  512 GB SSD Storage
# 8                     UHD 620     Intel              NO SSD
# 9  GeForce RTX 2050 GPU, 4 GB    NVIDIA  512 GB SSD Storage
#
#                    HDD Adapter                Battery_Life
# 0               No HDD      45    Upto 12 Hrs Battery Life
# 1               No HDD      65    Upto 11 Hrs Battery Life
# 2               No HDD      56    Upto 10 Hrs Battery Life
# 3               No HDD      no  Upto 7.30 Hrs Battery Life
# 4               No HDD      45     Upto 8 Hrs Battery Life
# 5               No HDD      45                 45W Adapter
# 6               No HDD      65     Upto 9 Hrs Battery Life
# 7               No HDD      45                 45W Adapter
# 8  1024 GB HDD Storage      45                 45W Adapter
# 9               No HDD     150                150W Adapter

# %%
print(df.columns)
# Out:
# Index(['Brand', 'Name', 'Price', 'Processor_Name', 'Processor_Brand',
#        'RAM_Expandable', 'RAM', 'RAM_TYPE', 'Ghz', 'Display_type', 'Display',
#        'GPU', 'GPU_Brand', 'SSD', 'HDD', 'Adapter', 'Battery_Life'],
#       dtype='object')

# %%
df.shape
# Out:
# (3972, 17)

# %% [markdown]
# #### OS

# %%
def gen(text):
    if ('Windows 11' in text.split('|')[3]) or 'Windows 10' in text.split('|')[3] or ('Windows 8.1' in text.split('|')[3]) or ('DOS' in text.split('|')[3]) or ('Linux' in text.split('|')[3]) or ('Ubuntu' in text.split('|')[3]) :
        return text.split('|')[3].strip()
    elif 'macOS' in text.split('|')[3]:
        return 'macOS'
    else:
        return 'Others'
    
df['Operating_System'] = df['Name'].apply(gen)
df['Operating_System'].value_counts()
# Out:
# Operating_System
# Windows 11     2133
# Windows 10     1512
# DOS             192
# macOS            49
# Others           31
# Windows 8.1      25
# Linux            23
# Ubuntu            7
# Name: count, dtype: int64

# %%
# #Extract OS
# df['OS'] = df['Name'].str.split('|').str[3].str.strip()

# print(df['OS'].value_counts())

# %%
# def gen(text):
#     part = text.split('|')[3]  # Extract the 4th part (OS info)

#     if ('Windows 11' in part) or ('Windows 10' in part) or ('Windows 8.1' in part) or ('DOS' in part):
#         return part.strip()
#     elif ('Linux' in part) or ('Ubuntu' in part):
#         return 'Linux'
#     elif 'macOS' in part:
#         return 'macOS'
#     else:
#         return 'Chrome'

# # Apply to dataframe
# df['Operating_System'] = df['Name'].apply(gen)

# # View counts
# print(df['Operating_System'].value_counts())

# %%
# # Filter rows where Operating_System is 'DOS'
# dos_laptops = df[df['Operating_System'] == 'DOS']

# # Show only the Name column
# print(dos_laptops['Name'])

# %%
df.head()
# Out:
#      Brand                                               Name  Price  \
# 0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...  22990
# 1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  36289
# 2     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  78500
# 3       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  55490
# 4  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...  21990
#
#              Processor_Name Processor_Brand     RAM_Expandable      RAM  \
# 0        MediaTek Octa-core        MediaTek     Not Expandable    4 GB
# 1     AMD Hexa-Core Ryzen 5             AMD   12 GB Expandable    8 GB
# 2  Intel Core i5 (12th Gen)           Intel   32 GB Expandable   16 GB
# 3  Intel Core i5 (12th Gen)           Intel    8 GB Expandable    8 GB
# 4  Intel Core i3 (11th Gen)           Intel     Not Expandable  8 GB LP
#
#        RAM_TYPE                 Ghz Display_type Display  \
# 0      DDR4 RAM   2.0 Ghz Processor          LED   11.6
# 1     DDR4 RAM    4.0 Ghz Processor          LCD   15.6
# 2     DDR5 RAM    3.3 Ghz Processor          LCD   15.6
# 3     DDR4 RAM    4.2 Ghz Processor          LCD   15.6
# 4   LPDDR4X RAM   1.7 Ghz Processor          LCD   15.6
#
#                           GPU GPU_Brand                 SSD     HDD Adapter  \
# 0         Integrated Graphics  MediaTek   64 GB SSD Storage  No HDD      45
# 1                      Radeon       AMD  512 GB SSD Storage  No HDD      65
# 2  GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD Storage  No HDD      56
# 3                     Iris Xe     Intel  512 GB SSD Storage  No HDD      no
# 4                         UHD     Intel  512 GB SSD Storage  No HDD      45
#
#                  Battery_Life Operating_System
# 0    Upto 12 Hrs Battery Life           Others
# 1    Upto 11 Hrs Battery Life       Windows 11
# 2    Upto 10 Hrs Battery Life       Windows 11
# 3  Upto 7.30 Hrs Battery Life       Windows 11
# 4     Upto 8 Hrs Battery Life       Windows 11

# %% [markdown]
# #### Brand

# %%
print("Brand Unique Values:", df['Brand'].nunique())
print("Missing Brand values:", df['Brand'].isna().sum())
print(df['Brand'].value_counts())
# Out:
# Brand Unique Values: 31
# Missing Brand values: 0
# Brand
# ASUS         989
# Lenovo       809
# HP           802
# Dell         420
# Acer         321
# MSI          316
# Samsung       61
# Apple         49
# Infinix       39
# Microsoft     34
# AVITA         23
# Gigabyte      17
# LG            15
# Honor         14
# iball         11
# Xiaomi        10
# Fujitsu        8
# Zebronics      8
# Wings          4
# Colorful       3
# Realme         3
# Micromax       3
# Coconics       3
# Tecno          2
# Smartron       2
# Huawei         1
# Razer          1
# VAIO           1
# Lava           1
# Nokia          1
# RDP            1
# Name: count, dtype: int64

# %%
# Here I can consider low quantity brands as "Other" category
top_brands = ['ASUS', 'Lenovo', 'HP', 'Dell', 'Acer', 'MSI','Samsung','Apple']
df['Brand'] = df['Brand'].apply(lambda x: x if x in top_brands else 'Other')

# %%
print(df['Brand'].value_counts())
# Out:
# Brand
# ASUS       989
# Lenovo     809
# HP         802
# Dell       420
# Acer       321
# MSI        316
# Other      205
# Samsung     61
# Apple       49
# Name: count, dtype: int64

# %% [markdown]
# #### Price

# %%
df.shape
# Out:
# (3972, 18)

# %%
print("Price Unique Values:", df['Price'].nunique())
print("Missing Price values:", df['Price'].isna().sum())
print(df['Price'].value_counts())
print((df['Price'] == 0).any())
# Out:
# Price Unique Values: 1799
# Missing Price values: 0
# Price
# 64990     46
# 79990     38
# 49990     38
# 42990     38
# 34990     37
# 69990     35
# 33990     33
# 59990     33
# 39990     33
# 54990     32
# 36990     30
# 89990     28
# 57990     27
# 32990     27
# 27990     25
# 58990     25
# 35990     24
# 30990     24
# 44990     24
# 52990     24
# 99990     24
# 109990    24
# 45990     24
# 50990     24
# 29990     23
# 74990     23
# 68990     23
# 37990     23
# 48990     22
# 41990     22
# 40990     22
# 72990     21
# 84990     21
# 62990     21
# 28990     21
# 65990     20
# 61990     20
# 38990     19
# 53990     19
# 46990     19
# 70990     19
# 56990     18
# 104990    17
# 63990     17
# 149990    17
# 114990    17
# 77990     16
# 43990     16
# 66990     16
# 51990     16
# 55990     16
# 78990     14
# 94990     14
# 60990     14
# 76990     14
# 47990     14
# 129990    14
# 75990     13
# 22990     13
# 73990     13
# 31990     13
# 81990     13
# 119990    13
# 24990     13
# 96990     13
# 71990     13
# 25990     12
# 88990     11
# 20990     11
# 92990     11
# 31490     10
# 69999     10
# 83990     10
# 67990     10
# 26990     10
# 108990     9
# 169990     9
# 21990      8
# 86990      8
# 102990     8
# 199990     8
# 82990      8
# 23990      8
# 139990     8
# 49999      8
# 85990      8
# 134990     8
# 107990     7
# 63999      7
# 79999      7
# 97990      7
# 144990     7
# 49490      7
# 87990      7
# 80990      7
# 17990      7
# 189990     7
# 55490      6
# 53490      6
# 124990     6
# 179990     6
# 47999      6
# 74999      6
# 56999      6
# 127990     6
# 41999      5
# 59999      5
# 24999      5
# 95990      5
# 151990     5
# 19990      5
# 47490      5
# 67999      5
# 162990     5
# 27490      5
# 56490      5
# 69490      5
# 93990      5
# 170990     5
# 103990     5
# 39900      5
# 41490      5
# 42999      5
# 128990     5
# 159990     5
# 35490      5
# 31999      4
# 37999      4
# 35500      4
# 111990     4
# 62999      4
# 165990     4
# 219990     4
# 33999      4
# 22899      4
# 15990      4
# 44999      4
# 66000      4
# 57490      4
# 36999      4
# 41391      4
# 36490      4
# 22490      4
# 91500      4
# 106990     4
# 249990     4
# 38490      4
# 45490      4
# 48490      4
# 26999      4
# 122990     4
# 60999      4
# 125990     4
# 57999      4
# 35999      4
# 172990     3
# 86999      3
# 41500      3
# 28490      3
# 49500      3
# 37490      3
# 65999      3
# 142990     3
# 32927      3
# 112990     3
# 58790      3
# 91990      3
# 13990      3
# 54490      3
# 76999      3
# 76900      3
# 39999      3
# 329990     3
# 52490      3
# 52999      3
# 100990     3
# 163990     3
# 52890      3
# 113990     3
# 171990     3
# 22999      3
# 62490      3
# 66890      3
# 46999      3
# 74190      3
# 20599      3
# 74590      3
# 184990     3
# 191990     3
# 72000      3
# 133990     3
# 64000      3
# 105990     3
# 65500      3
# 51490      3
# 54999      3
# 18990      3
# 60900      3
# 149900     3
# 98990      3
# 154990     3
# 55999      3
# 116990     3
# 75000      3
# 89999      3
# 164990     3
# 42500      3
# 58999      3
# 84999      3
# 52891      3
# 57500      3
# 32999      3
# 279990     3
# 51499      3
# 85999      3
# 48499      3
# 64999      3
# 78490      3
# 38999      3
# 234990     3
# 61999      3
# 68000      3
# 90990      3
# 43490      3
# 30490      3
# 34999      3
# 43500      3
# 17999      3
# 48999      3
# 33500      3
# 59900      3
# 30790      3
# 74890      3
# 33111      3
# 47890      3
# 33490      3
# 28999      3
# 37800      3
# 117990     3
# 33900      2
# 49900      2
# 90000      2
# 26487      2
# 36390      2
# 89500      2
# 154000     2
# 169999     2
# 52800      2
# 49599      2
# 25999      2
# 11990      2
# 60527      2
# 22890      2
# 29247      2
# 31179      2
# 20231      2
# 72499      2
# 34490      2
# 64207      2
# 63890      2
# 62000      2
# 96490      2
# 38000      2
# 47500      2
# 55532      2
# 83590      2
# 19311      2
# 35890      2
# 80900      2
# 78999      2
# 40190      2
# 59890      2
# 45899      2
# 24490      2
# 29490      2
# 66999      2
# 33571      2
# 19490      2
# 46590      2
# 41390      2
# 23819      2
# 60479      2
# 78900      2
# 77900      2
# 51890      2
# 40899      2
# 58499      2
# 173990     2
# 69500      2
# 63490      2
# 62500      2
# 31890      2
# 32490      2
# 31271      2
# 29800      2
# 44890      2
# 42290      2
# 65490      2
# 52250      2
# 205900     2
# 199999     2
# 281990     2
# 278990     2
# 25489      2
# 52190      2
# 43499      2
# 14999      2
# 82900      2
# 33800      2
# 35790      2
# 32190      2
# 34250      2
# 67500      2
# 67000      2
# 64500      2
# 78000      2
# 73500      2
# 43000      2
# 39499      2
# 43890      2
# 44190      2
# 99000      2
# 158990     2
# 179999     2
# 16990      2
# 75999      2
# 61490      2
# 25499      2
# 30999      2
# 29799      2
# 77490      2
# 48500      2
# 90490      2
# 39300      2
# 174990     2
# 239990     2
# 74490      2
# 86000      2
# 66499      2
# 148990     2
# 44800      2
# 86690      2
# 194990     2
# 42490      2
# 45900      2
# 199900     2
# 25200      2
# 61499      2
# 58490      2
# 289990     2
# 339990     2
# 99900      2
# 359990     2
# 71490      2
# 349990     2
# 68999      2
# 155990     2
# 53999      2
# 22071      2
# 36890      2
# 114999     2
# 299990     2
# 145990     2
# 157990     2
# 107000     2
# 151999     2
# 101490     2
# 80490      2
# 33799      2
# 26500      2
# 30443      2
# 129791     2
# 26590      2
# 52790      2
# 178990     2
# 130990     2
# 87999      2
# 53890      2
# 35100      2
# 50999      2
# 65890      2
# 211990     2
# 82190      2
# 135990     2
# 131990     2
# 201990     2
# 138990     2
# 115000     2
# 46833      2
# 65000      2
# 39551      2
# 38631      2
# 32500      2
# 37890      2
# 72024      2
# 81900      2
# 45999      2
# 30351      2
# 29980      2
# 36500      2
# 53000      2
# 45890      2
# 37500      2
# 167990     2
# 40980      2
# 44499      2
# 55500      2
# 44900      2
# 64200      2
# 36499      2
# 23999      2
# 19499      2
# 39390      2
# 49671      2
# 59800      2
# 181990     2
# 75900      2
# 209990     2
# 110000     2
# 34000      2
# 98000      2
# 59390      2
# 81390      2
# 78500      2
# 49000      2
# 71909      1
# 36289      1
# 112980     1
# 51891      1
# 74390      1
# 48890      1
# 71724      1
# 57890      1
# 55190      1
# 110890     1
# 149490     1
# 55139      1
# 146000     1
# 32245      1
# 56590      1
# 245990     1
# 23490      1
# 151791     1
# 56496      1
# 140131     1
# 21499      1
# 356166     1
# 63994      1
# 29671      1
# 87500      1
# 45300      1
# 84300      1
# 41920      1
# 26450      1
# 42450      1
# 88490      1
# 91590      1
# 134090     1
# 135999     1
# 77500      1
# 39090      1
# 36799      1
# 22100      1
# 61950      1
# 103060     1
# 68499      1
# 69911      1
# 349900     1
# 115499     1
# 104875     1
# 108900     1
# 35610      1
# 189400     1
# 175000     1
# 96500      1
# 101569     1
# 182990     1
# 105999     1
# 54950      1
# 71890      1
# 206250     1
# 71449      1
# 223999     1
# 95890      1
# 26490      1
# 55699      1
# 192990     1
# 62980      1
# 94900      1
# 125389     1
# 68931      1
# 251990     1
# 57899      1
# 261990     1
# 166199     1
# 175690     1
# 70600      1
# 128999     1
# 53566      1
# 94960      1
# 329989     1
# 124995     1
# 145490     1
# 58590      1
# 82999      1
# 31500      1
# 40250      1
# 87207      1
# 180000     1
# 96000      1
# 56390      1
# 37599      1
# 49650      1
# 90499      1
# 111490     1
# 151690     1
# 87021      1
# 127899     1
# 28465      1
# 32890      1
# 51390      1
# 72800      1
# 69000      1
# 94980      1
# 35548      1
# 33499      1
# 88400      1
# 18463      1
# 239900     1
# 125400     1
# 95999      1
# 144500     1
# 77550      1
# 87300      1
# 40132      1
# 216990     1
# 84190      1
# 52539      1
# 103790     1
# 32649      1
# 389990     1
# 105500     1
# 114190     1
# 149999     1
# 49390      1
# 56100      1
# 112230     1
# 62849      1
# 54499      1
# 39076      1
# 32590      1
# 107991     1
# 201447     1
# 169980     1
# 123990     1
# 165930     1
# 135008     1
# 48390      1
# 53590      1
# 74900      1
# 85400      1
# 75950      1
# 42398      1
# 71039      1
# 283589     1
# 84960      1
# 268965     1
# 361990     1
# 62363      1
# 125444     1
# 208490     1
# 81890      1
# 142890     1
# 170000     1
# 84900      1
# 155908     1
# 364990     1
# 289900     1
# 52350      1
# 101890     1
# 88390      1
# 32000      1
# 29999      1
# 51828      1
# 76490      1
# 106897     1
# 109032     1
# 107490     1
# 68071      1
# 30489      1
# 93190      1
# 33168      1
# 115290     1
# 358999     1
# 74290      1
# 49639      1
# 158490     1
# 106495     1
# 97106      1
# 87270      1
# 79890      1
# 53799      1
# 102490     1
# 84490      1
# 63100      1
# 257990     1
# 52599      1
# 78963      1
# 58524      1
# 39679      1
# 41206      1
# 148690     1
# 66390      1
# 42902      1
# 44790      1
# 212990     1
# 399990     1
# 372490     1
# 124890     1
# 48480      1
# 103226     1
# 40680      1
# 91071      1
# 26790      1
# 102000     1
# 79179      1
# 95400      1
# 61890      1
# 91999      1
# 125890     1
# 111850     1
# 45200      1
# 38349      1
# 37143      1
# 31699      1
# 160990     1
# 63993      1
# 51100      1
# 149500     1
# 71900      1
# 38700      1
# 198490     1
# 169978     1
# 157999     1
# 132999     1
# 79243      1
# 39500      1
# 58900      1
# 102890     1
# 79800      1
# 346935     1
# 449990     1
# 68900      1
# 195990     1
# 56463      1
# 32489      1
# 71799      1
# 94190      1
# 125999     1
# 285990     1
# 152990     1
# 105799     1
# 319990     1
# 33699      1
# 98999      1
# 126054     1
# 56389      1
# 171000     1
# 59400      1
# 69190      1
# 97499      1
# 47799      1
# 34100      1
# 125700     1
# 96900      1
# 97800      1
# 80390      1
# 51750      1
# 117599     1
# 132990     1
# 107500     1
# 147199     1
# 38900      1
# 85600      1
# 129589     1
# 119100     1
# 94000      1
# 81999      1
# 149000     1
# 32299      1
# 132321     1
# 61314      1
# 23949      1
# 47290      1
# 77960      1
# 195000     1
# 55479      1
# 221499     1
# 173617     1
# 55530      1
# 124999     1
# 87699      1
# 81300      1
# 46850      1
# 503890     1
# 63090      1
# 60070      1
# 61900      1
# 62899      1
# 89507      1
# 179100     1
# 44206      1
# 132590     1
# 70999      1
# 68899      1
# 63645      1
# 20554      1
# 64499      1
# 164980     1
# 51799      1
# 88999      1
# 51000      1
# 34890      1
# 61980      1
# 247900     1
# 50000      1
# 128900     1
# 76000      1
# 92500      1
# 104399     1
# 44599      1
# 109490     1
# 34998      1
# 173885     1
# 242990     1
# 60800      1
# 155411     1
# 92999      1
# 88000      1
# 246990     1
# 67399      1
# 139699     1
# 152001     1
# 71000      1
# 63362      1
# 73890      1
# 28971      1
# 225337     1
# 80999      1
# 22283      1
# 73999      1
# 331390     1
# 189900     1
# 85310      1
# 95046      1
# 108000     1
# 133329     1
# 232290     1
# 163690     1
# 33994      1
# 22000      1
# 64890      1
# 80485      1
# 108999     1
# 79469      1
# 51299      1
# 79299      1
# 82790      1
# 86190      1
# 40574      1
# 92064      1
# 103245     1
# 35190      1
# 77850      1
# 45071      1
# 30227      1
# 38581      1
# 23244      1
# 111890     1
# 28750      1
# 28338      1
# 85760      1
# 37498      1
# 62116      1
# 69088      1
# 71175      1
# 54721      1
# 78378      1
# 94490      1
# 43899      1
# 55000      1
# 23727      1
# 23266      1
# 20411      1
# 34859      1
# 30980      1
# 28409      1
# 24642      1
# 12437      1
# 76627      1
# 37590      1
# 38028      1
# 52390      1
# 39242      1
# 116500     1
# 30800      1
# 41590      1
# 48693      1
# 24371      1
# 50575      1
# 57217      1
# 49347      1
# 65989      1
# 76200      1
# 46190      1
# 54350      1
# 60802      1
# 153662     1
# 67650      1
# 41000      1
# 55300      1
# 22255      1
# 37874      1
# 20499      1
# 31087      1
# 39827      1
# 79900      1
# 39183      1
# 29946      1
# 30998      1
# 29632      1
# 46911      1
# 62900      1
# 57859      1
# 28327      1
# 33847      1
# 22991      1
# 14990      1
# 21690      1
# 121999     1
# 24463      1
# 18125      1
# 31549      1
# 34698      1
# 30226      1
# 22347      1
# 50076      1
# 59870      1
# 44390      1
# 28899      1
# 58871      1
# 43390      1
# 60890      1
# 9499       1
# 10490      1
# 66347      1
# 57635      1
# 53351      1
# 35865      1
# 32063      1
# 64390      1
# 28051      1
# 59000      1
# 23543      1
# 34292      1
# 21611      1
# 19219      1
# 92382      1
# 11500      1
# 109390     1
# 67490      1
# 67390      1
# 18460      1
# 59899      1
# 60407      1
# 24780      1
# 65547      1
# 37689      1
# 72899      1
# 56499      1
# 63000      1
# 66215      1
# 39275      1
# 69700      1
# 30729      1
# 81199      1
# 57951      1
# 37251      1
# 29100      1
# 19127      1
# 31400      1
# 72250      1
# 48935      1
# 34857      1
# 16490      1
# 21789      1
# 47000      1
# 25790      1
# 46175      1
# 45500      1
# 44980      1
# 21490      1
# 35174      1
# 27131      1
# 17994      1
# 33890      1
# 35534      1
# 37674      1
# 33463      1
# 26900      1
# 79939      1
# 63400      1
# 40475      1
# 54500      1
# 28603      1
# 34900      1
# 27743      1
# 11807      1
# 36710      1
# 40620      1
# 67749      1
# 35929      1
# 28699      1
# 41400      1
# 35871      1
# 38400      1
# 55499      1
# 52900      1
# 24050      1
# 25015      1
# 43489      1
# 40801      1
# 80116      1
# 54749      1
# 23451      1
# 29639      1
# 62643      1
# 58051      1
# 44694      1
# 72490      1
# 56950      1
# 156090     1
# 77460      1
# 37290      1
# 120999     1
# 77898      1
# 25265      1
# 81334      1
# 40999      1
# 48830      1
# 77290      1
# 99790      1
# 61658      1
# 92490      1
# 36515      1
# 40697      1
# 37790      1
# 105932     1
# 26650      1
# 51860      1
# 58750      1
# 26480      1
# 32050      1
# 59910      1
# 28349      1
# 60190      1
# 9990       1
# 40839      1
# 52340      1
# 57499      1
# 40230      1
# 24499      1
# 70800      1
# 47187      1
# 38961      1
# 99825      1
# 110490     1
# 49431      1
# 49995      1
# 31790      1
# 28143      1
# 56554      1
# 43058      1
# 22439      1
# 51859      1
# 33941      1
# 63954      1
# 69789      1
# 56250      1
# 54750      1
# 26399      1
# 24890      1
# 22500      1
# 46500      1
# 57750      1
# 39450      1
# 36359      1
# 24950      1
# 36298      1
# 20900      1
# 29489      1
# 19890      1
# 38499      1
# 38450      1
# 48599      1
# 47389      1
# 50330      1
# 30290      1
# 38899      1
# 74699      1
# 18290      1
# 33650      1
# 44100      1
# 20290      1
# 39000      1
# 39389      1
# 49899      1
# 49400      1
# 71950      1
# 26390      1
# 74723      1
# 41100      1
# 44519      1
# 52854      1
# 87543      1
# 43837      1
# 48790      1
# 112999     1
# 72190      1
# 63666      1
# 62917      1
# 131521     1
# 134900     1
# 133254     1
# 149890     1
# 154900     1
# 91499      1
# 80608      1
# 35855      1
# 64391      1
# 58800      1
# 51101      1
# 68489      1
# 45637      1
# 38890      1
# 54097      1
# 129900     1
# 30535      1
# 77999      1
# 87890      1
# 52290      1
# 75590      1
# 64128      1
# 68600      1
# 102849     1
# 36000      1
# 71999      1
# 61290      1
# 74400      1
# 81980      1
# 34400      1
# 61739      1
# 63499      1
# 57300      1
# 39700      1
# 38987      1
# 38800      1
# 70000      1
# 38307      1
# 31298      1
# 39490      1
# 69989      1
# 84104      1
# 41279      1
# 77752      1
# 65899      1
# 72629      1
# 31390      1
# 110064     1
# 86926      1
# 95029      1
# 83500      1
# 89490      1
# 73699      1
# 39799      1
# 27390      1
# 34074      1
# 40850      1
# 28799      1
# 31651      1
# 87490      1
# 28700      1
# 75300      1
# 51999      1
# 36496      1
# 27690      1
# 83411      1
# 30890      1
# 74104      1
# 51981      1
# 91880      1
# 83869      1
# 46540      1
# 75740      1
# 83490      1
# 90890      1
# 50941      1
# 66047      1
# 40500      1
# 45042      1
# 100639     1
# 57591      1
# 21550      1
# 37299      1
# 96698      1
# 28890      1
# 68212      1
# 46490      1
# 59490      1
# 52100      1
# 36300      1
# 63563      1
# 51790      1
# 42499      1
# 92359      1
# 152097     1
# 61190      1
# 134080     1
# 47119      1
# 120790     1
# 85090      1
# 43400      1
# 148949     1
# 72380      1
# 138911     1
# 33885      1
# 106178     1
# 116288     1
# 30500      1
# 65538      1
# 115900     1
# 135875     1
# 177000     1
# 74790      1
# 31750      1
# 102200     1
# 63250      1
# 85500      1
# 65680      1
# 309900     1
# 86261      1
# 33931      1
# 43100      1
# 119527     1
# 39880      1
# 93999      1
# 269900     1
# 51900      1
# 57900      1
# 93446      1
# 64599      1
# 107900     1
# 124191     1
# 69096      1
# 119273     1
# 66619      1
# 99999      1
# 40590      1
# 47899      1
# 64790      1
# 70790      1
# 63800      1
# 84420      1
# 197990     1
# 20890      1
# 54590      1
# 84086      1
# 118711     1
# 52000      1
# 103839     1
# 74500      1
# 48411      1
# 57099      1
# 68200      1
# 74250      1
# 120980     1
# 77614      1
# 34450      1
# 72855      1
# 249900     1
# 69850      1
# 95469      1
# 66280      1
# 77799      1
# 56800      1
# 75792      1
# 88750      1
# 159658     1
# 216985     1
# 99980      1
# 144900     1
# 264990     1
# 47980      1
# 146960     1
# 138607     1
# 168990     1
# 76500      1
# 58755      1
# 32599      1
# 50700      1
# 33600      1
# 86479      1
# 207990     1
# 179483     1
# 88500      1
# 239975     1
# 105900     1
# 84335      1
# 37390      1
# 167441     1
# 169752     1
# 76499      1
# 102214     1
# 79090      1
# 57350      1
# 38590      1
# 47900      1
# 139390     1
# 55400      1
# 25490      1
# 44350      1
# 50568      1
# 33390      1
# 30360      1
# 27775      1
# 35825      1
# 25190      1
# 68890      1
# 44899      1
# 388490     1
# 77590      1
# 274990     1
# 60880      1
# 331990     1
# 83799      1
# 121641     1
# 39600      1
# 50131      1
# 222990     1
# 113571     1
# 180999     1
# 47790      1
# 54299      1
# 98490      1
# 35900      1
# 85100      1
# 79490      1
# 56970      1
# 49850      1
# 439990     1
# 109031     1
# 233990     1
# 321990     1
# 66967      1
# 146290     1
# 173880     1
# 79845      1
# 159999     1
# 50499      1
# 154012     1
# 135500     1
# 161990     1
# 95630      1
# 247990     1
# 174999     1
# 175999     1
# 223290     1
# 220800     1
# 61399      1
# 409990     1
# 55390      1
# 43340      1
# 323490     1
# 59387      1
# 100023     1
# 30850      1
# 63900      1
# 47700      1
# 52799      1
# 97490      1
# 54599      1
# 123190     1
# 153990     1
# 109190     1
# 118300     1
# 47960      1
# 58700      1
# 62950      1
# 76100      1
# 89000      1
# 60199      1
# 344990     1
# 119890     1
# 117899     1
# 189999     1
# 116490     1
# 99960      1
# 58300      1
# 107030     1
# 257750     1
# 119380     1
# 79980      1
# 62880      1
# 89799      1
# 78299      1
# 271500     1
# 225190     1
# 66490      1
# 147490     1
# 106354     1
# 129500     1
# 65090      1
# 168000     1
# 55290      1
# 420990     1
# 47769      1
# 38500      1
# 56064      1
# 39448      1
# 43999      1
# 52185      1
# 79899      1
# 61475      1
# 142999     1
# 105600     1
# 188990     1
# 110790     1
# 79249      1
# 105589     1
# 46995      1
# 180403     1
# 90949      1
# 64762      1
# 61920      1
# 56150      1
# 96999      1
# 204990     1
# 96800      1
# 69450      1
# 219000     1
# 213556     1
# 19999      1
# 43191      1
# 139999     1
# 23420      1
# 58399      1
# 238990     1
# 91051      1
# 162000     1
# 169450     1
# 65422      1
# 125663     1
# 49395      1
# 85000      1
# 90464      1
# 48952      1
# 44795      1
# 26850      1
# 115391     1
# 39853      1
# 32007      1
# 24820      1
# 31357      1
# 141000     1
# 42084      1
# 78300      1
# 202639     1
# 18490      1
# 113290     1
# 67852      1
# 25900      1
# 114900     1
# 73991      1
# 21820      1
# 32182      1
# 33087      1
# 30020      1
# 72118      1
# 50591      1
# 48040      1
# 54989      1
# 20680      1
# 83999      1
# 16800      1
# 70716      1
# 56962      1
# 49916      1
# 38350      1
# 19790      1
# 18499      1
# 34225      1
# 53425      1
# 38355      1
# 31041      1
# 28975      1
# 85800      1
# 77495      1
# 73683      1
# 50314      1
# 64715      1
# 22790      1
# 64690      1
# 58244      1
# 26477      1
# 105000     1
# 27884      1
# 7990       1
# 32191      1
# 33755      1
# 30627      1
# 25383      1
# 20999      1
# 36975      1
# 30903      1
# 17931      1
# 25291      1
# 27225      1
# 25599      1
# 33996      1
# 30000      1
# 24101      1
# 24831      1
# 35276      1
# 75247      1
# 24943      1
# 36900      1
# 50299      1
# 61899      1
# 40940      1
# 39646      1
# 30900      1
# 42492      1
# 37099      1
# 66596      1
# 34499      1
# 63976      1
# 34690      1
# 50176      1
# 43139      1
# 20323      1
# 32656      1
# 31547      1
# 27039      1
# 39299      1
# 42917      1
# 71310      1
# 29707      1
# 129592     1
# 52155      1
# 34881      1
# 31406      1
# 56666      1
# 138256     1
# 36492      1
# 55007      1
# 8990       1
# 33256      1
# 51502      1
# 63500      1
# 65190      1
# 44611      1
# 21841      1
# 42771      1
# 61000      1
# 38079      1
# 27790      1
# 51919      1
# 17500      1
# 42043      1
# 41980      1
# 93265      1
# 44182      1
# 36883      1
# 32651      1
# 22532      1
# 40550      1
# 48188      1
# 36370      1
# 33978      1
# 45715      1
# 10990      1
# 71425      1
# 35924      1
# 115490     1
# 46989      1
# 56690      1
# 28190      1
# 18391      1
# 26579      1
# 49658      1
# 90243      1
# 60442      1
# 177990     1
# 80400      1
# 37961      1
# 62190      1
# 48629      1
# 50790      1
# 68853      1
# 50279      1
# 61400      1
# 85750      1
# 43507      1
# 31731      1
# 47493      1
# 111190     1
# 46303      1
# 27254      1
# 32743      1
# 46359      1
# 29643      1
# 45540      1
# 82490      1
# 18890      1
# 24610      1
# 31290      1
# 29497      1
# 63854      1
# 56890      1
# 85743      1
# 42900      1
# 75800      1
# 30950      1
# 40890      1
# 79000      1
# 159490     1
# 36054      1
# 49980      1
# 35233      1
# 49021      1
# 58830      1
# 44168      1
# 201734     1
# 70500      1
# 16900      1
# 46794      1
# 41900      1
# 24913      1
# 52820      1
# 37023      1
# 23804      1
# 62112      1
# 90900      1
# 71480      1
# 64551      1
# 30923      1
# 22150      1
# 31823      1
# 53826      1
# 54994      1
# 103794     1
# 101651     1
# 63761      1
# 97040      1
# 42399      1
# 53535      1
# 141990     1
# 25397      1
# 63590      1
# 73204      1
# 32197      1
# 36147      1
# 65212      1
# 94249      1
# 63641      1
# 215990     1
# 52431      1
# 48899      1
# 43146      1
# 29590      1
# 27195      1
# 21190      1
# 147400     1
# 24335      1
# 42890      1
# 32200      1
# 63494      1
# 59790      1
# 112040     1
# 27999      1
# 43231      1
# 93780      1
# 31897      1
# 38970      1
# 57599      1
# 40643      1
# 53779      1
# 42090      1
# 13900      1
# 160905     1
# 116941     1
# 82267      1
# 89752      1
# 23952      1
# 69303      1
# 50407      1
# 42790      1
# 38744      1
# 19320      1
# 64871      1
# 44500      1
# 45260      1
# 49800      1
# 256403     1
# 59989      1
# 36190      1
# 44855      1
# 41190      1
# 56991      1
# 47199      1
# 45808      1
# 36363      1
# 12499      1
# 38390      1
# 42000      1
# 25890      1
# 42400      1
# 44274      1
# 116999     1
# 29000      1
# 32639      1
# 77399      1
# 30131      1
# 84500      1
# 22807      1
# 19679      1
# 33424      1
# 90590      1
# 10499      1
# 75195      1
# 45274      1
# 135890     1
# 77154      1
# 39290      1
# 44441      1
# 35199      1
# 51160      1
# 27875      1
# 39250      1
# 147990     1
# 47390      1
# 101065     1
# 48300      1
# 62890      1
# 41800      1
# 69890      1
# 29690      1
# 117853     1
# 229990     1
# 40400      1
# 119900     1
# 222999     1
# 21900      1
# 44632      1
# 499373     1
# 75279      1
# 16010      1
# 39890      1
# 59791      1
# 51784      1
# 53811      1
# 187990     1
# 40172      1
# 13999      1
# 27889      1
# 77995      1
# 62994      1
# 19000      1
# 64344      1
# 34812      1
# 52400      1
# 24400      1
# 97695      1
# 69770      1
# 119600     1
# 57390      1
# 81978      1
# 45000      1
# 57823      1
# 69900      1
# 60641      1
# 79449      1
# 23500      1
# 39298      1
# 115990     1
# 58222      1
# 76390      1
# 78812      1
# 104999     1
# 39100      1
# 66255      1
# 24145      1
# 80118      1
# 79258      1
# 49190      1
# 250000     1
# 55157      1
# 164345     1
# 94890      1
# 102300     1
# 21999      1
# 69390      1
# 68500      1
# 128190     1
# 57741      1
# 175146     1
# 69494      1
# 121490     1
# 36740      1
# 128000     1
# 64821      1
# 165999     1
# 27155      1
# 77392      1
# 29876      1
# 18999      1
# 25449      1
# 77860      1
# 50347      1
# 46790      1
# 51416      1
# 22590      1
# 39643      1
# 109999     1
# 25935      1
# 21994      1
# 85590      1
# 77701      1
# 78850      1
# 297377     1
# 101400     1
# 28480      1
# 48794      1
# 45190      1
# 93094      1
# 75994      1
# 60000      1
# 65287      1
# 69437      1
# 101775     1
# 40660      1
# 19291      1
# 75490      1
# 50319      1
# 28000      1
# 72533      1
# 51199      1
# 40490      1
# 161494     1
# 221000     1
# 23189      1
# 40056      1
# 69608      1
# 121990     1
# 24900      1
# 80004      1
# 105871     1
# 118195     1
# 40031      1
# 185990     1
# 180990     1
# 61500      1
# 269990     1
# 200777     1
# 52188      1
# 44940      1
# 31063      1
# 120235     1
# 163601     1
# 126000     1
# 39997      1
# 51603      1
# 68428      1
# 94999      1
# 132790     1
# 74419      1
# 299999     1
# 32900      1
# 36350      1
# 91250      1
# 27890      1
# 88969      1
# 144999     1
# 215000     1
# 166499     1
# 41699      1
# 146990     1
# 154366     1
# 29240      1
# Name: count, dtype: int64
# False

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

mean_price = df['Price'].mean()
sns.histplot(df['Price'], kde=True, ax=axes[0])
axes[0].set_title('Distribution of Laptop Prices')

sns.boxplot(data=df, y='Price', ax=axes[1])
axes[1].set_title('Laptop Pricing Spread')
axes[1].set_ylabel('Price')

axes[1].axhline(mean_price, color='red', linestyle=':', linewidth=1, label='Mean')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
df.shape
# Out:
# (3972, 18)

# %%
df['Brand'].value_counts()
# Out:
# Brand
# ASUS       989
# Lenovo     809
# HP         802
# Dell       420
# Acer       321
# MSI        316
# Other      205
# Samsung     61
# Apple       49
# Name: count, dtype: int64

# %% [markdown]
# ##### Removing Outliars ( Not Finalized)

# %%
# Q1 = df['Price'].quantile(0.25)
# Q3 = df['Price'].quantile(0.75)
# IQR = Q3 - Q1

# lower_bound = Q1 - 1.5 * IQR
# upper_bound = Q3 + 1.5 * IQR

# df = df[(df['Price'] >= lower_bound) & (df['Price'] <= upper_bound)]

# %%
df.shape
# Out:
# (3972, 18)

# %%
df["Brand"].value_counts()
# Out:
# Brand
# ASUS       989
# Lenovo     809
# HP         802
# Dell       420
# Acer       321
# MSI        316
# Other      205
# Samsung     61
# Apple       49
# Name: count, dtype: int64

# %% [markdown]
# ##### Converting IND RS to LKR

# %%
df['Price'] = df['Price'] * 3.5 # Get Average Exchange Rate

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

mean_price = df['Price'].mean()
sns.histplot(df['Price'], kde=True, ax=axes[0])
axes[0].set_title('Distribution of Laptop Prices')

sns.boxplot(data=df, y='Price', ax=axes[1])
axes[1].set_title('Laptop Pricing Spread')
axes[1].set_ylabel('Price')

axes[1].axhline(mean_price, color='red', linestyle=':', linewidth=1, label='Mean')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
price_skew = df['Price'].skew()
print("Skewness of Price:", price_skew)
# Out:
# Skewness of Price: 2.686738067561258

# %%
print(df['Price'].describe())
# Out:
# count    3.972000e+03
# mean     2.536231e+05
# std      1.827672e+05
# min      2.796500e+04
# 25%      1.396412e+05
# 50%      2.064650e+05
# 75%      2.974650e+05
# max      1.763615e+06
# Name: Price, dtype: float64

# %%
df['Brand'].value_counts()
# Out:
# Brand
# ASUS       989
# Lenovo     809
# HP         802
# Dell       420
# Acer       321
# MSI        316
# Other      205
# Samsung     61
# Apple       49
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3972, 18)

# %%
print(df['Brand'].value_counts())
# Out:
# Brand
# ASUS       989
# Lenovo     809
# HP         802
# Dell       420
# Acer       321
# MSI        316
# Other      205
# Samsung     61
# Apple       49
# Name: count, dtype: int64

# %% [markdown]
# #### Processor Brand

# %%
# Filter rows where Processor_Brand is Apple
apple_df = df[df['Processor_Brand'] == 'Apple'][['Processor_Name', 'Processor_Brand']]

# View the resulting DataFrame
print(apple_df)
# Out:
#               Processor_Name Processor_Brand
# 80                  Apple M1           Apple
# 96        Apple M2 Processor           Apple
# 227       Apple M2 Processor           Apple
# 371       Apple M2 Processor           Apple
# 639             Apple M3 Pro           Apple
# 699   Apple M2 Max Processor           Apple
# 950             Apple M3 Pro           Apple
# 1557      Apple M1 Processor           Apple
# 1944      Apple M2 Processor           Apple
# 1972      Apple M2 Processor           Apple
# 1978      Apple M2 Processor           Apple
# 1980      Apple M2 Processor           Apple
# 1981      Apple M2 Processor           Apple
# 1982      Apple M2 Processor           Apple
# 1983      Apple M2 Processor           Apple
# 2204            Apple M2 Pro           Apple
# 2233            Apple M2 Pro           Apple
# 2247            Apple M2 Max           Apple
# 2320            Apple M2 Pro           Apple
# 3070            Apple M1 Pro           Apple

# %%
print("Processor_Brand Unique Values:", df['Processor_Brand'].nunique())
print("Missing Processor_Brand values:", df['Processor_Brand'].isna().sum())
df['Processor_Brand'].value_counts()
# Out:
# Processor_Brand Unique Values: 19
# Missing Processor_Brand values: 0
# Processor_Brand
# Intel        3006
# AMD           919
# Apple          20
# MediaTek        4
# 1.7             4
# 2.4             2
# 3.4             2
# 2.0             2
# 2.1             2
# 3.0             2
# Qualcomm        1
# 3.3             1
# 1.6             1
# 2.3             1
# 2.2             1
# 1.8             1
# Microsoft       1
# 1.9             1
# 2.6             1
# Name: count, dtype: int64

# %% [markdown]
# * Some Processors_Brands names have Ghz speeds as a wrong input. So we can remove those values.

# %%
# Here only consider Intel and AMD
df['Processor_Brand'].info
# Out:
# <bound method Series.info of 0        MediaTek
# 1             AMD
# 2           Intel
# 3           Intel
# 4           Intel
# 5           Intel
# 6             AMD
# 7           Intel
# 8           Intel
# 9           Intel
# 10            AMD
# 11            AMD
# 12          Intel
# 13          Intel
# 14          Intel
# 15          Intel
# 16          Intel
# 17          Intel
# 18          Intel
# 19          Intel
# 20          Intel
# 21          Intel
# 22          Intel
# 23            AMD
# 24          Intel
# 25          Intel
# 26          Intel
# 27          Intel
# 28          Intel
# 29          Intel
# 30            AMD
# 31          Intel
# 32            AMD
# 33          Intel
# 34            AMD
# 35            AMD
# 36          Intel
# 37          Intel
# 38          Intel
# 39          Intel
# 40          Intel
# 41          Intel
# 42          Intel
# 43          Intel
# 44          Intel
# 45            AMD
# 46          Intel
# 47          Intel
# 48          Intel
# 49            AMD
# 50          Intel
# 51            AMD
# 52          Intel
# 53          Intel
# 54          Intel
# 55          Intel
# 56          Intel
# 57          Intel
# 58            AMD
# 59            AMD
# 60          Intel
# 61          Intel
# 62          Intel
# 63            AMD
# 64          Intel
# 65            AMD
# 66          Intel
# 67          Intel
# 68          Intel
# 69          Intel
# 70          Intel
# 71            AMD
# 72            AMD
# 73          Intel
# 74            AMD
# 75            AMD
# 76            AMD
# 77            AMD
# 78          Intel
# 79          Intel
# 80          Apple
# 81          Intel
# 82          Intel
# 83            AMD
# 84          Intel
# 85          Intel
# 86            AMD
# 87          Intel
# 88          Intel
# 89          Intel
# 90          Intel
# 91          Intel
# 92            AMD
# 93          Intel
# 94          Intel
# 95          Intel
# 96          Apple
# 97            AMD
# 98            AMD
# 99            AMD
# 100           AMD
# 101         Intel
# 102         Intel
# 103           AMD
# 104           AMD
# 105         Intel
# 106         Intel
# 107         Intel
# 108         Intel
# 109         Intel
# 110           AMD
# 111         Intel
# 112         Intel
# 113         Intel
# 114         Intel
# 115         Intel
# 116         Intel
# 117         Intel
# 118         Intel
# 119         Intel
# 120         Intel
# 121         Intel
# 122         Intel
# 123         Intel
# 124           AMD
# 125         Intel
# 126           AMD
# 127           AMD
# 128         Intel
# 129         Intel
# 130         Intel
# 131         Intel
# 132           AMD
# 133         Intel
# 134           AMD
# 135           AMD
# 136           AMD
# 137         Intel
# 138         Intel
# 139         Intel
# 140         Intel
# 141           AMD
# 142         Intel
# 143           AMD
# 144         Intel
# 145           AMD
# 146         Intel
# 147         Intel
# 148         Intel
# 149         Intel
# 150         Intel
# 151         Intel
# 152         Intel
# 153         Intel
# 154           AMD
# 155         Intel
# 156         Intel
# 157           AMD
# 158         Intel
# 159         Intel
# 160           2.3
# 161         Intel
# 162         Intel
# 163           AMD
# 164         Intel
# 165         Intel
# 166         Intel
# 167         Intel
# 168           AMD
# 169         Intel
# 170         Intel
# 171         Intel
# 172           AMD
# 173           AMD
# 174         Intel
# 175         Intel
# 176         Intel
# 177         Intel
# 178         Intel
# 179         Intel
# 180         Intel
# 181         Intel
# 182         Intel
# 183           AMD
# 184           AMD
# 185         Intel
# 186         Intel
# 187         Intel
# 188         Intel
# 189         Intel
# 190         Intel
# 191         Intel
# 192           AMD
# 193         Intel
# 194         Intel
# 195           AMD
# 196           AMD
# 197         Intel
# 198           AMD
# 199           AMD
# 200         Intel
# 201         Intel
# 202         Intel
# 203         Intel
# 204         Intel
# 205         Intel
# 206         Intel
# 207         Intel
# 208         Intel
# 209         Intel
# 210         Intel
# 211         Intel
# 212         Intel
# 213         Intel
# 214         Intel
# 215         Intel
# 216         Intel
# 217         Intel
# 218         Intel
# 219           AMD
# 220         Intel
# 221         Intel
# 222         Intel
# 223         Intel
# 224           AMD
# 225         Intel
# 226           AMD
# 227         Apple
# 228         Intel
# 229           AMD
# 230         Intel
# 231         Intel
# 232         Intel
# 233           AMD
# 234           AMD
# 235         Intel
# 236           AMD
# 237         Intel
# 238         Intel
# 239           AMD
# 240           AMD
# 241         Intel
# 242         Intel
# 243           AMD
# 244         Intel
# 245           AMD
# 246         Intel
# 247           AMD
# 248         Intel
# 249         Intel
# 250         Intel
# 251           AMD
# 252         Intel
# 253         Intel
# 254         Intel
# 255           AMD
# 256         Intel
# 257         Intel
# 258         Intel
# 259           AMD
# 260           AMD
# 261         Intel
# 262         Intel
# 263         Intel
# 264           AMD
# 265         Intel
# 266         Intel
# 267           AMD
# 268         Intel
# 269         Intel
# 270         Intel
# 271         Intel
# 272           AMD
# 273         Intel
# 274         Intel
# 275         Intel
# 276         Intel
# 277         Intel
# 278         Intel
# 279         Intel
# 280           3.4
# 281         Intel
# 282         Intel
# 283         Intel
# 284         Intel
# 285         Intel
# 286           AMD
# 287         Intel
# 288         Intel
# 289         Intel
# 290           AMD
# 291         Intel
# 292         Intel
# 293           AMD
# 294         Intel
# 295         Intel
# 296         Intel
# 297         Intel
# 298         Intel
# 299           AMD
# 300         Intel
# 301         Intel
# 302           AMD
# 303           AMD
# 304         Intel
# 305         Intel
# 306      Qualcomm
# 307         Intel
# 308         Intel
# 309           AMD
# 310         Intel
# 311         Intel
# 312         Intel
# 313         Intel
# 314         Intel
# 315         Intel
# 316           AMD
# 317         Intel
# 318           AMD
# 319         Intel
# 320           AMD
# 321         Intel
# 322         Intel
# 323         Intel
# 324         Intel
# 325         Intel
# 326         Intel
# 327           AMD
# 328         Intel
# 329         Intel
# 330           AMD
# 331         Intel
# 332           AMD
# 333         Intel
# 334         Intel
# 335         Intel
# 336         Intel
# 337           AMD
# 338         Intel
# 339           AMD
# 340           AMD
# 341         Intel
# 342         Intel
# 343         Intel
# 344           AMD
# 345         Intel
# 346         Intel
# 347         Intel
# 348         Intel
# 349         Intel
# 350         Intel
# 351         Intel
# 352         Intel
# 353         Intel
# 354           AMD
# 355         Intel
# 356         Intel
# 357         Intel
# 358         Intel
# 359         Intel
# 360         Intel
# 361           AMD
# 362         Intel
# 363         Intel
# 364         Intel
# 365         Intel
# 366         Intel
# 367         Intel
# 368         Intel
# 369         Intel
# 370         Intel
# 371         Apple
# 372         Intel
# 373         Intel
# 374           AMD
# 375         Intel
# 376           AMD
# 377         Intel
# 378         Intel
# 379         Intel
# 380         Intel
# 381         Intel
# 382         Intel
# 383         Intel
# 384           AMD
# 385         Intel
# 386         Intel
# 387         Intel
# 388         Intel
# 389           AMD
# 390           AMD
# 391         Intel
# 392         Intel
# 393         Intel
# 394         Intel
# 395         Intel
# 396           AMD
# 397           AMD
# 398         Intel
# 399         Intel
# 400         Intel
# 401         Intel
# 402         Intel
# 403           AMD
# 404           AMD
# 405           AMD
# 406         Intel
# 407         Intel
# 408         Intel
# 409         Intel
# 410         Intel
# 411         Intel
# 412         Intel
# 413         Intel
# 414         Intel
# 415         Intel
# 416         Intel
# 417         Intel
# 418         Intel
# 419         Intel
# 420         Intel
# 421         Intel
# 422         Intel
# 423         Intel
# 424           AMD
# 425         Intel
# 426         Intel
# 427         Intel
# 428         Intel
# 429           AMD
# 430         Intel
# 431         Intel
# 432           AMD
# 433         Intel
# 434           AMD
# 435         Intel
# 436           AMD
# 437         Intel
# 438         Intel
# 439           AMD
# 440         Intel
# 441           AMD
# 442           AMD
# 443         Intel
# 444         Intel
# 445         Intel
# 446         Intel
# 447         Intel
# 448         Intel
# 449         Intel
# 450         Intel
# 451         Intel
# 452         Intel
# 453         Intel
# 454         Intel
# 455         Intel
# 456           AMD
# 457         Intel
# 458         Intel
# 459         Intel
# 460         Intel
# 461           AMD
# 462         Intel
# 463         Intel
# 464         Intel
# 465           AMD
# 466         Intel
# 467           AMD
# 468         Intel
# 469           AMD
# 470           AMD
# 471           AMD
# 472         Intel
# 473         Intel
# 474           AMD
# 475         Intel
# 476           AMD
# 477         Intel
# 478         Intel
# 479         Intel
# 480         Intel
# 481         Intel
# 482           AMD
# 483           AMD
# 484           AMD
# 485         Intel
# 486         Intel
# 487         Intel
# 488         Intel
# 489           AMD
# 490         Intel
# 491         Intel
# 492           AMD
# 493           AMD
# 494         Intel
# 495         Intel
# 496           AMD
# 497         Intel
# 498         Intel
# 499         Intel
# 500         Intel
# 501           AMD
# 502         Intel
# 503         Intel
# 504           AMD
# 505         Intel
# 506         Intel
# 507           AMD
# 508         Intel
# 509           AMD
# 510           AMD
# 511         Intel
# 512         Intel
# 513         Intel
# 514         Intel
# 515           AMD
# 516         Intel
# 517         Intel
# 518           AMD
# 519         Intel
# 520      MediaTek
# 521         Intel
# 522           AMD
# 523           AMD
# 524         Intel
# 525         Intel
# 526         Intel
# 527           AMD
# 528         Intel
# 529         Intel
# 530         Intel
# 531         Intel
# 532         Intel
# 533         Intel
# 534         Intel
# 535         Intel
# 536         Intel
# 537         Intel
# 538         Intel
# 539         Intel
# 540           AMD
# 541           AMD
# 542         Intel
# 543         Intel
# 544         Intel
# 545           AMD
# 546         Intel
# 547           AMD
# 548         Intel
# 549         Intel
# 550         Intel
# 551           AMD
# 552         Intel
# 553           AMD
# 554           AMD
# 555         Intel
# 556         Intel
# 557         Intel
# 558         Intel
# 559         Intel
# 560         Intel
# 561         Intel
# 562         Intel
# 563         Intel
# 564         Intel
# 565         Intel
# 566         Intel
# 567         Intel
# 568         Intel
# 569         Intel
# 570         Intel
# 571         Intel
# 572         Intel
# 573         Intel
# 574         Intel
# 575         Intel
# 576         Intel
# 577         Intel
# 578         Intel
# 579         Intel
# 580           AMD
# 581         Intel
# 582         Intel
# 583           AMD
# 584         Intel
# 585         Intel
# 586         Intel
# 587         Intel
# 588         Intel
# 589         Intel
# 590           AMD
# 591         Intel
# 592           AMD
# 593         Intel
# 594         Intel
# 595         Intel
# 596         Intel
# 597         Intel
# 598         Intel
# 599         Intel
# 600         Intel
# 601         Intel
# 602         Intel
# 603         Intel
# 604         Intel
# 605         Intel
# 606         Intel
# 607           AMD
# 608           AMD
# 609         Intel
# 610         Intel
# 611         Intel
# 612         Intel
# 613           AMD
# 614           AMD
# 615         Intel
# 616           AMD
# 617         Intel
# 618         Intel
# 619         Intel
# 620         Intel
# 621         Intel
# 622         Intel
# 623         Intel
# 624         Intel
# 625           AMD
# 626         Intel
# 627         Intel
# 628         Intel
# 629           AMD
# 630         Intel
# 631         Intel
# 632         Intel
# 633         Intel
# 634         Intel
# 635           AMD
# 636           AMD
# 637         Intel
# 638         Intel
# 639         Apple
# 640         Intel
# 641         Intel
# 642         Intel
# 643         Intel
# 644         Intel
# 645         Intel
# 646           AMD
# 647         Intel
# 648           AMD
# 649         Intel
# 650         Intel
# 651           AMD
# 652         Intel
# 653         Intel
# 654         Intel
# 655         Intel
# 656         Intel
# 657         Intel
# 658         Intel
# 659         Intel
# 660         Intel
# 661         Intel
# 662           AMD
# 663         Intel
# 664         Intel
# 665           AMD
# 666           AMD
# 667           AMD
# 668         Intel
# 669         Intel
# 670         Intel
# 671           AMD
# 672         Intel
# 673         Intel
# 674         Intel
# 675         Intel
# 676         Intel
# 677           AMD
# 678         Intel
# 679         Intel
# 680         Intel
# 681         Intel
# 682         Intel
# 683         Intel
# 684         Intel
# 685         Intel
# 686           AMD
# 687         Intel
# 688         Intel
# 689         Intel
# 690         Intel
# 691         Intel
# 692         Intel
# 693           AMD
# 694           AMD
# 695         Intel
# 696         Intel
# 697         Intel
# 698         Intel
# 699         Apple
# 700         Intel
# 701           AMD
# 702         Intel
# 703           AMD
# 704         Intel
# 705         Intel
# 706         Intel
# 707           AMD
# 708         Intel
# 709           AMD
# 710           AMD
# 711           AMD
# 712           AMD
# 713           AMD
# 714         Intel
# 715           AMD
# 716         Intel
# 717         Intel
# 718         Intel
# 719         Intel
# 720           AMD
# 721         Intel
# 722         Intel
# 723         Intel
# 724         Intel
# 725         Intel
# 726         Intel
# 727         Intel
# 728         Intel
# 729         Intel
# 730           AMD
# 731           AMD
# 732         Intel
# 733         Intel
# 734         Intel
# 735         Intel
# 736         Intel
# 737         Intel
# 738         Intel
# 739         Intel
# 740         Intel
# 741         Intel
# 742           AMD
# 743           AMD
# 744         Intel
# 745         Intel
# 746           AMD
# 747         Intel
# 748         Intel
# 749         Intel
# 750           AMD
# 751         Intel
# 752         Intel
# 753         Intel
# 754         Intel
# 755         Intel
# 756         Intel
# 757         Intel
# 758         Intel
# 759         Intel
# 760         Intel
# 761           AMD
# 762         Intel
# 763         Intel
# 764         Intel
# 765         Intel
# 766         Intel
# 767           AMD
# 768           AMD
# 769         Intel
# 770           AMD
# 771         Intel
# 772           AMD
# 773           AMD
# 774         Intel
# 775         Intel
# 776         Intel
# 777         Intel
# 778           AMD
# 779         Intel
# 780         Intel
# 781           AMD
# 782         Intel
# 783         Intel
# 784         Intel
# 785           AMD
# 786         Intel
# 787         Intel
# 788         Intel
# 789         Intel
# 790         Intel
# 791         Intel
# 792         Intel
# 793           AMD
# 794         Intel
# 795         Intel
# 796         Intel
# 797         Intel
# 798         Intel
# 799         Intel
# 800         Intel
# 801         Intel
# 802           AMD
# 803         Intel
# 804           AMD
# 805         Intel
# 806         Intel
# 807           AMD
# 808         Intel
# 809         Intel
# 810         Intel
# 811         Intel
# 812         Intel
# 813         Intel
# 814           AMD
# 815           AMD
# 816         Intel
# 817         Intel
# 818         Intel
# 819         Intel
# 820         Intel
# 821         Intel
# 822         Intel
# 823         Intel
# 824           AMD
# 825         Intel
# 826         Intel
# 827           AMD
# 828         Intel
# 829         Intel
# 830         Intel
# 831           AMD
# 832         Intel
# 833         Intel
# 834         Intel
# 835         Intel
# 836         Intel
# 837         Intel
# 838         Intel
# 839           AMD
# 840         Intel
# 841         Intel
# 842         Intel
# 843         Intel
# 844           AMD
# 845         Intel
# 846         Intel
# 847         Intel
# 848           AMD
# 849           AMD
# 850           AMD
# 851         Intel
# 852         Intel
# 853           AMD
# 854         Intel
# 855         Intel
# 856         Intel
# 857         Intel
# 858         Intel
# 859         Intel
# 860         Intel
# 861           AMD
# 862         Intel
# 863         Intel
# 864         Intel
# 865         Intel
# 866         Intel
# 867           AMD
# 868         Intel
# 869         Intel
# 870           AMD
# 871           AMD
# 872         Intel
# 873         Intel
# 874         Intel
# 875         Intel
# 876         Intel
# 877           AMD
# 878         Intel
# 879         Intel
# 880           AMD
# 881         Intel
# 882         Intel
# 883         Intel
# 884           AMD
# 885         Intel
# 886         Intel
# 887         Intel
# 888           AMD
# 889           AMD
# 890           AMD
# 891           AMD
# 892         Intel
# 893         Intel
# 894         Intel
# 895           AMD
# 896           AMD
# 897         Intel
# 898         Intel
# 899         Intel
# 900           AMD
# 901         Intel
# 902         Intel
# 903         Intel
# 904         Intel
# 905           AMD
# 906           AMD
# 907         Intel
# 908         Intel
# 909         Intel
# 910           AMD
# 911           AMD
# 912         Intel
# 913           AMD
# 914         Intel
# 915           AMD
# 916         Intel
# 917           AMD
# 918         Intel
# 919         Intel
# 920           AMD
# 921         Intel
# 922         Intel
# 923           AMD
# 924           AMD
# 925         Intel
# 926         Intel
# 927         Intel
# 928           AMD
# 929         Intel
# 930         Intel
# 931           AMD
# 932           AMD
# 933           AMD
# 934           AMD
# 935           AMD
# 936         Intel
# 937           AMD
# 938         Intel
# 939           AMD
# 940           AMD
# 941         Intel
# 942         Intel
# 943           AMD
# 944         Intel
# 945         Intel
# 946           AMD
# 947           AMD
# 948           3.3
# 949         Intel
# 950         Apple
# 951         Intel
# 952           AMD
# 953         Intel
# 954           AMD
# 955         Intel
# 956           AMD
# 957         Intel
# 958         Intel
# 959           AMD
# 960           AMD
# 961         Intel
# 962         Intel
# 963           AMD
# 964         Intel
# 965           AMD
# 966         Intel
# 967         Intel
# 968         Intel
# 969         Intel
# 970         Intel
# 971           AMD
# 972         Intel
# 973         Intel
# 974         Intel
# 975           AMD
# 976         Intel
# 977         Intel
# 978         Intel
# 979         Intel
# 980         Intel
# 981         Intel
# 982           AMD
# 983         Intel
# 984         Intel
# 985           AMD
# 986         Intel
# 987         Intel
# 988         Intel
# 989         Intel
# 990         Intel
# 991         Intel
# 992         Intel
# 993           AMD
# 994         Intel
# 995         Intel
# 996           AMD
# 997         Intel
# 998         Intel
# 999           AMD
# 1000        Intel
# 1001        Intel
# 1002        Intel
# 1003        Intel
# 1004        Intel
# 1005          AMD
# 1006        Intel
# 1007        Intel
# 1008        Intel
# 1009        Intel
# 1010        Intel
# 1011        Intel
# 1012        Intel
# 1013          AMD
# 1014        Intel
# 1015        Intel
# 1016        Intel
# 1017        Intel
# 1018        Intel
# 1019        Intel
# 1020        Intel
# 1021        Intel
# 1022          AMD
# 1023          AMD
# 1024        Intel
# 1025        Intel
# 1026        Intel
# 1027        Intel
# 1028        Intel
# 1029        Intel
# 1030        Intel
# 1031        Intel
# 1032        Intel
# 1033        Intel
# 1034        Intel
# 1035        Intel
# 1036        Intel
# 1037        Intel
# 1038        Intel
# 1039        Intel
# 1040        Intel
# 1041        Intel
# 1042        Intel
# 1043        Intel
# 1044        Intel
# 1045        Intel
# 1046        Intel
# 1047        Intel
# 1048        Intel
# 1049          AMD
# 1050        Intel
# 1051          AMD
# 1052        Intel
# 1053        Intel
# 1054          AMD
# 1055        Intel
# 1056        Intel
# 1057        Intel
# 1058          AMD
# 1059          AMD
# 1060        Intel
# 1061        Intel
# 1062        Intel
# 1063          AMD
# 1064        Intel
# 1065        Intel
# 1066        Intel
# 1067        Intel
# 1068        Intel
# 1069        Intel
# 1070        Intel
# 1071        Intel
# 1072          AMD
# 1073        Intel
# 1074        Intel
# 1075          AMD
# 1076        Intel
# 1077        Intel
# 1078        Intel
# 1079        Intel
# 1080        Intel
# 1081        Intel
# 1082        Intel
# 1083        Intel
# 1084        Intel
# 1085        Intel
# 1086          AMD
# 1087          AMD
# 1088          AMD
# 1089          AMD
# 1090        Intel
# 1091        Intel
# 1092          AMD
# 1093        Intel
# 1094        Intel
# 1095        Intel
# 1096        Intel
# 1097        Intel
# 1098        Intel
# 1099        Intel
# 1100        Intel
# 1101          AMD
# 1102        Intel
# 1103        Intel
# 1104        Intel
# 1105        Intel
# 1106        Intel
# 1107        Intel
# 1108        Intel
# 1109        Intel
# 1110        Intel
# 1111        Intel
# 1112        Intel
# 1113        Intel
# 1114        Intel
# 1115          AMD
# 1116        Intel
# 1117        Intel
# 1118        Intel
# 1119        Intel
# 1120        Intel
# 1121        Intel
# 1122        Intel
# 1123        Intel
# 1124        Intel
# 1125          AMD
# 1126        Intel
# 1127          AMD
# 1128        Intel
# 1129        Intel
# 1130        Intel
# 1131        Intel
# 1132          AMD
# 1133        Intel
# 1134        Intel
# 1135        Intel
# 1136        Intel
# 1137          AMD
# 1138        Intel
# 1139        Intel
# 1140          AMD
# 1141        Intel
# 1142        Intel
# 1143          AMD
# 1144        Intel
# 1145        Intel
# 1146        Intel
# 1147        Intel
# 1148        Intel
# 1149        Intel
# 1150        Intel
# 1151        Intel
# 1152        Intel
# 1153        Intel
# 1154          AMD
# 1155        Intel
# 1156          AMD
# 1157          AMD
# 1158          AMD
# 1159        Intel
# 1160        Intel
# 1161          AMD
# 1162        Intel
# 1163        Intel
# 1164        Intel
# 1165        Intel
# 1166        Intel
# 1167          AMD
# 1168          AMD
# 1169        Intel
# 1170          AMD
# 1171        Intel
# 1172        Intel
# 1173        Intel
# 1174        Intel
# 1175        Intel
# 1176          AMD
# 1177        Intel
# 1178        Intel
# 1179        Intel
# 1180        Intel
# 1181        Intel
# 1182        Intel
# 1183        Intel
# 1184          AMD
# 1185        Intel
# 1186        Intel
# 1187        Intel
# 1188        Intel
# 1189          AMD
# 1190          AMD
# 1191        Intel
# 1192        Intel
# 1193        Intel
# 1194          AMD
# 1195        Intel
# 1196        Intel
# 1197          AMD
# 1198          AMD
# 1199        Intel
# 1200        Intel
# 1201        Intel
# 1202        Intel
# 1203        Intel
# 1204        Intel
# 1205        Intel
# 1206        Intel
# 1207        Intel
# 1208        Intel
# 1209        Intel
# 1210        Intel
# 1211          AMD
# 1212        Intel
# 1213        Intel
# 1214        Intel
# 1215        Intel
# 1216        Intel
# 1217        Intel
# 1218        Intel
# 1219          AMD
# 1220        Intel
# 1221        Intel
# 1222        Intel
# 1223        Intel
# 1224        Intel
# 1225        Intel
# 1226        Intel
# 1227        Intel
# 1228          AMD
# 1229        Intel
# 1230          AMD
# 1231        Intel
# 1232          AMD
# 1233          AMD
# 1234        Intel
# 1235        Intel
# 1236        Intel
# 1237        Intel
# 1238        Intel
# 1239          AMD
# 1240        Intel
# 1241          AMD
# 1242        Intel
# 1243          AMD
# 1244          AMD
# 1245        Intel
# 1246        Intel
# 1247        Intel
# 1248        Intel
# 1249        Intel
# 1250          AMD
# 1251        Intel
# 1252        Intel
# 1253        Intel
# 1254        Intel
# 1255        Intel
# 1256        Intel
# 1257          AMD
# 1258          AMD
# 1259        Intel
# 1260          AMD
# 1261        Intel
# 1262        Intel
# 1263        Intel
# 1264        Intel
# 1265        Intel
# 1266        Intel
# 1267        Intel
# 1268          AMD
# 1269        Intel
# 1270        Intel
# 1271        Intel
# 1272          AMD
# 1273          AMD
# 1274        Intel
# 1275        Intel
# 1276          AMD
# 1277        Intel
# 1278        Intel
# 1279        Intel
# 1280        Intel
# 1281          AMD
# 1282          AMD
# 1283          AMD
# 1284        Intel
# 1285        Intel
# 1286        Intel
# 1287        Intel
# 1288        Intel
# 1289          AMD
# 1290          AMD
# 1291          AMD
# 1292          AMD
# 1293        Intel
# 1294        Intel
# 1295        Intel
# 1296          AMD
# 1297        Intel
# 1298          AMD
# 1299        Intel
# 1300        Intel
# 1301        Intel
# 1302        Intel
# 1303          AMD
# 1304        Intel
# 1305        Intel
# 1306        Intel
# 1307          AMD
# 1308        Intel
# 1309        Intel
# 1310        Intel
# 1311        Intel
# 1312        Intel
# 1313        Intel
# 1314        Intel
# 1315        Intel
# 1316        Intel
# 1317        Intel
# 1318          AMD
# 1319          AMD
# 1320        Intel
# 1321        Intel
# 1322        Intel
# 1323        Intel
# 1324        Intel
# 1325          AMD
# 1326        Intel
# 1327        Intel
# 1328        Intel
# 1329        Intel
# 1330        Intel
# 1331        Intel
# 1332          AMD
# 1333        Intel
# 1334        Intel
# 1335          AMD
# 1336          AMD
# 1337        Intel
# 1338        Intel
# 1339        Intel
# 1340        Intel
# 1341          AMD
# 1342          AMD
# 1343        Intel
# 1344        Intel
# 1345        Intel
# 1346        Intel
# 1347        Intel
# 1348          AMD
# 1349        Intel
# 1350        Intel
# 1351          AMD
# 1352          AMD
# 1353        Intel
# 1354        Intel
# 1355        Intel
# 1356        Intel
# 1357        Intel
# 1358        Intel
# 1359          1.6
# 1360          AMD
# 1361        Intel
# 1362        Intel
# 1363        Intel
# 1364        Intel
# 1365        Intel
# 1366        Intel
# 1367        Intel
# 1368        Intel
# 1369        Intel
# 1370        Intel
# 1371        Intel
# 1372        Intel
# 1373        Intel
# 1374        Intel
# 1375        Intel
# 1376          AMD
# 1377        Intel
# 1378          AMD
# 1379        Intel
# 1380        Intel
# 1381        Intel
# 1382          AMD
# 1383        Intel
# 1384        Intel
# 1385          AMD
# 1386        Intel
# 1387        Intel
# 1388          AMD
# 1389        Intel
# 1390        Intel
# 1391        Intel
# 1392        Intel
# 1393          AMD
# 1394        Intel
# 1395        Intel
# 1396        Intel
# 1397        Intel
# 1398        Intel
# 1399        Intel
# 1400        Intel
# 1401        Intel
# 1402        Intel
# 1403        Intel
# 1404        Intel
# 1405        Intel
# 1406        Intel
# 1407        Intel
# 1408        Intel
# 1409        Intel
# 1410        Intel
# 1411        Intel
# 1412        Intel
# 1413        Intel
# 1414        Intel
# 1415        Intel
# 1416        Intel
# 1417        Intel
# 1418        Intel
# 1419        Intel
# 1420        Intel
# 1421        Intel
# 1422          AMD
# 1423          AMD
# 1424        Intel
# 1425        Intel
# 1426        Intel
# 1427        Intel
# 1428        Intel
# 1429          AMD
# 1430          AMD
# 1431        Intel
# 1432        Intel
# 1433        Intel
# 1434          AMD
# 1435          AMD
# 1436        Intel
# 1437        Intel
# 1438        Intel
# 1439        Intel
# 1440        Intel
# 1441        Intel
# 1442        Intel
# 1443        Intel
# 1444          AMD
# 1445        Intel
# 1446        Intel
# 1447        Intel
# 1448        Intel
# 1449        Intel
# 1450        Intel
# 1451        Intel
# 1452        Intel
# 1453          AMD
# 1454        Intel
# 1455        Intel
# 1456        Intel
# 1457        Intel
# 1458        Intel
# 1459        Intel
# 1460        Intel
# 1461        Intel
# 1462        Intel
# 1463        Intel
# 1464        Intel
# 1465        Intel
# 1466          AMD
# 1467        Intel
# 1468        Intel
# 1469        Intel
# 1470        Intel
# 1471          AMD
# 1472        Intel
# 1473        Intel
# 1474          AMD
# 1475        Intel
# 1476          AMD
# 1477        Intel
# 1478          AMD
# 1479        Intel
# 1480        Intel
# 1481          AMD
# 1482          AMD
# 1483        Intel
# 1484          AMD
# 1485          AMD
# 1486          AMD
# 1487        Intel
# 1488          AMD
# 1489        Intel
# 1490        Intel
# 1491        Intel
# 1492        Intel
# 1493        Intel
# 1494          AMD
# 1495          AMD
# 1496        Intel
# 1497        Intel
# 1498          AMD
# 1499        Intel
# 1500        Intel
# 1501        Intel
# 1502        Intel
# 1503        Intel
# 1504        Intel
# 1505        Intel
# 1506     MediaTek
# 1507        Intel
# 1508        Intel
# 1509        Intel
# 1510        Intel
# 1511        Intel
# 1512        Intel
# 1513        Intel
# 1514        Intel
# 1515        Intel
# 1516        Intel
# 1517        Intel
# 1518        Intel
# 1519        Intel
# 1520        Intel
# 1521          AMD
# 1522        Intel
# 1523        Intel
# 1524        Intel
# 1525          AMD
# 1526        Intel
# 1527          AMD
# 1528        Intel
# 1529        Intel
# 1530          AMD
# 1531        Intel
# 1532        Intel
# 1533        Intel
# 1534        Intel
# 1535        Intel
# 1536          AMD
# 1537        Intel
# 1538        Intel
# 1539        Intel
# 1540        Intel
# 1541          AMD
# 1542        Intel
# 1543        Intel
# 1544        Intel
# 1545        Intel
# 1546        Intel
# 1547          AMD
# 1548          AMD
# 1549        Intel
# 1550        Intel
# 1551          AMD
# 1552        Intel
# 1553        Intel
# 1554          AMD
# 1555          AMD
# 1556        Intel
# 1557        Apple
# 1558        Intel
# 1559        Intel
# 1560          AMD
# 1561        Intel
# 1562          AMD
# 1563        Intel
# 1564          AMD
# 1565          AMD
# 1566          AMD
# 1567          AMD
# 1568        Intel
# 1569        Intel
# 1570        Intel
# 1571        Intel
# 1572        Intel
# 1573        Intel
# 1574        Intel
# 1575        Intel
# 1576        Intel
# 1577        Intel
# 1578        Intel
# 1579        Intel
# 1580        Intel
# 1581        Intel
# 1582        Intel
# 1583          AMD
# 1584        Intel
# 1585        Intel
# 1586        Intel
# 1587        Intel
# 1588        Intel
# 1589        Intel
# 1590        Intel
# 1591        Intel
# 1592          AMD
# 1593        Intel
# 1594        Intel
# 1595        Intel
# 1596        Intel
# 1597        Intel
# 1598        Intel
# 1599          AMD
# 1600          AMD
# 1601          AMD
# 1602        Intel
# 1603        Intel
# 1604        Intel
# 1605          AMD
# 1606          AMD
# 1607        Intel
# 1608        Intel
# 1609        Intel
# 1610        Intel
# 1611          AMD
# 1612        Intel
# 1613        Intel
# 1614          AMD
# 1615          AMD
# 1616        Intel
# 1617          AMD
# 1618        Intel
# 1619        Intel
# 1620        Intel
# 1621        Intel
# 1622          AMD
# 1623          AMD
# 1624        Intel
# 1625        Intel
# 1626        Intel
# 1627        Intel
# 1628        Intel
# 1629        Intel
# 1630        Intel
# 1631        Intel
# 1632          AMD
# 1633        Intel
# 1634        Intel
# 1635          AMD
# 1636        Intel
# 1637        Intel
# 1638        Intel
# 1639        Intel
# 1640          AMD
# 1641        Intel
# 1642        Intel
# 1643          AMD
# 1644        Intel
# 1645        Intel
# 1646        Intel
# 1647          AMD
# 1648        Intel
# 1649          AMD
# 1650        Intel
# 1651        Intel
# 1652        Intel
# 1653        Intel
# 1654        Intel
# 1655          AMD
# 1656        Intel
# 1657          AMD
# 1658        Intel
# 1659        Intel
# 1660          AMD
# 1661        Intel
# 1662        Intel
# 1663        Intel
# 1664        Intel
# 1665          AMD
# 1666        Intel
# 1667        Intel
# 1668        Intel
# 1669        Intel
# 1670        Intel
# 1671        Intel
# 1672        Intel
# 1673        Intel
# 1674          AMD
# 1675        Intel
# 1676          AMD
# 1677        Intel
# 1678        Intel
# 1679        Intel
# 1680        Intel
# 1681          AMD
# 1682          AMD
# 1683        Intel
# 1684        Intel
# 1685        Intel
# 1686        Intel
# 1687        Intel
# 1688        Intel
# 1689        Intel
# 1690          AMD
# 1691        Intel
# 1692        Intel
# 1693        Intel
# 1694        Intel
# 1695        Intel
# 1696        Intel
# 1697        Intel
# 1698        Intel
# 1699        Intel
# 1700        Intel
# 1701          AMD
# 1702        Intel
# 1703        Intel
# 1704          AMD
# 1705          AMD
# 1706        Intel
# 1707        Intel
# 1708          AMD
# 1709        Intel
# 1710          AMD
# 1711        Intel
# 1712        Intel
# 1713        Intel
# 1714        Intel
# 1715        Intel
# 1716        Intel
# 1717        Intel
# 1718        Intel
# 1719          AMD
# 1720        Intel
# 1721          AMD
# 1722        Intel
# 1723        Intel
# 1724        Intel
# 1725        Intel
# 1726        Intel
# 1727        Intel
# 1728          AMD
# 1729        Intel
# 1730        Intel
# 1731        Intel
# 1732        Intel
# 1733        Intel
# 1734          AMD
# 1735        Intel
# 1736        Intel
# 1737        Intel
# 1738        Intel
# 1739          AMD
# 1740        Intel
# 1741          AMD
# 1742        Intel
# 1743        Intel
# 1744        Intel
# 1745          AMD
# 1746        Intel
# 1747        Intel
# 1748        Intel
# 1749        Intel
# 1750        Intel
# 1751        Intel
# 1752        Intel
# 1753        Intel
# 1754        Intel
# 1755        Intel
# 1756        Intel
# 1757        Intel
# 1758        Intel
# 1759        Intel
# 1760        Intel
# 1761          AMD
# 1762          AMD
# 1763        Intel
# 1764        Intel
# 1765          AMD
# 1766        Intel
# 1767        Intel
# 1768        Intel
# 1769        Intel
# 1770        Intel
# 1771        Intel
# 1772        Intel
# 1773        Intel
# 1774        Intel
# 1775          AMD
# 1776          AMD
# 1777        Intel
# 1778        Intel
# 1779        Intel
# 1780        Intel
# 1781        Intel
# 1782        Intel
# 1783          AMD
# 1784          AMD
# 1785        Intel
# 1786        Intel
# 1787        Intel
# 1788        Intel
# 1789        Intel
# 1790        Intel
# 1791        Intel
# 1792        Intel
# 1793        Intel
# 1794          AMD
# 1795          AMD
# 1796        Intel
# 1797        Intel
# 1798          AMD
# 1799        Intel
# 1800        Intel
# 1801          AMD
# 1802        Intel
# 1803        Intel
# 1804        Intel
# 1805        Intel
# 1806        Intel
# 1807          2.4
# 1808        Intel
# 1809        Intel
# 1810        Intel
# 1811          AMD
# 1812        Intel
# 1813        Intel
# 1814        Intel
# 1815        Intel
# 1816        Intel
# 1817        Intel
# 1818        Intel
# 1819        Intel
# 1820        Intel
# 1821        Intel
# 1822        Intel
# 1823        Intel
# 1824          AMD
# 1825        Intel
# 1826          AMD
# 1827        Intel
# 1828        Intel
# 1829        Intel
# 1830        Intel
# 1831          AMD
# 1832        Intel
# 1833        Intel
# 1834          AMD
# 1835          AMD
# 1836          AMD
# 1837          AMD
# 1838        Intel
# 1839        Intel
# 1840        Intel
# 1841        Intel
# 1842        Intel
# 1843        Intel
# 1844          AMD
# 1845          AMD
# 1846          AMD
# 1847        Intel
# 1848        Intel
# 1849        Intel
# 1850        Intel
# 1851        Intel
# 1852        Intel
# 1853        Intel
# 1854        Intel
# 1855        Intel
# 1856        Intel
# 1857        Intel
# 1858          AMD
# 1859        Intel
# 1860          AMD
# 1861          AMD
# 1862        Intel
# 1863        Intel
# 1864          AMD
# 1865        Intel
# 1866        Intel
# 1867        Intel
# 1868        Intel
# 1869        Intel
# 1870          AMD
# 1871          AMD
# 1872        Intel
# 1873        Intel
# 1874          AMD
# 1875          AMD
# 1876        Intel
# 1877          AMD
# 1878        Intel
# 1879        Intel
# 1880        Intel
# 1881        Intel
# 1882        Intel
# 1883          AMD
# 1884        Intel
# 1885        Intel
# 1886        Intel
# 1887        Intel
# 1888        Intel
# 1889          AMD
# 1890        Intel
# 1891          AMD
# 1892        Intel
# 1893        Intel
# 1894        Intel
# 1895          AMD
# 1896        Intel
# 1897        Intel
# 1898        Intel
# 1899        Intel
# 1900          AMD
# 1901          AMD
# 1902          AMD
# 1903        Intel
# 1904        Intel
# 1905        Intel
# 1906          AMD
# 1907        Intel
# 1908        Intel
# 1909        Intel
# 1910          AMD
# 1911          AMD
# 1912        Intel
# 1913          AMD
# 1914          AMD
# 1915          AMD
# 1916          AMD
# 1917        Intel
# 1918          AMD
# 1919        Intel
# 1920        Intel
# 1921        Intel
# 1922        Intel
# 1923          AMD
# 1924        Intel
# 1925        Intel
# 1926        Intel
# 1927        Intel
# 1928        Intel
# 1929        Intel
# 1930          AMD
# 1931        Intel
# 1932          AMD
# 1933        Intel
# 1934        Intel
# 1935        Intel
# 1936        Intel
# 1937        Intel
# 1938        Intel
# 1939        Intel
# 1940          AMD
# 1941          AMD
# 1942        Intel
# 1943        Intel
# 1944        Apple
# 1945        Intel
# 1946        Intel
# 1947        Intel
# 1948        Intel
# 1949          AMD
# 1950        Intel
# 1951        Intel
# 1952        Intel
# 1953        Intel
# 1954        Intel
# 1955          AMD
# 1956        Intel
# 1957        Intel
# 1958          AMD
# 1959        Intel
# 1960          AMD
# 1961          AMD
# 1962        Intel
# 1963          AMD
# 1964          AMD
# 1965          AMD
# 1966          AMD
# 1967        Intel
# 1968        Intel
# 1969          AMD
# 1970          AMD
# 1971        Intel
# 1972        Apple
# 1973          AMD
# 1974          AMD
# 1975        Intel
# 1976        Intel
# 1977        Intel
# 1978        Apple
# 1979        Intel
# 1980        Apple
# 1981        Apple
# 1982        Apple
# 1983        Apple
# 1984          AMD
# 1985        Intel
# 1986          AMD
# 1987        Intel
# 1988          AMD
# 1989          3.4
# 1990        Intel
# 1991        Intel
# 1992          AMD
# 1993        Intel
# 1994        Intel
# 1995          AMD
# 1996        Intel
# 1997        Intel
# 1998        Intel
# 1999        Intel
# 2000        Intel
# 2001        Intel
# 2002        Intel
# 2003          AMD
# 2004        Intel
# 2005          AMD
# 2006        Intel
# 2007        Intel
# 2008        Intel
# 2009        Intel
# 2010        Intel
# 2011        Intel
# 2012        Intel
# 2013          AMD
# 2014        Intel
# 2015        Intel
# 2016        Intel
# 2017        Intel
# 2018        Intel
# 2019        Intel
# 2020        Intel
# 2021        Intel
# 2022          AMD
# 2023          AMD
# 2024        Intel
# 2025        Intel
# 2026        Intel
# 2027        Intel
# 2028        Intel
# 2029        Intel
# 2030        Intel
# 2031          AMD
# 2032        Intel
# 2033        Intel
# 2034        Intel
# 2035        Intel
# 2036        Intel
# 2037        Intel
# 2038        Intel
# 2039          AMD
# 2040          AMD
# 2041        Intel
# 2042        Intel
# 2043        Intel
# 2044          AMD
# 2045        Intel
# 2046        Intel
# 2047        Intel
# 2048          AMD
# 2049        Intel
# 2050          AMD
# 2051          AMD
# 2052        Intel
# 2053        Intel
# 2054          AMD
# 2055        Intel
# 2056          AMD
# 2057        Intel
# 2058        Intel
# 2059        Intel
# 2060        Intel
# 2061          AMD
# 2062        Intel
# 2063          AMD
# 2064        Intel
# 2065          AMD
# 2066        Intel
# 2067        Intel
# 2068          AMD
# 2069        Intel
# 2070        Intel
# 2071        Intel
# 2072        Intel
# 2073        Intel
# 2074        Intel
# 2075          AMD
# 2076        Intel
# 2077          AMD
# 2078        Intel
# 2079        Intel
# 2080        Intel
# 2081        Intel
# 2082        Intel
# 2083        Intel
# 2084        Intel
# 2085          AMD
# 2086        Intel
# 2087        Intel
# 2088        Intel
# 2089        Intel
# 2090        Intel
# 2091        Intel
# 2092        Intel
# 2093        Intel
# 2094        Intel
# 2095        Intel
# 2096        Intel
# 2097        Intel
# 2098        Intel
# 2099        Intel
# 2100        Intel
# 2101          AMD
# 2102        Intel
# 2103          AMD
# 2104        Intel
# 2105        Intel
# 2106          AMD
# 2107          AMD
# 2108        Intel
# 2109        Intel
# 2110          AMD
# 2111        Intel
# 2112        Intel
# 2113          AMD
# 2114        Intel
# 2115          AMD
# 2116        Intel
# 2117        Intel
# 2118        Intel
# 2119        Intel
# 2120        Intel
# 2121          AMD
# 2122        Intel
# 2123        Intel
# 2124        Intel
# 2125          AMD
# 2126        Intel
# 2127        Intel
# 2128        Intel
# 2129          AMD
# 2130        Intel
# 2131          AMD
# 2132          AMD
# 2133          AMD
# 2134          AMD
# 2135        Intel
# 2136        Intel
# 2137          AMD
# 2138          AMD
# 2139          AMD
# 2140          AMD
# 2141          AMD
# 2142          AMD
# 2143        Intel
# 2144          AMD
# 2145          AMD
# 2146        Intel
# 2147        Intel
# 2148        Intel
# 2149        Intel
# 2150        Intel
# 2151        Intel
# 2152        Intel
# 2153        Intel
# 2154        Intel
# 2155          AMD
# 2156        Intel
# 2157          AMD
# 2158        Intel
# 2159        Intel
# 2160        Intel
# 2161        Intel
# 2162        Intel
# 2163        Intel
# 2164        Intel
# 2165        Intel
# 2166          AMD
# 2167        Intel
# 2168        Intel
# 2169        Intel
# 2170        Intel
# 2171        Intel
# 2172        Intel
# 2173        Intel
# 2174        Intel
# 2175        Intel
# 2176          AMD
# 2177        Intel
# 2178        Intel
# 2179        Intel
# 2180          AMD
# 2181        Intel
# 2182        Intel
# 2183        Intel
# 2184        Intel
# 2185        Intel
# 2186          AMD
# 2187        Intel
# 2188        Intel
# 2189        Intel
# 2190        Intel
# 2191        Intel
# 2192          AMD
# 2193        Intel
# 2194          AMD
# 2195          AMD
# 2196        Intel
# 2197        Intel
# 2198          AMD
# 2199        Intel
# 2200        Intel
# 2201          AMD
# 2202          AMD
# 2203        Intel
# 2204        Apple
# 2205        Intel
# 2206        Intel
# 2207        Intel
# 2208        Intel
# 2209        Intel
# 2210        Intel
# 2211        Intel
# 2212        Intel
# 2213        Intel
# 2214        Intel
# 2215          AMD
# 2216        Intel
# 2217        Intel
# 2218          3.0
# 2219        Intel
# 2220        Intel
# 2221        Intel
# 2222        Intel
# 2223        Intel
# 2224          AMD
# 2225          AMD
# 2226        Intel
# 2227        Intel
# 2228        Intel
# 2229        Intel
# 2230        Intel
# 2231        Intel
# 2232        Intel
# 2233        Apple
# 2234          AMD
# 2235        Intel
# 2236        Intel
# 2237        Intel
# 2238          AMD
# 2239        Intel
# 2240        Intel
# 2241        Intel
# 2242        Intel
# 2243        Intel
# 2244        Intel
# 2245          AMD
# 2246        Intel
# 2247        Apple
# 2248        Intel
# 2249          AMD
# 2250        Intel
# 2251          AMD
# 2252        Intel
# 2253          AMD
# 2254        Intel
# 2255          AMD
# 2256          AMD
# 2257        Intel
# 2258        Intel
# 2259          AMD
# 2260        Intel
# 2261          AMD
# 2262          AMD
# 2263        Intel
# 2264        Intel
# 2265          AMD
# 2266          AMD
# 2267        Intel
# 2268        Intel
# 2269          AMD
# 2270          AMD
# 2271        Intel
# 2272          AMD
# 2273        Intel
# 2274          AMD
# 2275        Intel
# 2276        Intel
# 2277          AMD
# 2278        Intel
# 2279          AMD
# 2280        Intel
# 2281        Intel
# 2282          AMD
# 2283        Intel
# 2284        Intel
# 2285        Intel
# 2286          AMD
# 2287        Intel
# 2288        Intel
# 2289          AMD
# 2290          AMD
# 2291          AMD
# 2292        Intel
# 2293        Intel
# 2294        Intel
# 2295        Intel
# 2296        Intel
# 2297        Intel
# 2298        Intel
# 2299          AMD
# 2300        Intel
# 2301        Intel
# 2302        Intel
# 2303        Intel
# 2304        Intel
# 2305        Intel
# 2306        Intel
# 2307        Intel
# 2308        Intel
# 2309        Intel
# 2310        Intel
# 2311        Intel
# 2312        Intel
# 2313        Intel
# 2314        Intel
# 2315        Intel
# 2316          AMD
# 2317        Intel
# 2318        Intel
# 2319          AMD
# 2320        Apple
# 2321        Intel
# 2322        Intel
# 2323          AMD
# 2324        Intel
# 2325        Intel
# 2326        Intel
# 2327        Intel
# 2328        Intel
# 2329        Intel
# 2330          AMD
# 2331        Intel
# 2332        Intel
# 2333          AMD
# 2334          AMD
# 2335        Intel
# 2336        Intel
# 2337        Intel
# 2338        Intel
# 2339        Intel
# 2340        Intel
# 2341        Intel
# 2342        Intel
# 2343        Intel
# 2344        Intel
# 2345        Intel
# 2346        Intel
# 2347          AMD
# 2348          AMD
# 2349          AMD
# 2350        Intel
# 2351        Intel
# 2352        Intel
# 2353        Intel
# 2354          AMD
# 2355        Intel
# 2356        Intel
# 2357        Intel
# 2358        Intel
# 2359          AMD
# 2360        Intel
# 2361        Intel
# 2362          AMD
# 2363        Intel
# 2364        Intel
# 2365        Intel
# 2366        Intel
# 2367        Intel
# 2368        Intel
# 2369        Intel
# 2370        Intel
# 2371        Intel
# 2372          AMD
# 2373          AMD
# 2374        Intel
# 2375        Intel
# 2376        Intel
# 2377        Intel
# 2378        Intel
# 2379        Intel
# 2380        Intel
# 2381          AMD
# 2382          AMD
# 2383        Intel
# 2384        Intel
# 2385        Intel
# 2386        Intel
# 2387        Intel
# 2388        Intel
# 2389          AMD
# 2390        Intel
# 2391        Intel
# 2392          AMD
# 2393        Intel
# 2394        Intel
# 2395        Intel
# 2396        Intel
# 2397        Intel
# 2398        Intel
# 2399          AMD
# 2400          AMD
# 2401        Intel
# 2402        Intel
# 2403        Intel
# 2404        Intel
# 2405        Intel
# 2406        Intel
# 2407          AMD
# 2408        Intel
# 2409        Intel
# 2410        Intel
# 2411        Intel
# 2412        Intel
# 2413        Intel
# 2414          AMD
# 2415        Intel
# 2416          AMD
# 2417        Intel
# 2418        Intel
# 2419        Intel
# 2420        Intel
# 2421        Intel
# 2422        Intel
# 2423          AMD
# 2424        Intel
# 2425        Intel
# 2426          AMD
# 2427          AMD
# 2428        Intel
# 2429        Intel
# 2430        Intel
# 2431          AMD
# 2432          AMD
# 2433        Intel
# 2434        Intel
# 2435          AMD
# 2436        Intel
# 2437          AMD
# 2438        Intel
# 2439        Intel
# 2440        Intel
# 2441        Intel
# 2442        Intel
# 2443        Intel
# 2444        Intel
# 2445        Intel
# 2446        Intel
# 2447        Intel
# 2448        Intel
# 2449          AMD
# 2450        Intel
# 2451        Intel
# 2452        Intel
# 2453          AMD
# 2454        Intel
# 2455        Intel
# 2456        Intel
# 2457        Intel
# 2458        Intel
# 2459        Intel
# 2460        Intel
# 2461        Intel
# 2462          AMD
# 2463        Intel
# 2464        Intel
# 2465        Intel
# 2466          AMD
# 2467          AMD
# 2468          AMD
# 2469        Intel
# 2470        Intel
# 2471          AMD
# 2472        Intel
# 2473        Intel
# 2474        Intel
# 2475        Intel
# 2476          AMD
# 2477        Intel
# 2478        Intel
# 2479        Intel
# 2480          AMD
# 2481        Intel
# 2482        Intel
# 2483        Intel
# 2484        Intel
# 2485        Intel
# 2486        Intel
# 2487        Intel
# 2488        Intel
# 2489        Intel
# 2490        Intel
# 2491        Intel
# 2492        Intel
# 2493        Intel
# 2494        Intel
# 2495          AMD
# 2496        Intel
# 2497        Intel
# 2498        Intel
# 2499        Intel
# 2500        Intel
# 2501        Intel
# 2502          AMD
# 2503          AMD
# 2504        Intel
# 2505          AMD
# 2506        Intel
# 2507        Intel
# 2508          AMD
# 2509          AMD
# 2510          AMD
# 2511        Intel
# 2512          AMD
# 2513        Intel
# 2514          AMD
# 2515        Intel
# 2516          AMD
# 2517          AMD
# 2518          AMD
# 2519        Intel
# 2520        Intel
# 2521          AMD
# 2522          AMD
# 2523        Intel
# 2524        Intel
# 2525        Intel
# 2526          AMD
# 2527        Intel
# 2528        Intel
# 2529        Intel
# 2530          AMD
# 2531        Intel
# 2532        Intel
# 2533        Intel
# 2534        Intel
# 2535        Intel
# 2536        Intel
# 2537        Intel
# 2538        Intel
# 2539        Intel
# 2540        Intel
# 2541        Intel
# 2542        Intel
# 2543        Intel
# 2544        Intel
# 2545        Intel
# 2546        Intel
# 2547        Intel
# 2548        Intel
# 2549        Intel
# 2550        Intel
# 2551        Intel
# 2552        Intel
# 2553        Intel
# 2554        Intel
# 2555        Intel
# 2556          AMD
# 2557        Intel
# 2558        Intel
# 2559        Intel
# 2560        Intel
# 2561          AMD
# 2562        Intel
# 2563        Intel
# 2564        Intel
# 2565        Intel
# 2566        Intel
# 2567          AMD
# 2568        Intel
# 2569        Intel
# 2570        Intel
# 2571        Intel
# 2572        Intel
# 2573        Intel
# 2574        Intel
# 2575          AMD
# 2576        Intel
# 2577        Intel
# 2578        Intel
# 2579        Intel
# 2580        Intel
# 2581        Intel
# 2582        Intel
# 2583        Intel
# 2584        Intel
# 2585        Intel
# 2586        Intel
# 2587        Intel
# 2588        Intel
# 2589        Intel
# 2590        Intel
# 2591        Intel
# 2592        Intel
# 2593        Intel
# 2594        Intel
# 2595        Intel
# 2596        Intel
# 2597        Intel
# 2598        Intel
# 2599          AMD
# 2600        Intel
# 2601        Intel
# 2602        Intel
# 2603        Intel
# 2604        Intel
# 2605        Intel
# 2606        Intel
# 2607        Intel
# 2608          AMD
# 2609        Intel
# 2610          AMD
# 2611        Intel
# 2612        Intel
# 2613          AMD
# 2614          AMD
# 2615        Intel
# 2616          AMD
# 2617        Intel
# 2618        Intel
# 2619          AMD
# 2620        Intel
# 2621        Intel
# 2622        Intel
# 2623        Intel
# 2624        Intel
# 2625        Intel
# 2626        Intel
# 2627        Intel
# 2628        Intel
# 2629        Intel
# 2630        Intel
# 2631        Intel
# 2632        Intel
# 2633        Intel
# 2634        Intel
# 2635        Intel
# 2636        Intel
# 2637        Intel
# 2638        Intel
# 2639        Intel
# 2640        Intel
# 2641          AMD
# 2642          AMD
# 2643        Intel
# 2644        Intel
# 2645          AMD
# 2646        Intel
# 2647        Intel
# 2648        Intel
# 2649        Intel
# 2650        Intel
# 2651        Intel
# 2652        Intel
# 2653        Intel
# 2654        Intel
# 2655        Intel
# 2656          AMD
# 2657        Intel
# 2658        Intel
# 2659          AMD
# 2660        Intel
# 2661          AMD
# 2662        Intel
# 2663        Intel
# 2664        Intel
# ...
# 3088        Intel
# 3089        Intel
# 3090        Intel
# 3091        Intel
# 3092        Intel
# 3093        Intel
# 3094        Intel
# 3095        Intel
# 3096        Intel
# 3097        Intel
# 3098        Intel
# 3099        Intel
# 3100        Intel
# 3101        Intel
# 3102        Intel
# 3103        Intel
# 3105        Intel
# 3106        Intel
# 3107        Intel
# 3108        Intel
# 3109        Intel
# 3110        Intel
# 3111        Intel
# 3112        Intel
# 3113        Intel
# 3114          AMD
# 3115        Intel
# 3116          AMD
# 3117          AMD
# 3118          AMD
# 3119        Intel
# 3120        Intel
# 3121        Intel
# 3122          AMD
# 3123        Intel
# 3124        Intel
# 3125        Intel
# 3126          AMD
# 3127          AMD
# 3128        Intel
# 3129          AMD
# 3130          AMD
# 3131        Intel
# 3132        Intel
# 3133        Intel
# 3134        Intel
# 3135          AMD
# 3136        Intel
# 3137        Intel
# 3138        Intel
# 3139        Intel
# 3140        Intel
# 3141        Intel
# 3142        Intel
# 3143        Intel
# 3144        Intel
# 3145        Intel
# 3146          AMD
# 3147        Intel
# 3148        Intel
# 3149        Intel
# 3150        Intel
# 3151        Intel
# 3152        Intel
# 3153        Intel
# 3154        Intel
# 3155        Intel
# 3156        Intel
# 3157          2.2
# 3158        Intel
# 3159        Intel
# 3160        Intel
# 3161        Intel
# 3162        Intel
# 3163        Intel
# 3164          1.7
# 3165        Intel
# 3166          AMD
# 3167          AMD
# 3168          AMD
# 3169          AMD
# 3170          AMD
# 3171        Intel
# 3172        Intel
# 3173        Intel
# 3174          AMD
# 3175        Intel
# 3176        Intel
# 3177        Intel
# 3178          AMD
# 3179          AMD
# 3180        Intel
# 3181        Intel
# 3182        Intel
# 3183        Intel
# 3184        Intel
# 3185        Intel
# 3186        Intel
# 3187        Intel
# 3188          AMD
# 3189        Intel
# 3190        Intel
# 3191        Intel
# 3192        Intel
# 3193        Intel
# 3194        Intel
# 3195        Intel
# 3196        Intel
# 3197        Intel
# 3198        Intel
# 3199        Intel
# 3200        Intel
# 3201        Intel
# 3202        Intel
# 3203          AMD
# 3204        Intel
# 3205        Intel
# 3206        Intel
# 3207        Intel
# 3208        Intel
# 3209        Intel
# 3210        Intel
# 3211        Intel
# 3212        Intel
# 3213        Intel
# 3214        Intel
# 3215        Intel
# 3216        Intel
# 3217        Intel
# 3218        Intel
# 3219        Intel
# 3220        Intel
# 3221        Intel
# 3222        Intel
# 3223        Intel
# 3224        Intel
# 3225        Intel
# 3226          AMD
# 3227        Intel
# 3228        Intel
# 3229        Intel
# 3230        Intel
# 3231        Intel
# 3232        Intel
# 3233        Intel
# 3234          AMD
# 3235        Intel
# 3236        Intel
# 3237        Intel
# 3238        Intel
# 3239        Intel
# 3240        Intel
# 3241        Intel
# 3242          AMD
# 3243        Intel
# 3244          AMD
# 3245        Intel
# 3246        Intel
# 3247        Intel
# 3248        Intel
# 3249        Intel
# 3250          1.7
# 3251        Intel
# 3252          AMD
# 3253          AMD
# 3254        Intel
# 3255          AMD
# 3256        Intel
# 3257          AMD
# 3258          AMD
# 3259          AMD
# 3260          AMD
# 3261        Intel
# 3262        Intel
# 3263        Intel
# 3264        Intel
# 3265        Intel
# 3266        Intel
# 3267        Intel
# 3268          AMD
# 3269        Intel
# 3270        Intel
# 3271        Intel
# 3272        Intel
# 3273        Intel
# 3274        Intel
# 3275          2.0
# 3276        Intel
# 3277        Intel
# 3278        Intel
# 3279        Intel
# 3280        Intel
# 3281        Intel
# 3282        Intel
# 3283        Intel
# 3284        Intel
# 3285          AMD
# 3286        Intel
# 3287        Intel
# 3288        Intel
# 3289        Intel
# 3290        Intel
# 3291        Intel
# 3292          AMD
# 3293        Intel
# 3294        Intel
# 3295          AMD
# 3296        Intel
# 3297          AMD
# 3298        Intel
# 3299        Intel
# 3300        Intel
# 3301        Intel
# 3302        Intel
# 3303        Intel
# 3304        Intel
# 3305        Intel
# 3306        Intel
# 3307          AMD
# 3308        Intel
# 3309        Intel
# 3310        Intel
# 3311        Intel
# 3312        Intel
# 3313        Intel
# 3314          AMD
# 3315        Intel
# 3316        Intel
# 3317        Intel
# 3318        Intel
# 3319          AMD
# 3320        Intel
# 3322        Intel
# 3323        Intel
# 3324          AMD
# 3325        Intel
# 3326        Intel
# 3327        Intel
# 3328        Intel
# 3329        Intel
# 3330        Intel
# 3331          AMD
# 3332        Intel
# 3333        Intel
# 3334        Intel
# 3335        Intel
# 3336        Intel
# 3337        Intel
# 3338        Intel
# 3339        Intel
# 3340        Intel
# 3341        Intel
# 3342        Intel
# 3343          AMD
# 3344          AMD
# 3345        Intel
# 3346          AMD
# 3347        Intel
# 3348        Intel
# 3349        Intel
# 3350          AMD
# 3351        Intel
# 3352          AMD
# 3353          AMD
# 3354        Intel
# 3355        Intel
# 3356        Intel
# 3357          AMD
# 3358        Intel
# 3359        Intel
# 3360        Intel
# 3361          AMD
# 3362          AMD
# 3363        Intel
# 3364        Intel
# 3365        Intel
# 3366        Intel
# 3367        Intel
# 3368        Intel
# 3369        Intel
# 3370        Intel
# 3371        Intel
# 3372        Intel
# 3373        Intel
# 3374        Intel
# 3375        Intel
# 3376        Intel
# 3377          AMD
# 3378        Intel
# 3379        Intel
# 3380        Intel
# 3381        Intel
# 3382        Intel
# 3383        Intel
# 3384          AMD
# 3385        Intel
# 3386        Intel
# 3387          AMD
# 3388        Intel
# 3389          AMD
# 3390        Intel
# 3391        Intel
# 3392        Intel
# 3393        Intel
# 3394        Intel
# 3395          AMD
# 3396        Intel
# 3397        Intel
# 3398        Intel
# 3399        Intel
# 3400          AMD
# 3401        Intel
# 3402        Intel
# 3403        Intel
# 3404          AMD
# 3405        Intel
# 3406          AMD
# 3407        Intel
# 3408        Intel
# 3409        Intel
# 3410        Intel
# 3411        Intel
# 3412        Intel
# 3413        Intel
# 3414        Intel
# 3415        Intel
# 3416          AMD
# 3417          AMD
# 3418        Intel
# 3419        Intel
# 3420        Intel
# 3421          AMD
# 3422        Intel
# 3423        Intel
# 3424        Intel
# 3425        Intel
# 3426        Intel
# 3427        Intel
# 3428        Intel
# 3429        Intel
# 3430          AMD
# 3431        Intel
# 3432          AMD
# 3433        Intel
# 3434        Intel
# 3435        Intel
# 3436          AMD
# 3437          AMD
# 3438        Intel
# 3439        Intel
# 3440          AMD
# 3441        Intel
# 3442        Intel
# 3443        Intel
# 3444        Intel
# 3445        Intel
# 3446        Intel
# 3447        Intel
# 3448        Intel
# 3449        Intel
# 3450          AMD
# 3451        Intel
# 3452        Intel
# 3453        Intel
# 3454          AMD
# 3455          AMD
# 3456        Intel
# 3457        Intel
# 3458        Intel
# 3459        Intel
# 3460        Intel
# 3461        Intel
# 3462          AMD
# 3463          AMD
# 3464          AMD
# 3465        Intel
# 3466        Intel
# 3467          AMD
# 3468        Intel
# 3469        Intel
# 3470        Intel
# 3471        Intel
# 3472        Intel
# 3473          AMD
# 3474        Intel
# 3475          AMD
# 3476          AMD
# 3477        Intel
# 3478          2.1
# 3479        Intel
# 3480        Intel
# 3481        Intel
# 3482          AMD
# 3483        Intel
# 3484        Intel
# 3485        Intel
# 3486          AMD
# 3487          2.4
# 3488        Intel
# 3489        Intel
# 3490        Intel
# 3491          AMD
# 3492        Intel
# 3493        Intel
# 3494        Intel
# 3495        Intel
# 3496        Intel
# 3497        Intel
# 3498        Intel
# 3499          2.0
# 3500        Intel
# 3501        Intel
# 3502          AMD
# 3503        Intel
# 3504          1.8
# 3505        Intel
# 3506        Intel
# 3507        Intel
# 3508        Intel
# 3509          AMD
# 3510        Intel
# 3511        Intel
# 3512          1.7
# 3513        Intel
# 3514        Intel
# 3515        Intel
# 3516        Intel
# 3517        Intel
# 3518        Intel
# 3519        Intel
# 3520          AMD
# 3521        Intel
# 3522        Intel
# 3523          AMD
# 3524        Intel
# 3525        Intel
# 3526        Intel
# 3527        Intel
# 3528        Intel
# 3529        Intel
# 3530        Intel
# 3531        Intel
# 3532        Intel
# 3533          AMD
# 3534        Intel
# 3535          2.1
# 3536        Intel
# 3537        Intel
# 3538        Intel
# 3539        Intel
# 3540        Intel
# 3541        Intel
# 3542        Intel
# 3543        Intel
# 3544          AMD
# 3545        Intel
# 3546        Intel
# 3547        Intel
# 3548          AMD
# 3549        Intel
# 3550          AMD
# 3551        Intel
# 3552        Intel
# 3553          AMD
# 3554          AMD
# 3555          AMD
# 3556        Intel
# 3557          AMD
# 3558          AMD
# 3559        Intel
# 3560          AMD
# 3561        Intel
# 3562        Intel
# 3563        Intel
# 3564        Intel
# 3565        Intel
# 3566        Intel
# 3567          AMD
# 3568        Intel
# 3569        Intel
# 3570        Intel
# 3571        Intel
# 3572          AMD
# 3573        Intel
# 3574          AMD
# 3575        Intel
# 3576          AMD
# 3577        Intel
# 3578          AMD
# 3579        Intel
# 3580        Intel
# 3581        Intel
# 3582        Intel
# 3583        Intel
# 3584        Intel
# 3585        Intel
# 3586          AMD
# 3587        Intel
# 3588        Intel
# 3589        Intel
# 3590        Intel
# 3591        Intel
# 3592        Intel
# 3593        Intel
# 3594        Intel
# 3595        Intel
# 3596        Intel
# 3597          AMD
# 3598        Intel
# 3599        Intel
# 3600        Intel
# 3601        Intel
# 3602        Intel
# 3603        Intel
# 3604        Intel
# 3605        Intel
# 3606        Intel
# 3607        Intel
# 3608        Intel
# 3609        Intel
# 3610        Intel
# 3611        Intel
# 3612        Intel
# 3613          AMD
# 3614        Intel
# 3615        Intel
# 3616        Intel
# 3617        Intel
# 3618        Intel
# 3619        Intel
# 3620        Intel
# 3621          AMD
# 3622        Intel
# 3623        Intel
# 3624        Intel
# 3625        Intel
# 3626        Intel
# 3627        Intel
# 3628        Intel
# 3629        Intel
# 3630          AMD
# 3631        Intel
# 3632        Intel
# 3633        Intel
# 3634        Intel
# 3635        Intel
# 3636        Intel
# 3637        Intel
# 3638        Intel
# 3639          AMD
# 3640        Intel
# 3641        Intel
# 3642    Microsoft
# 3643        Intel
# 3644        Intel
# 3645          AMD
# 3646        Intel
# 3647        Intel
# 3648        Intel
# 3649          AMD
# 3650        Intel
# 3651        Intel
# 3652        Intel
# 3653        Intel
# 3654        Intel
# 3655        Intel
# 3656        Intel
# 3657        Intel
# 3658          AMD
# 3659          AMD
# 3660          AMD
# 3661        Intel
# 3662        Intel
# 3663        Intel
# 3664        Intel
# 3665        Intel
# 3666        Intel
# 3667        Intel
# 3668          AMD
# 3669        Intel
# 3670        Intel
# 3671        Intel
# 3672          AMD
# 3673        Intel
# 3674        Intel
# 3675        Intel
# 3676        Intel
# 3677        Intel
# 3678          AMD
# 3679        Intel
# 3680        Intel
# 3681        Intel
# 3682        Intel
# 3683        Intel
# 3684        Intel
# 3685        Intel
# 3686        Intel
# 3687          AMD
# 3688          AMD
# 3689        Intel
# 3690        Intel
# 3691        Intel
# 3692        Intel
# 3693          AMD
# 3694        Intel
# 3695          AMD
# 3696        Intel
# 3697        Intel
# 3698        Intel
# 3699        Intel
# 3700        Intel
# 3701        Intel
# 3702        Intel
# 3703        Intel
# 3704        Intel
# 3705          AMD
# 3706        Intel
# 3707        Intel
# 3708        Intel
# 3709          3.0
# 3710          AMD
# 3711        Intel
# 3712        Intel
# 3713        Intel
# 3714        Intel
# 3715        Intel
# 3716        Intel
# 3717        Intel
# 3718        Intel
# 3719          AMD
# 3720        Intel
# 3721        Intel
# 3722        Intel
# 3723        Intel
# 3724        Intel
# 3725          AMD
# 3726        Intel
# 3727          AMD
# 3728        Intel
# 3729          AMD
# 3730          AMD
# 3731        Intel
# 3732        Intel
# 3733        Intel
# 3734        Intel
# 3735        Intel
# 3736        Intel
# 3737        Intel
# 3738        Intel
# 3739        Intel
# 3740        Intel
# 3741        Intel
# 3742        Intel
# 3743          AMD
# 3744        Intel
# 3745          AMD
# 3746        Intel
# 3747        Intel
# 3748          AMD
# 3749        Intel
# 3750        Intel
# 3751        Intel
# 3752        Intel
# 3753        Intel
# 3754        Intel
# 3755          AMD
# 3756          AMD
# 3757        Intel
# 3758        Intel
# 3759        Intel
# 3760          AMD
# 3761          AMD
# 3762        Intel
# 3763        Intel
# 3764        Intel
# 3765        Intel
# 3766        Intel
# 3767        Intel
# 3768        Intel
# 3769        Intel
# 3770          AMD
# 3771        Intel
# 3772        Intel
# 3773        Intel
# 3774        Intel
# 3775        Intel
# 3776        Intel
# 3777        Intel
# 3778        Intel
# 3779        Intel
# 3780        Intel
# 3781          AMD
# 3782        Intel
# 3783        Intel
# 3784        Intel
# 3785        Intel
# 3786        Intel
# 3787        Intel
# 3788        Intel
# 3789        Intel
# 3790        Intel
# 3791          AMD
# 3792        Intel
# 3793          1.9
# 3794        Intel
# 3795          AMD
# 3796        Intel
# 3797        Intel
# 3798        Intel
# 3799        Intel
# 3800        Intel
# 3801        Intel
# 3802        Intel
# 3803        Intel
# 3804        Intel
# 3805        Intel
# 3806        Intel
# 3807        Intel
# 3808          AMD
# 3809        Intel
# 3810        Intel
# 3811        Intel
# 3812        Intel
# 3813        Intel
# 3814        Intel
# 3815          1.7
# 3816          AMD
# 3817        Intel
# 3818          AMD
# 3819        Intel
# 3820        Intel
# 3821        Intel
# 3822        Intel
# 3823        Intel
# 3824        Intel
# 3825        Intel
# 3826          AMD
# 3827          AMD
# 3828        Intel
# 3829        Intel
# 3830        Intel
# 3831          AMD
# 3832        Intel
# 3833        Intel
# 3834        Intel
# 3835        Intel
# 3836        Intel
# 3837          AMD
# 3838        Intel
# 3839        Intel
# 3840        Intel
# 3841          AMD
# 3842        Intel
# 3843        Intel
# 3844        Intel
# 3845          AMD
# 3846        Intel
# 3847        Intel
# 3848          AMD
# 3849          AMD
# 3850        Intel
# 3851        Intel
# 3852        Intel
# 3853        Intel
# 3854        Intel
# 3855        Intel
# 3856          AMD
# 3857        Intel
# 3858        Intel
# 3859          AMD
# 3860        Intel
# 3861        Intel
# 3862        Intel
# 3863        Intel
# 3864        Intel
# 3865        Intel
# 3866        Intel
# 3867          AMD
# 3868        Intel
# 3869        Intel
# 3870          AMD
# 3871          AMD
# 3872        Intel
# 3873        Intel
# 3874        Intel
# 3875        Intel
# 3876        Intel
# 3877        Intel
# 3878        Intel
# 3879        Intel
# 3880        Intel
# 3881        Intel
# 3882        Intel
# 3883          AMD
# 3884        Intel
# 3885          AMD
# 3886        Intel
# 3887        Intel
# 3888        Intel
# 3889        Intel
# 3890        Intel
# 3891        Intel
# 3892        Intel
# 3893          AMD
# 3894        Intel
# 3895        Intel
# 3896          AMD
# 3897        Intel
# 3898          AMD
# 3899        Intel
# 3900        Intel
# 3901        Intel
# 3902        Intel
# 3903        Intel
# 3904        Intel
# 3905        Intel
# 3906          AMD
# 3907        Intel
# 3908        Intel
# 3909        Intel
# 3910          AMD
# 3911        Intel
# 3912          AMD
# 3913        Intel
# 3914          2.6
# 3915          AMD
# 3916        Intel
# 3917          AMD
# 3918          AMD
# 3919        Intel
# 3920        Intel
# 3921        Intel
# 3922        Intel
# 3923        Intel
# 3924        Intel
# 3925          AMD
# 3926        Intel
# 3927        Intel
# 3928        Intel
# 3929        Intel
# 3930        Intel
# 3931        Intel
# 3932        Intel
# 3933        Intel
# 3934        Intel
# 3935          AMD
# 3936        Intel
# 3937        Intel
# 3938        Intel
# 3939        Intel
# 3940        Intel
# 3941        Intel
# 3942        Intel
# 3943        Intel
# 3944          AMD
# 3945        Intel
# 3946        Intel
# 3947        Intel
# 3948        Intel
# 3949        Intel
# 3950          AMD
# 3951        Intel
# 3952        Intel
# 3953        Intel
# 3954        Intel
# 3955        Intel
# 3956        Intel
# 3957        Intel
# 3958        Intel
# 3959        Intel
# 3960        Intel
# 3961        Intel
# 3962        Intel
# 3963        Intel
# 3964        Intel
# 3965        Intel
# 3966        Intel
# 3967          AMD
# 3968        Intel
# 3969        Intel
# 3970        Intel
# 3971        Intel
# 3972        Intel
# 3973          AMD
# 3974          AMD
# 3975        Intel
# Name: Processor_Brand, dtype: object>

# %%
df.shape
# Out:
# (3972, 18)

# %%
valid_processors = ['Intel', 'AMD', 'Apple', 'MediaTek', 'Qualcomm', 'Microsoft']
df = df[df['Processor_Brand'].isin(valid_processors)]

# %%
df.shape
# Out:
# (3951, 18)

# %%
df['Processor_Brand'].value_counts()
# Out:
# Processor_Brand
# Intel        3006
# AMD           919
# Apple          20
# MediaTek        4
# Qualcomm        1
# Microsoft       1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15, 6))
sns.countplot(data=df, x='Processor_Brand', hue='Processor_Brand', palette='Set2')
plt.xticks(rotation=45)
plt.title("Processor Brands Count")
plt.show()

# %%
print(df['Processor_Brand'].value_counts(normalize=True) * 100)
# Out:
# Processor_Brand
# Intel        76.082005
# AMD          23.259934
# Apple         0.506201
# MediaTek      0.101240
# Qualcomm      0.025310
# Microsoft     0.025310
# Name: proportion, dtype: float64

# %% [markdown]
# * Intel and AMD are the prominant, but apple laptops has special apple chips therefore it also need to be consider. reset can be ignore/drop

# %%
print(df.shape)
top_processor = ['Intel', 'AMD', 'Apple']
df = df[df['Processor_Brand'].isin(top_processor)]
print(df.shape)
df['Processor_Brand'].value_counts()
# Out:
# (3951, 18)
# (3945, 18)
# Processor_Brand
# Intel    3006
# AMD       919
# Apple      20
# Name: count, dtype: int64

# %%
pd.set_option('display.max_rows', None)
df['Processor_Name'].value_counts()
# Out:
# Processor_Name
# Intel Core i5 (11th Gen)              316
# Intel Core i5 (12th Gen)              294
# AMD Hexa-Core Ryzen 5                 245
# AMD Octa-Core Ryzen 7                 238
# Intel Core i3 (11th Gen)              188
# Intel Core i5 (10th Gen)              177
# Intel Core i5 (8th Gen)               174
# Intel Core i7 (12th Gen)              171
# Intel Core i3 (10th Gen)              152
# Intel Core i7 (13th Gen)              136
# Intel Core i5 (13th Gen)              134
# AMD Quad-Core Ryzen 5                 108
# Intel Celeron Dual-Core               103
# Intel Core i7 (11th Gen)               92
# Intel Core i3 (12th Gen)               90
# Intel Core i3 (7th Gen)                72
# Intel Core i7 (8th Gen)                68
# AMD Dual-Core Ryzen 3                  67
# Intel Core i3 (6th Gen)                62
# Intel Core i5 (7th Gen)                60
# Intel Core i7 (10th Gen)               58
# Intel Core Ultra 7                     52
# AMD Quad-Core Ryzen 3                  46
# AMD Octa-Core Ryzen 9                  45
# Intel Pentium Quad-Core                43
# Intel Core i5 (11th Gen) Processor     38
# Intel Core i5 (9th Gen)                36
# Intel Core i9 (13th Gen)               35
# Intel Core i3 (13th Gen)               34
# Intel Core i7 (7th Gen)                34
# AMD Dual-Core Athlon                   34
# Intel Core i3 (8th Gen)                33
# Intel Core i7 (9th Gen)                26
# Intel Core i7 (11th Gen) Processor     25
# Intel Core Ultra 5                     24
# Intel Core i3 (11th Gen) Processor     23
# Intel Core i9 (12th Gen)               22
# AMD Dual-Core A6 APU                   21
# AMD Dual-Core A9 APU                   20
# Intel Core i9 (14th Gen)               18
# Intel Core i5 (6th Gen)                17
# Intel Core Ultra 9                     17
# AMD Hexa-Core Ryzen 5 Processor        16
# AMD Octa-Core Ryzen 7 Processor        16
# Intel Core i7 (14th Gen)               15
# Intel Atom Quad-Core                   14
# AMD Quad-Core Ryzen 7                  11
# Intel Core 5 (Series 1)                11
# Apple M2 Processor                     10
# Intel Core i5 (12th Gen) Processor     10
# Intel Core i3 (12th Gen) Processor      9
# Intel Core i5 (13th Gen) Processor      9
# Intel Core i5 (5th Gen)                 9
# AMD Dual-Core APU                       8
# Intel Core i9 (11th Gen)                8
# Intel Pentium Dual-Core                 8
# Intel Core i3 (5th Gen)                 8
# Intel Core i7 (13th Gen) Processor      7
# AMD Quad-Core A8 APU                    7
# Intel Celeron Quad-Core                 6
# AMD Dual-Core A4 APU                    6
# Intel Pentium Gold                      6
# Intel Core 7 (Series 1)                 5
# Intel Core i7 (10th Gen) Processor      5
# Intel Core i5 (10th Gen) Processor      4
# Intel Core i7 (6th Gen)                 4
# AMD Quad-Core APU                       4
# Intel Core M3 (7th Gen)                 4
# AMD Dual-Core E1 APU                    4
# Intel Core i9 (10th Gen)                4
# Intel Core i5 (4th Gen)                 4
# Intel Core i3 (3rd Gen)                 3
# AMD Quad-Core Ryzen 3 Processor         3
# Intel Core i3 (10th Gen) Processor      3
# Intel Core i7 (12th Gen) Processor      3
# Intel Core i3 (13th Gen) Processor      3
# Intel Celeron Dual-Core Processor       3
# AMD Quad-Core Ryzen 5 Processor         3
# Apple M2 Pro                            3
# AMD Quad-Core A12 APU                   3
# Intel Core i3 (4th Gen)                 3
# AMD Quad-Core A10 APU                   2
# AMD Dual-Core Ryzen 3 Processor         2
# Apple M3 Pro                            2
# Intel Core i5 (1st Gen)                 2
# AMD Quad-Core A6 APU                    2
# Intel Core i9 (9th Gen)                 2
# AMD Quad-Core E2 APU                    2
# Apple M1                                1
# AMD Hexadeca-Core Ryzen 9               1
# Apple M2 Max Processor                  1
# Intel Core i9 (14th Gen) Processor      1
# Intel Core i9 (13th Gen) Processor      1
# Apple M1 Processor                      1
# Intel Pentium Quad-Core Processor       1
# Apple M1 Pro                            1
# AMD Quad-Core Ryzen 7 Processor         1
# Apple M2 Max                            1
# AMD Octa-Core Ryzen 7 Pro               1
# Intel Core i9 (8th Gen)                 1
# Intel Core 3 (Series 1)                 1
# Intel Core M3 (6th Gen)                 1
# Intel Core M5 (6th Gen)                 1
# AMD Dual-Core Athlon Processor          1
# Intel Core i5 (9th Gen) Processor       1
# Intel Core i7 (5th Gen)                 1
# Intel Core i7 (4th Gen)                 1
# AMD Dual-Core A9 APU Processor          1
# AMD Octa-Core Ryzen 9 Processor         1
# Name: count, dtype: int64

# %%
# import re

# def categorize_processor(row):
#     name = row['Processor_Name']
#     brand = row['Processor_Brand']
    
#     if brand == 'Intel':
#         # Capture i3/i5/i7/i9 or Core Ultra, Core series, etc.
#         match = re.search(r'i[3579]', name)
#         if match:
#             return f"Intel {match.group(0).upper()}"
#         elif re.search(r'Ultra\s*5', name, re.I):
#             return "Intel Ultra 5"
#         elif re.search(r'Ultra\s*7', name, re.I):
#             return "Intel Ultra 7"
#         elif re.search(r'Ultra\s*9', name, re.I):
#             return "Intel Ultra 9"
#         elif re.search(r'Pentium', name, re.I):
#             return "Intel Pentium"
#         elif re.search(r'Celeron', name, re.I):
#             return "Intel Celeron"
#         else:
#             return "Intel Other"
    
#     elif brand == 'AMD':
#         # Ryzen families or Athlon/A-series
#         match = re.search(r'Ryzen\s*[3579]', name, re.I)
#         if match:
#             return f"AMD {match.group(0).title()}"
#         elif re.search(r'Athlon', name, re.I):
#             return "AMD Athlon"
#         elif re.search(r'A\d', name, re.I):
#             # e.g., A6, A8, A10, A12
#             a_match = re.search(r'A\d+', name, re.I)
#             return f"AMD {a_match.group(0).upper()}"
#         else:
#             return "AMD Other"
    
#     elif brand == 'Apple':
#         # All M-series grouped together
#         return "Apple M-series"
    
#     else:
#         return "Other"

# # Apply to DataFrame
# df['Processor_Category'] = df.apply(categorize_processor, axis=1)

# # Quick look at the result
# print(df['Processor_Category'].value_counts())

# %%
import re

def categorize_processor(row):
    name = row['Processor_Name']
    brand = row['Processor_Brand']
    
    if brand == 'Intel':
        # Capture i3/i5/i7/i9 or Core Ultra, Core series, etc.
        match = re.search(r'i[3579]', name)
        if match:
            return f"Intel {match.group(0).upper()}"
        elif re.search(r'Ultra\s*5', name, re.I):
            return "Intel Ultra 5"
        elif re.search(r'Ultra\s*7', name, re.I):
            return "Intel Ultra 7"
        elif re.search(r'Ultra\s*9', name, re.I):
            return "Intel Ultra 9"
        elif re.search(r'Pentium', name, re.I):
            return "Intel Pentium"
        elif re.search(r'Celeron', name, re.I):
            return "Intel Celeron"
        else:
            return "Intel Other"
    
    elif brand == 'AMD':
        # Ryzen families or Athlon/A-series
        match = re.search(r'Ryzen\s*[3579]', name, re.I)
        if match:
            return f"AMD {match.group(0).title()}"
        elif re.search(r'Athlon', name, re.I):
            return "AMD Athlon"
        elif re.search(r'\bA\d+\b', name, re.I):
            return "AMD A-Series"
        else:
            return "AMD Other"
    
    elif brand == 'Apple':
        # All M-series grouped together
        return "Apple M-series"
    
    else:
        return "Other"

# Apply to DataFrame
df['Processor_Category'] = df.apply(categorize_processor, axis=1)

# Quick look at the result
print(df['Processor_Category'].value_counts())
# Out:
# Processor_Category
# Intel I5          1285
# Intel I3           683
# Intel I7           646
# AMD Ryzen 5        372
# AMD Ryzen 7        267
# AMD Ryzen 3        118
# Intel Celeron      112
# Intel I9            92
# AMD A-Series        62
# Intel Pentium       58
# Intel Ultra 7       52
# AMD Ryzen 9         47
# Intel Other         37
# AMD Athlon          35
# Intel Ultra 5       24
# Apple M-series      20
# AMD Other           18
# Intel Ultra 9       17
# Name: count, dtype: int64

# %%
avg_price = df.groupby('Processor_Category')['Price'].mean().sort_values()

plt.figure(figsize=(18,5))
plt.barh(avg_price.index, avg_price.values)   # horizontal bar chart
plt.xlabel("Average Price")
plt.ylabel("Processor Category")
plt.title("Average Laptop Price by Processor Category")
plt.tight_layout()
plt.show()

# %% [markdown]
# - Map every Intel, AMD processor in to high/mid/low-end

# %%
# def map_segment(row):
#     brand = row['Processor_Brand']
#     cat   = row['Processor_Category']

#     if brand == 'Intel':
#         if cat in ['Intel I9', 'Intel Ultra 9']:
#             return 'High-End'
#         elif cat in ['Intel I7', 'Intel Ultra 7']:
#             return 'Upper Mid-End'
#         elif cat in ['Intel I5', 'Intel Ultra 5']:
#             return 'Mid-End'
#         elif cat in ['Intel I3', 'Intel Celeron', 'Intel Pentium', 'Intel Other']:
#             return 'Low-End'

#     elif brand == 'AMD':
#         if cat in ['AMD Ryzen 9']:
#             return 'High-End'
#         elif cat in ['AMD Ryzen 7']:
#             return 'Upper Mid-End'
#         elif cat in ['AMD Ryzen 5']:
#             return 'Mid-End'
#         elif cat in [
#             'AMD Ryzen 3', 'AMD Athlon', 'AMD A12', 'AMD A10',
#             'AMD A9', 'AMD A8', 'AMD A6', 'AMD A4', 'AMD Other'
#         ]:
#             return 'Low-End'

#     elif brand == 'Apple':
#         return 'Apple M-series' 

#     return 'Other'

# %%
def map_segment(row):
    brand = row['Processor_Brand']
    cat   = row['Processor_Category']

    if brand == 'Intel':
        if cat in ['Intel I9', 'Intel Ultra 9']:
            return 'High-End'
        elif cat in ['Intel I7', 'Intel Ultra 7']:
            return 'Upper Mid-End'
        elif cat in ['Intel I5', 'Intel Ultra 5']:
            return 'Mid-End'
        elif cat in ['Intel I3', 'Intel Celeron', 'Intel Pentium', 'Intel Other']:
            return 'Low-End'

    elif brand == 'AMD':
        if cat in ['AMD Ryzen 9']:
            return 'High-End'
        elif cat in ['AMD Ryzen 7']:
            return 'Upper Mid-End'
        elif cat in ['AMD Ryzen 5']:
            return 'Mid-End'
        elif cat in [
            'AMD Ryzen 3', 'AMD Athlon', "AMD A-Series", 'AMD Other'
        ]:
            return 'Low-End'

    elif brand == 'Apple':
        return 'Apple M-series' 

    return 'Other'

# %%
df['Processor_Tier'] = df.apply(map_segment, axis=1)
print(df['Processor_Tier'].value_counts())
# Out:
# Processor_Tier
# Mid-End           1681
# Low-End           1123
# Upper Mid-End      965
# High-End           156
# Apple M-series      20
# Name: count, dtype: int64

# %%
# Calculate mean price by Processor_Tier
avg_price_tier = df.groupby('Processor_Tier')['Price'].mean().sort_values()

# Plot horizontal bar chart
plt.figure(figsize=(18,3))
plt.barh(avg_price_tier.index, avg_price_tier.values, color='skyblue')
plt.xlabel("Average Price")
plt.ylabel("Processor Tier")
plt.title("Average Laptop Price by Processor Tier")
plt.tight_layout()
plt.show()

# %%
df.head(5)
# Out:
#     Brand                                               Name     Price  \
# 1  Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  127011.5
# 2    Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  274750.0
# 3      HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  194215.0
# 4   Other  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...   76965.0
# 5    Acer  Acer One 14 Z8-415 (UN.599SI.020) Laptop (14 I...  122465.0
#
#                        Processor_Name Processor_Brand     RAM_Expandable  \
# 1               AMD Hexa-Core Ryzen 5             AMD   12 GB Expandable
# 2            Intel Core i5 (12th Gen)           Intel   32 GB Expandable
# 3            Intel Core i5 (12th Gen)           Intel    8 GB Expandable
# 4            Intel Core i3 (11th Gen)           Intel     Not Expandable
# 5  Intel Core i5 (11th Gen) Processor           Intel   32 GB Expandable
#
#        RAM      RAM_TYPE                 Ghz Display_type Display  \
# 1    8 GB      DDR4 RAM    4.0 Ghz Processor          LCD   15.6
# 2   16 GB      DDR5 RAM    3.3 Ghz Processor          LCD   15.6
# 3    8 GB      DDR4 RAM    4.2 Ghz Processor          LCD   15.6
# 4  8 GB LP   LPDDR4X RAM   1.7 Ghz Processor          LCD   15.6
# 5   16 GB      DDR4 RAM                    0          LCD     14
#
#                           GPU GPU_Brand                 SSD     HDD Adapter  \
# 1                      Radeon       AMD  512 GB SSD Storage  No HDD      65
# 2  GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD Storage  No HDD      56
# 3                     Iris Xe     Intel  512 GB SSD Storage  No HDD      no
# 4                         UHD     Intel  512 GB SSD Storage  No HDD      45
# 5                     Iris Xe     Intel  512 GB SSD Storage  No HDD      45
#
#                  Battery_Life Operating_System Processor_Category  \
# 1    Upto 11 Hrs Battery Life       Windows 11        AMD Ryzen 5
# 2    Upto 10 Hrs Battery Life       Windows 11           Intel I5
# 3  Upto 7.30 Hrs Battery Life       Windows 11           Intel I5
# 4     Upto 8 Hrs Battery Life       Windows 11           Intel I3
# 5                 45W Adapter       Windows 11           Intel I5
#
#   Processor_Tier
# 1        Mid-End
# 2        Mid-End
# 3        Mid-End
# 4        Low-End
# 5        Mid-End

# %% [markdown]
# #### RAM

# %%
# Filter rows where 'RAM_TYPE' contains 'LP'
filtered_df = df[df['RAM_TYPE'].str.contains('LP', case=False, na=False)]

# Count unique (RAM, RAM_TYPE) combinations
print(filtered_df[['RAM', 'RAM_TYPE']].value_counts())
# Out:
# RAM       RAM_TYPE
# 16 GB LP  LPDDR5 RAM      84
#           LPDDR5 RAM      66
#           LPDDR4X RAM     64
# 8 GB LP   LPDDR5 RAM      48
#           LPDDR4X RAM     43
#           LPDDR3 RAM      35
# 16 GB LP  LPDDR5X RAM     30
# 8 GB LP   LPDDR5 RAM      27
# 16 GB LP  LPDDR4X RAM     19
#           LPDDR5X RAM     19
# 32 GB LP  LPDDR5X RAM     16
# 8 GB LP   LPDDR4X RAM     15
# 4 GB LP   LPDDR4 RAM      13
# 32 GB LP  LPDDR5X RAM     12
#           LPDDR5 RAM      10
# 4 GB LP   LPDDR4X RAM      9
# 8 GB LP   LPDDR4 RAM       8
# 16 GB LP  LPDDR3 RAM       7
# 32 GB LP  LPDDR5 RAM       6
# 4 GB LP   LPDDR3 RAM       6
# 16 GB LP  LPDDR4 RAM       5
#           LPDDR4 RAM       5
# 4 GB LP   LPDDR4 RAM       3
# 32 GB LP  LPDDR4X RAM      3
#           LPDDR4X RAM      1
# 4 GB LP   LPDDR3 RAM       1
#           LPDDR4X RAM      1
# 8 GB LP   LPDDR3 RAM       1
#           LPDDR5X RAM      1
#           LPDDR5X RAM      1
# Name: count, dtype: int64

# %%
print("RAM Unique Values:", df['RAM'].nunique())
print("Missing RAM values:", df['RAM'].isna().sum())
df['RAM'].value_counts()
# Out:
# RAM Unique Values: 20
# Missing RAM values: 0
# RAM
# 8 GB          1603
# 16 GB         1084
# 4 GB           535
# 16 GB LP       299
# 8 GB LP        179
# 32 GB           87
# 32 GB LP        48
# 4 GB LP         33
# 2 GB            22
# 16 GB RAM       16
# 8 GB RAM        14
# 64 GB            6
# 12 GB            6
# 16 GB RAM        4
# 32 GB RAM        3
# 3 GB             2
# 18 GB RAM        1
# 36 GB RAM        1
# 24 GB            1
# 6 GB             1
# Name: count, dtype: int64

# %% [markdown]
# - Clean RAM to get the capacity value

# %%
# df['RAM'] = df['RAM'].str.replace('RAM', '', regex=False)
# df['RAM'] = df['RAM'].str.replace('LP', '', regex=False)
# df['RAM'] = df['RAM'].str.replace('GB', '', regex=False)
# df['RAM'] = df['RAM'].str.strip().astype(int)

# %%
# def clean_ram(value):
#     if pd.isna(value):
#         return value  # keep NaN as is
    
#     text = str(value).upper().strip()

#     # Detect LP variants
#     if "LP" in text:
#         match = re.search(r'\d+', text)
#         if match:
#             return f"{match.group()} LP"
    
#     # Non-LP variants
#     match = re.search(r'\d+', text)
#     if match:
#         return match.group()  # just the number
    
#     return value  # fallback if unexpected

# # Apply to your dataframe
# df['RAM'] = df['RAM'].apply(clean_ram)

# %%
import pandas as pd
import re

def clean_ram(value):
    if pd.isna(value):
        return value  # keep NaN as is
    
    text = str(value).upper().strip()
    
    # Extract the first number in the string
    match = re.search(r'\d+', text)
    if match:
        return match.group()  # just the number
    
    return value 

# Apply to your dataframe
df['RAM'] = df['RAM'].apply(clean_ram)
df['RAM'] = df['RAM'].astype(int)

# %%
print(df['RAM'].value_counts().sort_index())
# Out:
# RAM
# 2       22
# 3        2
# 4      568
# 6        1
# 8     1796
# 12       6
# 16    1403
# 18       1
# 24       1
# 32     138
# 36       1
# 64       6
# Name: count, dtype: int64

# %%
avg_price_ram = df.groupby('RAM')['Price'].mean().sort_index()

# Plot
plt.figure(figsize=(18,6))
plt.bar(avg_price_ram.index.astype(str), avg_price_ram.values, color='teal')
plt.xlabel("RAM (GB)")
plt.ylabel("Average Price")
plt.title("Average Laptop Price by RAM Size")
plt.tight_layout()
plt.show()

# %%
# Here i map ram in to nearest standard sizes
# ram_map = {
#     2: 4,    # 2 GB → 4 GB
#     3: 4,    # 3 GB → 4 GB
#     6: 8,    # 6 GB → 8 GB 
#     12: 16,  # 12 GB → 16 GB
#     24: 32   # 24 GB → 32 GB
# }
# df['RAM'] = df['RAM'].replace(ram_map)

# %%
# standard_ram_sizes = [4, 8, 16, 32]
# df = df[df['RAM'].isin(standard_ram_sizes)]
# df.shape

# %%
standard_ram_sizes = [4, 8, 16, 32]
df = df[df['RAM'].isin(standard_ram_sizes)]
print(df.shape)
# Out:
# (3905, 20)

# %%
df['RAM'].value_counts()
# Out:
# RAM
# 8     1796
# 16    1403
# 4      568
# 32     138
# Name: count, dtype: int64

# %%
plt.figure(figsize=(18, 6))
sns.countplot(data=df, x='RAM', hue='RAM', palette='Set2')
plt.xticks(rotation=45)
plt.title("RAM Size Distribution")
plt.show()

# %%
df['Brand'].value_counts()
# Out:
# Brand
# ASUS       977
# Lenovo     803
# HP         784
# Dell       420
# Acer       317
# MSI        309
# Other      191
# Samsung     59
# Apple       45
# Name: count, dtype: int64

# %% [markdown]
# #### RAM Type and Processor Speed(Ghz)

# %%
print("RAM_TYPE Unique Values:", df['RAM_TYPE'].nunique())
print("Missing RAM_TYPE values:", df['RAM_TYPE'].isna().sum())
df['RAM_TYPE'].value_counts()
# Out:
# RAM_TYPE Unique Values: 19
# Missing RAM_TYPE values: 0
# RAM_TYPE
# DDR4 RAM        1497
# DDR4 RAM        1307
# DDR5 RAM         242
# LPDDR5 RAM       142
# DDR5 RAM         141
# LPDDR4X RAM      119
# LPDDR5 RAM        99
# DDR3 RAM          68
# DDR3 RAM          53
# LPDDR3 RAM        48
# LPDDR5X RAM       43
# LPDDR5X RAM       36
# LPDDR4X RAM       36
# RAM               33
# LPDDR4 RAM        26
# LPDDR4 RAM         8
# RAM                4
# LPDDR3 RAM         2
# DDR2 RAM           1
# Name: count, dtype: int64

# %%
df['Ghz'].value_counts().head(10)
# Out:
# Ghz
#  4.2 Ghz Processor    331
#  2.4 Ghz Processor    249
#  4.7 Ghz Processor    244
#  1.6 Ghz Processor    233
#  2.3 Ghz Processor    212
# 0                     202
#  3.3 Ghz Processor    197
#  4.8 Ghz Processor    181
#  2.1 Ghz Processor    176
#  2.6 Ghz Processor    175
# Name: count, dtype: int64

# %% [markdown]
# - Cleaning RAM-TYPE column

# %%
# df['RAM_TYPE'] = (
#     df['RAM_TYPE']
#     .astype(str)
#     .str.upper()                             
#     .str.replace(r'\s+', ' ', regex=True)    
#     .str.strip()                            
# )

# df['RAM_TYPE'] = df['RAM_TYPE'].replace({
#     'DDR4 RAM': 'DDR4',
#     'LPDDR4 RAM': 'DDR4',
#     'LPDDR4X RAM': 'DDR4',

#     'DDR5 RAM': 'DDR5',
#     'LPDDR5 RAM': 'DDR5',
#     'LPDDR5X RAM': 'DDR5',

#     'DDR3 RAM': 'DDR3',
#     'LPDDR3 RAM': 'DDR3',

#     'DDR2 RAM': 'DDR2'
# })

# df = df[df['RAM_TYPE'] != 'DDR2']

# %%
df['RAM_TYPE'] = (
    df['RAM_TYPE']
    .astype(str)
    .str.upper()
    .str.replace(r'\s+', ' ', regex=True)
    .str.strip()
)

df['RAM_TYPE'] = df['RAM_TYPE'].replace({
    # DDR4 family
    'DDR4 RAM': 'DDR4',
    'LPDDR4 RAM': 'LPDDR4',
    'LPDDR4X RAM': 'LPDDR4',

    # DDR5 family
    'DDR5 RAM': 'DDR5',
    'LPDDR5 RAM': 'LPDDR5',
    'LPDDR5X RAM': 'LPDDR5',

    # DDR3 family
    'DDR3 RAM': 'DDR3',
    'LPDDR3 RAM': 'LPDDR3',

    # DDR2 family (remove)
    'DDR2 RAM': 'DDR2'
})

# Remove old DDR2 laptops
df = df[df['RAM_TYPE'] != 'DDR2']

# %%
df['RAM_TYPE'].value_counts()
# Out:
# RAM_TYPE
# DDR4      2804
# DDR5       383
# LPDDR5     320
# LPDDR4     189
# DDR3       121
# LPDDR3      50
# RAM         37
# Name: count, dtype: int64

# %%
df['Ghz'].value_counts().head(10)
# Out:
# Ghz
#  4.2 Ghz Processor    331
#  2.4 Ghz Processor    249
#  4.7 Ghz Processor    244
#  1.6 Ghz Processor    233
#  2.3 Ghz Processor    212
# 0                     202
#  3.3 Ghz Processor    197
#  4.8 Ghz Processor    181
#  2.1 Ghz Processor    176
#  2.6 Ghz Processor    175
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3904, 20)

# %% [markdown]
# - Cleaning Ghz column

# %%
# Remove everything except the number at the start
df['Ghz'] = (
    df['Ghz']
      .astype(str)                                   # ensure string
      .str.extract(r'([\d\.]+)')                     # capture digits & decimal point
      .astype(float)                                  # convert to float
)

# %%
df.shape
# Out:
# (3904, 20)

# %%
df['Ghz'].value_counts()
# Out:
# Ghz
# 4.2    331
# 2.4    249
# 4.7    244
# 1.6    233
# 2.3    212
# 0.0    202
# 3.3    197
# 4.8    181
# 2.1    176
# 2.6    175
# 2.5    163
# 2.0    157
# 1.2    148
# 3.0    138
# 3.4    137
# 4.0    106
# 1.1    103
# 1.8     97
# 2.2     96
# 2.8     89
# 1.0     81
# 3.1     80
# 1.7     74
# 2.7     56
# 1.3     44
# 2.9     34
# 1.4     26
# 1.5     24
# 0.8     20
# 5.5     16
# 1.9     15
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3904, 20)

# %% [markdown]
# - Filling unkonwn values for Apple Ghz and RAM_TYPE ( Here manually fill not use any statistical method because of less data)
# - Here consider Apple seperately due to specific chips its has and dataset is rare

# %%
df[(df['Brand'] == 'Apple') & (df['Brand'] == 'Apple')][['Ghz', 'RAM_TYPE', 'Processor_Name','Processor_Tier']].head(10)
# Out:
#       Ghz RAM_TYPE           Processor_Name  Processor_Tier
# 80    2.9     DDR4                 Apple M1  Apple M-series
# 82    1.8   LPDDR3  Intel Core i5 (5th Gen)         Mid-End
# 96    0.0      RAM       Apple M2 Processor  Apple M-series
# 227   0.0   LPDDR5       Apple M2 Processor  Apple M-series
# 366   2.4   LPDDR3  Intel Core i5 (8th Gen)         Mid-End
# 371   0.0      RAM       Apple M2 Processor  Apple M-series
# 699   0.0      RAM   Apple M2 Max Processor  Apple M-series
# 1349  1.6   LPDDR3  Intel Core i5 (8th Gen)         Mid-End
# 1355  1.6   LPDDR3  Intel Core i5 (8th Gen)         Mid-End
# 1356  1.6   LPDDR3  Intel Core i5 (8th Gen)         Mid-End

# %%
# Apple M2 rows: set Ghz=3.49 and RAM_TYPE='LPDDR5 RAM'
df.loc[
    (df['Brand'] == 'Apple') &
    (df['Processor_Brand'] == 'Apple') &
    ((df['Ghz'] == 0.0) | (df['RAM_TYPE'] == 'RAM')) &
    df['Processor_Name'].str.contains('M2', na=False),
    ['Ghz', 'RAM_TYPE']
] = [3.49, 'DDR5'] # Values inserted manually by search in web

# Apple M1 rows: set Ghz=2.9 and RAM_TYPE='DDR4 RAM'
df.loc[
    (df['Brand'] == 'Apple') &
    (df['Processor_Brand'] == 'Apple') &
    ((df['Ghz'] == 0.0) | (df['RAM_TYPE'] == 'RAM')) &
    df['Processor_Name'].str.contains('M1', na=False),
    ['Ghz', 'RAM_TYPE']
] = [2.9, 'DDR4']

# Apple Intel Core i3 empty Ghz replaced with real value 1.1 Ghz
df.loc[
    (df['Brand'] == 'Apple') &
    (df['Processor_Brand'] == 'Intel') &
    ((df['Ghz'] == 0.0) | (df['RAM_TYPE'] == 'RAM')) &
    df['Processor_Name'].str.contains('Intel Core i3', na=False),
    ['Ghz', 'RAM_TYPE']
] = [1.1, 'DDR4']

# %%
df[(df['Brand'] == 'Apple') & (df['Brand'] == 'Apple')][['Ghz', 'RAM_TYPE', 'Processor_Name']].head(10)
# Out:
#        Ghz RAM_TYPE           Processor_Name
# 80    2.90     DDR4                 Apple M1
# 82    1.80   LPDDR3  Intel Core i5 (5th Gen)
# 96    3.49     DDR5       Apple M2 Processor
# 227   3.49     DDR5       Apple M2 Processor
# 366   2.40   LPDDR3  Intel Core i5 (8th Gen)
# 371   3.49     DDR5       Apple M2 Processor
# 699   3.49     DDR5   Apple M2 Max Processor
# 1349  1.60   LPDDR3  Intel Core i5 (8th Gen)
# 1355  1.60   LPDDR3  Intel Core i5 (8th Gen)
# 1356  1.60   LPDDR3  Intel Core i5 (8th Gen)

# %%
df[(df['Brand'] == 'Apple') & (df['Brand'] == 'Apple')][['Ghz', 'RAM_TYPE', 'Processor_Name']].shape
# Out:
# (45, 3)

# %% [markdown]
# * Filling unknown Processor speed and RAM for Intel or AMD by existing data

# %%
df[(df['RAM_TYPE'] == 'RAM') | (df['Ghz'] == 0.0)].shape
# Out:
# (210, 20)

# %% [markdown]
# 1. Filling RAM

# %% [markdown]
# Here Select most frequent RAM-Type by processor tier (High/Mid/Low-End)

# %%
most_freq_ram = (
    df[df['RAM_TYPE'] != 'RAM']  # exclude placeholder 'RAM'
      .groupby(['Processor_Brand', 'Processor_Tier'])['RAM_TYPE']
      .agg(lambda x: x.mode()[0] if not x.mode().empty else None)
      .reset_index()
      .rename(columns={'RAM_TYPE': 'Most_Freq_RAM'})
)

#Merge back to the original dataframe
df = df.merge(most_freq_ram, on=['Processor_Brand', 'Processor_Tier'], how='left')

#Replace 'RAM' with the most frequent RAM_TYPE
df['RAM_TYPE'] = df.apply(
    lambda row: row['Most_Freq_RAM'] if row['RAM_TYPE'] == 'RAM' else row['RAM_TYPE'],
    axis=1
)

df = df.drop(columns=['Most_Freq_RAM'])

df['RAM_TYPE'].value_counts()
# Out:
# RAM_TYPE
# DDR4      2828
# DDR5       399
# LPDDR5     318
# LPDDR4     188
# DDR3       121
# LPDDR3      50
# Name: count, dtype: int64

# %% [markdown]
# Filling Ghz

# %%
mean_ghz = (
    df[df['Ghz'] != 0.0]                       # exclude zeros from mean calc
      .groupby(['Processor_Brand', 'Processor_Tier'])['Ghz']
      .mean()
      .reset_index()
      .rename(columns={'Ghz': 'Mean_Ghz'})
)

#Merge the mean values back to df
df = df.merge(mean_ghz, on=['Processor_Brand', 'Processor_Tier'], how='left')

#Replace 0.0 with the corresponding mean
df['Ghz'] = df.apply(
    lambda row: row['Mean_Ghz'] if row['Processor_Brand'] in ['Intel','AMD'] 
                and row['Ghz'] == 0.0 else row['Ghz'],
    axis=1
)

df = df.drop(columns=['Mean_Ghz'])

print(df['Ghz'].value_counts().head())
# Out:
# Ghz
# 4.2    331
# 2.4    249
# 4.7    244
# 1.6    233
# 2.3    211
# Name: count, dtype: int64

# %% [markdown]
# - Rounding Ghz to nearest 0.5 GHz

# %%
df['Processor_Speed(Ghz)'] = (df['Ghz'] * 2).round() / 2

# %%
df['Processor_Speed(Ghz)'].value_counts()
# Out:
# Processor_Speed(Ghz)
# 2.5    923
# 2.0    582
# 4.0    438
# 3.0    402
# 1.5    401
# 3.5    364
# 1.0    353
# 4.5    244
# 5.0    181
# 5.5     16
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3904, 21)

# %% [markdown]
# - Extract the digit (3,4,5) from DDR string and convert to int

# %%
# import re

# # Extract the number after 'DDR' as an integer
# df['RAM_TYPE'] = df['RAM_TYPE'].str.extract(r'(\d+)').astype('Int64')
# df = df.rename(columns={'RAM_TYPE': 'RAM_TYPE(DDR)'})
# df['RAM_TYPE(DDR)'].value_counts()

# %%
import re

# Remove only 'DDR' text, keep 'LP' and other parts
df['RAM_TYPE'] = df['RAM_TYPE'].str.replace(r'DDR', '', regex=True).str.strip()

# Rename the column (optional)
df = df.rename(columns={'RAM_TYPE': 'RAM_TYPE(DDR)'})

# View unique categories or counts
df['RAM_TYPE(DDR)'].value_counts()
# Out:
# RAM_TYPE(DDR)
# 4      2828
# 5       399
# LP5     318
# LP4     188
# 3       121
# LP3      50
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3904, 21)

# %% [markdown]
# #### RAM Expandability

# %%
df['RAM_Expandable'].value_counts()
# Out:
# RAM_Expandable
# Not Expandable       2117
#  16 GB Expandable     753
#  32 GB Expandable     530
#  8 GB Expandable      179
#  12 GB Expandable     155
#  64 GB Expandable     152
#  48 GB Expandable       9
#  4 GB Expandable        6
#  2 GB Expandable        2
#  10 GB Expandable       1
# Name: count, dtype: int64

# %%
# Convert RAM_Expandable to Yes/No
df['RAM_Expandable'] = df['RAM_Expandable'].apply(lambda x: 'No' if 'Not' in x else 'Yes')
df['RAM_Expandable'].value_counts()
# Out:
# RAM_Expandable
# No     2117
# Yes    1787
# Name: count, dtype: int64

# %%
df.head()
# Out:
#     Brand                                               Name     Price  \
# 0  Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  127011.5
# 1    Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  274750.0
# 2      HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  194215.0
# 3   Other  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...   76965.0
# 4    Acer  Acer One 14 Z8-415 (UN.599SI.020) Laptop (14 I...  122465.0
#
#                        Processor_Name Processor_Brand RAM_Expandable  RAM  \
# 0               AMD Hexa-Core Ryzen 5             AMD            Yes    8
# 1            Intel Core i5 (12th Gen)           Intel            Yes   16
# 2            Intel Core i5 (12th Gen)           Intel            Yes    8
# 3            Intel Core i3 (11th Gen)           Intel             No    8
# 4  Intel Core i5 (11th Gen) Processor           Intel            Yes   16
#
#   RAM_TYPE(DDR)       Ghz Display_type Display                         GPU  \
# 0             4  4.000000          LCD   15.6                       Radeon
# 1             5  3.300000          LCD   15.6   GeForce RTX 3050 GPU, 4 GB
# 2             4  4.200000          LCD   15.6                      Iris Xe
# 3           LP4  1.700000          LCD   15.6                          UHD
# 4             4  2.650322          LCD     14                      Iris Xe
#
#   GPU_Brand                 SSD     HDD Adapter                Battery_Life  \
# 0       AMD  512 GB SSD Storage  No HDD      65    Upto 11 Hrs Battery Life
# 1    NVIDIA  512 GB SSD Storage  No HDD      56    Upto 10 Hrs Battery Life
# 2     Intel  512 GB SSD Storage  No HDD      no  Upto 7.30 Hrs Battery Life
# 3     Intel  512 GB SSD Storage  No HDD      45     Upto 8 Hrs Battery Life
# 4     Intel  512 GB SSD Storage  No HDD      45                 45W Adapter
#
#   Operating_System Processor_Category Processor_Tier  Processor_Speed(Ghz)
# 0       Windows 11        AMD Ryzen 5        Mid-End                   4.0
# 1       Windows 11           Intel I5        Mid-End                   3.5
# 2       Windows 11           Intel I5        Mid-End                   4.0
# 3       Windows 11           Intel I3        Low-End                   1.5
# 4       Windows 11           Intel I5        Mid-End                   2.5

# %% [markdown]
# #### Display Size

# %%
df = df.rename(columns={'Display': 'Display_Size'})
df['Display_Size'] = pd.to_numeric(df['Display_Size'], errors='coerce') # Convert to numeric

# %%
# def display_category(x):
#     if x <= 14.0:
#         return 'Small'
#     elif x <= 15.6:
#         return 'Medium'
#     else:
#         return 'Large'

# df['Display_Tier'] = df['Display_Size'].apply(display_category)
# df['Display_Tier'].value_counts()

# %%
def display_category(x):
    if x <= 15.6:
        return 'Small'
    else:
        return 'Large'

df['Display_Tier'] = df['Display_Size'].apply(display_category)
df['Display_Tier'].value_counts()
# Out:
# Display_Tier
# Small    3495
# Large     409
# Name: count, dtype: int64

# %%
# def display_category(x):
#     if x <= 14.0:
#         return 'Small'
#     else:
#         return 'Large'

# df['Display_Tier'] = df['Display_Size'].apply(display_category)
# df['Display_Tier'].value_counts()

# %%
avg_price = df.groupby('Display_Tier')['Price'].mean().reset_index()

plt.figure(figsize=(8,5))
sns.barplot(data=avg_price, x='Display_Tier', y='Price', palette='cool')
plt.title('Average Price by Display Tier')
plt.show()
# Out:
# /tmp/ipykernel_3465/3406001435.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_price, x='Display_Tier', y='Price', palette='cool')

# %% [markdown]
# #### GPU_Brand

# %%
df.dropna(subset=['GPU_Brand'], inplace=True)
df['GPU_Brand'].value_counts(dropna=False)
# Out:
# GPU_Brand
# Intel      1901
# NVIDIA     1358
# AMD         614
# Apple        18
# Nvidia        8
# NIVIDIA       1
# ATI           1
# Name: count, dtype: int64

# %%
# Standardize GPU_Brand names
df['GPU_Brand'] = df['GPU_Brand'].str.upper()  # Convert all to uppercase

# Map only desired brands to proper casing
brand_mapping = {
    'INTEL': 'Intel',
    'NVIDIA': 'NVIDIA',
    'NIVIDIA': 'NVIDIA',
    'AMD': 'AMD',
    'APPLE': 'Apple'
}

df['GPU_Brand'] = df['GPU_Brand'].map(brand_mapping)


# Check the result
df.dropna(subset=['GPU_Brand'], inplace=True)
print(df['GPU_Brand'].value_counts(dropna=False))
# Out:
# GPU_Brand
# Intel     1901
# NVIDIA    1367
# AMD        614
# Apple       18
# Name: count, dtype: int64

# %% [markdown]
# #### GPU

# %%
# Drop rows where GPU is NaN
df.dropna(subset=['GPU'], inplace=True)

# %%
print("Missing GPU values:", df['GPU'].isna().sum())
df['GPU'].value_counts(dropna=False)
# Out:
# Missing GPU values: 0
# GPU
# UHD                                         649
# Iris Xe                                     571
# Radeon                                      313
# GeForce RTX 3050 GPU, 4 GB                  202
# Integrated                                  155
# GeForce GTX 1650 GPU, 4 GB                  143
# UHD 620                                     119
# GeForce RTX 4050 GPU, 6 GB                   93
# GeForce RTX 3060 GPU, 6 GB                   90
# HD 620                                       84
# GeForce RTX 2050 GPU, 4 GB                   78
# GeForce RTX 4060 GPU, 8 GB                   71
# Radeon Vega 8                                54
# Arc                                          54
# HD 520                                       53
# GeForce RTX 3050 Ti GPU, 4 GB                50
# Geforce GTX 1650 GPU, 4 GB                   37
# GeForce RTX 3050 GPU, 6 GB                   36
# UHD 600                                      34
# GeForce RTX 4070 GPU, 8 GB                   33
# GeForce GTX 1050 GPU, 4 GB                   25
# GeForce RTX 3070 Ti GPU, 8 GB                22
# Radeon R5                                    21
# Radeon R4                                    20
# Radeon R2                                    19
# GeForce MX450 GPU, 2 GB                      19
# Radeon Vega 3                                19
# GeForce MX250 GPU, 2 GB                      17
# GeForce RTX 3070 GPU, 8 GB                   17
# Geforce GTX 1650 Ti GPU, 4 GB                17
# UHD Graphics                                 16
# GeForce MX150 GPU, 2 GB                      15
# GeForce GTX 1060 GPU, 6 GB                   15
# GeForce MX350 GPU, 2 GB                      15
# Iris Plus                                    14
# Geforce MX150 GPU, 2 GB                      14
# Radeon 520 GPU, 2 GB                         14
# Radeon 610M                                  12
# HD                                           12
# Geforce MX130 GPU, 2 GB                      12
# Radeon Graphics                              11
# Iris Xe Graphics                             11
# HD 500                                       11
# UHD 617                                      11
# Geforce GTX 1660 Ti GPU, 6 GB                11
# UHD 605                                      11
# Iris X                                       10
# GeForce MX110 GPU, 2 GB                      10
# GeForce RTX 4090 GPU, 16 GB                  10
# Geforce GTX 1050Ti GPU, 4 GB                 10
# GeForce RTX 2060 GPU, 6 GB                    9
# M2                                            9
# GeForce RTX 4080 GPU, 12 GB                   9
# GeForce MX330 GPU, 2 GB                       9
# GeForce RTX 3080 Ti GPU, 16 GB                8
# HD 615                                        8
# GeForce 940MX GPU, 2 GB                       8
# GeForce MX550 GPU, 2 GB                       8
# Radeon Vega                                   8
# HD Graphics                                   8
# GeForce MX230 GPU, 2 GB                       8
# Radeon R5 M430 GPU, 2 GB                      8
# Geforce MX250 GPU, 2 GB                       8
# GeForce GTX 1650 Ti GPU, 4 GB                 8
# GeForce MX130 GPU, 2 GB                       8
# Geforce RTX 2060 GPU, 6 GB                    7
# GeForce RTX 2080 GPU, 8 GB                    7
# GeForce GTX 1050Ti GPU, 4 GB                  7
# HD 610                                        7
# Radeon Vega 6                                 6
# GeForce GTX 1660 Ti GPU, 6 GB                 6
# GeForce 920MX GPU, 2 GB                       6
# Radeon R3                                     6
# Radeon 530 GPU, 2 GB                          6
# HD 5500                                       5
# HD 505                                        5
# HD 405                                        5
# UHD GPU, 128 MB                               5
# GeForce 940MX GPU, 4 GB                       5
# HD 4400                                       5
# GeForce 830M GPU, 2 GB                        5
# Geforce 940MX GPU, 2 GB                       5
# GeForce GTX 1050 GPU, 3 GB                    5
# Geforce MX110 GPU, 2 GB                       5
# GeForce GTX 1650 Max Q GPU, 4 GB              4
# Radeon RX 5500M GPU, 4 GB                     4
# GeForce GTX 1650 MAX Q GPU, 4 GB              4
# Integrated UHD                                4
# Radeon RX 6500M GPU, 4 GB                     4
# Radeon RX 6700S GPU, 8 GB                     4
# Radeon RX 560X GPU, 4 GB                      4
# Radeon RX 6600M GPU, 8 GB                     4
# GeForce RTX 3080 GPU, 8 GB                    4
# HD 400                                        4
# Radeon RX Vega 10                             4
# GeForce GTX 1050 GPU, 2 GB                    4
# GeForce GT 940MX GPU, 2 GB                    3
# Geforce GTX 1050 Ti GPU, 4 GB                 3
# GeForce 820M GPU, 2 GB                        3
# GeForce 930M GPU, 2 GB                        3
# Geforce MX230 GPU, 2 GB                       3
# Geforce MX330 GPU, 2 GB                       3
# Radeon HD 520 GPU, 2 GB                       3
# Radeon 780M                                   3
# GeForce GT 940MX GPU, 4 GB                    3
# Quadro T1200 GPU, 4 GB                        3
# Arc A370M GPU, 4 GB                           3
# GeForce RTX 3080 GPU, 16 GB                   3
# Radeon Vega 7                                 3
# GeForce MX570 GPU, 2 GB                       3
# GeForce GTX 3050 GPU, 4 GB                    3
# Radeon R7                                     3
# Geforce GTX 1050 GPU, 4 GB                    3
# M2 Pro                                        2
# Geforce RTX 2070 GPU, 8 GB                    2
# Geforce GTX 1050 GPU, 2 GB                    2
# UHD 605                                       2
# GeForce 920M GPU, 2 GB                        2
# GeForce MX150 GPU, 4 GB                       2
# Radeon 530 GPU, 4 GB                          2
# Quadro T600 GPU, 4 GB                         2
# Radeon RX 6500M  GPU, 4 GB                    2
# HD 6000                                       2
# M1                                            2
# GeForce GTX 1050T GPU, 4 GB                   2
# GeForce RTX 4060 GPU, 6 GB                    2
# Geforce GTX 1060 GPU, 6 GB                    2
# M2 Integrated                                 2
# GeForce N16V-GMR1 GPU, 2 GB                   2
# UHD Graphics 620                              2
# Iris Plus 655                                 2
# UHD                                           2
# M2 Max                                        2
# Integrated Iris Xe                            2
# Radeon RX 5600M GPU, 6 GB                     2
# Geforce RTX 3050 GPU, 4 GB                    2
# Geforce GTX 1070 GPU, 8 GB                    2
# GeForce GTX 1650Ti GPU, 4 GB                  2
# Radeon RX Vega 6                              2
# Geforce 940M GPU, 2 GB                        2
# HD 4000                                       2
# Radeon HD 8670M GPU, 2 GB                     2
# Geforce RTX 2080 Super GPU, 8 GB              2
# Radeon RX 6800M GPU, 12 GB                    2
# Radeon RX6550M GPU, 4 GB                      2
# GeForce RTX 3050Ti GPU, 4 GB                  1
# GeForce RTX 3050 Ti  GPU, 4 GB                1
# GeForce RTX 3050 GPU, 4                       1
# Radeon R5 M330 GPU, 2 GB                      1
# GEFORCE RTX 3050 Ti GPU, 4 GB                 1
# UHD Graphics 600                              1
# Radeon 610M Vega 2                            1
# GeForce RTX 3050                              1
# MX350 GPU, 2 GB                               1
# Radeon RX Vega 8                              1
# Geforce GTX 1650 Ti GPU, 6 GB                 1
# Radeon R16M-M1-30 GPU, 2 GB                   1
# Geforce GTX 1650 Max-Q GPU, 4 GB              1
# Geoforce RTX3050 GPU, 4 GB                    1
# Quadro T50 GPU, 4 GB                          1
# GeForce GTX 1050 Ti  GPU, 4 GB                1
# Geforce MX150 GPU, 4 GB                       1
# RTX 3050 Ti GPU, 4 GB                         1
# GeForce P620 GPU, 4 GB                        1
# T1200 GPU, 4 GB                               1
# GeForce RTX 4070                              1
# UMA                                           1
# GeForce MX250                                 1
# GeForce RTX 2070 GPU, 8 GB                    1
# GeForce MX550  GPU, 2 GB                      1
# Radeon GPU, 6 GB                              1
# Radeon 680M GPU, 6 GB                         1
# Radeon 760M                                   1
# GeForce RTX 4060 GPU, 8                       1
# Integrated Arc                                1
# Radeon 680M                                   1
# GeForce RTX 4080 GPU, 8 GB                    1
# RTX A500 GPU, 4 GB                            1
# GeForce RTX 4050 GPU, 8 GB                    1
# Graphics                                      1
# Integrated HD                                 1
# GeForce RTX 3070 GPU, 8                       1
# GeForce RTX 3070 Ti GPU, 8                    1
# Quadro T2000  GPU, 4 GB                       1
# Radeon RX 6700S GPU, 8                        1
# Intel Iris Xe                                 1
# Radeon RX 580 GPU, 4 GB                       1
# GeForce GTX 1660 GPU, 6 GB                    1
# Geforce GT 940MX GPU, 2 GB                    1
# Radeon RX6500M GPU, 4 GB                      1
# Geforce RTX 2070 Super GPU, 8 GB              1
# GeForce RTX 2050                              1
# HD Graphics 620                               1
# Radeon 535 GPU, 2 GB                          1
# GeForce RTX A1000 GPU, 4 GB                   1
# GeForce RTX 2060 GPU, 8 GB                    1
# Iris Xe GPU, 4 GB                             1
# Iris Xe Max GPU, 4 GB                         1
# GeForce GTX 1050TI GPU, 4 GB                  1
# GeForce 920MX  GPU, 2 GB                      1
# GeForce 1650 Ti GPU, 4 GB                     1
# GeForce 940 MX GPU, 2 GB                      1
# GeForce 940MX  GPU, 4 GB                      1
# GeForce GTX 1050 Ti GPU, 4 GB                 1
# GeForce GTX 1650 Ti GPU, 6 GB                 1
# Geforce MX350 GPU, 2 GB                       1
# Geforce 940MX GPU, 4 GB                       1
# M1 Integrated                                 1
# RTX 3050 GPU, 4 GB                            1
# GeForce GPU, 2 GB                             1
# GeForce MX 450 GPU, 2 GB                      1
# GeForce RTX 1650 GPU, 4 GB                    1
# Radeon Vega 8 Mobile                          1
# Radeon HD 8210 GPU, 2 GB                      1
# Geforce GTX 1050 GPU, 3 GB                    1
# R17M-M1-70 GPU, 2 GB                          1
# Geforce GTX 1050Ti GPU, 8 GB                  1
# Geforce GTX 1650Ti GPU, 6 GB                  1
# MX450 GPU, 2 GB                               1
# GeForce RTX A2000 GPU, 8 GB                   1
# GeForce MX550 GPU, 2                          1
# GeForce MX 350 GPU, 2 GB                      1
# RTX A1000 GPU, 6 GB                           1
# GeForce RTX 4080 GPU, 16 GB                   1
# Radeon RX 7600S GPU, 8 GB                     1
# GeForce GTX 1070 GPU, 8 GB                    1
# UHD GPU, 2 GB                                 1
# GeForce RTX 3060 GPU, 6                       1
# GeForce RTX 3060 GPU GPU, 6 GB                1
# Radeon RX 6650M GPU, 8 GB                     1
# Quadro T550 GPU, 4 GB                         1
# Integrated GPU, 512 MB                        1
# GeForce RTX 3070 GPU, 16 GB                   1
# Arc A530M GPU, 4 GB                           1
# Radeon RX 5500M                               1
# Radeon R5 M430  GPU, 2 GB                     1
# Radeon RX6700M                                1
# Radeon Athlon 3000G                           1
# GeForce MX550                                 1
# Geforce GTX 1650 Ti with Max-Q GPU, 4 GB      1
# GeForce RTX 3060 GPU, 4 GB                    1
# GeForce GTX 1650 Ti Max Q GPU, 4 GB           1
# Geforce MX 150 GPU, 2 GB                      1
# Integrated Graphics                           1
# Radeon R4                                     1
# GeForce GTX 940MX GPU, 4 GB                   1
# Iris Pro                                      1
# Radeon R5 M430 GPU, 4 GB                      1
# T600 GPU, 4 GB                                1
# Geforce GTX 1650 Ti` GPU, 4 GB                1
# GeForce GTX 1050  GPU, 2 GB                   1
# Radeon Pro 5500M GPU, 4 GB                    1
# Iris Plus 640                                 1
# Iris Plus Graphics 645                        1
# HD 515                                        1
# GeForce 920M                                  1
# GeForce MX150  GPU, 2 GB                      1
# GeForce GTX 960M GPU, 2 GB                    1
# Radeon R7 M260 GPU, 2 GB                      1
# Geforce GTX 1650Ti GPU, 4 GB                  1
# GeForce GTX 940MX GPU, 2 GB                   1
# Radeon R7 M440 GPU, 2 GB                      1
# Iris graphics                                 1
# Radeon Pro 450 GPU, 2 GB                      1
# GeForce GTX 960M GPU, 4 GB                    1
# Iris Plus Graphics 655                        1
# Radeon HD 8670M GPU, 1 GB                     1
# Radeon HD R7 M265 GPU, 2 GB                   1
# GeForce 930MX GPU, 2 GB                       1
# GeForce 940M GPU, 4 GB                        1
# GeForce GTX 850M GPU, 4 GB                    1
# GeForce GT 820M GPU, 1 GB                     1
# Geforce GTX MX330 GPU, 2 GB                   1
# GeForce GT 740M GPU, 2 GB                     1
# Geforce RTX 2080 with Max-Q GPU, 8 GB         1
# Radeon RX640 GPU, 2 GB                        1
# Radeon RX Vega 5                              1
# Radeon RX 640 GPU, 2 GB                       1
# Geforce RTX 2080 GPU, 8 GB                    1
# Radeon RX Vega 7                              1
# GeForce MX230                                 1
# Geforce Gt 940MX GPU, 2 GB                    1
# Name: count, dtype: int64

# %%
print(df['GPU_Brand'].value_counts(dropna=False))
# Out:
# GPU_Brand
# Intel     1893
# NVIDIA    1367
# AMD        614
# Apple       18
# Name: count, dtype: int64

# %% [markdown]
# ##### INTEL GPU CLEANING

# %% [markdown]
#  - funtion to clean current intel gpu

# %%
# Filter Intel GPUs
intel_df = df[df['GPU_Brand'] == 'Intel'].copy()

def standardize_intel_name(gpu_name):
    """Standardize Intel GPU names"""
    if pd.isna(gpu_name):
        return 'Unknown'
    
    gpu = str(gpu_name).strip().upper()
    
    # Remove common prefixes
    gpu = re.sub(r'^(INTEL\s*)?', '', gpu)
    
    # Standardize UHD series
    if 'UHD' in gpu:
        # Extract number if present
        uhd_match = re.search(r'UHD\s*(\d+)?', gpu)
        if uhd_match and uhd_match.group(1):
            return f"UHD {uhd_match.group(1)}"
        else:
            return "UHD Graphics"
    
    # Standardize HD series
    elif re.search(r'HD\s*(\d+)', gpu):
        hd_match = re.search(r'HD\s*(\d+)', gpu)
        return f"HD {hd_match.group(1)}"
    
    # Standardize Iris series
    elif 'IRIS XE' in gpu:
        if 'MAX' in gpu:
            return "Iris Xe Max"  # Discrete version
        else:
            return "Iris Xe"
    elif 'IRIS PLUS' in gpu:
        return "Iris Plus"
    elif 'IRIS PRO' in gpu:
        return "Iris Pro"
    elif 'IRIS' in gpu:
        return "Iris"
    
    # Standardize Arc series (discrete)
    elif 'ARC' in gpu:
        arc_match = re.search(r'ARC\s*([A-Z]?\d+M?)', gpu)
        if arc_match:
            return f"Arc {arc_match.group(1)}"
        else:
            return "Arc"
    
    # Handle integrated variants
    elif 'INTEGRATED' in gpu:
        if 'UHD' in gpu:
            return "UHD Graphics"
        elif 'IRIS' in gpu:
            return "Iris Xe"
        else:
            return "Integrated Graphics"
    
    # Generic graphics
    elif gpu in ['GRAPHICS', 'UMA']:
        return "Integrated Graphics"
    
    return gpu.title()

# %% [markdown]
#  - funtion to map in to tiers

# %%
def get_intel_tier(gpu_name):
    """Assign performance tier to Intel GPUs"""
    if pd.isna(gpu_name):
        return 'Unknown'
    
    gpu_upper = str(gpu_name).upper()
    
    # Mid-end: Discrete Intel GPUs
    if any(x in gpu_upper for x in ['ARC A530M', 'ARC A370M', 'IRIS XE MAX']):
        return 'Mid-end'
    
    # Low-end: Good integrated graphics
    elif any(x in gpu_upper for x in ['IRIS XE', 'IRIS PLUS', 'IRIS PRO', 'ARC']):
        return 'Low-end'
    
    # Entry-level: Basic integrated graphics
    else:
        return 'Entry-level'

# %% [markdown]
# - Apply above functions

# %%
# Apply cleaning functions
intel_df['GPU_Standardized'] = intel_df['GPU'].apply(standardize_intel_name)
intel_df['GPU_Tier'] = intel_df['GPU_Standardized'].apply(get_intel_tier)

# Display results
print("\nIntel GPU Tier Distribution:")
print(intel_df['GPU_Tier'].value_counts())

for col in ['GPU_Standardized','GPU_Tier']:
    df.loc[df['GPU_Brand']=='Intel', col] = intel_df[col].values
# Out:
# Intel GPU Tier Distribution:
# GPU_Tier
# Entry-level    1227
# Low-end         661
# Mid-end           5
# Name: count, dtype: int64

# %% [markdown]
# ##### AMD GPU CLEANING

# %% [markdown]
#  - funtion to clean amd gpu

# %%
# Filter AMD GPUs
amd_df = df[df['GPU_Brand'] == 'AMD'].copy()

def standardize_amd_name(gpu_name):
    """Standardize AMD GPU names"""
    if pd.isna(gpu_name):
        return 'Unknown'
    
    gpu = str(gpu_name).strip()
    
    # Remove Radeon prefix for consistency
    gpu = re.sub(r'^Radeon\s+', '', gpu, flags=re.IGNORECASE)
    
    # Standardize RX series (discrete)
    if re.search(r'RX\s*(\d+[MS]?)', gpu, re.IGNORECASE):
        rx_match = re.search(r'RX\s*(\d+[MS]?)', gpu, re.IGNORECASE)
        return f"RX {rx_match.group(1)}"
    
    # Standardize Vega series (APU integrated)
    elif re.search(r'Vega\s*(\d+)', gpu, re.IGNORECASE):
        vega_match = re.search(r'Vega\s*(\d+)', gpu, re.IGNORECASE)
        return f"Vega {vega_match.group(1)}"
    
    # Standardize R-series (older discrete)
    elif re.search(r'R([2-7])\s*(M?\d*)', gpu, re.IGNORECASE):
        r_match = re.search(r'R([2-7])\s*(M?\d*)', gpu, re.IGNORECASE)
        if r_match.group(2):
            return f"R{r_match.group(1)} {r_match.group(2)}"
        else:
            return f"R{r_match.group(1)}"
    
    # Standardize mobile APU graphics
    elif re.search(r'(\d{3})M', gpu):
        mobile_match = re.search(r'(\d{3})M', gpu)
        return f"{mobile_match.group(1)}M"
    
    # Standardize HD series (older discrete)
    elif re.search(r'HD\s*(\d+)', gpu, re.IGNORECASE):
        hd_match = re.search(r'HD\s*(\d+)', gpu, re.IGNORECASE)
        return f"HD {hd_match.group(1)}"
    
    # Handle generic cases
    elif gpu.upper() in ['RADEON', 'INTEGRATED']:
        return 'Radeon Graphics'
    elif 'GRAPHICS' in gpu.upper():
        return 'Radeon Graphics'
    
    return gpu.title()

# %% [markdown]
#  - funtion to get tier

# %%
def get_amd_tier(gpu_name):
    """Assign performance tier to AMD GPUs"""
    if pd.isna(gpu_name):
        return 'Unknown'
    
    gpu_upper = str(gpu_name).upper()
    
    # High-end: High-performance discrete GPUs
    if any(x in gpu_upper for x in ['RX 6800', 'RX 6700', 'RX 7600']):
        return 'High-end'
    
    # Mid-end: Mid-performance discrete GPUs
    elif any(x in gpu_upper for x in ['RX 6600', 'RX 6550', 'RX 6500', 'RX 580', 'RX 560', 'RX 5600', 'RX 5500']):
        return 'Mid-end'
    elif any(x in gpu_upper for x in ['R5 M', 'R7 M', 'HD 8']):
        return 'Mid-end'
    
    # Low-end: APU integrated graphics (decent)
    elif any(x in gpu_upper for x in ['VEGA', '780M', '760M', '680M', '610M']):
        return 'Low-end'
    elif any(x in gpu_upper for x in ['530', '535', '520']):
        return 'Low-end'
    
    # Entry-level: Basic integrated
    else:
        return 'Entry-level'

# %% [markdown]
#  - Apply above functions

# %%
# Apply cleaning functions
amd_df['GPU_Standardized'] = amd_df['GPU'].apply(standardize_amd_name)
amd_df['GPU_Tier'] = amd_df['GPU_Standardized'].apply(get_amd_tier)

# Display results
print("\nAMD GPU Tier Distribution:")
print(amd_df['GPU_Tier'].value_counts())

for col in ['GPU_Standardized','GPU_Tier']:
    df.loc[df['GPU_Brand']=='AMD', col] = amd_df[col].values
# Out:
# AMD GPU Tier Distribution:
# GPU_Tier
# Entry-level    420
# Low-end        145
# Mid-end         40
# High-end         9
# Name: count, dtype: int64

# %% [markdown]
# ##### NVIDIA GPU CLEANING

# %% [markdown]
# - funtion to clean Nvidia gpu

# %%
# Filter NVIDIA GPUs
nvidia_df = df[df['GPU_Brand'] == 'NVIDIA'].copy()

def standardize_nvidia_name(gpu_name):
    """Standardize NVIDIA GPU names"""
    if pd.isna(gpu_name):
        return 'Unknown'
    
    gpu = str(gpu_name).strip()
    
    # Remove GeForce prefix for consistency
    gpu = re.sub(r'^GeForce\s+', '', gpu, flags=re.IGNORECASE)
    gpu = re.sub(r'^GEFORCE\s+', '', gpu, flags=re.IGNORECASE)
    gpu = re.sub(r'^Geforce\s+', '', gpu, flags=re.IGNORECASE)
    
    # Remove GPU suffix and VRAM info
    gpu = re.sub(r'\s*GPU,?\s*\d+\s*GB?', '', gpu, flags=re.IGNORECASE)
    gpu = re.sub(r'\s*GPU\s*$', '', gpu, flags=re.IGNORECASE)
    
    # Standardize RTX series
    if re.search(r'RTX\s*(\d{4})\s*(Ti)?', gpu, re.IGNORECASE):
        rtx_match = re.search(r'RTX\s*(\d{4})\s*(Ti)?', gpu, re.IGNORECASE)
        ti_suffix = ' Ti' if rtx_match.group(2) else ''
        return f"RTX {rtx_match.group(1)}{ti_suffix}"
    
    # Standardize GTX series
    elif re.search(r'GTX\s*(\d{4})\s*(Ti)?', gpu, re.IGNORECASE):
        gtx_match = re.search(r'GTX\s*(\d{4})\s*(Ti)?', gpu, re.IGNORECASE)
        ti_suffix = ' Ti' if gtx_match.group(2) else ''
        return f"GTX {gtx_match.group(1)}{ti_suffix}"
    
    # Standardize MX series
    elif re.search(r'MX\s*(\d{3})', gpu, re.IGNORECASE):
        mx_match = re.search(r'MX\s*(\d{3})', gpu, re.IGNORECASE)
        return f"MX {mx_match.group(1)}"
    
    # Standardize GT series
    elif re.search(r'GT\s*(\d{3}MX)', gpu, re.IGNORECASE):
        gt_match = re.search(r'GT\s*(\d{3}MX)', gpu, re.IGNORECASE)
        return gt_match.group(1)
    
    # Handle Quadro series (professional)
    elif 'QUADRO' in gpu.upper():
        quadro_match = re.search(r'Quadro\s+([A-Z]?\d+)', gpu, re.IGNORECASE)
        if quadro_match:
            return f"Quadro {quadro_match.group(1)}"
        else:
            return "Quadro"
    
    # Clean up Max-Q variants
    gpu = re.sub(r'MAX[\s-]?Q', 'Max-Q', gpu, flags=re.IGNORECASE)
    gpu = re.sub(r'Max Q', 'Max-Q', gpu, flags=re.IGNORECASE)
    
    # Clean up Ti variants
    gpu = re.sub(r'Ti`', 'Ti', gpu)
    gpu = re.sub(r'TI\b', 'Ti', gpu)
    
    return gpu.strip()

# %% [markdown]
# - funtion for tier seperation

# %%
def get_nvidia_tier(gpu_name):
    """Assign performance tier to NVIDIA GPUs"""
    if pd.isna(gpu_name):
        return 'Unknown'
    
    gpu_upper = str(gpu_name).upper()
    
    # High-end: Flagship gaming and professional GPUs
    high_end_patterns = [
        'RTX 4070', 'RTX 4070 TI', 'RTX 3080', 'RTX 3080 TI', 'RTX 3070', 'RTX 3070 TI',
        'RTX 2080', 'RTX 2080 TI', 'RTX 2070', 'GTX 1080', 'GTX 1070',
        'QUADRO', 'RTX A'
    ]
    if any(pattern in gpu_upper for pattern in high_end_patterns):
        return 'High-end'
    
    # Mid-end: Good gaming performance
    mid_end_patterns = [
        'RTX 4060', 'RTX 4060 TI', 'RTX 4050', 'RTX 4050 TI', 'RTX 3060', 'RTX 3060 TI', 'RTX 3050', 'RTX 3050 TI',
        'RTX 2060', 'RTX 2050', 'GTX 1660', 'GTX 1660 TI', 'GTX 1650', 'GTX 1650 TI',
        'GTX 1060', 'GTX 1050', 'GTX 1050 TI'
    ]
    if any(pattern in gpu_upper for pattern in mid_end_patterns):
        return 'Mid-end'
    
    # Low-end: Entry gaming and productivity
    low_end_patterns = [
        'MX', 'GT 9', 'GT 8', 'GT 7', 'GTX 960M', 'GTX 950M', 'GTX 850M'
    ]
    if any(pattern in gpu_upper for pattern in low_end_patterns):
        return 'Low-end'
    
    # Entry-level: Basic discrete graphics
    return 'Entry-level'

# %% [markdown]
# - Apply above functions

# %%
# Apply cleaning functions
nvidia_df['GPU_Standardized'] = nvidia_df['GPU'].apply(standardize_nvidia_name)
nvidia_df['GPU_Tier'] = nvidia_df['GPU_Standardized'].apply(get_nvidia_tier)

# Display results
print("\nNVIDIA GPU Tier Distribution:")
print(nvidia_df['GPU_Tier'].value_counts())

for col in ['GPU_Standardized','GPU_Tier']:
    df.loc[df['GPU_Brand']=='NVIDIA', col] = nvidia_df[col].values
# Out:
# NVIDIA GPU Tier Distribution:
# GPU_Tier
# Mid-end        980
# Low-end        217
# High-end       121
# Entry-level     49
# Name: count, dtype: int64

# %% [markdown]
# ##### APPLE GPU CLEANING

# %% [markdown]
# - APPLE GPU CLEANING

# %%
# Filter Apple GPUs
apple_df = df[df['GPU_Brand'] == 'Apple'].copy()

def standardize_apple_name(gpu_name):
    """Standardize Apple GPU names"""
    if pd.isna(gpu_name):
        return 'Unknown'
    
    gpu = str(gpu_name).strip().upper()
    
    if 'M2' in gpu:
        return 'M2'
    elif 'M1' in gpu:
        return 'M1'
    else:
        return gpu.title()

def get_apple_tier(gpu_name):
    """All Apple Silicon GPUs are considered high-end for efficiency"""
    return 'High-end'


# Apply cleaning functions
apple_df['GPU_Standardized'] = apple_df['GPU'].apply(standardize_apple_name)
apple_df['GPU_Tier'] = apple_df['GPU_Standardized'].apply(get_apple_tier)

# Display results
print("\nApple GPU Tier Distribution:")
print(apple_df['GPU_Tier'].value_counts())

for col in ['GPU_Standardized','GPU_Tier']:
    df.loc[df['GPU_Brand']=='Apple', col] = apple_df[col].values
# Out:
# Apple GPU Tier Distribution:
# GPU_Tier
# High-end    18
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3892, 24)

# %% [markdown]
# #### SSD and HDD

# %% [markdown]
# ##### SSD

# %%
print(df['SSD'].value_counts(dropna=False))
# Out:
# SSD
# 512 GB SSD Storage     1912
# NO SSD                  641
# 1024 GB SSD Storage     586
# 256 GB SSD Storage      353
# 256 GB SSD Storage      205
# 128 GB SSD Storage       56
# 128 GB SSD Storage       44
# 2048 GB SSD Storage      28
# 64 GB SSD Storage        21
# 512 GB SSD Storage       15
# 16 GB SSD Storage        12
# 32 GB SSD Storage         8
# 8 GB SSD Storage          4
# 512  SSD Storage          2
# 256  SSD Storage          2
# 1 GB SSD Storage          1
# 16 GB SSD Storage         1
# 4098 GB SSD Storage       1
# Name: count, dtype: int64

# %% [markdown]
# - Cleaning Inconsistent names

# %%
def clean_ssd(ssd):
    if pd.isna(ssd) or 'NO' in str(ssd).upper():
        return 'No SSD'
    
    # Remove extra spaces
    ssd = str(ssd).strip()
    
    # Extract numeric value (size)
    match = re.search(r'(\d+)', ssd)
    if match:
        size = match.group(1)
        return f"{size} GB SSD"
    else:
        return 'Unknown'

# Apply the cleaning function
df['SSD'] = df['SSD'].apply(clean_ssd)

# Check results
print(df['SSD'].value_counts())
# Out:
# SSD
# 512 GB SSD     1929
# No SSD          641
# 1024 GB SSD     586
# 256 GB SSD      560
# 128 GB SSD      100
# 2048 GB SSD      28
# 64 GB SSD        21
# 16 GB SSD        13
# 32 GB SSD         8
# 8 GB SSD          4
# 1 GB SSD          1
# 4098 GB SSD       1
# Name: count, dtype: int64

# %% [markdown]
# - Convert SSD capacities to numbers to int

# %%
def ssd_to_number(ssd):
    if pd.isna(ssd) or 'NO' in str(ssd).upper():
        return 0
    # Extract the first number found in the string
    match = re.search(r'(\d+)', str(ssd))
    if match:
        return int(match.group(1))
    else:
        return 0

# Apply the function
df['SSD(GB)'] = df['SSD'].apply(ssd_to_number)
print(df['SSD(GB)'].value_counts())
# Out:
# SSD(GB)
# 512     1929
# 0        641
# 1024     586
# 256      560
# 128      100
# 2048      28
# 64        21
# 16        13
# 32         8
# 8          4
# 1          1
# 4098       1
# Name: count, dtype: int64

# %% [markdown]
# - Keep only dominat capacities

# %%
# Define main sizes and include 0 for No SSD
keep_sizes = [0, 128, 256, 512, 1024]

# Keep only these values
df = df[df['SSD(GB)'].isin(keep_sizes)]

# Check results
print(df['SSD(GB)'].value_counts())
# Out:
# SSD(GB)
# 512     1929
# 0        641
# 1024     586
# 256      560
# 128      100
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3816, 25)

# %% [markdown]
# ##### HDD

# %%
print(df['HDD'].value_counts(dropna=False))
# Out:
# HDD
# No HDD                  2897
# 1024 GB HDD Storage      588
#  1024 GB HDD Storage     277
# 500 GB HDD Storage        34
# 2048 GB HDD Storage       18
#  2048 GB HDD Storage       1
# 1 GB HDD Storage           1
# Name: count, dtype: int64

# %% [markdown]
# -  Clean HDD naming inconsitencies

# %%
def clean_hdd(hdd):
    if pd.isna(hdd) or 'NO' in str(hdd).upper():
        return 'No HDD'
    
    # Remove extra spaces
    hdd = str(hdd).strip()
    
    # Extract numeric value (size)
    match = re.search(r'(\d+)', hdd)
    if match:
        size = match.group(1)
        return f"{size} GB HDD"
    else:
        return 'Unknown'

# Apply the cleaning function
df['HDD'] = df['HDD'].apply(clean_hdd)
print(df['HDD'].value_counts(dropna=False))
# Out:
# HDD
# No HDD         2897
# 1024 GB HDD     865
# 500 GB HDD       34
# 2048 GB HDD      19
# 1 GB HDD          1
# Name: count, dtype: int64

# %% [markdown]
# - Convert to int

# %%
def hdd_to_number(hdd):
    if pd.isna(hdd) or 'NO' in str(hdd).upper():
        return 0
    
    # Remove extra spaces
    hdd = str(hdd).strip()
    
    # Extract the first number (size in GB)
    match = re.search(r'(\d+)', hdd)
    if match:
        return int(match.group(1))
    else:
        return 0

# Apply the function
df['HDD(GB)'] = df['HDD'].apply(hdd_to_number)

# Check results
print(df['HDD(GB)'].value_counts(dropna=False))
# Out:
# HDD(GB)
# 0       2897
# 1024     865
# 500       34
# 2048      19
# 1          1
# Name: count, dtype: int64

# %% [markdown]
# - Keep only dominat capacities

# %%
keep_hdd = [0, 500, 1024]

# Keep only these values
df = df[df['HDD(GB)'].isin(keep_hdd)]

# Check results
print(df['HDD(GB)'].value_counts())
# Out:
# HDD(GB)
# 0       2897
# 1024     865
# 500       34
# Name: count, dtype: int64

# %%
df.head()
# Out:
#     Brand                                               Name     Price  \
# 0  Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  127011.5
# 1    Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  274750.0
# 2      HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  194215.0
# 3   Other  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...   76965.0
# 4    Acer  Acer One 14 Z8-415 (UN.599SI.020) Laptop (14 I...  122465.0
#
#                        Processor_Name Processor_Brand RAM_Expandable  RAM  \
# 0               AMD Hexa-Core Ryzen 5             AMD            Yes    8
# 1            Intel Core i5 (12th Gen)           Intel            Yes   16
# 2            Intel Core i5 (12th Gen)           Intel            Yes    8
# 3            Intel Core i3 (11th Gen)           Intel             No    8
# 4  Intel Core i5 (11th Gen) Processor           Intel            Yes   16
#
#   RAM_TYPE(DDR)       Ghz Display_type  Display_Size  \
# 0             4  4.000000          LCD          15.6
# 1             5  3.300000          LCD          15.6
# 2             4  4.200000          LCD          15.6
# 3           LP4  1.700000          LCD          15.6
# 4             4  2.650322          LCD          14.0
#
#                           GPU GPU_Brand         SSD     HDD Adapter  \
# 0                      Radeon       AMD  512 GB SSD  No HDD      65
# 1  GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD  No HDD      56
# 2                     Iris Xe     Intel  512 GB SSD  No HDD      no
# 3                         UHD     Intel  512 GB SSD  No HDD      45
# 4                     Iris Xe     Intel  512 GB SSD  No HDD      45
#
#                  Battery_Life Operating_System Processor_Category  \
# 0    Upto 11 Hrs Battery Life       Windows 11        AMD Ryzen 5
# 1    Upto 10 Hrs Battery Life       Windows 11           Intel I5
# 2  Upto 7.30 Hrs Battery Life       Windows 11           Intel I5
# 3     Upto 8 Hrs Battery Life       Windows 11           Intel I3
# 4                 45W Adapter       Windows 11           Intel I5
#
#   Processor_Tier  Processor_Speed(Ghz) Display_Tier GPU_Standardized  \
# 0        Mid-End                   4.0        Small  Radeon Graphics
# 1        Mid-End                   3.5        Small         RTX 3050
# 2        Mid-End                   4.0        Small          Iris Xe
# 3        Low-End                   1.5        Small     UHD Graphics
# 4        Mid-End                   2.5        Small          Iris Xe
#
#       GPU_Tier  SSD(GB)  HDD(GB)
# 0  Entry-level      512        0
# 1      Mid-end      512        0
# 2      Low-end      512        0
# 3  Entry-level      512        0
# 4      Low-end      512        0

# %% [markdown]
# #### Battery_Life and Adapter Not considered

# %% [markdown]
# - Battery_Life consist of lot of missing values and mixed with Adapter watt values. Therefore not considered

# %% [markdown]
# #### Final Cleaned Dataset

# %%
df.rename(columns={'RAM': 'RAM_Capacity'}, inplace=True)

# %% [markdown]
# - Drop unnessary columns

# %%
cols_to_drop = [
    'Processor_Name', 'Display_Size', 'Ghz', 'SSD', 'HDD','GPU',
    'Adapter', 'Battery_Life', 'GPU_Standardized', 'Name', 'Operating_System', 'Processor_Tier'
]
# Drop columns
df = df.drop(columns=cols_to_drop)
# Check the updated DataFrame
df.head(10)
# Out:
#     Brand     Price Processor_Brand RAM_Expandable  RAM_Capacity  \
# 0  Lenovo  127011.5             AMD            Yes             8
# 1    Dell  274750.0           Intel            Yes            16
# 2      HP  194215.0           Intel            Yes             8
# 3   Other   76965.0           Intel             No             8
# 4    Acer  122465.0           Intel            Yes            16
# 5      HP  173596.5             AMD            Yes             8
# 6    Acer  139965.0           Intel            Yes             8
# 7  Lenovo  115888.5           Intel            Yes             4
# 8    ASUS  171465.0           Intel             No             8
# 9  Lenovo  325465.0             AMD            Yes            16
#
#   RAM_TYPE(DDR) Display_type GPU_Brand Processor_Category  \
# 0             4          LCD       AMD        AMD Ryzen 5
# 1             5          LCD    NVIDIA           Intel I5
# 2             4          LCD     Intel           Intel I5
# 3           LP4          LCD     Intel           Intel I3
# 4             4          LCD     Intel           Intel I5
# 5             4          LCD       AMD        AMD Ryzen 5
# 6             4          LCD     Intel           Intel I5
# 7             4          LED     Intel           Intel I3
# 8             4          LCD    NVIDIA           Intel I5
# 9             5          LCD    NVIDIA        AMD Ryzen 7
#
#    Processor_Speed(Ghz) Display_Tier     GPU_Tier  SSD(GB)  HDD(GB)
# 0                   4.0        Small  Entry-level      512        0
# 1                   3.5        Small      Mid-end      512        0
# 2                   4.0        Small      Low-end      512        0
# 3                   1.5        Small  Entry-level      512        0
# 4                   2.5        Small      Low-end      512        0
# 5                   4.0        Small  Entry-level      512        0
# 6                   2.5        Small      Low-end      512        0
# 7                   2.0        Small  Entry-level        0     1024
# 8                   3.0        Small      Mid-end      512        0
# 9                   3.5        Small      Mid-end      512        0

# %%
df[df.duplicated()]
# Out:
#         Brand     Price Processor_Brand RAM_Expandable  RAM_Capacity  \
# 94       ASUS  178465.0           Intel            Yes             8
# 440      ASUS  150465.0           Intel            Yes             8
# 441      ASUS  150465.0           Intel            Yes             8
# 523        HP  244996.5           Intel             No            16
# 567   Samsung  384965.0           Intel             No            16
# 614      Acer  248465.0           Intel            Yes            16
# 647     Other  349965.0           Intel            Yes             8
# 870      ASUS  192465.0             AMD             No            16
# 888      ASUS  706965.0             AMD             No            16
# 1020     ASUS  244965.0           Intel             No            16
# 1167      MSI  769965.0           Intel            Yes            32
# 1275   Lenovo  115465.0           Intel             No             4
# 1284   Lenovo  122465.0           Intel             No             8
# 1302     ASUS  206465.0           Intel             No            16
# 1555     ASUS  286965.0           Intel             No             8
# 1658       HP  174965.0           Intel             No             8
# 1685   Lenovo   62965.0             AMD             No             4
# 1746   Lenovo   88200.0           Intel             No             4
# 1790     ASUS  227465.0           Intel             No             8
# 1794     ASUS  227465.0           Intel             No             8
# 1884     Acer  110215.0           Intel             No             8
# 1924   Lenovo  143465.0           Intel            Yes             8
# 1932       HP  108465.0             AMD            Yes             8
# 1948   Lenovo  115465.0           Intel            Yes             8
# 1949    Apple  524650.0           Apple             No             8
# 1952     ASUS  122465.0           Intel            Yes             8
# 1983     Acer  199465.0           Intel            Yes            16
# 1994     ASUS  111965.0           Intel             No             8
# 2001   Lenovo  115465.0           Intel             No             4
# 2025   Lenovo  227465.0             AMD            Yes            16
# 2027       HP  262465.0           Intel             No            16
# 2093       HP  216965.0           Intel            Yes             8
# 2120     Acer  229215.0             AMD            Yes             8
# 2138   Lenovo  115465.0           Intel             No             4
# 2151       HP   89246.5             AMD             No             8
# 2250     Acer  132965.0           Intel             No             8
# 2375      MSI  150465.0           Intel             No             8
# 2421     Dell  146965.0           Intel             No             8
# 2471     ASUS  979965.0           Intel            Yes            32
# 2486     ASUS  570465.0             AMD             No            16
# 2505     ASUS  206465.0           Intel             No            16
# 2530     ASUS  391965.0           Intel             No            16
# 2535     ASUS  129465.0           Intel            Yes             8
# 2536     ASUS  384965.0           Intel            Yes            16
# 2543     ASUS  339465.0           Intel             No            16
# 2550   Lenovo  159215.0           Intel            Yes             8
# 2677     ASUS  276465.0           Intel             No            16
# 2684       HP  531965.0           Intel             No            16
# 2686       HP  531965.0           Intel             No            16
# 2789       HP  129465.0           Intel            Yes             8
# 2826     ASUS  227465.0           Intel             No            16
# 2834   Lenovo   62965.0             AMD             No             4
# 2912       HP  101465.0           Intel             No             4
# 3009       HP  174965.0           Intel             No             8
# 3054   Lenovo  139965.0           Intel             No             4
# 3114     Acer  192465.0           Intel             No             8
# 3120     ASUS  160965.0           Intel            Yes             8
# 3142    Apple  367465.0           Intel             No             8
# 3145     ASUS  136465.0           Intel             No             8
# 3164     ASUS  227465.0           Intel             No             8
# 3177    Apple  447965.0           Intel             No             8
# 3242   Lenovo  122465.0           Intel             No             4
# 3307   Lenovo   87465.0           Intel             No             4
# 3345   Lenovo  139965.0             AMD             No             8
# 3458       HP  104965.0           Intel             No             4
# 3484   Lenovo  209965.0           Intel             No             8
# 3524   Lenovo   73465.0             AMD             No             4
# 3662       HP  127365.0           Intel            Yes             4
# 3676       HP   97965.0           Intel             No             4
# 3740     ASUS  339465.0             AMD            Yes            16
# 3826     ASUS  227465.0             AMD            Yes            16
#
#      RAM_TYPE(DDR) Display_type GPU_Brand Processor_Category  \
# 94               4          LCD    NVIDIA           Intel I5
# 440              4          LCD     Intel           Intel I3
# 441              4          LCD     Intel           Intel I3
# 523              4          LCD     Intel           Intel I5
# 567              4          LED     Intel           Intel I5
# 614              5          LCD    NVIDIA           Intel I5
# 647            LP5          LCD     Intel           Intel I5
# 870              4          LCD       AMD        AMD Ryzen 7
# 888              5          LCD    NVIDIA        AMD Ryzen 9
# 1020             4          LCD    NVIDIA           Intel I5
# 1167             5          LCD    NVIDIA           Intel I7
# 1275             4          LED     Intel           Intel I3
# 1284             4          LED     Intel           Intel I3
# 1302             4          LCD     Intel           Intel I5
# 1555             4          LED    NVIDIA           Intel I7
# 1658             4          LED     Intel           Intel I5
# 1685             4          LED       AMD       AMD A-Series
# 1746             4          LED     Intel      Intel Celeron
# 1790             4          LED     Intel           Intel I5
# 1794             4          LED     Intel           Intel I5
# 1884           LP5          LCD     Intel           Intel I3
# 1924             4          LCD     Intel           Intel I3
# 1932             4          LCD       AMD        AMD Ryzen 3
# 1948             4          LCD     Intel           Intel I3
# 1949             5          LCD     Apple     Apple M-series
# 1952             4          LCD     Intel           Intel I3
# 1983             5          LCD    NVIDIA           Intel I5
# 1994             4          LCD     Intel           Intel I3
# 2001             4          LED     Intel           Intel I3
# 2025             5          LCD    NVIDIA        AMD Ryzen 5
# 2027             4          LCD     Intel           Intel I5
# 2093             4          LCD     Intel           Intel I5
# 2120             5          LCD    NVIDIA        AMD Ryzen 5
# 2138             4          LED     Intel           Intel I3
# 2151             4          LCD       AMD        AMD Ryzen 3
# 2250           LP5          LCD     Intel           Intel I3
# 2375             4          LCD    NVIDIA           Intel I5
# 2421             4          LCD     Intel           Intel I3
# 2471             5          LCD    NVIDIA           Intel I9
# 2486             5          LCD    NVIDIA        AMD Ryzen 7
# 2505             4          LCD     Intel           Intel I5
# 2530           LP5          LED     Intel      Intel Ultra 7
# 2535             4          LCD     Intel           Intel I3
# 2536             5          LCD    NVIDIA           Intel I7
# 2543           LP5          LED     Intel      Intel Ultra 5
# 2550             4          LCD     Intel           Intel I5
# 2677             4          LCD    NVIDIA           Intel I7
# 2684             5          LCD    NVIDIA           Intel I7
# 2686             5          LCD    NVIDIA           Intel I7
# 2789             4          LCD     Intel           Intel I3
# 2826             4          LCD     Intel           Intel I7
# 2834             4          LED       AMD       AMD A-Series
# 2912             4          LED     Intel           Intel I3
# 3009             4          LED     Intel           Intel I5
# 3054             4          LED     Intel           Intel I3
# 3114             4          LED     Intel           Intel I5
# 3120             4          LED    NVIDIA           Intel I5
# 3142           LP3          LED     Intel           Intel I5
# 3145             4          LCD     Intel           Intel I3
# 3164             4          LED     Intel           Intel I5
# 3177           LP3          LED     Intel           Intel I5
# 3242             4          LED     Intel           Intel I3
# 3307             4          LED     Intel           Intel I3
# 3345             4          LED       AMD        AMD Ryzen 5
# 3458             4          LED     Intel           Intel I3
# 3484             4          LED     Intel           Intel I5
# 3524             4          LED       AMD       AMD A-Series
# 3662             3          LED     Intel           Intel I3
# 3676             4          LED     Intel           Intel I3
# 3740             5          LCD    NVIDIA        AMD Ryzen 7
# 3826           LP5          LCD    NVIDIA        AMD Ryzen 7
#
#       Processor_Speed(Ghz) Display_Tier     GPU_Tier  SSD(GB)  HDD(GB)
# 94                     2.5        Small      Mid-end      512        0
# 440                    1.0        Small  Entry-level      512        0
# 441                    1.0        Small  Entry-level      512        0
# 523                    4.5        Small      Low-end      512        0
# 567                    2.0        Small      Low-end      512        0
# 614                    2.5        Small      Mid-end      512        0
# 647                    4.0        Small  Entry-level      256        0
# 870                    2.0        Large  Entry-level      512        0
# 888                    5.0        Small     High-end     1024        0
# 1020                   2.5        Large      Mid-end      512        0
# 1167                   5.0        Large      Mid-end     1024        0
# 1275                   3.0        Small  Entry-level      256        0
# 1284                   2.0        Small  Entry-level      256        0
# 1302                   1.5        Small      Low-end      512        0
# 1555                   2.0        Small      Low-end      256     1024
# 1658                   1.0        Small  Entry-level      512        0
# 1685                   2.5        Small  Entry-level        0     1024
# 1746                   3.0        Small  Entry-level      256        0
# 1790                   1.5        Small  Entry-level      256     1024
# 1794                   1.5        Small  Entry-level      256     1024
# 1884                   2.0        Small  Entry-level      256        0
# 1924                   3.0        Small  Entry-level      512        0
# 1932                   2.5        Small  Entry-level      512        0
# 1948                   3.0        Small  Entry-level      512        0
# 1949                   3.5        Small     High-end      512        0
# 1952                   2.0        Small  Entry-level      512        0
# 1983                   2.5        Small      Mid-end      512        0
# 1994                   3.0        Small  Entry-level      512        0
# 2001                   3.0        Small  Entry-level      256        0
# 2025                   3.5        Small      Mid-end      512        0
# 2027                   4.5        Small      Low-end      512        0
# 2093                   4.5        Small      Low-end      512        0
# 2120                   3.5        Small      Mid-end      512        0
# 2138                   3.0        Small  Entry-level      256        0
# 2151                   2.5        Small  Entry-level      512        0
# 2250                   2.0        Small  Entry-level      512        0
# 2375                   4.0        Small      Mid-end      512        0
# 2421                   4.0        Small  Entry-level      512        0
# 2471                   2.0        Large  Entry-level     1024        0
# 2486                   4.5        Small      Mid-end     1024        0
# 2505                   1.5        Small      Low-end      512        0
# 2530                   1.5        Small      Low-end     1024        0
# 2535                   1.0        Small  Entry-level      512        0
# 2536                   2.5        Small      Mid-end      512        0
# 2543                   1.0        Small      Low-end     1024        0
# 2550                   2.5        Small  Entry-level      512        0
# 2677                   2.5        Large      Mid-end      512        0
# 2684                   5.0        Large      Mid-end      512        0
# 2686                   5.0        Large      Mid-end      512        0
# 2789                   4.0        Small  Entry-level      512        0
# 2826                   2.5        Small  Entry-level      512        0
# 2834                   2.5        Small  Entry-level        0     1024
# 2912                   2.5        Small  Entry-level        0     1024
# 3009                   1.5        Small  Entry-level        0     1024
# 3054                   2.0        Small  Entry-level      256        0
# 3114                   2.5        Small      Low-end      512        0
# 3120                   1.5        Small      Low-end        0     1024
# 3142                   1.5        Small  Entry-level      256        0
# 3145                   1.0        Small  Entry-level      512        0
# 3164                   1.5        Small  Entry-level      256     1024
# 3177                   1.5        Small  Entry-level      256        0
# 3242                   2.0        Small  Entry-level      256        0
# 3307                   2.5        Small  Entry-level        0     1024
# 3345                   2.0        Small      Low-end      512        0
# 3458                   2.0        Small  Entry-level        0     1024
# 3484                   1.5        Small  Entry-level      128     1024
# 3524                   2.5        Small  Entry-level        0     1024
# 3662                   1.5        Small  Entry-level        0      500
# 3676                   2.0        Small  Entry-level        0     1024
# 3740                   4.5        Small      Mid-end     1024        0
# 3826                   3.0        Small      Mid-end      512        0

# %%
df.drop_duplicates(inplace=True)
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Brand, Price, Processor_Brand, RAM_Expandable, RAM_Capacity, RAM_TYPE(DDR), Display_type, GPU_Brand, Processor_Category, Processor_Speed(Ghz), Display_Tier, GPU_Tier, SSD(GB), HDD(GB)]
# Index: []

# %%
df.shape
# Out:
# (3725, 14)

# %% [markdown]
# ### Preprocessing

# %%
df.shape
df.dtypes
# Out:
# Brand                    object
# Price                   float64
# Processor_Brand          object
# RAM_Expandable           object
# RAM_Capacity              int64
# RAM_TYPE(DDR)            object
# Display_type             object
# GPU_Brand                object
# Processor_Category       object
# Processor_Speed(Ghz)    float64
# Display_Tier             object
# GPU_Tier                 object
# SSD(GB)                   int64
# HDD(GB)                   int64
# dtype: object

# %%
# Categorical columns
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
print("Categorical columns:", list(categorical_cols))

# Numerical columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
print("Numerical columns:", list(numerical_cols))
# Out:
# Categorical columns: ['Brand', 'Processor_Brand', 'RAM_Expandable', 'RAM_TYPE(DDR)', 'Display_type', 'GPU_Brand', 'Processor_Category', 'Display_Tier', 'GPU_Tier']
# Numerical columns: ['Price', 'RAM_Capacity', 'Processor_Speed(Ghz)', 'SSD(GB)', 'HDD(GB)']

# %%
for col in categorical_cols:
    print(f"{col}: {df[col].nunique()} unique values")
    print(df[col].value_counts().head(20))
# Out:
# Brand: 9 unique values
# Brand
# ASUS       920
# Lenovo     765
# HP         753
# Dell       413
# Acer       301
# MSI        296
# Other      186
# Samsung     51
# Apple       40
# Name: count, dtype: int64
# Processor_Brand: 3 unique values
# Processor_Brand
# Intel    2811
# AMD       897
# Apple      17
# Name: count, dtype: int64
# RAM_Expandable: 2 unique values
# RAM_Expandable
# No     2012
# Yes    1713
# Name: count, dtype: int64
# RAM_TYPE(DDR): 6 unique values
# RAM_TYPE(DDR)
# 4      2733
# 5       364
# LP5     308
# LP4     165
# 3       110
# LP3      45
# Name: count, dtype: int64
# Display_type: 2 unique values
# Display_type
# LCD    1938
# LED    1787
# Name: count, dtype: int64
# GPU_Brand: 4 unique values
# GPU_Brand
# Intel     1811
# NVIDIA    1298
# AMD        599
# Apple       17
# Name: count, dtype: int64
# Processor_Category: 18 unique values
# Processor_Category
# Intel I5          1235
# Intel I3           652
# Intel I7           623
# AMD Ryzen 5        369
# AMD Ryzen 7        261
# AMD Ryzen 3        116
# Intel Celeron       75
# Intel I9            68
# AMD A-Series        57
# Intel Pentium       56
# Intel Ultra 7       48
# AMD Ryzen 9         43
# AMD Athlon          35
# Intel Ultra 5       23
# Intel Other         17
# Apple M-series      17
# AMD Other           16
# Intel Ultra 9       14
# Name: count, dtype: int64
# Display_Tier: 2 unique values
# Display_Tier
# Small    3350
# Large     375
# Name: count, dtype: int64
# GPU_Tier: 4 unique values
# GPU_Tier
# Entry-level    1606
# Mid-end        1000
# Low-end         987
# High-end        132
# Name: count, dtype: int64

# %% [markdown]
# #### Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder

# %%
df_encoded = df.copy()

# %% [markdown]
# - Binary encoding

# %%
df_encoded['RAM_Expandable'] = df_encoded['RAM_Expandable'].map({'Yes': 1, 'No': 0})
df_encoded['Display_type'] = df_encoded['Display_type'].map({'LCD': 0, 'LED': 1})

# %% [markdown]
# - Ordinal Encoding

# %%
# tier_map = {'Low-End': 0, 'Mid-End': 1, 'Upper Mid-End': 2,'High-End': 3}
# df_encoded['Processor_Tier'] = df_encoded['Processor_Tier'].map(tier_map)
# Apple M-series set Nan becuase only Intel,AMD has tier order

df_encoded['Display_Tier'] = df_encoded['Display_Tier'].map({
    'Small': 1, 'Large': 2
})
# df_encoded['Display_Tier'] = df_encoded['Display_Tier'].map({
#     'Small': 1, 'Medium':2, 'Large': 3
# })

df_encoded['GPU_Tier'] = df_encoded['GPU_Tier'].map({
    'Entry-level': 1, 'Low-end': 2, 'Mid-end': 3, 'High-end': 4
})


df_encoded['RAM_TYPE(DDR)'] = df_encoded['RAM_TYPE(DDR)'].map({
    '3': 1, 'LP3': 2,
    '4': 3, 'LP4': 4,
    '5': 5, 'LP5': 6
})

# df_encoded['Operating_System'] = df_encoded['Operating_System'].map({
#     'Chrome': 0, 'DOS': 1, 'Linux': 2, 'Windows 10': 3,
#     'Windows 11': 4, 'Windows 8.1': 5, 'macOS': 6
# })

# %% [markdown]
# - Categorical variables also keep as label encoded because lightgbm not affected by the order of values

# %%
# # le_OS = LabelEncoder()
# # df_encoded['Operating_System'] = le_OS.fit_transform(df_encoded['Operating_System'])

# le_processor_cat = LabelEncoder()
# df_encoded['Processor_Category'] = le_processor_cat.fit_transform(df_encoded['Processor_Category'])

# # Encode 'Brand'
# le_brand = LabelEncoder()
# df_encoded['Brand'] = le_brand.fit_transform(df_encoded['Brand'])

# # Encode 'Processor_Brand'
# le_processor = LabelEncoder()
# df_encoded['Processor_Brand'] = le_processor.fit_transform(df_encoded['Processor_Brand'])

# # Encode 'GPU_Brand'
# le_gpu = LabelEncoder()
# df_encoded['GPU_Brand'] = le_gpu.fit_transform(df_encoded['GPU_Brand'])

# %%
df_encoded['Processor_Category'].value_counts()
# Out:
# Processor_Category
# Intel I5          1235
# Intel I3           652
# Intel I7           623
# AMD Ryzen 5        369
# AMD Ryzen 7        261
# AMD Ryzen 3        116
# Intel Celeron       75
# Intel I9            68
# AMD A-Series        57
# Intel Pentium       56
# Intel Ultra 7       48
# AMD Ryzen 9         43
# AMD Athlon          35
# Intel Ultra 5       23
# Intel Other         17
# Apple M-series      17
# AMD Other           16
# Intel Ultra 9       14
# Name: count, dtype: int64

# %%
# View mapping

# processor_cat_mapping = dict(zip(le_processor_cat.classes_, le_processor_cat.transform(le_processor_cat.classes_)))
# print("Processor Category Mapping:")
# print(processor_cat_mapping)

# brand_mapping = dict(zip(le_brand.classes_, le_brand.transform(le_brand.classes_)))
# print("Brand Mapping:")
# print(brand_mapping)

# processor_mapping = dict(zip(le_processor.classes_, le_processor.transform(le_processor.classes_)))
# print("\nProcessor_Brand Mapping:")
# print(processor_mapping)

# gpu_mapping = dict(zip(le_gpu.classes_, le_gpu.transform(le_gpu.classes_)))
# print("\nGPU_Brand Mapping:")
# print(gpu_mapping)

# %% [markdown]
#  - One hot Encoding

# %%
df_encoded = pd.get_dummies(
    df_encoded, 
    columns=['Processor_Category', 'Brand', 'Processor_Brand', 'GPU_Brand'],
    drop_first=False  # keep all categories
)

# %%
pd.set_option('display.max_columns', None)
df_encoded.head(10)
# Out:
#       Price  RAM_Expandable  RAM_Capacity  RAM_TYPE(DDR)  Display_type  \
# 0  127011.5               1             8              3             0
# 1  274750.0               1            16              5             0
# 2  194215.0               1             8              3             0
# 3   76965.0               0             8              4             0
# 4  122465.0               1            16              3             0
# 5  173596.5               1             8              3             0
# 6  139965.0               1             8              3             0
# 7  115888.5               1             4              3             1
# 8  171465.0               0             8              3             0
# 9  325465.0               1            16              5             0
#
#    Processor_Speed(Ghz)  Display_Tier  GPU_Tier  SSD(GB)  HDD(GB)  \
# 0                   4.0             1         1      512        0
# 1                   3.5             1         3      512        0
# 2                   4.0             1         2      512        0
# 3                   1.5             1         1      512        0
# 4                   2.5             1         2      512        0
# 5                   4.0             1         1      512        0
# 6                   2.5             1         2      512        0
# 7                   2.0             1         1        0     1024
# 8                   3.0             1         3      512        0
# 9                   3.5             1         3      512        0
#
#    Processor_Category_AMD A-Series  Processor_Category_AMD Athlon  \
# 0                            False                          False
# 1                            False                          False
# 2                            False                          False
# 3                            False                          False
# 4                            False                          False
# 5                            False                          False
# 6                            False                          False
# 7                            False                          False
# 8                            False                          False
# 9                            False                          False
#
#    Processor_Category_AMD Other  Processor_Category_AMD Ryzen 3  \
# 0                         False                           False
# 1                         False                           False
# 2                         False                           False
# 3                         False                           False
# 4                         False                           False
# 5                         False                           False
# 6                         False                           False
# 7                         False                           False
# 8                         False                           False
# 9                         False                           False
#
#    Processor_Category_AMD Ryzen 5  Processor_Category_AMD Ryzen 7  \
# 0                            True                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
# 5                            True                           False
# 6                           False                           False
# 7                           False                           False
# 8                           False                           False
# 9                           False                            True
#
#    Processor_Category_AMD Ryzen 9  Processor_Category_Apple M-series  \
# 0                           False                              False
# 1                           False                              False
# 2                           False                              False
# 3                           False                              False
# 4                           False                              False
# 5                           False                              False
# 6                           False                              False
# 7                           False                              False
# 8                           False                              False
# 9                           False                              False
#
#    Processor_Category_Intel Celeron  Processor_Category_Intel I3  \
# 0                             False                        False
# 1                             False                        False
# 2                             False                        False
# 3                             False                         True
# 4                             False                        False
# 5                             False                        False
# 6                             False                        False
# 7                             False                         True
# 8                             False                        False
# 9                             False                        False
#
#    Processor_Category_Intel I5  Processor_Category_Intel I7  \
# 0                        False                        False
# 1                         True                        False
# 2                         True                        False
# 3                        False                        False
# 4                         True                        False
# 5                        False                        False
# 6                         True                        False
# 7                        False                        False
# 8                         True                        False
# 9                        False                        False
#
#    Processor_Category_Intel I9  Processor_Category_Intel Other  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
# 5                        False                           False
# 6                        False                           False
# 7                        False                           False
# 8                        False                           False
# 9                        False                           False
#
#    Processor_Category_Intel Pentium  Processor_Category_Intel Ultra 5  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
# 5                             False                             False
# 6                             False                             False
# 7                             False                             False
# 8                             False                             False
# 9                             False                             False
#
#    Processor_Category_Intel Ultra 7  Processor_Category_Intel Ultra 9  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
# 5                             False                             False
# 6                             False                             False
# 7                             False                             False
# 8                             False                             False
# 9                             False                             False
#
#    Brand_ASUS  Brand_Acer  Brand_Apple  Brand_Dell  Brand_HP  Brand_Lenovo  \
# 0       False       False        False       False     False          True
# 1       False       False        False        True     False         False
# 2       False       False        False       False      True         False
# 3       False       False        False       False     False         False
# 4       False        True        False       False     False         False
# 5       False       False        False       False      True         False
# 6       False        True        False       False     False         False
# 7       False       False        False       False     False          True
# 8        True       False        False       False     False         False
# 9       False       False        False       False     False          True
#
#    Brand_MSI  Brand_Other  Brand_Samsung  Processor_Brand_AMD  \
# 0      False        False          False                 True
# 1      False        False          False                False
# 2      False        False          False                False
# 3      False         True          False                False
# 4      False        False          False                False
# 5      False        False          False                 True
# 6      False        False          False                False
# 7      False        False          False                False
# 8      False        False          False                False
# 9      False        False          False                 True
#
#    Processor_Brand_Apple  Processor_Brand_Intel  GPU_Brand_AMD  \
# 0                  False                  False           True
# 1                  False                   True          False
# 2                  False                   True          False
# 3                  False                   True          False
# 4                  False                   True          False
# 5                  False                  False           True
# 6                  False                   True          False
# 7                  False                   True          False
# 8                  False                   True          False
# 9                  False                  False          False
#
#    GPU_Brand_Apple  GPU_Brand_Intel  GPU_Brand_NVIDIA
# 0            False            False             False
# 1            False            False              True
# 2            False             True             False
# 3            False             True             False
# 4            False             True             False
# 5            False            False             False
# 6            False             True             False
# 7            False             True             False
# 8            False            False              True
# 9            False            False              True

# %%
df_encoded.shape
# Out:
# (3725, 44)

# %%
df_encoded.dtypes
# Out:
# Price                                float64
# RAM_Expandable                         int64
# RAM_Capacity                           int64
# RAM_TYPE(DDR)                          int64
# Display_type                           int64
# Processor_Speed(Ghz)                 float64
# Display_Tier                           int64
# GPU_Tier                               int64
# SSD(GB)                                int64
# HDD(GB)                                int64
# Processor_Category_AMD A-Series         bool
# Processor_Category_AMD Athlon           bool
# Processor_Category_AMD Other            bool
# Processor_Category_AMD Ryzen 3          bool
# Processor_Category_AMD Ryzen 5          bool
# Processor_Category_AMD Ryzen 7          bool
# Processor_Category_AMD Ryzen 9          bool
# Processor_Category_Apple M-series       bool
# Processor_Category_Intel Celeron        bool
# Processor_Category_Intel I3             bool
# Processor_Category_Intel I5             bool
# Processor_Category_Intel I7             bool
# Processor_Category_Intel I9             bool
# Processor_Category_Intel Other          bool
# Processor_Category_Intel Pentium        bool
# Processor_Category_Intel Ultra 5        bool
# Processor_Category_Intel Ultra 7        bool
# Processor_Category_Intel Ultra 9        bool
# Brand_ASUS                              bool
# Brand_Acer                              bool
# Brand_Apple                             bool
# Brand_Dell                              bool
# Brand_HP                                bool
# Brand_Lenovo                            bool
# Brand_MSI                               bool
# Brand_Other                             bool
# Brand_Samsung                           bool
# Processor_Brand_AMD                     bool
# Processor_Brand_Apple                   bool
# Processor_Brand_Intel                   bool
# GPU_Brand_AMD                           bool
# GPU_Brand_Apple                         bool
# GPU_Brand_Intel                         bool
# GPU_Brand_NVIDIA                        bool
# dtype: object

# %% [markdown]
# #### Heat Map

# %%
#Separate features and target
feature_cols = [col for col in df_encoded.columns if col != 'Price'] 
X = df_encoded[feature_cols]  # 23 features
y = df_encoded['Price']       # 1 target

# %%
plt.figure(figsize=(20,18))
sns.heatmap(X.corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Correlation Matrix of Features")
plt.show()

# %%
# from statsmodels.stats.outliers_influence import variance_inflation_factor

# X_vif = X.copy()

# # 2. Fill NaN in Processor_Tier for VIF calculation
# X_vif['Processor_Tier'] = X_vif['Processor_Tier'].fillna(-1)

# # 3. Keep only numeric columns
# X_vif = X_vif.select_dtypes(include=['int64', 'float64', 'uint8', 'bool'])

# # 4. Convert all to float
# X_vif = X_vif.astype(float)

# # 5. Compute VIF
# from statsmodels.stats.outliers_influence import variance_inflation_factor
# import pandas as pd

# vif_data = pd.DataFrame()
# vif_data["Feature"] = X_vif.columns
# vif_data["VIF"] = [variance_inflation_factor(X_vif.values, i) for i in range(X_vif.shape[1])]

# print(vif_data.sort_values(by="VIF", ascending=False))

# %%
df_cleaned = df_encoded.copy()
df_cleaned.to_csv("cleaned_data_5.csv", index=False)

# %%
# df_cleaned['Processor_Tier'].value_counts(dropna=False)

# %%
# print("Brand Unique Values:", df_cleaned['Brand'].nunique())
# print("Missing Brand values:", df_cleaned['Brand'].isna().sum())
# print(df_cleaned['Brand'].value_counts())
