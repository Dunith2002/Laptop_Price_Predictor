# %% [markdown]
# # Data Cleaning and Preprocessing

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('../../../data/raw/laptop_data.csv')

# %%
data.head(10)
# Out:
#    Unnamed: 0    Brand                                               Name  \
# 0           0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...
# 1           1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....
# 2           3     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...
# 3           4       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...
# 4           6  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...
# 5           7     Acer  Acer One 14 Z8-415 (UN.599SI.020) Laptop (14 I...
# 6           8       HP  HP 14s-fq1092AU (50M60PA) Laptop (14 Inch | AM...
# 7           9     Acer  Acer One 14 Z8-415 (UN.599SI.018) Laptop (14 I...
# 8          10   Lenovo  Lenovo Ideapad S145 (81VD008PIN) Laptop (15.6 ...
# 9          11     ASUS  ASUS TUF Gaming F15 FX506HF-HN075W Laptop (15....
#
#    Price                      Processor_Name Processor_Brand  \
# 0  22990                  MediaTek Octa-core        MediaTek
# 1  36289               AMD Hexa-Core Ryzen 5             AMD
# 2  78500            Intel Core i5 (12th Gen)           Intel
# 3  55490            Intel Core i5 (12th Gen)           Intel
# 4  21990            Intel Core i3 (11th Gen)           Intel
# 5  34990  Intel Core i5 (11th Gen) Processor           Intel
# 6  49599               AMD Hexa-Core Ryzen 5             AMD
# 7  39990            Intel Core i5 (11th Gen)           Intel
# 8  33111             Intel Core i3 (8th Gen)           Intel
# 9  48990            Intel Core i5 (11th Gen)           Intel
#
#       RAM_Expandable      RAM      RAM_TYPE                 Ghz Display_type  \
# 0     Not Expandable    4 GB       DDR4 RAM   2.0 Ghz Processor          LED
# 1   12 GB Expandable    8 GB      DDR4 RAM    4.0 Ghz Processor          LCD
# 2   32 GB Expandable   16 GB      DDR5 RAM    3.3 Ghz Processor          LCD
# 3    8 GB Expandable    8 GB      DDR4 RAM    4.2 Ghz Processor          LCD
# 4     Not Expandable  8 GB LP   LPDDR4X RAM   1.7 Ghz Processor          LCD
# 5   32 GB Expandable   16 GB      DDR4 RAM                    0          LCD
# 6   16 GB Expandable    8 GB      DDR4 RAM    4.0 Ghz Processor          LCD
# 7   32 GB Expandable    8 GB      DDR4 RAM    2.5 Ghz Processor          LCD
# 8   12 GB Expandable    4 GB      DDR4 RAM    2.2 Ghz Processor          LED
# 9     Not Expandable    8 GB       DDR4 RAM   2.9 Ghz Processor          LCD
#
#   Display                         GPU GPU_Brand                 SSD  \
# 0   11.6          Integrated Graphics  MediaTek   64 GB SSD Storage
# 1   15.6                       Radeon       AMD  512 GB SSD Storage
# 2   15.6   GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD Storage
# 3   15.6                      Iris Xe     Intel  512 GB SSD Storage
# 4   15.6                          UHD     Intel  512 GB SSD Storage
# 5     14                      Iris Xe     Intel  512 GB SSD Storage
# 6     14                       Radeon       AMD  512 GB SSD Storage
# 7     14                      Iris Xe     Intel  512 GB SSD Storage
# 8   15.6                      UHD 620     Intel              NO SSD
# 9   15.6   GeForce RTX 2050 GPU, 4 GB    NVIDIA  512 GB SSD Storage
#
#                    HDD Adapter                Battery_Life
# 0               No HDD      45    Upto 12 Hrs Battery Life
# 1               No HDD      65    Upto 11 Hrs Battery Life
# 2               No HDD      56    Upto 10 Hrs Battery Life
# 3               No HDD      no  Upto 7.30 Hrs Battery Life
# 4               No HDD      45     Upto 8 Hrs Battery Life
# 5               No HDD      45                 45W Adapter
# 6               No HDD      65     Upto 9 Hrs Battery Life
# 7               No HDD      45                 45W Adapter
# 8  1024 GB HDD Storage      45                 45W Adapter
# 9               No HDD     150                150W Adapter

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3976 entries, 0 to 3975
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       3976 non-null   int64
#  1   Brand            3976 non-null   object
#  2   Name             3976 non-null   object
#  3   Price            3976 non-null   int64
#  4   Processor_Name   3976 non-null   object
#  5   Processor_Brand  3976 non-null   object
#  6   RAM_Expandable   3976 non-null   object
#  7   RAM              3976 non-null   object
#  8   RAM_TYPE         3976 non-null   object
#  9   Ghz              3976 non-null   object
#  10  Display_type     3976 non-null   object
#  11  Display          3976 non-null   object
#  12  GPU              3968 non-null   object
#  13  GPU_Brand        3972 non-null   object
#  14  SSD              3976 non-null   object
#  15  HDD              3976 non-null   object
#  16  Adapter          3976 non-null   object
#  17  Battery_Life     3558 non-null   object
# dtypes: int64(2), object(16)
# memory usage: 559.3+ KB

# %%
#Creating copy of data frame
df = data.copy()

# %% [markdown]
# ### Remove unnecessary coulmns

# %%
df.shape
# Out:
# (3976, 18)

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.head()
# Out:
#      Brand                                               Name  Price  \
# 0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...  22990
# 1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  36289
# 2     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  78500
# 3       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  55490
# 4  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...  21990
#
#              Processor_Name Processor_Brand     RAM_Expandable      RAM  \
# 0        MediaTek Octa-core        MediaTek     Not Expandable    4 GB
# 1     AMD Hexa-Core Ryzen 5             AMD   12 GB Expandable    8 GB
# 2  Intel Core i5 (12th Gen)           Intel   32 GB Expandable   16 GB
# 3  Intel Core i5 (12th Gen)           Intel    8 GB Expandable    8 GB
# 4  Intel Core i3 (11th Gen)           Intel     Not Expandable  8 GB LP
#
#        RAM_TYPE                 Ghz Display_type Display  \
# 0      DDR4 RAM   2.0 Ghz Processor          LED   11.6
# 1     DDR4 RAM    4.0 Ghz Processor          LCD   15.6
# 2     DDR5 RAM    3.3 Ghz Processor          LCD   15.6
# 3     DDR4 RAM    4.2 Ghz Processor          LCD   15.6
# 4   LPDDR4X RAM   1.7 Ghz Processor          LCD   15.6
#
#                           GPU GPU_Brand                 SSD     HDD Adapter  \
# 0         Integrated Graphics  MediaTek   64 GB SSD Storage  No HDD      45
# 1                      Radeon       AMD  512 GB SSD Storage  No HDD      65
# 2  GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD Storage  No HDD      56
# 3                     Iris Xe     Intel  512 GB SSD Storage  No HDD      no
# 4                         UHD     Intel  512 GB SSD Storage  No HDD      45
#
#                  Battery_Life
# 0    Upto 12 Hrs Battery Life
# 1    Upto 11 Hrs Battery Life
# 2    Upto 10 Hrs Battery Life
# 3  Upto 7.30 Hrs Battery Life
# 4     Upto 8 Hrs Battery Life

# %%
df.shape
# Out:
# (3976, 17)

# %%
df['Brand'].value_counts()
# Out:
# Brand
# ASUS         989
# Lenovo       811
# HP           803
# Dell         420
# Acer         322
# MSI          316
# Samsung       61
# Apple         49
# Infinix       39
# Microsoft     34
# AVITA         23
# Gigabyte      17
# LG            15
# Honor         14
# iball         11
# Xiaomi        10
# Fujitsu        8
# Zebronics      8
# Wings          4
# Colorful       3
# Realme         3
# Micromax       3
# Coconics       3
# Tecno          2
# Smartron       2
# Huawei         1
# Razer          1
# VAIO           1
# Lava           1
# Nokia          1
# RDP            1
# Name: count, dtype: int64

# %% [markdown]
# ### Drop Duplicate Rows

# %%
df[df.duplicated()]
# Out:
#        Brand                                               Name  Price  \
# 2867  Lenovo  Lenovo Ideapad 3 15ITL6 (82H801L7IN) Laptop (1...  33900
# 3018      HP  HP 15s-du1044tu (18N71PA) Laptop (15.6 Inch | ...  22071
# 3104    Acer  Acer Aspire 5 A514-53 (NX.HZ6SI.001) Laptop (1...  27775
# 3321  Lenovo  Lenovo Ideapad Gaming 3 15ACH6 (82K200X3IN) La...  81990
#
#                 Processor_Name Processor_Brand     RAM_Expandable     RAM  \
# 2867  Intel Core i3 (11th Gen)           Intel   12 GB Expandable   8 GB
# 3018   Intel Celeron Dual-Core           Intel     Not Expandable   4 GB
# 3104  Intel Core i3 (10th Gen)           Intel   12 GB Expandable   4 GB
# 3321     AMD Octa-Core Ryzen 7             AMD   16 GB Expandable  16 GB
#
#         RAM_TYPE                 Ghz Display_type Display  \
# 2867   DDR4 RAM    4.0 Ghz Processor          LCD   15.6
# 3018    DDR4 RAM   1.1 Ghz Processor          LED   15.6
# 3104   DDR4 RAM    1.2 Ghz Processor          LED     14
# 3321   DDR4 RAM    3.1 Ghz Processor          LCD   15.6
#
#                              GPU GPU_Brand                 SSD  \
# 2867                         UHD     Intel  512 GB SSD Storage
# 3018                     UHD 600     Intel              NO SSD
# 3104                         UHD     Intel  512 GB SSD Storage
# 3321  GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD Storage
#
#                       HDD Adapter               Battery_Life
# 2867               No HDD      45   Upto 12 Hrs Battery Life
# 3018  1024 GB HDD Storage      46                46W Adapter
# 3104               No HDD      48   Upto 11 Hrs Battery Life
# 3321               No HDD      65    Upto 5 Hrs Battery Life

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Brand, Name, Price, Processor_Name, Processor_Brand, RAM_Expandable, RAM, RAM_TYPE, Ghz, Display_type, Display, GPU, GPU_Brand, SSD, HDD, Adapter, Battery_Life]
# Index: []

# %%
df['Brand'].value_counts()
# Out:
# Brand
# ASUS         989
# Lenovo       809
# HP           802
# Dell         420
# Acer         321
# MSI          316
# Samsung       61
# Apple         49
# Infinix       39
# Microsoft     34
# AVITA         23
# Gigabyte      17
# LG            15
# Honor         14
# iball         11
# Xiaomi        10
# Fujitsu        8
# Zebronics      8
# Wings          4
# Colorful       3
# Realme         3
# Micromax       3
# Coconics       3
# Tecno          2
# Smartron       2
# Huawei         1
# Razer          1
# VAIO           1
# Lava           1
# Nokia          1
# RDP            1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3972, 17)

# %%
# For every column
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# Brand                0
# Name                 0
# Price                0
# Processor_Name       0
# Processor_Brand      0
# RAM_Expandable       0
# RAM                  0
# RAM_TYPE             0
# Ghz                  0
# Display_type         0
# Display              0
# GPU                  8
# GPU_Brand            4
# SSD                  0
# HDD                  0
# Adapter              0
# Battery_Life       418
# dtype: int64

# %%
print(df.dtypes)
# Out:
# Brand              object
# Name               object
# Price               int64
# Processor_Name     object
# Processor_Brand    object
# RAM_Expandable     object
# RAM                object
# RAM_TYPE           object
# Ghz                object
# Display_type       object
# Display            object
# GPU                object
# GPU_Brand          object
# SSD                object
# HDD                object
# Adapter            object
# Battery_Life       object
# dtype: object

# %% [markdown]
# ### Clean by Feature

# %%
df.head(10)
# Out:
#      Brand                                               Name  Price  \
# 0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...  22990
# 1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  36289
# 2     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  78500
# 3       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  55490
# 4  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...  21990
# 5     Acer  Acer One 14 Z8-415 (UN.599SI.020) Laptop (14 I...  34990
# 6       HP  HP 14s-fq1092AU (50M60PA) Laptop (14 Inch | AM...  49599
# 7     Acer  Acer One 14 Z8-415 (UN.599SI.018) Laptop (14 I...  39990
# 8   Lenovo  Lenovo Ideapad S145 (81VD008PIN) Laptop (15.6 ...  33111
# 9     ASUS  ASUS TUF Gaming F15 FX506HF-HN075W Laptop (15....  48990
#
#                        Processor_Name Processor_Brand     RAM_Expandable  \
# 0                  MediaTek Octa-core        MediaTek     Not Expandable
# 1               AMD Hexa-Core Ryzen 5             AMD   12 GB Expandable
# 2            Intel Core i5 (12th Gen)           Intel   32 GB Expandable
# 3            Intel Core i5 (12th Gen)           Intel    8 GB Expandable
# 4            Intel Core i3 (11th Gen)           Intel     Not Expandable
# 5  Intel Core i5 (11th Gen) Processor           Intel   32 GB Expandable
# 6               AMD Hexa-Core Ryzen 5             AMD   16 GB Expandable
# 7            Intel Core i5 (11th Gen)           Intel   32 GB Expandable
# 8             Intel Core i3 (8th Gen)           Intel   12 GB Expandable
# 9            Intel Core i5 (11th Gen)           Intel     Not Expandable
#
#        RAM      RAM_TYPE                 Ghz Display_type Display  \
# 0    4 GB       DDR4 RAM   2.0 Ghz Processor          LED   11.6
# 1    8 GB      DDR4 RAM    4.0 Ghz Processor          LCD   15.6
# 2   16 GB      DDR5 RAM    3.3 Ghz Processor          LCD   15.6
# 3    8 GB      DDR4 RAM    4.2 Ghz Processor          LCD   15.6
# 4  8 GB LP   LPDDR4X RAM   1.7 Ghz Processor          LCD   15.6
# 5   16 GB      DDR4 RAM                    0          LCD     14
# 6    8 GB      DDR4 RAM    4.0 Ghz Processor          LCD     14
# 7    8 GB      DDR4 RAM    2.5 Ghz Processor          LCD     14
# 8    4 GB      DDR4 RAM    2.2 Ghz Processor          LED   15.6
# 9    8 GB       DDR4 RAM   2.9 Ghz Processor          LCD   15.6
#
#                           GPU GPU_Brand                 SSD  \
# 0         Integrated Graphics  MediaTek   64 GB SSD Storage
# 1                      Radeon       AMD  512 GB SSD Storage
# 2  GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD Storage
# 3                     Iris Xe     Intel  512 GB SSD Storage
# 4                         UHD     Intel  512 GB SSD Storage
# 5                     Iris Xe     Intel  512 GB SSD Storage
# 6                      Radeon       AMD  512 GB SSD Storage
# 7                     Iris Xe     Intel  512 GB SSD Storage
# 8                     UHD 620     Intel              NO SSD
# 9  GeForce RTX 2050 GPU, 4 GB    NVIDIA  512 GB SSD Storage
#
#                    HDD Adapter                Battery_Life
# 0               No HDD      45    Upto 12 Hrs Battery Life
# 1               No HDD      65    Upto 11 Hrs Battery Life
# 2               No HDD      56    Upto 10 Hrs Battery Life
# 3               No HDD      no  Upto 7.30 Hrs Battery Life
# 4               No HDD      45     Upto 8 Hrs Battery Life
# 5               No HDD      45                 45W Adapter
# 6               No HDD      65     Upto 9 Hrs Battery Life
# 7               No HDD      45                 45W Adapter
# 8  1024 GB HDD Storage      45                 45W Adapter
# 9               No HDD     150                150W Adapter

# %%
print(df.columns)
# Out:
# Index(['Brand', 'Name', 'Price', 'Processor_Name', 'Processor_Brand',
#        'RAM_Expandable', 'RAM', 'RAM_TYPE', 'Ghz', 'Display_type', 'Display',
#        'GPU', 'GPU_Brand', 'SSD', 'HDD', 'Adapter', 'Battery_Life'],
#       dtype='object')

# %%
df.shape
# Out:
# (3972, 17)

# %% [markdown]
# #### OS

# %%
def gen(text):
    if ('Windows 11' in text.split('|')[3]) or 'Windows 10' in text.split('|')[3] or ('Windows 8.1' in text.split('|')[3]) or ('DOS' in text.split('|')[3]) or ('Linux' in text.split('|')[3]) or ('Ubuntu' in text.split('|')[3]) :
        return text.split('|')[3].strip()
    elif 'macOS' in text.split('|')[3]:
        return 'macOS'
    else:
        return 'Others'
    
df['Operating_System'] = df['Name'].apply(gen)
df['Operating_System'].value_counts()
# Out:
# Operating_System
# Windows 11     2133
# Windows 10     1512
# DOS             192
# macOS            49
# Others           31
# Windows 8.1      25
# Linux            23
# Ubuntu            7
# Name: count, dtype: int64

# %%
# #Extract OS
# df['OS'] = df['Name'].str.split('|').str[3].str.strip()

# print(df['OS'].value_counts())

# %%
# def gen(text):
#     part = text.split('|')[3]  # Extract the 4th part (OS info)

#     if ('Windows 11' in part) or ('Windows 10' in part) or ('Windows 8.1' in part) or ('DOS' in part):
#         return part.strip()
#     elif ('Linux' in part) or ('Ubuntu' in part):
#         return 'Linux'
#     elif 'macOS' in part:
#         return 'macOS'
#     else:
#         return 'Chrome'

# # Apply to dataframe
# df['Operating_System'] = df['Name'].apply(gen)

# # View counts
# print(df['Operating_System'].value_counts())

# %%
# # Filter rows where Operating_System is 'DOS'
# dos_laptops = df[df['Operating_System'] == 'DOS']

# # Show only the Name column
# print(dos_laptops['Name'])

# %%
df.head()
# Out:
#      Brand                                               Name  Price  \
# 0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...  22990
# 1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  36289
# 2     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  78500
# 3       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  55490
# 4  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...  21990
#
#              Processor_Name Processor_Brand     RAM_Expandable      RAM  \
# 0        MediaTek Octa-core        MediaTek     Not Expandable    4 GB
# 1     AMD Hexa-Core Ryzen 5             AMD   12 GB Expandable    8 GB
# 2  Intel Core i5 (12th Gen)           Intel   32 GB Expandable   16 GB
# 3  Intel Core i5 (12th Gen)           Intel    8 GB Expandable    8 GB
# 4  Intel Core i3 (11th Gen)           Intel     Not Expandable  8 GB LP
#
#        RAM_TYPE                 Ghz Display_type Display  \
# 0      DDR4 RAM   2.0 Ghz Processor          LED   11.6
# 1     DDR4 RAM    4.0 Ghz Processor          LCD   15.6
# 2     DDR5 RAM    3.3 Ghz Processor          LCD   15.6
# 3     DDR4 RAM    4.2 Ghz Processor          LCD   15.6
# 4   LPDDR4X RAM   1.7 Ghz Processor          LCD   15.6
#
#                           GPU GPU_Brand                 SSD     HDD Adapter  \
# 0         Integrated Graphics  MediaTek   64 GB SSD Storage  No HDD      45
# 1                      Radeon       AMD  512 GB SSD Storage  No HDD      65
# 2  GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD Storage  No HDD      56
# 3                     Iris Xe     Intel  512 GB SSD Storage  No HDD      no
# 4                         UHD     Intel  512 GB SSD Storage  No HDD      45
#
#                  Battery_Life Operating_System
# 0    Upto 12 Hrs Battery Life           Others
# 1    Upto 11 Hrs Battery Life       Windows 11
# 2    Upto 10 Hrs Battery Life       Windows 11
# 3  Upto 7.30 Hrs Battery Life       Windows 11
# 4     Upto 8 Hrs Battery Life       Windows 11

# %% [markdown]
# #### Brand

# %%
print("Brand Unique Values:", df['Brand'].nunique())
print("Missing Brand values:", df['Brand'].isna().sum())
print(df['Brand'].value_counts())
# Out:
# Brand Unique Values: 31
# Missing Brand values: 0
# Brand
# ASUS         989
# Lenovo       809
# HP           802
# Dell         420
# Acer         321
# MSI          316
# Samsung       61
# Apple         49
# Infinix       39
# Microsoft     34
# AVITA         23
# Gigabyte      17
# LG            15
# Honor         14
# iball         11
# Xiaomi        10
# Fujitsu        8
# Zebronics      8
# Wings          4
# Colorful       3
# Realme         3
# Micromax       3
# Coconics       3
# Tecno          2
# Smartron       2
# Huawei         1
# Razer          1
# VAIO           1
# Lava           1
# Nokia          1
# RDP            1
# Name: count, dtype: int64

# %%
# Here I can consider low quantity brands as "Other" category
top_brands = ['ASUS', 'Lenovo', 'HP', 'Dell', 'Acer', 'MSI','Samsung','Apple']
df['Brand'] = df['Brand'].apply(lambda x: x if x in top_brands else 'Other')

# %%
print(df['Brand'].value_counts())
# Out:
# Brand
# ASUS       989
# Lenovo     809
# HP         802
# Dell       420
# Acer       321
# MSI        316
# Other      205
# Samsung     61
# Apple       49
# Name: count, dtype: int64

# %% [markdown]
# #### Price

# %%
df.shape
# Out:
# (3972, 18)

# %%
print("Price Unique Values:", df['Price'].nunique())
print("Missing Price values:", df['Price'].isna().sum())
print(df['Price'].value_counts())
print((df['Price'] == 0).any())
# Out:
# Price Unique Values: 1799
# Missing Price values: 0
# Price
# 64990     46
# 79990     38
# 49990     38
# 42990     38
# 34990     37
#           ..
# 166499     1
# 41699      1
# 146990     1
# 154366     1
# 29240      1
# Name: count, Length: 1799, dtype: int64
# False

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

mean_price = df['Price'].mean()
sns.histplot(df['Price'], kde=True, ax=axes[0])
axes[0].set_title('Distribution of Laptop Prices')

sns.boxplot(data=df, y='Price', ax=axes[1])
axes[1].set_title('Laptop Pricing Spread')
axes[1].set_ylabel('Price')

axes[1].axhline(mean_price, color='red', linestyle=':', linewidth=1, label='Mean')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
df.shape
# Out:
# (3972, 18)

# %%
df['Brand'].value_counts()
# Out:
# Brand
# ASUS       989
# Lenovo     809
# HP         802
# Dell       420
# Acer       321
# MSI        316
# Other      205
# Samsung     61
# Apple       49
# Name: count, dtype: int64

# %% [markdown]
# ##### Removing Outliars ( Not Finalized)

# %%
Q1 = df['Price'].quantile(0.25)
Q3 = df['Price'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['Price'] >= lower_bound) & (df['Price'] <= upper_bound)]

# %%
df.shape
# Out:
# (3692, 18)

# %%
df["Brand"].value_counts()
# Out:
# Brand
# ASUS       901
# Lenovo     773
# HP         769
# Dell       399
# Acer       314
# MSI        263
# Other      190
# Samsung     51
# Apple       32
# Name: count, dtype: int64

# %% [markdown]
# ##### Converting IND RS to LKR

# %%
df['Price'] = df['Price'] * 3.5 # Get Average Exchange Rate

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

mean_price = df['Price'].mean()
sns.histplot(df['Price'], kde=True, ax=axes[0])
axes[0].set_title('Distribution of Laptop Prices')

sns.boxplot(data=df, y='Price', ax=axes[1])
axes[1].set_title('Laptop Pricing Spread')
axes[1].set_ylabel('Price')

axes[1].axhline(mean_price, color='red', linestyle=':', linewidth=1, label='Mean')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
price_skew = df['Price'].skew()
print("Skewness of Price:", price_skew)
# Out:
# Skewness of Price: 0.9014009678245692

# %%
print(df['Price'].describe())
# Out:
# count      3692.000000
# mean     215212.614843
# std      103789.414643
# min       27965.000000
# 25%      134749.125000
# 50%      195965.000000
# 75%      272702.500000
# max      532339.500000
# Name: Price, dtype: float64

# %%
df['Brand'].value_counts()
# Out:
# Brand
# ASUS       901
# Lenovo     773
# HP         769
# Dell       399
# Acer       314
# MSI        263
# Other      190
# Samsung     51
# Apple       32
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3692, 18)

# %%
print(df['Brand'].value_counts())
# Out:
# Brand
# ASUS       901
# Lenovo     773
# HP         769
# Dell       399
# Acer       314
# MSI        263
# Other      190
# Samsung     51
# Apple       32
# Name: count, dtype: int64

# %% [markdown]
# #### Processor Brand

# %%
# Filter rows where Processor_Brand is Apple
apple_df = df[df['Processor_Brand'] == 'Apple'][['Processor_Name', 'Processor_Brand']]

# View the resulting DataFrame
print(apple_df)
# Out:
#           Processor_Name Processor_Brand
# 80              Apple M1           Apple
# 96    Apple M2 Processor           Apple
# 227   Apple M2 Processor           Apple
# 371   Apple M2 Processor           Apple
# 1557  Apple M1 Processor           Apple
# 1944  Apple M2 Processor           Apple
# 1972  Apple M2 Processor           Apple
# 1980  Apple M2 Processor           Apple
# 1981  Apple M2 Processor           Apple
# 1982  Apple M2 Processor           Apple
# 1983  Apple M2 Processor           Apple

# %%
print("Processor_Brand Unique Values:", df['Processor_Brand'].nunique())
print("Missing Processor_Brand values:", df['Processor_Brand'].isna().sum())
df['Processor_Brand'].value_counts()
# Out:
# Processor_Brand Unique Values: 17
# Missing Processor_Brand values: 0
# Processor_Brand
# Intel        2774
# AMD           882
# Apple          11
# MediaTek        4
# 1.7             4
# 2.4             2
# 2.0             2
# 3.0             2
# 3.4             2
# 2.1             2
# 1.6             1
# Qualcomm        1
# 3.3             1
# 2.2             1
# 1.8             1
# Microsoft       1
# 1.9             1
# Name: count, dtype: int64

# %% [markdown]
# * Some Processors_Brands names have Ghz speeds as a wrong input. So we can remove those values.

# %%
# Here only consider Intel and AMD
df['Processor_Brand'].info
# Out:
# <bound method Series.info of 0       MediaTek
# 1            AMD
# 2          Intel
# 3          Intel
# 4          Intel
#           ...
# 3971       Intel
# 3972       Intel
# 3973         AMD
# 3974         AMD
# 3975       Intel
# Name: Processor_Brand, Length: 3692, dtype: object>

# %%
df.shape
# Out:
# (3692, 18)

# %%
valid_processors = ['Intel', 'AMD', 'Apple', 'MediaTek', 'Qualcomm', 'Microsoft']
df = df[df['Processor_Brand'].isin(valid_processors)]

# %%
df.shape
# Out:
# (3673, 18)

# %%
df['Processor_Brand'].value_counts()
# Out:
# Processor_Brand
# Intel        2774
# AMD           882
# Apple          11
# MediaTek        4
# Qualcomm        1
# Microsoft       1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15, 6))
sns.countplot(data=df, x='Processor_Brand', hue='Processor_Brand', palette='Set2')
plt.xticks(rotation=45)
plt.title("Processor Brands Count")
plt.show()

# %%
print(df['Processor_Brand'].value_counts(normalize=True) * 100)
# Out:
# Processor_Brand
# Intel        75.524095
# AMD          24.013068
# Apple         0.299483
# MediaTek      0.108903
# Qualcomm      0.027226
# Microsoft     0.027226
# Name: proportion, dtype: float64

# %% [markdown]
# * Intel and AMD are the prominant, but apple laptops has special apple chips therefore it also need to be consider. reset can be ignore/drop

# %%
print(df.shape)
top_processor = ['Intel', 'AMD', 'Apple']
df = df[df['Processor_Brand'].isin(top_processor)]
print(df.shape)
df['Processor_Brand'].value_counts()
# Out:
# (3673, 18)
# (3667, 18)
# Processor_Brand
# Intel    2774
# AMD       882
# Apple      11
# Name: count, dtype: int64

# %%
pd.set_option('display.max_rows', None)
df['Processor_Name'].value_counts()
# Out:
# Processor_Name
# Intel Core i5 (11th Gen)              316
# Intel Core i5 (12th Gen)              293
# AMD Hexa-Core Ryzen 5                 245
# AMD Octa-Core Ryzen 7                 224
# Intel Core i3 (11th Gen)              188
# Intel Core i5 (10th Gen)              173
# Intel Core i5 (8th Gen)               173
# Intel Core i3 (10th Gen)              152
# Intel Core i7 (12th Gen)              134
# Intel Core i5 (13th Gen)              132
# Intel Core i7 (13th Gen)              113
# AMD Quad-Core Ryzen 5                 108
# Intel Celeron Dual-Core               103
# Intel Core i3 (12th Gen)               90
# Intel Core i7 (11th Gen)               76
# Intel Core i3 (7th Gen)                72
# AMD Dual-Core Ryzen 3                  67
# Intel Core i3 (6th Gen)                62
# Intel Core i5 (7th Gen)                60
# Intel Core i7 (8th Gen)                59
# Intel Core i7 (10th Gen)               48
# AMD Quad-Core Ryzen 3                  46
# Intel Pentium Quad-Core                43
# Intel Core i5 (11th Gen) Processor     38
# Intel Core i5 (9th Gen)                36
# Intel Core i3 (13th Gen)               34
# AMD Dual-Core Athlon                   34
# Intel Core i3 (8th Gen)                33
# Intel Core i7 (7th Gen)                33
# AMD Octa-Core Ryzen 9                  25
# Intel Core Ultra 7                     25
# Intel Core i3 (11th Gen) Processor     23
# Intel Core Ultra 5                     23
# Intel Core i7 (11th Gen) Processor     23
# AMD Dual-Core A6 APU                   21
# Intel Core i7 (9th Gen)                21
# AMD Dual-Core A9 APU                   20
# Intel Core i5 (6th Gen)                17
# AMD Octa-Core Ryzen 7 Processor        16
# AMD Hexa-Core Ryzen 5 Processor        16
# Intel Core i9 (13th Gen)               14
# Intel Atom Quad-Core                   14
# Intel Core 5 (Series 1)                11
# AMD Quad-Core Ryzen 7                  11
# Intel Core i5 (12th Gen) Processor     10
# Intel Core i5 (13th Gen) Processor      9
# Apple M2 Processor                      9
# Intel Core i3 (12th Gen) Processor      9
# Intel Core i5 (5th Gen)                 9
# Intel Core i3 (5th Gen)                 8
# Intel Pentium Dual-Core                 8
# AMD Dual-Core APU                       8
# AMD Quad-Core A8 APU                    7
# Intel Core i7 (14th Gen)                7
# Intel Core i7 (13th Gen) Processor      6
# Intel Pentium Gold                      6
# AMD Dual-Core A4 APU                    6
# Intel Celeron Quad-Core                 6
# Intel Core Ultra 9                      5
# Intel Core i9 (12th Gen)                5
# Intel Core 7 (Series 1)                 5
# AMD Dual-Core E1 APU                    4
# Intel Core i9 (11th Gen)                4
# Intel Core M3 (7th Gen)                 4
# Intel Core i5 (4th Gen)                 4
# Intel Core i5 (10th Gen) Processor      4
# AMD Quad-Core APU                       4
# Intel Core i7 (10th Gen) Processor      4
# Intel Core i3 (10th Gen) Processor      3
# Intel Celeron Dual-Core Processor       3
# Intel Core i7 (12th Gen) Processor      3
# Intel Core i3 (3rd Gen)                 3
# Intel Core i3 (13th Gen) Processor      3
# AMD Quad-Core Ryzen 3 Processor         3
# AMD Quad-Core Ryzen 5 Processor         3
# AMD Quad-Core A12 APU                   3
# Intel Core i3 (4th Gen)                 3
# Intel Core i7 (6th Gen)                 2
# AMD Quad-Core E2 APU                    2
# AMD Quad-Core A10 APU                   2
# AMD Quad-Core A6 APU                    2
# AMD Dual-Core Ryzen 3 Processor         2
# Intel Core i5 (1st Gen)                 2
# Apple M1                                1
# Apple M1 Processor                      1
# Intel Pentium Quad-Core Processor       1
# Intel Core 3 (Series 1)                 1
# Intel Core M5 (6th Gen)                 1
# Intel Core i5 (9th Gen) Processor       1
# AMD Dual-Core Athlon Processor          1
# Intel Core i9 (8th Gen)                 1
# AMD Octa-Core Ryzen 7 Pro               1
# Intel Core M3 (6th Gen)                 1
# Intel Core i7 (5th Gen)                 1
# AMD Dual-Core A9 APU Processor          1
# Name: count, dtype: int64

# %%
# import re

# def categorize_processor(row):
#     name = row['Processor_Name']
#     brand = row['Processor_Brand']
    
#     if brand == 'Intel':
#         # Capture i3/i5/i7/i9 or Core Ultra, Core series, etc.
#         match = re.search(r'i[3579]', name)
#         if match:
#             return f"Intel {match.group(0).upper()}"
#         elif re.search(r'Ultra\s*5', name, re.I):
#             return "Intel Ultra 5"
#         elif re.search(r'Ultra\s*7', name, re.I):
#             return "Intel Ultra 7"
#         elif re.search(r'Ultra\s*9', name, re.I):
#             return "Intel Ultra 9"
#         elif re.search(r'Pentium', name, re.I):
#             return "Intel Pentium"
#         elif re.search(r'Celeron', name, re.I):
#             return "Intel Celeron"
#         else:
#             return "Intel Other"
    
#     elif brand == 'AMD':
#         # Ryzen families or Athlon/A-series
#         match = re.search(r'Ryzen\s*[3579]', name, re.I)
#         if match:
#             return f"AMD {match.group(0).title()}"
#         elif re.search(r'Athlon', name, re.I):
#             return "AMD Athlon"
#         elif re.search(r'A\d', name, re.I):
#             # e.g., A6, A8, A10, A12
#             a_match = re.search(r'A\d+', name, re.I)
#             return f"AMD {a_match.group(0).upper()}"
#         else:
#             return "AMD Other"
    
#     elif brand == 'Apple':
#         # All M-series grouped together
#         return "Apple M-series"
    
#     else:
#         return "Other"

# # Apply to DataFrame
# df['Processor_Category'] = df.apply(categorize_processor, axis=1)

# # Quick look at the result
# print(df['Processor_Category'].value_counts())

# %%
import re

def categorize_processor(row):
    name = row['Processor_Name']
    brand = row['Processor_Brand']
    
    if brand == 'Intel':
        # Capture i3/i5/i7/i9 or Core Ultra, Core series, etc.
        match = re.search(r'i[3579]', name)
        if match:
            return f"Intel {match.group(0).upper()}"
        elif re.search(r'Ultra\s*5', name, re.I):
            return "Intel Ultra 5"
        elif re.search(r'Ultra\s*7', name, re.I):
            return "Intel Ultra 7"
        elif re.search(r'Ultra\s*9', name, re.I):
            return "Intel Ultra 9"
        elif re.search(r'Pentium', name, re.I):
            return "Intel Pentium"
        elif re.search(r'Celeron', name, re.I):
            return "Intel Celeron"
        else:
            return "Intel Other"
    
    elif brand == 'AMD':
        # Ryzen families or Athlon/A-series
        match = re.search(r'Ryzen\s*[3579]', name, re.I)
        if match:
            return f"AMD {match.group(0).title()}"
        elif re.search(r'Athlon', name, re.I):
            return "AMD Athlon"
        elif re.search(r'\bA\d+\b', name, re.I):
            return "AMD A-Series"
        else:
            return "AMD Other"
    
    elif brand == 'Apple':
        # All M-series grouped together
        return "Apple M-series"
    
    else:
        return "Other"

# Apply to DataFrame
df['Processor_Category'] = df.apply(categorize_processor, axis=1)

# Quick look at the result
print(df['Processor_Category'].value_counts())
# Out:
# Processor_Category
# Intel I5          1277
# Intel I3           683
# Intel I7           530
# AMD Ryzen 5        372
# AMD Ryzen 7        252
# AMD Ryzen 3        118
# Intel Celeron      112
# AMD A-Series        62
# Intel Pentium       58
# Intel Other         37
# AMD Athlon          35
# AMD Ryzen 9         25
# Intel Ultra 7       25
# Intel I9            24
# Intel Ultra 5       23
# AMD Other           18
# Apple M-series      11
# Intel Ultra 9        5
# Name: count, dtype: int64

# %%
avg_price = df.groupby('Processor_Category')['Price'].mean().sort_values()

plt.figure(figsize=(18,5))
plt.barh(avg_price.index, avg_price.values)   # horizontal bar chart
plt.xlabel("Average Price")
plt.ylabel("Processor Category")
plt.title("Average Laptop Price by Processor Category")
plt.tight_layout()
plt.show()

# %% [markdown]
# - Map every Intel, AMD processor in to high/mid/low-end

# %%
# def map_segment(row):
#     brand = row['Processor_Brand']
#     cat   = row['Processor_Category']

#     if brand == 'Intel':
#         if cat in ['Intel I9', 'Intel Ultra 9']:
#             return 'High-End'
#         elif cat in ['Intel I7', 'Intel Ultra 7']:
#             return 'Upper Mid-End'
#         elif cat in ['Intel I5', 'Intel Ultra 5']:
#             return 'Mid-End'
#         elif cat in ['Intel I3', 'Intel Celeron', 'Intel Pentium', 'Intel Other']:
#             return 'Low-End'

#     elif brand == 'AMD':
#         if cat in ['AMD Ryzen 9']:
#             return 'High-End'
#         elif cat in ['AMD Ryzen 7']:
#             return 'Upper Mid-End'
#         elif cat in ['AMD Ryzen 5']:
#             return 'Mid-End'
#         elif cat in [
#             'AMD Ryzen 3', 'AMD Athlon', 'AMD A12', 'AMD A10',
#             'AMD A9', 'AMD A8', 'AMD A6', 'AMD A4', 'AMD Other'
#         ]:
#             return 'Low-End'

#     elif brand == 'Apple':
#         return 'Apple M-series' 

#     return 'Other'

# %%
def map_segment(row):
    brand = row['Processor_Brand']
    cat   = row['Processor_Category']

    if brand == 'Intel':
        if cat in ['Intel I9', 'Intel Ultra 9']:
            return 'High-End'
        elif cat in ['Intel I7', 'Intel Ultra 7']:
            return 'Upper Mid-End'
        elif cat in ['Intel I5', 'Intel Ultra 5']:
            return 'Mid-End'
        elif cat in ['Intel I3', 'Intel Celeron', 'Intel Pentium', 'Intel Other']:
            return 'Low-End'

    elif brand == 'AMD':
        if cat in ['AMD Ryzen 9']:
            return 'High-End'
        elif cat in ['AMD Ryzen 7']:
            return 'Upper Mid-End'
        elif cat in ['AMD Ryzen 5']:
            return 'Mid-End'
        elif cat in [
            'AMD Ryzen 3', 'AMD Athlon', "AMD A-Series", 'AMD Other'
        ]:
            return 'Low-End'

    elif brand == 'Apple':
        return 'Apple M-series' 

    return 'Other'

# %%
df['Processor_Tier'] = df.apply(map_segment, axis=1)
print(df['Processor_Tier'].value_counts())
# Out:
# Processor_Tier
# Mid-End           1672
# Low-End           1123
# Upper Mid-End      807
# High-End            54
# Apple M-series      11
# Name: count, dtype: int64

# %%
# Calculate mean price by Processor_Tier
avg_price_tier = df.groupby('Processor_Tier')['Price'].mean().sort_values()

# Plot horizontal bar chart
plt.figure(figsize=(18,3))
plt.barh(avg_price_tier.index, avg_price_tier.values, color='skyblue')
plt.xlabel("Average Price")
plt.ylabel("Processor Tier")
plt.title("Average Laptop Price by Processor Tier")
plt.tight_layout()
plt.show()

# %%
df.head(5)
# Out:
#     Brand                                               Name     Price  \
# 1  Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  127011.5
# 2    Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  274750.0
# 3      HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  194215.0
# 4   Other  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...   76965.0
# 5    Acer  Acer One 14 Z8-415 (UN.599SI.020) Laptop (14 I...  122465.0
#
#                        Processor_Name Processor_Brand     RAM_Expandable  \
# 1               AMD Hexa-Core Ryzen 5             AMD   12 GB Expandable
# 2            Intel Core i5 (12th Gen)           Intel   32 GB Expandable
# 3            Intel Core i5 (12th Gen)           Intel    8 GB Expandable
# 4            Intel Core i3 (11th Gen)           Intel     Not Expandable
# 5  Intel Core i5 (11th Gen) Processor           Intel   32 GB Expandable
#
#        RAM      RAM_TYPE                 Ghz Display_type Display  \
# 1    8 GB      DDR4 RAM    4.0 Ghz Processor          LCD   15.6
# 2   16 GB      DDR5 RAM    3.3 Ghz Processor          LCD   15.6
# 3    8 GB      DDR4 RAM    4.2 Ghz Processor          LCD   15.6
# 4  8 GB LP   LPDDR4X RAM   1.7 Ghz Processor          LCD   15.6
# 5   16 GB      DDR4 RAM                    0          LCD     14
#
#                           GPU GPU_Brand                 SSD     HDD Adapter  \
# 1                      Radeon       AMD  512 GB SSD Storage  No HDD      65
# 2  GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD Storage  No HDD      56
# 3                     Iris Xe     Intel  512 GB SSD Storage  No HDD      no
# 4                         UHD     Intel  512 GB SSD Storage  No HDD      45
# 5                     Iris Xe     Intel  512 GB SSD Storage  No HDD      45
#
#                  Battery_Life Operating_System Processor_Category  \
# 1    Upto 11 Hrs Battery Life       Windows 11        AMD Ryzen 5
# 2    Upto 10 Hrs Battery Life       Windows 11           Intel I5
# 3  Upto 7.30 Hrs Battery Life       Windows 11           Intel I5
# 4     Upto 8 Hrs Battery Life       Windows 11           Intel I3
# 5                 45W Adapter       Windows 11           Intel I5
#
#   Processor_Tier
# 1        Mid-End
# 2        Mid-End
# 3        Mid-End
# 4        Low-End
# 5        Mid-End

# %% [markdown]
# #### RAM

# %%
# Filter rows where 'RAM_TYPE' contains 'LP'
filtered_df = df[df['RAM_TYPE'].str.contains('LP', case=False, na=False)]

# Count unique (RAM, RAM_TYPE) combinations
print(filtered_df[['RAM', 'RAM_TYPE']].value_counts())
# Out:
# RAM       RAM_TYPE
# 16 GB LP  LPDDR5 RAM      69
#           LPDDR4X RAM     64
#           LPDDR5 RAM      62
# 8 GB LP   LPDDR5 RAM      48
#           LPDDR4X RAM     43
#           LPDDR3 RAM      34
#           LPDDR5 RAM      27
# 16 GB LP  LPDDR5X RAM     21
# 8 GB LP   LPDDR4X RAM     15
# 16 GB LP  LPDDR4X RAM     14
#           LPDDR5X RAM     14
# 4 GB LP   LPDDR4 RAM      13
#           LPDDR4X RAM      9
# 8 GB LP   LPDDR4 RAM       8
# 32 GB LP  LPDDR5X RAM      7
# 4 GB LP   LPDDR3 RAM       6
# 32 GB LP  LPDDR5 RAM       5
#           LPDDR5X RAM      5
# 16 GB LP  LPDDR4 RAM       4
#           LPDDR3 RAM       4
# 4 GB LP   LPDDR4 RAM       3
# 16 GB LP  LPDDR4 RAM       3
# 32 GB LP  LPDDR4X RAM      2
#           LPDDR4X RAM      1
#           LPDDR5 RAM       1
# 4 GB LP   LPDDR3 RAM       1
#           LPDDR4X RAM      1
# 8 GB LP   LPDDR3 RAM       1
#           LPDDR5X RAM      1
#           LPDDR5X RAM      1
# Name: count, dtype: int64

# %%
print("RAM Unique Values:", df['RAM'].nunique())
print("Missing RAM values:", df['RAM'].isna().sum())
df['RAM'].value_counts()
# Out:
# RAM Unique Values: 16
# Missing RAM values: 0
# RAM
# 8 GB          1603
# 16 GB          980
# 4 GB           535
# 16 GB LP       255
# 8 GB LP        178
# 4 GB LP         33
# 2 GB            22
# 32 GB LP        21
# 8 GB RAM        13
# 16 GB RAM       10
# 32 GB            7
# 12 GB            4
# 16 GB RAM        2
# 3 GB             2
# 24 GB            1
# 6 GB             1
# Name: count, dtype: int64

# %% [markdown]
# - Clean RAM to get the capacity value

# %%
# df['RAM'] = df['RAM'].str.replace('RAM', '', regex=False)
# df['RAM'] = df['RAM'].str.replace('LP', '', regex=False)
# df['RAM'] = df['RAM'].str.replace('GB', '', regex=False)
# df['RAM'] = df['RAM'].str.strip().astype(int)

# %%
# def clean_ram(value):
#     if pd.isna(value):
#         return value  # keep NaN as is
    
#     text = str(value).upper().strip()

#     # Detect LP variants
#     if "LP" in text:
#         match = re.search(r'\d+', text)
#         if match:
#             return f"{match.group()} LP"
    
#     # Non-LP variants
#     match = re.search(r'\d+', text)
#     if match:
#         return match.group()  # just the number
    
#     return value  # fallback if unexpected

# # Apply to your dataframe
# df['RAM'] = df['RAM'].apply(clean_ram)

# %%
import pandas as pd
import re

def clean_ram(value):
    if pd.isna(value):
        return value  # keep NaN as is
    
    text = str(value).upper().strip()
    
    # Extract the first number in the string
    match = re.search(r'\d+', text)
    if match:
        return match.group()  # just the number
    
    return value 

# Apply to your dataframe
df['RAM'] = df['RAM'].apply(clean_ram)
df['RAM'] = df['RAM'].astype(int)

# %%
print(df['RAM'].value_counts().sort_index())
# Out:
# RAM
# 2       22
# 3        2
# 4      568
# 6        1
# 8     1794
# 12       4
# 16    1247
# 24       1
# 32      28
# Name: count, dtype: int64

# %%
avg_price_ram = df.groupby('RAM')['Price'].mean().sort_index()

# Plot
plt.figure(figsize=(18,6))
plt.bar(avg_price_ram.index.astype(str), avg_price_ram.values, color='teal')
plt.xlabel("RAM (GB)")
plt.ylabel("Average Price")
plt.title("Average Laptop Price by RAM Size")
plt.tight_layout()
plt.show()

# %%
# Here i map ram in to nearest standard sizes
# ram_map = {
#     2: 4,    # 2 GB → 4 GB
#     3: 4,    # 3 GB → 4 GB
#     6: 8,    # 6 GB → 8 GB 
#     12: 16,  # 12 GB → 16 GB
#     24: 32   # 24 GB → 32 GB
# }
# df['RAM'] = df['RAM'].replace(ram_map)

# %%
# standard_ram_sizes = [4, 8, 16, 32]
# df = df[df['RAM'].isin(standard_ram_sizes)]
# df.shape

# %%
standard_ram_sizes = [4, 8, 16, 32]
df = df[df['RAM'].isin(standard_ram_sizes)]
print(df.shape)
# Out:
# (3637, 20)

# %%
df['RAM'].value_counts()
# Out:
# RAM
# 8     1794
# 16    1247
# 4      568
# 32      28
# Name: count, dtype: int64

# %%
plt.figure(figsize=(18, 6))
sns.countplot(data=df, x='RAM', hue='RAM', palette='Set2')
plt.xticks(rotation=45)
plt.title("RAM Size Distribution")
plt.show()

# %%
df['Brand'].value_counts()
# Out:
# Brand
# ASUS       890
# Lenovo     767
# HP         752
# Dell       399
# Acer       310
# MSI        263
# Other      176
# Samsung     49
# Apple       31
# Name: count, dtype: int64

# %% [markdown]
# #### RAM Type and Processor Speed(Ghz)

# %%
print("RAM_TYPE Unique Values:", df['RAM_TYPE'].nunique())
print("Missing RAM_TYPE values:", df['RAM_TYPE'].isna().sum())
df['RAM_TYPE'].value_counts()
# Out:
# RAM_TYPE Unique Values: 19
# Missing RAM_TYPE values: 0
# RAM_TYPE
# DDR4 RAM        1463
# DDR4 RAM        1276
# DDR5 RAM         173
# LPDDR5 RAM       122
# LPDDR4X RAM      118
# DDR5 RAM          92
# LPDDR5 RAM        90
# DDR3 RAM          67
# DDR3 RAM          53
# LPDDR3 RAM        44
# LPDDR4X RAM       31
# LPDDR5X RAM       29
# LPDDR4 RAM        25
# RAM               23
# LPDDR5X RAM       20
# LPDDR4 RAM         6
# RAM                2
# LPDDR3 RAM         2
# DDR2 RAM           1
# Name: count, dtype: int64

# %%
df['Ghz'].value_counts().head(10)
# Out:
# Ghz
#  4.2 Ghz Processor    331
#  2.4 Ghz Processor    242
#  1.6 Ghz Processor    226
#  4.7 Ghz Processor    214
#  3.3 Ghz Processor    195
# 0                     192
#  2.3 Ghz Processor    190
#  2.1 Ghz Processor    175
#  2.6 Ghz Processor    160
#  2.0 Ghz Processor    154
# Name: count, dtype: int64

# %% [markdown]
# - Cleaning RAM-TYPE column

# %%
# df['RAM_TYPE'] = (
#     df['RAM_TYPE']
#     .astype(str)
#     .str.upper()                             
#     .str.replace(r'\s+', ' ', regex=True)    
#     .str.strip()                            
# )

# df['RAM_TYPE'] = df['RAM_TYPE'].replace({
#     'DDR4 RAM': 'DDR4',
#     'LPDDR4 RAM': 'DDR4',
#     'LPDDR4X RAM': 'DDR4',

#     'DDR5 RAM': 'DDR5',
#     'LPDDR5 RAM': 'DDR5',
#     'LPDDR5X RAM': 'DDR5',

#     'DDR3 RAM': 'DDR3',
#     'LPDDR3 RAM': 'DDR3',

#     'DDR2 RAM': 'DDR2'
# })

# df = df[df['RAM_TYPE'] != 'DDR2']

# %%
df['RAM_TYPE'] = (
    df['RAM_TYPE']
    .astype(str)
    .str.upper()
    .str.replace(r'\s+', ' ', regex=True)
    .str.strip()
)

df['RAM_TYPE'] = df['RAM_TYPE'].replace({
    # DDR4 family
    'DDR4 RAM': 'DDR4',
    'LPDDR4 RAM': 'LPDDR4',
    'LPDDR4X RAM': 'LPDDR4',

    # DDR5 family
    'DDR5 RAM': 'DDR5',
    'LPDDR5 RAM': 'LPDDR5',
    'LPDDR5X RAM': 'LPDDR5',

    # DDR3 family
    'DDR3 RAM': 'DDR3',
    'LPDDR3 RAM': 'LPDDR3',

    # DDR2 family (remove)
    'DDR2 RAM': 'DDR2'
})

# Remove old DDR2 laptops
df = df[df['RAM_TYPE'] != 'DDR2']

# %%
df['RAM_TYPE'].value_counts()
# Out:
# RAM_TYPE
# DDR4      2739
# DDR5       265
# LPDDR5     261
# LPDDR4     180
# DDR3       120
# LPDDR3      46
# RAM         25
# Name: count, dtype: int64

# %%
df['Ghz'].value_counts().head(10)
# Out:
# Ghz
#  4.2 Ghz Processor    331
#  2.4 Ghz Processor    242
#  1.6 Ghz Processor    226
#  4.7 Ghz Processor    214
#  3.3 Ghz Processor    195
# 0                     192
#  2.3 Ghz Processor    190
#  2.1 Ghz Processor    175
#  2.6 Ghz Processor    160
#  2.0 Ghz Processor    154
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3636, 20)

# %% [markdown]
# - Cleaning Ghz column

# %%
# Remove everything except the number at the start
df['Ghz'] = (
    df['Ghz']
      .astype(str)                                   # ensure string
      .str.extract(r'([\d\.]+)')                     # capture digits & decimal point
      .astype(float)                                  # convert to float
)

# %%
df.shape
# Out:
# (3636, 20)

# %%
df['Ghz'].value_counts()
# Out:
# Ghz
# 4.2    331
# 2.4    242
# 1.6    226
# 4.7    214
# 3.3    195
# 0.0    192
# 2.3    190
# 2.1    175
# 2.6    160
# 2.0    154
# 2.5    153
# 1.2    145
# 3.0    137
# 3.4    118
# 4.8    113
# 1.1    102
# 4.0    100
# 1.8     94
# 2.8     84
# 1.0     79
# 2.2     77
# 3.1     76
# 1.7     69
# 2.7     54
# 1.3     44
# 2.9     33
# 1.4     22
# 0.8     20
# 1.5     20
# 1.9     11
# 5.5      6
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3636, 20)

# %% [markdown]
# - Filling unkonwn values for Apple Ghz and RAM_TYPE ( Here manually fill not use any statistical method because of less data)
# - Here consider Apple seperately due to specific chips its has and dataset is rare

# %%
df[(df['Brand'] == 'Apple') & (df['Brand'] == 'Apple')][['Ghz', 'RAM_TYPE', 'Processor_Name','Processor_Tier']].head(10)
# Out:
#       Ghz RAM_TYPE           Processor_Name  Processor_Tier
# 80    2.9     DDR4                 Apple M1  Apple M-series
# 82    1.8   LPDDR3  Intel Core i5 (5th Gen)         Mid-End
# 96    0.0      RAM       Apple M2 Processor  Apple M-series
# 227   0.0   LPDDR5       Apple M2 Processor  Apple M-series
# 371   0.0      RAM       Apple M2 Processor  Apple M-series
# 1349  1.6   LPDDR3  Intel Core i5 (8th Gen)         Mid-End
# 1355  1.6   LPDDR3  Intel Core i5 (8th Gen)         Mid-End
# 1356  1.6   LPDDR3  Intel Core i5 (8th Gen)         Mid-End
# 1358  1.6   LPDDR3  Intel Core i5 (8th Gen)         Mid-End
# 1424  1.1   LPDDR3  Intel Core M3 (7th Gen)         Low-End

# %%
# Apple M2 rows: set Ghz=3.49 and RAM_TYPE='LPDDR5 RAM'
df.loc[
    (df['Brand'] == 'Apple') &
    (df['Processor_Brand'] == 'Apple') &
    ((df['Ghz'] == 0.0) | (df['RAM_TYPE'] == 'RAM')) &
    df['Processor_Name'].str.contains('M2', na=False),
    ['Ghz', 'RAM_TYPE']
] = [3.49, 'DDR5'] # Values inserted manually by search in web

# Apple M1 rows: set Ghz=2.9 and RAM_TYPE='DDR4 RAM'
df.loc[
    (df['Brand'] == 'Apple') &
    (df['Processor_Brand'] == 'Apple') &
    ((df['Ghz'] == 0.0) | (df['RAM_TYPE'] == 'RAM')) &
    df['Processor_Name'].str.contains('M1', na=False),
    ['Ghz', 'RAM_TYPE']
] = [2.9, 'DDR4']

# Apple Intel Core i3 empty Ghz replaced with real value 1.1 Ghz
df.loc[
    (df['Brand'] == 'Apple') &
    (df['Processor_Brand'] == 'Intel') &
    ((df['Ghz'] == 0.0) | (df['RAM_TYPE'] == 'RAM')) &
    df['Processor_Name'].str.contains('Intel Core i3', na=False),
    ['Ghz', 'RAM_TYPE']
] = [1.1, 'DDR4']

# %%
df[(df['Brand'] == 'Apple') & (df['Brand'] == 'Apple')][['Ghz', 'RAM_TYPE', 'Processor_Name']].head(10)
# Out:
#        Ghz RAM_TYPE           Processor_Name
# 80    2.90     DDR4                 Apple M1
# 82    1.80   LPDDR3  Intel Core i5 (5th Gen)
# 96    3.49     DDR5       Apple M2 Processor
# 227   3.49     DDR5       Apple M2 Processor
# 371   3.49     DDR5       Apple M2 Processor
# 1349  1.60   LPDDR3  Intel Core i5 (8th Gen)
# 1355  1.60   LPDDR3  Intel Core i5 (8th Gen)
# 1356  1.60   LPDDR3  Intel Core i5 (8th Gen)
# 1358  1.60   LPDDR3  Intel Core i5 (8th Gen)
# 1424  1.10   LPDDR3  Intel Core M3 (7th Gen)

# %%
df[(df['Brand'] == 'Apple') & (df['Brand'] == 'Apple')][['Ghz', 'RAM_TYPE', 'Processor_Name']].shape
# Out:
# (31, 3)

# %% [markdown]
# * Filling unknown Processor speed and RAM for Intel or AMD by existing data

# %%
df[(df['RAM_TYPE'] == 'RAM') | (df['Ghz'] == 0.0)].shape
# Out:
# (198, 20)

# %% [markdown]
# 1. Filling RAM

# %% [markdown]
# Here Select most frequent RAM-Type by processor tier (High/Mid/Low-End)

# %%
most_freq_ram = (
    df[df['RAM_TYPE'] != 'RAM']  # exclude placeholder 'RAM'
      .groupby(['Processor_Brand', 'Processor_Tier'])['RAM_TYPE']
      .agg(lambda x: x.mode()[0] if not x.mode().empty else None)
      .reset_index()
      .rename(columns={'RAM_TYPE': 'Most_Freq_RAM'})
)

#Merge back to the original dataframe
df = df.merge(most_freq_ram, on=['Processor_Brand', 'Processor_Tier'], how='left')

#Replace 'RAM' with the most frequent RAM_TYPE
df['RAM_TYPE'] = df.apply(
    lambda row: row['Most_Freq_RAM'] if row['RAM_TYPE'] == 'RAM' else row['RAM_TYPE'],
    axis=1
)

df = df.drop(columns=['Most_Freq_RAM'])

df['RAM_TYPE'].value_counts()
# Out:
# RAM_TYPE
# DDR4      2758
# DDR5       274
# LPDDR5     259
# LPDDR4     179
# DDR3       120
# LPDDR3      46
# Name: count, dtype: int64

# %% [markdown]
# Filling Ghz

# %%
mean_ghz = (
    df[df['Ghz'] != 0.0]                       # exclude zeros from mean calc
      .groupby(['Processor_Brand', 'Processor_Tier'])['Ghz']
      .mean()
      .reset_index()
      .rename(columns={'Ghz': 'Mean_Ghz'})
)

#Merge the mean values back to df
df = df.merge(mean_ghz, on=['Processor_Brand', 'Processor_Tier'], how='left')

#Replace 0.0 with the corresponding mean
df['Ghz'] = df.apply(
    lambda row: row['Mean_Ghz'] if row['Processor_Brand'] in ['Intel','AMD'] 
                and row['Ghz'] == 0.0 else row['Ghz'],
    axis=1
)

df = df.drop(columns=['Mean_Ghz'])

print(df['Ghz'].value_counts().head())
# Out:
# Ghz
# 4.2    331
# 2.4    242
# 1.6    226
# 4.7    214
# 3.3    195
# Name: count, dtype: int64

# %% [markdown]
# - Rounding Ghz to nearest 0.5 GHz

# %%
df['Processor_Speed(Ghz)'] = (df['Ghz'] * 2).round() / 2

# %%
df['Processor_Speed(Ghz)'].value_counts()
# Out:
# Processor_Speed(Ghz)
# 2.5    868
# 2.0    552
# 4.0    431
# 3.0    386
# 1.5    381
# 1.0    347
# 3.5    338
# 4.5    214
# 5.0    113
# 5.5      6
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3636, 21)

# %% [markdown]
# - Extract the digit (3,4,5) from DDR string and convert to int

# %%
# import re

# # Extract the number after 'DDR' as an integer
# df['RAM_TYPE'] = df['RAM_TYPE'].str.extract(r'(\d+)').astype('Int64')
# df = df.rename(columns={'RAM_TYPE': 'RAM_TYPE(DDR)'})
# df['RAM_TYPE(DDR)'].value_counts()

# %%
import re

# Remove only 'DDR' text, keep 'LP' and other parts
df['RAM_TYPE'] = df['RAM_TYPE'].str.replace(r'DDR', '', regex=True).str.strip()

# Rename the column (optional)
df = df.rename(columns={'RAM_TYPE': 'RAM_TYPE(DDR)'})

# View unique categories or counts
df['RAM_TYPE(DDR)'].value_counts()
# Out:
# RAM_TYPE(DDR)
# 4      2758
# 5       274
# LP5     259
# LP4     179
# 3       120
# LP3      46
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3636, 21)

# %% [markdown]
# #### RAM Expandability

# %%
df['RAM_Expandable'].value_counts()
# Out:
# RAM_Expandable
# Not Expandable       1983
#  16 GB Expandable     739
#  32 GB Expandable     463
#  8 GB Expandable      178
#  12 GB Expandable     155
#  64 GB Expandable     101
#  48 GB Expandable       8
#  4 GB Expandable        6
#  2 GB Expandable        2
#  10 GB Expandable       1
# Name: count, dtype: int64

# %%
# Convert RAM_Expandable to Yes/No
df['RAM_Expandable'] = df['RAM_Expandable'].apply(lambda x: 'No' if 'Not' in x else 'Yes')
df['RAM_Expandable'].value_counts()
# Out:
# RAM_Expandable
# No     1983
# Yes    1653
# Name: count, dtype: int64

# %%
df.head()
# Out:
#     Brand                                               Name     Price  \
# 0  Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  127011.5
# 1    Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  274750.0
# 2      HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  194215.0
# 3   Other  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...   76965.0
# 4    Acer  Acer One 14 Z8-415 (UN.599SI.020) Laptop (14 I...  122465.0
#
#                        Processor_Name Processor_Brand RAM_Expandable  RAM  \
# 0               AMD Hexa-Core Ryzen 5             AMD            Yes    8
# 1            Intel Core i5 (12th Gen)           Intel            Yes   16
# 2            Intel Core i5 (12th Gen)           Intel            Yes    8
# 3            Intel Core i3 (11th Gen)           Intel             No    8
# 4  Intel Core i5 (11th Gen) Processor           Intel            Yes   16
#
#   RAM_TYPE(DDR)       Ghz Display_type  ...                         GPU  \
# 0             4  4.000000          LCD  ...                      Radeon
# 1             5  3.300000          LCD  ...  GeForce RTX 3050 GPU, 4 GB
# 2             4  4.200000          LCD  ...                     Iris Xe
# 3           LP4  1.700000          LCD  ...                         UHD
# 4             4  2.655951          LCD  ...                     Iris Xe
#
#   GPU_Brand                 SSD     HDD Adapter                Battery_Life  \
# 0       AMD  512 GB SSD Storage  No HDD      65    Upto 11 Hrs Battery Life
# 1    NVIDIA  512 GB SSD Storage  No HDD      56    Upto 10 Hrs Battery Life
# 2     Intel  512 GB SSD Storage  No HDD      no  Upto 7.30 Hrs Battery Life
# 3     Intel  512 GB SSD Storage  No HDD      45     Upto 8 Hrs Battery Life
# 4     Intel  512 GB SSD Storage  No HDD      45                 45W Adapter
#
#   Operating_System Processor_Category Processor_Tier Processor_Speed(Ghz)
# 0       Windows 11        AMD Ryzen 5        Mid-End                  4.0
# 1       Windows 11           Intel I5        Mid-End                  3.5
# 2       Windows 11           Intel I5        Mid-End                  4.0
# 3       Windows 11           Intel I3        Low-End                  1.5
# 4       Windows 11           Intel I5        Mid-End                  2.5
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Display Size

# %%
df = df.rename(columns={'Display': 'Display_Size'})
df['Display_Size'] = pd.to_numeric(df['Display_Size'], errors='coerce') # Convert to numeric

# %%
# def display_category(x):
#     if x <= 14.0:
#         return 'Small'
#     elif x <= 15.6:
#         return 'Medium'
#     else:
#         return 'Large'

# df['Display_Tier'] = df['Display_Size'].apply(display_category)
# df['Display_Tier'].value_counts()

# %%
def display_category(x):
    if x <= 15.6:
        return 'Small'
    else:
        return 'Large'

df['Display_Tier'] = df['Display_Size'].apply(display_category)
df['Display_Tier'].value_counts()
# Out:
# Display_Tier
# Small    3362
# Large     274
# Name: count, dtype: int64

# %%
# def display_category(x):
#     if x <= 14.0:
#         return 'Small'
#     else:
#         return 'Large'

# df['Display_Tier'] = df['Display_Size'].apply(display_category)
# df['Display_Tier'].value_counts()

# %%
avg_price = df.groupby('Display_Tier')['Price'].mean().reset_index()

plt.figure(figsize=(8,5))
sns.barplot(data=avg_price, x='Display_Tier', y='Price', palette='cool')
plt.title('Average Price by Display Tier')
plt.show()
# Out:
# /tmp/ipykernel_16786/3406001435.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_price, x='Display_Tier', y='Price', palette='cool')

# %% [markdown]
# #### GPU_Brand

# %%
df.dropna(subset=['GPU_Brand'], inplace=True)
df['GPU_Brand'].value_counts(dropna=False)
# Out:
# GPU_Brand
# Intel      1848
# NVIDIA     1160
# AMD         607
# Apple        11
# Nvidia        7
# NIVIDIA       1
# ATI           1
# Name: count, dtype: int64

# %%
# Standardize GPU_Brand names
df['GPU_Brand'] = df['GPU_Brand'].str.upper()  # Convert all to uppercase

# Map only desired brands to proper casing
brand_mapping = {
    'INTEL': 'Intel',
    'NVIDIA': 'NVIDIA',
    'NIVIDIA': 'NVIDIA',
    'AMD': 'AMD',
    'APPLE': 'Apple'
}

df['GPU_Brand'] = df['GPU_Brand'].map(brand_mapping)


# Check the result
df.dropna(subset=['GPU_Brand'], inplace=True)
print(df['GPU_Brand'].value_counts(dropna=False))
# Out:
# GPU_Brand
# Intel     1848
# NVIDIA    1168
# AMD        607
# Apple       11
# Name: count, dtype: int64

# %% [markdown]
# #### GPU

# %%
# Drop rows where GPU is NaN
df.dropna(subset=['GPU'], inplace=True)

# %%
print("Missing GPU values:", df['GPU'].isna().sum())
df['GPU'].value_counts(dropna=False)
# Out:
# Missing GPU values: 0
# GPU
# UHD                                         647
# Iris Xe                                     547
# Radeon                                      313
# GeForce RTX 3050 GPU, 4 GB                  198
# Integrated                                  148
# GeForce GTX 1650 GPU, 4 GB                  142
# UHD 620                                     119
# GeForce RTX 4050 GPU, 6 GB                   86
# HD 620                                       83
# GeForce RTX 2050 GPU, 4 GB                   78
# GeForce RTX 3060 GPU, 6 GB                   67
# Radeon Vega 8                                54
# HD 520                                       53
# GeForce RTX 4060 GPU, 8 GB                   50
# GeForce RTX 3050 Ti GPU, 4 GB                43
# Arc                                          40
# Geforce GTX 1650 GPU, 4 GB                   36
# GeForce RTX 3050 GPU, 6 GB                   36
# UHD 600                                      34
# GeForce GTX 1050 GPU, 4 GB                   25
# Radeon R5                                    21
# Radeon R4                                    20
# Radeon R2                                    19
# GeForce MX450 GPU, 2 GB                      19
# Radeon Vega 3                                19
# GeForce MX250 GPU, 2 GB                      17
# Geforce GTX 1650 Ti GPU, 4 GB                17
# UHD Graphics                                 16
# GeForce GTX 1060 GPU, 6 GB                   15
# GeForce MX350 GPU, 2 GB                      15
# GeForce MX150 GPU, 2 GB                      15
# Radeon 520 GPU, 2 GB                         14
# Geforce MX150 GPU, 2 GB                      14
# Iris Plus                                    12
# Radeon 610M                                  12
# Geforce MX130 GPU, 2 GB                      12
# HD                                           12
# HD 500                                       11
# UHD 617                                      11
# Iris Xe Graphics                             11
# Radeon Graphics                              11
# UHD 605                                      11
# Geforce GTX 1660 Ti GPU, 6 GB                11
# Geforce GTX 1050Ti GPU, 4 GB                 10
# Iris X                                       10
# GeForce MX110 GPU, 2 GB                      10
# GeForce MX330 GPU, 2 GB                       9
# GeForce 940MX GPU, 2 GB                       8
# GeForce GTX 1650 Ti GPU, 4 GB                 8
# GeForce MX550 GPU, 2 GB                       8
# GeForce RTX 3070 GPU, 8 GB                    8
# HD 615                                        8
# Geforce MX250 GPU, 2 GB                       8
# HD Graphics                                   8
# GeForce MX230 GPU, 2 GB                       8
# Radeon R5 M430 GPU, 2 GB                      8
# Radeon Vega                                   8
# GeForce MX130 GPU, 2 GB                       8
# GeForce RTX 2060 GPU, 6 GB                    8
# HD 610                                        7
# M2                                            7
# GeForce GTX 1050Ti GPU, 4 GB                  7
# Radeon R3                                     6
# Radeon 530 GPU, 2 GB                          6
# GeForce 920MX GPU, 2 GB                       6
# Radeon Vega 6                                 6
# HD 405                                        5
# GeForce GTX 1050 GPU, 3 GB                    5
# UHD GPU, 128 MB                               5
# HD 505                                        5
# HD 5500                                       5
# GeForce 830M GPU, 2 GB                        5
# HD 4400                                       5
# Geforce RTX 2060 GPU, 6 GB                    5
# GeForce 940MX GPU, 4 GB                       5
# Geforce 940MX GPU, 2 GB                       5
# Geforce MX110 GPU, 2 GB                       5
# GeForce GTX 1650 MAX Q GPU, 4 GB              4
# Radeon RX 5500M GPU, 4 GB                     4
# GeForce GTX 1650 Max Q GPU, 4 GB              4
# HD 400                                        4
# Radeon RX 6500M GPU, 4 GB                     4
# GeForce RTX 3070 Ti GPU, 8 GB                 4
# Radeon RX Vega 10                             4
# Integrated UHD                                4
# Radeon RX 6600M GPU, 8 GB                     4
# Radeon RX 560X GPU, 4 GB                      4
# GeForce GTX 1660 Ti GPU, 6 GB                 4
# Geforce MX330 GPU, 2 GB                       3
# GeForce 930M GPU, 2 GB                        3
# GeForce 820M GPU, 2 GB                        3
# Radeon R7                                     3
# Geforce MX230 GPU, 2 GB                       3
# Radeon HD 520 GPU, 2 GB                       3
# Geforce GTX 1050 Ti GPU, 4 GB                 3
# Radeon Vega 7                                 3
# GeForce GTX 3050 GPU, 4 GB                    3
# GeForce MX570 GPU, 2 GB                       3
# GeForce GT 940MX GPU, 4 GB                    3
# GeForce RTX 4070 GPU, 8 GB                    3
# Radeon 780M                                   3
# Geforce GTX 1050 GPU, 4 GB                    3
# GeForce GT 940MX GPU, 2 GB                    3
# GeForce GTX 1050T GPU, 4 GB                   2
# Radeon RX 6700S GPU, 8 GB                     2
# M2 Integrated                                 2
# Radeon RX 5600M GPU, 6 GB                     2
# Geforce GTX 1060 GPU, 6 GB                    2
# UHD Graphics 620                              2
# GeForce GTX 1650Ti GPU, 4 GB                  2
# GeForce N16V-GMR1 GPU, 2 GB                   2
# UHD                                           2
# Integrated Iris Xe                            2
# Radeon RX6550M GPU, 4 GB                      2
# Radeon RX 6800M GPU, 12 GB                    2
# HD 6000                                       2
# Geforce RTX 3050 GPU, 4 GB                    2
# GeForce GTX 1050 GPU, 2 GB                    2
# UHD 605                                       2
# Radeon 530 GPU, 4 GB                          2
# HD 4000                                       2
# Radeon RX Vega 6                              2
# Radeon HD 8670M GPU, 2 GB                     2
# Geforce 940M GPU, 2 GB                        2
# GeForce 920M GPU, 2 GB                        2
# GeForce MX150 GPU, 4 GB                       2
# Quadro T600 GPU, 4 GB                         2
# Radeon RX 6500M  GPU, 4 GB                    2
# Geforce GTX 1050 GPU, 2 GB                    2
# Radeon RX Vega 8                              1
# Geforce GTX 1650 Ti GPU, 6 GB                 1
# Geoforce RTX3050 GPU, 4 GB                    1
# Quadro T50 GPU, 4 GB                          1
# Radeon RX 6700S GPU, 8                        1
# GeForce RTX 3050Ti GPU, 4 GB                  1
# UHD Graphics 600                              1
# Radeon 610M Vega 2                            1
# GeForce RTX 3050 Ti  GPU, 4 GB                1
# GeForce RTX 3050 GPU, 4                       1
# GeForce RTX 3050                              1
# MX350 GPU, 2 GB                               1
# GeForce MX250                                 1
# GeForce MX550  GPU, 2 GB                      1
# GEFORCE RTX 3050 Ti GPU, 4 GB                 1
# Intel Iris Xe                                 1
# Arc A370M GPU, 4 GB                           1
# UMA                                           1
# Geforce GTX 1650 Max-Q GPU, 4 GB              1
# Radeon RX6500M GPU, 4 GB                      1
# M1                                            1
# GeForce RTX 2050                              1
# Radeon R16M-M1-30 GPU, 2 GB                   1
# Geforce MX150 GPU, 4 GB                       1
# GeForce GTX 1050 Ti  GPU, 4 GB                1
# RTX A500 GPU, 4 GB                            1
# Radeon 760M                                   1
# GeForce RTX 4060 GPU, 6 GB                    1
# Radeon 680M                                   1
# Integrated Arc                                1
# Graphics                                      1
# GeForce RTX 4050 GPU, 8 GB                    1
# Integrated HD                                 1
# GeForce RTX 3070 Ti GPU, 8                    1
# GeForce 940MX  GPU, 4 GB                      1
# Radeon RX 5500M                               1
# Quadro T550 GPU, 4 GB                         1
# GeForce GTX 1050 Ti GPU, 4 GB                 1
# GeForce GTX 1650 Ti GPU, 6 GB                 1
# Geforce MX350 GPU, 2 GB                       1
# Geforce 940MX GPU, 4 GB                       1
# M1 Integrated                                 1
# Geforce GTX 1050Ti GPU, 8 GB                  1
# Geforce GTX 1050 GPU, 3 GB                    1
# Geforce GTX 1650Ti GPU, 6 GB                  1
# Radeon HD 8210 GPU, 2 GB                      1
# GeForce MX 450 GPU, 2 GB                      1
# GeForce GPU, 2 GB                             1
# RTX 3050 GPU, 4 GB                            1
# Radeon Vega 8 Mobile                          1
# Radeon R5 M430  GPU, 2 GB                     1
# R17M-M1-70 GPU, 2 GB                          1
# Geforce GTX 1650 Ti` GPU, 4 GB                1
# Radeon R4                                     1
# GeForce GTX 940MX GPU, 4 GB                   1
# UHD GPU, 2 GB                                 1
# Radeon RX 7600S GPU, 8 GB                     1
# GeForce MX 350 GPU, 2 GB                      1
# GeForce MX550 GPU, 2                          1
# T600 GPU, 4 GB                                1
# Integrated GPU, 512 MB                        1
# GeForce RTX 1650 GPU, 4 GB                    1
# GeForce MX550                                 1
# Radeon Athlon 3000G                           1
# Radeon RX6700M                                1
# GeForce RTX 3070 GPU, 16 GB                   1
# Arc A530M GPU, 4 GB                           1
# Geforce MX 150 GPU, 2 GB                      1
# GeForce MX150  GPU, 2 GB                      1
# Geforce GTX 1650Ti GPU, 4 GB                  1
# GeForce GTX 940MX GPU, 2 GB                   1
# Geforce GTX 1650 Ti with Max-Q GPU, 4 GB      1
# GeForce RTX 3060 GPU, 4 GB                    1
# Radeon R7 M260 GPU, 2 GB                      1
# Iris Plus Graphics 645                        1
# GeForce 920M                                  1
# GeForce GTX 960M GPU, 4 GB                    1
# GeForce GTX 1050  GPU, 2 GB                   1
# Iris Plus 640                                 1
# Iris Plus 655                                 1
# GeForce GTX 1650 Ti Max Q GPU, 4 GB           1
# Integrated Graphics                           1
# Radeon R5 M430 GPU, 4 GB                      1
# Iris Pro                                      1
# Iris graphics                                 1
# Radeon R7 M440 GPU, 2 GB                      1
# Iris Plus Graphics 655                        1
# HD 515                                        1
# Radeon HD R7 M265 GPU, 2 GB                   1
# Radeon HD 8670M GPU, 1 GB                     1
# GeForce 940M GPU, 4 GB                        1
# GeForce 930MX GPU, 2 GB                       1
# GeForce GT 740M GPU, 2 GB                     1
# GeForce GTX 850M GPU, 4 GB                    1
# GeForce GT 820M GPU, 1 GB                     1
# Radeon RX 580 GPU, 4 GB                       1
# Iris Xe Max GPU, 4 GB                         1
# GeForce GTX 1050TI GPU, 4 GB                  1
# GeForce 920MX  GPU, 2 GB                      1
# GeForce 1650 Ti GPU, 4 GB                     1
# GeForce 940 MX GPU, 2 GB                      1
# Iris Xe GPU, 4 GB                             1
# GeForce RTX A1000 GPU, 4 GB                   1
# Geforce GTX 1070 GPU, 8 GB                    1
# Radeon R5 M330 GPU, 2 GB                      1
# HD Graphics 620                               1
# Radeon 535 GPU, 2 GB                          1
# GeForce GTX 1660 GPU, 6 GB                    1
# Geforce GT 940MX GPU, 2 GB                    1
# Geforce GTX MX330 GPU, 2 GB                   1
# Radeon RX640 GPU, 2 GB                        1
# Radeon RX 640 GPU, 2 GB                       1
# Radeon RX Vega 5                              1
# Radeon RX Vega 7                              1
# GeForce MX230                                 1
# Geforce Gt 940MX GPU, 2 GB                    1
# Name: count, dtype: int64

# %%
print(df['GPU_Brand'].value_counts(dropna=False))
# Out:
# GPU_Brand
# Intel     1840
# NVIDIA    1168
# AMD        607
# Apple       11
# Name: count, dtype: int64

# %% [markdown]
# ##### INTEL GPU CLEANING

# %% [markdown]
#  - funtion to clean current intel gpu

# %%
# Filter Intel GPUs
intel_df = df[df['GPU_Brand'] == 'Intel'].copy()

def standardize_intel_name(gpu_name):
    """Standardize Intel GPU names"""
    if pd.isna(gpu_name):
        return 'Unknown'
    
    gpu = str(gpu_name).strip().upper()
    
    # Remove common prefixes
    gpu = re.sub(r'^(INTEL\s*)?', '', gpu)
    
    # Standardize UHD series
    if 'UHD' in gpu:
        # Extract number if present
        uhd_match = re.search(r'UHD\s*(\d+)?', gpu)
        if uhd_match and uhd_match.group(1):
            return f"UHD {uhd_match.group(1)}"
        else:
            return "UHD Graphics"
    
    # Standardize HD series
    elif re.search(r'HD\s*(\d+)', gpu):
        hd_match = re.search(r'HD\s*(\d+)', gpu)
        return f"HD {hd_match.group(1)}"
    
    # Standardize Iris series
    elif 'IRIS XE' in gpu:
        if 'MAX' in gpu:
            return "Iris Xe Max"  # Discrete version
        else:
            return "Iris Xe"
    elif 'IRIS PLUS' in gpu:
        return "Iris Plus"
    elif 'IRIS PRO' in gpu:
        return "Iris Pro"
    elif 'IRIS' in gpu:
        return "Iris"
    
    # Standardize Arc series (discrete)
    elif 'ARC' in gpu:
        arc_match = re.search(r'ARC\s*([A-Z]?\d+M?)', gpu)
        if arc_match:
            return f"Arc {arc_match.group(1)}"
        else:
            return "Arc"
    
    # Handle integrated variants
    elif 'INTEGRATED' in gpu:
        if 'UHD' in gpu:
            return "UHD Graphics"
        elif 'IRIS' in gpu:
            return "Iris Xe"
        else:
            return "Integrated Graphics"
    
    # Generic graphics
    elif gpu in ['GRAPHICS', 'UMA']:
        return "Integrated Graphics"
    
    return gpu.title()

# %% [markdown]
#  - funtion to map in to tiers

# %%
def get_intel_tier(gpu_name):
    """Assign performance tier to Intel GPUs"""
    if pd.isna(gpu_name):
        return 'Unknown'
    
    gpu_upper = str(gpu_name).upper()
    
    # Mid-end: Discrete Intel GPUs
    if any(x in gpu_upper for x in ['ARC A530M', 'ARC A370M', 'IRIS XE MAX']):
        return 'Mid-end'
    
    # Low-end: Good integrated graphics
    elif any(x in gpu_upper for x in ['IRIS XE', 'IRIS PLUS', 'IRIS PRO', 'ARC']):
        return 'Low-end'
    
    # Entry-level: Basic integrated graphics
    else:
        return 'Entry-level'

# %% [markdown]
# - Apply above functions

# %%
# Apply cleaning functions
intel_df['GPU_Standardized'] = intel_df['GPU'].apply(standardize_intel_name)
intel_df['GPU_Tier'] = intel_df['GPU_Standardized'].apply(get_intel_tier)

# Display results
print("\nIntel GPU Tier Distribution:")
print(intel_df['GPU_Tier'].value_counts())

for col in ['GPU_Standardized','GPU_Tier']:
    df.loc[df['GPU_Brand']=='Intel', col] = intel_df[col].values
# Out:
# Intel GPU Tier Distribution:
# GPU_Tier
# Entry-level    1217
# Low-end         620
# Mid-end           3
# Name: count, dtype: int64

# %% [markdown]
# ##### AMD GPU CLEANING

# %% [markdown]
#  - funtion to clean amd gpu

# %%
# Filter AMD GPUs
amd_df = df[df['GPU_Brand'] == 'AMD'].copy()

def standardize_amd_name(gpu_name):
    """Standardize AMD GPU names"""
    if pd.isna(gpu_name):
        return 'Unknown'
    
    gpu = str(gpu_name).strip()
    
    # Remove Radeon prefix for consistency
    gpu = re.sub(r'^Radeon\s+', '', gpu, flags=re.IGNORECASE)
    
    # Standardize RX series (discrete)
    if re.search(r'RX\s*(\d+[MS]?)', gpu, re.IGNORECASE):
        rx_match = re.search(r'RX\s*(\d+[MS]?)', gpu, re.IGNORECASE)
        return f"RX {rx_match.group(1)}"
    
    # Standardize Vega series (APU integrated)
    elif re.search(r'Vega\s*(\d+)', gpu, re.IGNORECASE):
        vega_match = re.search(r'Vega\s*(\d+)', gpu, re.IGNORECASE)
        return f"Vega {vega_match.group(1)}"
    
    # Standardize R-series (older discrete)
    elif re.search(r'R([2-7])\s*(M?\d*)', gpu, re.IGNORECASE):
        r_match = re.search(r'R([2-7])\s*(M?\d*)', gpu, re.IGNORECASE)
        if r_match.group(2):
            return f"R{r_match.group(1)} {r_match.group(2)}"
        else:
            return f"R{r_match.group(1)}"
    
    # Standardize mobile APU graphics
    elif re.search(r'(\d{3})M', gpu):
        mobile_match = re.search(r'(\d{3})M', gpu)
        return f"{mobile_match.group(1)}M"
    
    # Standardize HD series (older discrete)
    elif re.search(r'HD\s*(\d+)', gpu, re.IGNORECASE):
        hd_match = re.search(r'HD\s*(\d+)', gpu, re.IGNORECASE)
        return f"HD {hd_match.group(1)}"
    
    # Handle generic cases
    elif gpu.upper() in ['RADEON', 'INTEGRATED']:
        return 'Radeon Graphics'
    elif 'GRAPHICS' in gpu.upper():
        return 'Radeon Graphics'
    
    return gpu.title()

# %% [markdown]
#  - funtion to get tier

# %%
def get_amd_tier(gpu_name):
    """Assign performance tier to AMD GPUs"""
    if pd.isna(gpu_name):
        return 'Unknown'
    
    gpu_upper = str(gpu_name).upper()
    
    # High-end: High-performance discrete GPUs
    if any(x in gpu_upper for x in ['RX 6800', 'RX 6700', 'RX 7600']):
        return 'High-end'
    
    # Mid-end: Mid-performance discrete GPUs
    elif any(x in gpu_upper for x in ['RX 6600', 'RX 6550', 'RX 6500', 'RX 580', 'RX 560', 'RX 5600', 'RX 5500']):
        return 'Mid-end'
    elif any(x in gpu_upper for x in ['R5 M', 'R7 M', 'HD 8']):
        return 'Mid-end'
    
    # Low-end: APU integrated graphics (decent)
    elif any(x in gpu_upper for x in ['VEGA', '780M', '760M', '680M', '610M']):
        return 'Low-end'
    elif any(x in gpu_upper for x in ['530', '535', '520']):
        return 'Low-end'
    
    # Entry-level: Basic integrated
    else:
        return 'Entry-level'

# %% [markdown]
#  - Apply above functions

# %%
# Apply cleaning functions
amd_df['GPU_Standardized'] = amd_df['GPU'].apply(standardize_amd_name)
amd_df['GPU_Tier'] = amd_df['GPU_Standardized'].apply(get_amd_tier)

# Display results
print("\nAMD GPU Tier Distribution:")
print(amd_df['GPU_Tier'].value_counts())

for col in ['GPU_Standardized','GPU_Tier']:
    df.loc[df['GPU_Brand']=='AMD', col] = amd_df[col].values
# Out:
# AMD GPU Tier Distribution:
# GPU_Tier
# Entry-level    416
# Low-end        144
# Mid-end         40
# High-end         7
# Name: count, dtype: int64

# %% [markdown]
# ##### NVIDIA GPU CLEANING

# %% [markdown]
# - funtion to clean Nvidia gpu

# %%
# Filter NVIDIA GPUs
nvidia_df = df[df['GPU_Brand'] == 'NVIDIA'].copy()

def standardize_nvidia_name(gpu_name):
    """Standardize NVIDIA GPU names"""
    if pd.isna(gpu_name):
        return 'Unknown'
    
    gpu = str(gpu_name).strip()
    
    # Remove GeForce prefix for consistency
    gpu = re.sub(r'^GeForce\s+', '', gpu, flags=re.IGNORECASE)
    gpu = re.sub(r'^GEFORCE\s+', '', gpu, flags=re.IGNORECASE)
    gpu = re.sub(r'^Geforce\s+', '', gpu, flags=re.IGNORECASE)
    
    # Remove GPU suffix and VRAM info
    gpu = re.sub(r'\s*GPU,?\s*\d+\s*GB?', '', gpu, flags=re.IGNORECASE)
    gpu = re.sub(r'\s*GPU\s*$', '', gpu, flags=re.IGNORECASE)
    
    # Standardize RTX series
    if re.search(r'RTX\s*(\d{4})\s*(Ti)?', gpu, re.IGNORECASE):
        rtx_match = re.search(r'RTX\s*(\d{4})\s*(Ti)?', gpu, re.IGNORECASE)
        ti_suffix = ' Ti' if rtx_match.group(2) else ''
        return f"RTX {rtx_match.group(1)}{ti_suffix}"
    
    # Standardize GTX series
    elif re.search(r'GTX\s*(\d{4})\s*(Ti)?', gpu, re.IGNORECASE):
        gtx_match = re.search(r'GTX\s*(\d{4})\s*(Ti)?', gpu, re.IGNORECASE)
        ti_suffix = ' Ti' if gtx_match.group(2) else ''
        return f"GTX {gtx_match.group(1)}{ti_suffix}"
    
    # Standardize MX series
    elif re.search(r'MX\s*(\d{3})', gpu, re.IGNORECASE):
        mx_match = re.search(r'MX\s*(\d{3})', gpu, re.IGNORECASE)
        return f"MX {mx_match.group(1)}"
    
    # Standardize GT series
    elif re.search(r'GT\s*(\d{3}MX)', gpu, re.IGNORECASE):
        gt_match = re.search(r'GT\s*(\d{3}MX)', gpu, re.IGNORECASE)
        return gt_match.group(1)
    
    # Handle Quadro series (professional)
    elif 'QUADRO' in gpu.upper():
        quadro_match = re.search(r'Quadro\s+([A-Z]?\d+)', gpu, re.IGNORECASE)
        if quadro_match:
            return f"Quadro {quadro_match.group(1)}"
        else:
            return "Quadro"
    
    # Clean up Max-Q variants
    gpu = re.sub(r'MAX[\s-]?Q', 'Max-Q', gpu, flags=re.IGNORECASE)
    gpu = re.sub(r'Max Q', 'Max-Q', gpu, flags=re.IGNORECASE)
    
    # Clean up Ti variants
    gpu = re.sub(r'Ti`', 'Ti', gpu)
    gpu = re.sub(r'TI\b', 'Ti', gpu)
    
    return gpu.strip()

# %% [markdown]
# - funtion for tier seperation

# %%
def get_nvidia_tier(gpu_name):
    """Assign performance tier to NVIDIA GPUs"""
    if pd.isna(gpu_name):
        return 'Unknown'
    
    gpu_upper = str(gpu_name).upper()
    
    # High-end: Flagship gaming and professional GPUs
    high_end_patterns = [
        'RTX 4070', 'RTX 4070 TI', 'RTX 3080', 'RTX 3080 TI', 'RTX 3070', 'RTX 3070 TI',
        'RTX 2080', 'RTX 2080 TI', 'RTX 2070', 'GTX 1080', 'GTX 1070',
        'QUADRO', 'RTX A'
    ]
    if any(pattern in gpu_upper for pattern in high_end_patterns):
        return 'High-end'
    
    # Mid-end: Good gaming performance
    mid_end_patterns = [
        'RTX 4060', 'RTX 4060 TI', 'RTX 4050', 'RTX 4050 TI', 'RTX 3060', 'RTX 3060 TI', 'RTX 3050', 'RTX 3050 TI',
        'RTX 2060', 'RTX 2050', 'GTX 1660', 'GTX 1660 TI', 'GTX 1650', 'GTX 1650 TI',
        'GTX 1060', 'GTX 1050', 'GTX 1050 TI'
    ]
    if any(pattern in gpu_upper for pattern in mid_end_patterns):
        return 'Mid-end'
    
    # Low-end: Entry gaming and productivity
    low_end_patterns = [
        'MX', 'GT 9', 'GT 8', 'GT 7', 'GTX 960M', 'GTX 950M', 'GTX 850M'
    ]
    if any(pattern in gpu_upper for pattern in low_end_patterns):
        return 'Low-end'
    
    # Entry-level: Basic discrete graphics
    return 'Entry-level'

# %% [markdown]
# - Apply above functions

# %%
# Apply cleaning functions
nvidia_df['GPU_Standardized'] = nvidia_df['GPU'].apply(standardize_nvidia_name)
nvidia_df['GPU_Tier'] = nvidia_df['GPU_Standardized'].apply(get_nvidia_tier)

# Display results
print("\nNVIDIA GPU Tier Distribution:")
print(nvidia_df['GPU_Tier'].value_counts())

for col in ['GPU_Standardized','GPU_Tier']:
    df.loc[df['GPU_Brand']=='NVIDIA', col] = nvidia_df[col].values
# Out:
# NVIDIA GPU Tier Distribution:
# GPU_Tier
# Mid-end        903
# Low-end        215
# Entry-level     26
# High-end        24
# Name: count, dtype: int64

# %% [markdown]
# ##### APPLE GPU CLEANING

# %% [markdown]
# - APPLE GPU CLEANING

# %%
# Filter Apple GPUs
apple_df = df[df['GPU_Brand'] == 'Apple'].copy()

def standardize_apple_name(gpu_name):
    """Standardize Apple GPU names"""
    if pd.isna(gpu_name):
        return 'Unknown'
    
    gpu = str(gpu_name).strip().upper()
    
    if 'M2' in gpu:
        return 'M2'
    elif 'M1' in gpu:
        return 'M1'
    else:
        return gpu.title()

def get_apple_tier(gpu_name):
    """All Apple Silicon GPUs are considered high-end for efficiency"""
    return 'High-end'


# Apply cleaning functions
apple_df['GPU_Standardized'] = apple_df['GPU'].apply(standardize_apple_name)
apple_df['GPU_Tier'] = apple_df['GPU_Standardized'].apply(get_apple_tier)

# Display results
print("\nApple GPU Tier Distribution:")
print(apple_df['GPU_Tier'].value_counts())

for col in ['GPU_Standardized','GPU_Tier']:
    df.loc[df['GPU_Brand']=='Apple', col] = apple_df[col].values
# Out:
# Apple GPU Tier Distribution:
# GPU_Tier
# High-end    11
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3626, 24)

# %% [markdown]
# #### SSD and HDD

# %% [markdown]
# ##### SSD

# %%
print(df['SSD'].value_counts(dropna=False))
# Out:
# SSD
# 512 GB SSD Storage     1883
# NO SSD                  639
# 1024 GB SSD Storage     390
# 256 GB SSD Storage      350
# 256 GB SSD Storage      202
# 128 GB SSD Storage       56
# 128 GB SSD Storage       44
# 64 GB SSD Storage        21
# 16 GB SSD Storage        12
# 512 GB SSD Storage       11
# 32 GB SSD Storage         8
# 8 GB SSD Storage          4
# 256  SSD Storage          2
# 512  SSD Storage          2
# 1 GB SSD Storage          1
# 16 GB SSD Storage         1
# Name: count, dtype: int64

# %% [markdown]
# - Cleaning Inconsistent names

# %%
def clean_ssd(ssd):
    if pd.isna(ssd) or 'NO' in str(ssd).upper():
        return 'No SSD'
    
    # Remove extra spaces
    ssd = str(ssd).strip()
    
    # Extract numeric value (size)
    match = re.search(r'(\d+)', ssd)
    if match:
        size = match.group(1)
        return f"{size} GB SSD"
    else:
        return 'Unknown'

# Apply the cleaning function
df['SSD'] = df['SSD'].apply(clean_ssd)

# Check results
print(df['SSD'].value_counts())
# Out:
# SSD
# 512 GB SSD     1896
# No SSD          639
# 256 GB SSD      554
# 1024 GB SSD     390
# 128 GB SSD      100
# 64 GB SSD        21
# 16 GB SSD        13
# 32 GB SSD         8
# 8 GB SSD          4
# 1 GB SSD          1
# Name: count, dtype: int64

# %% [markdown]
# - Convert SSD capacities to numbers to int

# %%
def ssd_to_number(ssd):
    if pd.isna(ssd) or 'NO' in str(ssd).upper():
        return 0
    # Extract the first number found in the string
    match = re.search(r'(\d+)', str(ssd))
    if match:
        return int(match.group(1))
    else:
        return 0

# Apply the function
df['SSD(GB)'] = df['SSD'].apply(ssd_to_number)
print(df['SSD(GB)'].value_counts())
# Out:
# SSD(GB)
# 512     1896
# 0        639
# 256      554
# 1024     390
# 128      100
# 64        21
# 16        13
# 32         8
# 8          4
# 1          1
# Name: count, dtype: int64

# %% [markdown]
# - Keep only dominat capacities

# %%
# Define main sizes and include 0 for No SSD
keep_sizes = [0, 128, 256, 512, 1024]

# Keep only these values
df = df[df['SSD(GB)'].isin(keep_sizes)]

# Check results
print(df['SSD(GB)'].value_counts())
# Out:
# SSD(GB)
# 512     1896
# 0        639
# 256      554
# 1024     390
# 128      100
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3579, 25)

# %% [markdown]
# ##### HDD

# %%
print(df['HDD'].value_counts(dropna=False))
# Out:
# HDD
# No HDD                  2669
# 1024 GB HDD Storage      586
#  1024 GB HDD Storage     270
# 500 GB HDD Storage        34
# 2048 GB HDD Storage       18
#  2048 GB HDD Storage       1
# 1 GB HDD Storage           1
# Name: count, dtype: int64

# %% [markdown]
# -  Clean HDD naming inconsitencies

# %%
def clean_hdd(hdd):
    if pd.isna(hdd) or 'NO' in str(hdd).upper():
        return 'No HDD'
    
    # Remove extra spaces
    hdd = str(hdd).strip()
    
    # Extract numeric value (size)
    match = re.search(r'(\d+)', hdd)
    if match:
        size = match.group(1)
        return f"{size} GB HDD"
    else:
        return 'Unknown'

# Apply the cleaning function
df['HDD'] = df['HDD'].apply(clean_hdd)
print(df['HDD'].value_counts(dropna=False))
# Out:
# HDD
# No HDD         2669
# 1024 GB HDD     856
# 500 GB HDD       34
# 2048 GB HDD      19
# 1 GB HDD          1
# Name: count, dtype: int64

# %% [markdown]
# - Convert to int

# %%
def hdd_to_number(hdd):
    if pd.isna(hdd) or 'NO' in str(hdd).upper():
        return 0
    
    # Remove extra spaces
    hdd = str(hdd).strip()
    
    # Extract the first number (size in GB)
    match = re.search(r'(\d+)', hdd)
    if match:
        return int(match.group(1))
    else:
        return 0

# Apply the function
df['HDD(GB)'] = df['HDD'].apply(hdd_to_number)

# Check results
print(df['HDD(GB)'].value_counts(dropna=False))
# Out:
# HDD(GB)
# 0       2669
# 1024     856
# 500       34
# 2048      19
# 1          1
# Name: count, dtype: int64

# %% [markdown]
# - Keep only dominat capacities

# %%
keep_hdd = [0, 500, 1024]

# Keep only these values
df = df[df['HDD(GB)'].isin(keep_hdd)]

# Check results
print(df['HDD(GB)'].value_counts())
# Out:
# HDD(GB)
# 0       2669
# 1024     856
# 500       34
# Name: count, dtype: int64

# %%
df.head()
# Out:
#     Brand                                               Name     Price  \
# 0  Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  127011.5
# 1    Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  274750.0
# 2      HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  194215.0
# 3   Other  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...   76965.0
# 4    Acer  Acer One 14 Z8-415 (UN.599SI.020) Laptop (14 I...  122465.0
#
#                        Processor_Name Processor_Brand RAM_Expandable  RAM  \
# 0               AMD Hexa-Core Ryzen 5             AMD            Yes    8
# 1            Intel Core i5 (12th Gen)           Intel            Yes   16
# 2            Intel Core i5 (12th Gen)           Intel            Yes    8
# 3            Intel Core i3 (11th Gen)           Intel             No    8
# 4  Intel Core i5 (11th Gen) Processor           Intel            Yes   16
#
#   RAM_TYPE(DDR)       Ghz Display_type  ...                Battery_Life  \
# 0             4  4.000000          LCD  ...    Upto 11 Hrs Battery Life
# 1             5  3.300000          LCD  ...    Upto 10 Hrs Battery Life
# 2             4  4.200000          LCD  ...  Upto 7.30 Hrs Battery Life
# 3           LP4  1.700000          LCD  ...     Upto 8 Hrs Battery Life
# 4             4  2.655951          LCD  ...                 45W Adapter
#
#   Operating_System Processor_Category Processor_Tier Processor_Speed(Ghz)  \
# 0       Windows 11        AMD Ryzen 5        Mid-End                  4.0
# 1       Windows 11           Intel I5        Mid-End                  3.5
# 2       Windows 11           Intel I5        Mid-End                  4.0
# 3       Windows 11           Intel I3        Low-End                  1.5
# 4       Windows 11           Intel I5        Mid-End                  2.5
#
#   Display_Tier GPU_Standardized     GPU_Tier SSD(GB) HDD(GB)
# 0        Small  Radeon Graphics  Entry-level     512       0
# 1        Small         RTX 3050      Mid-end     512       0
# 2        Small          Iris Xe      Low-end     512       0
# 3        Small     UHD Graphics  Entry-level     512       0
# 4        Small          Iris Xe      Low-end     512       0
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Battery_Life and Adapter Not considered

# %% [markdown]
# - Battery_Life consist of lot of missing values and mixed with Adapter watt values. Therefore not considered

# %% [markdown]
# #### Final Cleaned Dataset

# %%
df.rename(columns={'RAM': 'RAM_Capacity'}, inplace=True)

# %% [markdown]
# - Drop unnessary columns

# %%
cols_to_drop = [
    'Processor_Name', 'Display_Size', 'Ghz', 'SSD', 'HDD','GPU',
    'Adapter', 'Battery_Life', 'GPU_Standardized', 'Name', 'Operating_System', 'Processor_Tier'
]
# Drop columns
df = df.drop(columns=cols_to_drop)
# Check the updated DataFrame
df.head(10)
# Out:
#     Brand     Price Processor_Brand RAM_Expandable  RAM_Capacity  \
# 0  Lenovo  127011.5             AMD            Yes             8
# 1    Dell  274750.0           Intel            Yes            16
# 2      HP  194215.0           Intel            Yes             8
# 3   Other   76965.0           Intel             No             8
# 4    Acer  122465.0           Intel            Yes            16
# 5      HP  173596.5             AMD            Yes             8
# 6    Acer  139965.0           Intel            Yes             8
# 7  Lenovo  115888.5           Intel            Yes             4
# 8    ASUS  171465.0           Intel             No             8
# 9  Lenovo  325465.0             AMD            Yes            16
#
#   RAM_TYPE(DDR) Display_type GPU_Brand Processor_Category  \
# 0             4          LCD       AMD        AMD Ryzen 5
# 1             5          LCD    NVIDIA           Intel I5
# 2             4          LCD     Intel           Intel I5
# 3           LP4          LCD     Intel           Intel I3
# 4             4          LCD     Intel           Intel I5
# 5             4          LCD       AMD        AMD Ryzen 5
# 6             4          LCD     Intel           Intel I5
# 7             4          LED     Intel           Intel I3
# 8             4          LCD    NVIDIA           Intel I5
# 9             5          LCD    NVIDIA        AMD Ryzen 7
#
#    Processor_Speed(Ghz) Display_Tier     GPU_Tier  SSD(GB)  HDD(GB)
# 0                   4.0        Small  Entry-level      512        0
# 1                   3.5        Small      Mid-end      512        0
# 2                   4.0        Small      Low-end      512        0
# 3                   1.5        Small  Entry-level      512        0
# 4                   2.5        Small      Low-end      512        0
# 5                   4.0        Small  Entry-level      512        0
# 6                   2.5        Small      Low-end      512        0
# 7                   2.0        Small  Entry-level        0     1024
# 8                   3.0        Small      Mid-end      512        0
# 9                   3.5        Small      Mid-end      512        0

# %%
df[df.duplicated()]
# Out:
#         Brand     Price Processor_Brand RAM_Expandable  RAM_Capacity  \
# 93       ASUS  178465.0           Intel            Yes             8
# 437      ASUS  150465.0           Intel            Yes             8
# 438      ASUS  150465.0           Intel            Yes             8
# 518        HP  244996.5           Intel             No            16
# 560   Samsung  384965.0           Intel             No            16
# 604      Acer  248465.0           Intel            Yes            16
# 636     Other  349965.0           Intel            Yes             8
# 829      ASUS  192465.0             AMD             No            16
# 954      ASUS  244965.0           Intel             No            16
# 1160   Lenovo  115465.0           Intel             No             4
# 1168   Lenovo  122465.0           Intel             No             8
# 1184     ASUS  206465.0           Intel             No            16
# 1430     ASUS  286965.0           Intel             No             8
# 1533       HP  174965.0           Intel             No             8
# 1560   Lenovo   62965.0             AMD             No             4
# 1620   Lenovo   88200.0           Intel             No             4
# 1664     ASUS  227465.0           Intel             No             8
# 1668     ASUS  227465.0           Intel             No             8
# 1758     Acer  110215.0           Intel             No             8
# 1798   Lenovo  143465.0           Intel            Yes             8
# 1806       HP  108465.0             AMD            Yes             8
# 1822   Lenovo  115465.0           Intel            Yes             8
# 1823    Apple  524650.0           Apple             No             8
# 1826     ASUS  122465.0           Intel            Yes             8
# 1856     Acer  199465.0           Intel            Yes            16
# 1867     ASUS  111965.0           Intel             No             8
# 1874   Lenovo  115465.0           Intel             No             4
# 1898   Lenovo  227465.0             AMD            Yes            16
# 1900       HP  262465.0           Intel             No            16
# 1966       HP  216965.0           Intel            Yes             8
# 1993     Acer  229215.0             AMD            Yes             8
# 2011   Lenovo  115465.0           Intel             No             4
# 2024       HP   89246.5             AMD             No             8
# 2116     Acer  132965.0           Intel             No             8
# 2222      MSI  150465.0           Intel             No             8
# 2268     Dell  146965.0           Intel             No             8
# 2327     ASUS  206465.0           Intel             No            16
# 2348     ASUS  391965.0           Intel             No            16
# 2352     ASUS  129465.0           Intel            Yes             8
# 2353     ASUS  384965.0           Intel            Yes            16
# 2360     ASUS  339465.0           Intel             No            16
# 2366   Lenovo  159215.0           Intel            Yes             8
# 2469     ASUS  276465.0           Intel             No            16
# 2476       HP  531965.0           Intel             No            16
# 2478       HP  531965.0           Intel             No            16
# 2563       HP  129465.0           Intel            Yes             8
# 2598     ASUS  227465.0           Intel             No            16
# 2605   Lenovo   62965.0             AMD             No             4
# 2683       HP  101465.0           Intel             No             4
# 2780       HP  174965.0           Intel             No             8
# 2824   Lenovo  139965.0           Intel             No             4
# 2883     Acer  192465.0           Intel             No             8
# 2889     ASUS  160965.0           Intel            Yes             8
# 2911    Apple  367465.0           Intel             No             8
# 2914     ASUS  136465.0           Intel             No             8
# 2933     ASUS  227465.0           Intel             No             8
# 2946    Apple  447965.0           Intel             No             8
# 3009   Lenovo  122465.0           Intel             No             4
# 3074   Lenovo   87465.0           Intel             No             4
# 3110   Lenovo  139965.0             AMD             No             8
# 3221       HP  104965.0           Intel             No             4
# 3244   Lenovo  209965.0           Intel             No             8
# 3281   Lenovo   73465.0             AMD             No             4
# 3412       HP  127365.0           Intel            Yes             4
# 3426       HP   97965.0           Intel             No             4
# 3486     ASUS  339465.0             AMD            Yes            16
# 3569     ASUS  227465.0             AMD            Yes            16
#
#      RAM_TYPE(DDR) Display_type GPU_Brand Processor_Category  \
# 93               4          LCD    NVIDIA           Intel I5
# 437              4          LCD     Intel           Intel I3
# 438              4          LCD     Intel           Intel I3
# 518              4          LCD     Intel           Intel I5
# 560              4          LED     Intel           Intel I5
# 604              5          LCD    NVIDIA           Intel I5
# 636            LP5          LCD     Intel           Intel I5
# 829              4          LCD       AMD        AMD Ryzen 7
# 954              4          LCD    NVIDIA           Intel I5
# 1160             4          LED     Intel           Intel I3
# 1168             4          LED     Intel           Intel I3
# 1184             4          LCD     Intel           Intel I5
# 1430             4          LED    NVIDIA           Intel I7
# 1533             4          LED     Intel           Intel I5
# 1560             4          LED       AMD       AMD A-Series
# 1620             4          LED     Intel      Intel Celeron
# 1664             4          LED     Intel           Intel I5
# 1668             4          LED     Intel           Intel I5
# 1758           LP5          LCD     Intel           Intel I3
# 1798             4          LCD     Intel           Intel I3
# 1806             4          LCD       AMD        AMD Ryzen 3
# 1822             4          LCD     Intel           Intel I3
# 1823             5          LCD     Apple     Apple M-series
# 1826             4          LCD     Intel           Intel I3
# 1856             5          LCD    NVIDIA           Intel I5
# 1867             4          LCD     Intel           Intel I3
# 1874             4          LED     Intel           Intel I3
# 1898             5          LCD    NVIDIA        AMD Ryzen 5
# 1900             4          LCD     Intel           Intel I5
# 1966             4          LCD     Intel           Intel I5
# 1993             5          LCD    NVIDIA        AMD Ryzen 5
# 2011             4          LED     Intel           Intel I3
# 2024             4          LCD       AMD        AMD Ryzen 3
# 2116           LP5          LCD     Intel           Intel I3
# 2222             4          LCD    NVIDIA           Intel I5
# 2268             4          LCD     Intel           Intel I3
# 2327             4          LCD     Intel           Intel I5
# 2348           LP5          LED     Intel      Intel Ultra 7
# 2352             4          LCD     Intel           Intel I3
# 2353             5          LCD    NVIDIA           Intel I7
# 2360           LP5          LED     Intel      Intel Ultra 5
# 2366             4          LCD     Intel           Intel I5
# 2469             4          LCD    NVIDIA           Intel I7
# 2476             5          LCD    NVIDIA           Intel I7
# 2478             5          LCD    NVIDIA           Intel I7
# 2563             4          LCD     Intel           Intel I3
# 2598             4          LCD     Intel           Intel I7
# 2605             4          LED       AMD       AMD A-Series
# 2683             4          LED     Intel           Intel I3
# 2780             4          LED     Intel           Intel I5
# 2824             4          LED     Intel           Intel I3
# 2883             4          LED     Intel           Intel I5
# 2889             4          LED    NVIDIA           Intel I5
# 2911           LP3          LED     Intel           Intel I5
# 2914             4          LCD     Intel           Intel I3
# 2933             4          LED     Intel           Intel I5
# 2946           LP3          LED     Intel           Intel I5
# 3009             4          LED     Intel           Intel I3
# 3074             4          LED     Intel           Intel I3
# 3110             4          LED       AMD        AMD Ryzen 5
# 3221             4          LED     Intel           Intel I3
# 3244             4          LED     Intel           Intel I5
# 3281             4          LED       AMD       AMD A-Series
# 3412             3          LED     Intel           Intel I3
# 3426             4          LED     Intel           Intel I3
# 3486             5          LCD    NVIDIA        AMD Ryzen 7
# 3569           LP5          LCD    NVIDIA        AMD Ryzen 7
#
#       Processor_Speed(Ghz) Display_Tier     GPU_Tier  SSD(GB)  HDD(GB)
# 93                     2.5        Small      Mid-end      512        0
# 437                    1.0        Small  Entry-level      512        0
# 438                    1.0        Small  Entry-level      512        0
# 518                    4.5        Small      Low-end      512        0
# 560                    2.0        Small      Low-end      512        0
# 604                    2.5        Small      Mid-end      512        0
# 636                    4.0        Small  Entry-level      256        0
# 829                    2.0        Large  Entry-level      512        0
# 954                    2.5        Large      Mid-end      512        0
# 1160                   3.0        Small  Entry-level      256        0
# 1168                   2.0        Small  Entry-level      256        0
# 1184                   1.5        Small      Low-end      512        0
# 1430                   2.0        Small      Low-end      256     1024
# 1533                   1.0        Small  Entry-level      512        0
# 1560                   2.5        Small  Entry-level        0     1024
# 1620                   3.0        Small  Entry-level      256        0
# 1664                   1.5        Small  Entry-level      256     1024
# 1668                   1.5        Small  Entry-level      256     1024
# 1758                   2.0        Small  Entry-level      256        0
# 1798                   3.0        Small  Entry-level      512        0
# 1806                   2.5        Small  Entry-level      512        0
# 1822                   3.0        Small  Entry-level      512        0
# 1823                   3.5        Small     High-end      512        0
# 1826                   2.0        Small  Entry-level      512        0
# 1856                   2.5        Small      Mid-end      512        0
# 1867                   3.0        Small  Entry-level      512        0
# 1874                   3.0        Small  Entry-level      256        0
# 1898                   3.5        Small      Mid-end      512        0
# 1900                   4.5        Small      Low-end      512        0
# 1966                   4.5        Small      Low-end      512        0
# 1993                   3.5        Small      Mid-end      512        0
# 2011                   3.0        Small  Entry-level      256        0
# 2024                   2.5        Small  Entry-level      512        0
# 2116                   2.0        Small  Entry-level      512        0
# 2222                   4.0        Small      Mid-end      512        0
# 2268                   4.0        Small  Entry-level      512        0
# 2327                   1.5        Small      Low-end      512        0
# 2348                   1.5        Small      Low-end     1024        0
# 2352                   1.0        Small  Entry-level      512        0
# 2353                   2.5        Small      Mid-end      512        0
# 2360                   1.0        Small      Low-end     1024        0
# 2366                   2.5        Small  Entry-level      512        0
# 2469                   2.5        Large      Mid-end      512        0
# 2476                   5.0        Large      Mid-end      512        0
# 2478                   5.0        Large      Mid-end      512        0
# 2563                   4.0        Small  Entry-level      512        0
# 2598                   2.5        Small  Entry-level      512        0
# 2605                   2.5        Small  Entry-level        0     1024
# 2683                   2.5        Small  Entry-level        0     1024
# 2780                   1.5        Small  Entry-level        0     1024
# 2824                   2.0        Small  Entry-level      256        0
# 2883                   2.5        Small      Low-end      512        0
# 2889                   1.5        Small      Low-end        0     1024
# 2911                   1.5        Small  Entry-level      256        0
# 2914                   1.0        Small  Entry-level      512        0
# 2933                   1.5        Small  Entry-level      256     1024
# 2946                   1.5        Small  Entry-level      256        0
# 3009                   2.0        Small  Entry-level      256        0
# 3074                   2.5        Small  Entry-level        0     1024
# 3110                   2.0        Small      Low-end      512        0
# 3221                   2.0        Small  Entry-level        0     1024
# 3244                   1.5        Small  Entry-level      128     1024
# 3281                   2.5        Small  Entry-level        0     1024
# 3412                   1.5        Small  Entry-level        0      500
# 3426                   2.0        Small  Entry-level        0     1024
# 3486                   4.5        Small      Mid-end     1024        0
# 3569                   3.0        Small      Mid-end      512        0

# %%
df.drop_duplicates(inplace=True)
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Brand, Price, Processor_Brand, RAM_Expandable, RAM_Capacity, RAM_TYPE(DDR), Display_type, GPU_Brand, Processor_Category, Processor_Speed(Ghz), Display_Tier, GPU_Tier, SSD(GB), HDD(GB)]
# Index: []

# %%
df.shape
# Out:
# (3492, 14)

# %% [markdown]
# ### Preprocessing

# %%
df.shape
df.dtypes
# Out:
# Brand                    object
# Price                   float64
# Processor_Brand          object
# RAM_Expandable           object
# RAM_Capacity              int64
# RAM_TYPE(DDR)            object
# Display_type             object
# GPU_Brand                object
# Processor_Category       object
# Processor_Speed(Ghz)    float64
# Display_Tier             object
# GPU_Tier                 object
# SSD(GB)                   int64
# HDD(GB)                   int64
# dtype: object

# %%
# Categorical columns
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
print("Categorical columns:", list(categorical_cols))

# Numerical columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
print("Numerical columns:", list(numerical_cols))
# Out:
# Categorical columns: ['Brand', 'Processor_Brand', 'RAM_Expandable', 'RAM_TYPE(DDR)', 'Display_type', 'GPU_Brand', 'Processor_Category', 'Display_Tier', 'GPU_Tier']
# Numerical columns: ['Price', 'RAM_Capacity', 'Processor_Speed(Ghz)', 'SSD(GB)', 'HDD(GB)']

# %%
for col in categorical_cols:
    print(f"{col}: {df[col].nunique()} unique values")
    print(df[col].value_counts().head(20))
# Out:
# Brand: 9 unique values
# Brand
# ASUS       851
# Lenovo     730
# HP         723
# Dell       392
# Acer       294
# MSI        262
# Other      171
# Samsung     41
# Apple       28
# Name: count, dtype: int64
# Processor_Brand: 3 unique values
# Processor_Brand
# Intel    2616
# AMD       866
# Apple      10
# Name: count, dtype: int64
# RAM_Expandable: 2 unique values
# RAM_Expandable
# No     1892
# Yes    1600
# Name: count, dtype: int64
# RAM_TYPE(DDR): 6 unique values
# RAM_TYPE(DDR)
# 4      2670
# 5       265
# LP5     251
# LP4     156
# 3       109
# LP3      41
# Name: count, dtype: int64
# Display_type: 2 unique values
# Display_type
# LCD    1791
# LED    1701
# Name: count, dtype: int64
# GPU_Brand: 4 unique values
# GPU_Brand
# Intel     1760
# NVIDIA    1130
# AMD        592
# Apple       10
# Name: count, dtype: int64
# Processor_Category: 18 unique values
# Processor_Category
# Intel I5          1227
# Intel I3           652
# Intel I7           516
# AMD Ryzen 5        369
# AMD Ryzen 7        249
# AMD Ryzen 3        116
# Intel Celeron       75
# AMD A-Series        57
# Intel Pentium       56
# AMD Athlon          35
# AMD Ryzen 9         24
# Intel I9            24
# Intel Ultra 5       22
# Intel Ultra 7       22
# Intel Other         17
# AMD Other           16
# Apple M-series      10
# Intel Ultra 9        5
# Name: count, dtype: int64
# Display_Tier: 2 unique values
# Display_Tier
# Small    3223
# Large     269
# Name: count, dtype: int64
# GPU_Tier: 4 unique values
# GPU_Tier
# Entry-level    1581
# Low-end         945
# Mid-end         925
# High-end         41
# Name: count, dtype: int64

# %% [markdown]
# #### Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder

# %%
df_encoded = df.copy()

# %% [markdown]
# - Binary encoding

# %%
df_encoded['RAM_Expandable'] = df_encoded['RAM_Expandable'].map({'Yes': 1, 'No': 0})
df_encoded['Display_type'] = df_encoded['Display_type'].map({'LCD': 0, 'LED': 1})

# %% [markdown]
# - Ordinal Encoding

# %%
# tier_map = {'Low-End': 0, 'Mid-End': 1, 'Upper Mid-End': 2,'High-End': 3}
# df_encoded['Processor_Tier'] = df_encoded['Processor_Tier'].map(tier_map)
# Apple M-series set Nan becuase only Intel,AMD has tier order

df_encoded['Display_Tier'] = df_encoded['Display_Tier'].map({
    'Small': 1, 'Large': 2
})
# df_encoded['Display_Tier'] = df_encoded['Display_Tier'].map({
#     'Small': 1, 'Medium':2, 'Large': 3
# })

df_encoded['GPU_Tier'] = df_encoded['GPU_Tier'].map({
    'Entry-level': 1, 'Low-end': 2, 'Mid-end': 3, 'High-end': 4
})


df_encoded['RAM_TYPE(DDR)'] = df_encoded['RAM_TYPE(DDR)'].map({
    '3': 1, 'LP3': 2,
    '4': 3, 'LP4': 4,
    '5': 5, 'LP5': 6
})

# df_encoded['Operating_System'] = df_encoded['Operating_System'].map({
#     'Chrome': 0, 'DOS': 1, 'Linux': 2, 'Windows 10': 3,
#     'Windows 11': 4, 'Windows 8.1': 5, 'macOS': 6
# })

# %% [markdown]
# - Categorical variables also keep as label encoded because lightgbm not affected by the order of values

# %%
# # le_OS = LabelEncoder()
# # df_encoded['Operating_System'] = le_OS.fit_transform(df_encoded['Operating_System'])

# le_processor_cat = LabelEncoder()
# df_encoded['Processor_Category'] = le_processor_cat.fit_transform(df_encoded['Processor_Category'])

# # Encode 'Brand'
# le_brand = LabelEncoder()
# df_encoded['Brand'] = le_brand.fit_transform(df_encoded['Brand'])

# # Encode 'Processor_Brand'
# le_processor = LabelEncoder()
# df_encoded['Processor_Brand'] = le_processor.fit_transform(df_encoded['Processor_Brand'])

# # Encode 'GPU_Brand'
# le_gpu = LabelEncoder()
# df_encoded['GPU_Brand'] = le_gpu.fit_transform(df_encoded['GPU_Brand'])

# %%
df_encoded['Processor_Category'].value_counts()
# Out:
# Processor_Category
# Intel I5          1227
# Intel I3           652
# Intel I7           516
# AMD Ryzen 5        369
# AMD Ryzen 7        249
# AMD Ryzen 3        116
# Intel Celeron       75
# AMD A-Series        57
# Intel Pentium       56
# AMD Athlon          35
# AMD Ryzen 9         24
# Intel I9            24
# Intel Ultra 5       22
# Intel Ultra 7       22
# Intel Other         17
# AMD Other           16
# Apple M-series      10
# Intel Ultra 9        5
# Name: count, dtype: int64

# %%
# View mapping

# processor_cat_mapping = dict(zip(le_processor_cat.classes_, le_processor_cat.transform(le_processor_cat.classes_)))
# print("Processor Category Mapping:")
# print(processor_cat_mapping)

# brand_mapping = dict(zip(le_brand.classes_, le_brand.transform(le_brand.classes_)))
# print("Brand Mapping:")
# print(brand_mapping)

# processor_mapping = dict(zip(le_processor.classes_, le_processor.transform(le_processor.classes_)))
# print("\nProcessor_Brand Mapping:")
# print(processor_mapping)

# gpu_mapping = dict(zip(le_gpu.classes_, le_gpu.transform(le_gpu.classes_)))
# print("\nGPU_Brand Mapping:")
# print(gpu_mapping)

# %% [markdown]
#  - One hot Encoding

# %%
df_encoded = pd.get_dummies(
    df_encoded, 
    columns=['Processor_Category', 'Brand', 'Processor_Brand', 'GPU_Brand'],
    drop_first=True  # keep all categories
)

# %%
pd.set_option('display.max_columns', None)
df_encoded.head(10)
# Out:
#       Price  RAM_Expandable  RAM_Capacity  RAM_TYPE(DDR)  Display_type  \
# 0  127011.5               1             8              3             0
# 1  274750.0               1            16              5             0
# 2  194215.0               1             8              3             0
# 3   76965.0               0             8              4             0
# 4  122465.0               1            16              3             0
# 5  173596.5               1             8              3             0
# 6  139965.0               1             8              3             0
# 7  115888.5               1             4              3             1
# 8  171465.0               0             8              3             0
# 9  325465.0               1            16              5             0
#
#    Processor_Speed(Ghz)  Display_Tier  GPU_Tier  SSD(GB)  HDD(GB)  \
# 0                   4.0             1         1      512        0
# 1                   3.5             1         3      512        0
# 2                   4.0             1         2      512        0
# 3                   1.5             1         1      512        0
# 4                   2.5             1         2      512        0
# 5                   4.0             1         1      512        0
# 6                   2.5             1         2      512        0
# 7                   2.0             1         1        0     1024
# 8                   3.0             1         3      512        0
# 9                   3.5             1         3      512        0
#
#    Processor_Category_AMD Athlon  Processor_Category_AMD Other  \
# 0                          False                         False
# 1                          False                         False
# 2                          False                         False
# 3                          False                         False
# 4                          False                         False
# 5                          False                         False
# 6                          False                         False
# 7                          False                         False
# 8                          False                         False
# 9                          False                         False
#
#    Processor_Category_AMD Ryzen 3  Processor_Category_AMD Ryzen 5  \
# 0                           False                            True
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
# 5                           False                            True
# 6                           False                           False
# 7                           False                           False
# 8                           False                           False
# 9                           False                           False
#
#    Processor_Category_AMD Ryzen 7  Processor_Category_AMD Ryzen 9  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
# 5                           False                           False
# 6                           False                           False
# 7                           False                           False
# 8                           False                           False
# 9                            True                           False
#
#    Processor_Category_Apple M-series  Processor_Category_Intel Celeron  \
# 0                              False                             False
# 1                              False                             False
# 2                              False                             False
# 3                              False                             False
# 4                              False                             False
# 5                              False                             False
# 6                              False                             False
# 7                              False                             False
# 8                              False                             False
# 9                              False                             False
#
#    Processor_Category_Intel I3  Processor_Category_Intel I5  \
# 0                        False                        False
# 1                        False                         True
# 2                        False                         True
# 3                         True                        False
# 4                        False                         True
# 5                        False                        False
# 6                        False                         True
# 7                         True                        False
# 8                        False                         True
# 9                        False                        False
#
#    Processor_Category_Intel I7  Processor_Category_Intel I9  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
# 5                        False                        False
# 6                        False                        False
# 7                        False                        False
# 8                        False                        False
# 9                        False                        False
#
#    Processor_Category_Intel Other  Processor_Category_Intel Pentium  \
# 0                           False                             False
# 1                           False                             False
# 2                           False                             False
# 3                           False                             False
# 4                           False                             False
# 5                           False                             False
# 6                           False                             False
# 7                           False                             False
# 8                           False                             False
# 9                           False                             False
#
#    Processor_Category_Intel Ultra 5  Processor_Category_Intel Ultra 7  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
# 5                             False                             False
# 6                             False                             False
# 7                             False                             False
# 8                             False                             False
# 9                             False                             False
#
#    Processor_Category_Intel Ultra 9  Brand_Acer  Brand_Apple  Brand_Dell  \
# 0                             False       False        False       False
# 1                             False       False        False        True
# 2                             False       False        False       False
# 3                             False       False        False       False
# 4                             False        True        False       False
# 5                             False       False        False       False
# 6                             False        True        False       False
# 7                             False       False        False       False
# 8                             False       False        False       False
# 9                             False       False        False       False
#
#    Brand_HP  Brand_Lenovo  Brand_MSI  Brand_Other  Brand_Samsung  \
# 0     False          True      False        False          False
# 1     False         False      False        False          False
# 2      True         False      False        False          False
# 3     False         False      False         True          False
# 4     False         False      False        False          False
# 5      True         False      False        False          False
# 6     False         False      False        False          False
# 7     False          True      False        False          False
# 8     False         False      False        False          False
# 9     False          True      False        False          False
#
#    Processor_Brand_Apple  Processor_Brand_Intel  GPU_Brand_Apple  \
# 0                  False                  False            False
# 1                  False                   True            False
# 2                  False                   True            False
# 3                  False                   True            False
# 4                  False                   True            False
# 5                  False                  False            False
# 6                  False                   True            False
# 7                  False                   True            False
# 8                  False                   True            False
# 9                  False                  False            False
#
#    GPU_Brand_Intel  GPU_Brand_NVIDIA
# 0            False             False
# 1            False              True
# 2             True             False
# 3             True             False
# 4             True             False
# 5            False             False
# 6             True             False
# 7             True             False
# 8            False              True
# 9            False              True

# %%
df_encoded.shape
# Out:
# (3492, 40)

# %%
df_encoded.dtypes
# Out:
# Price                                float64
# RAM_Expandable                         int64
# RAM_Capacity                           int64
# RAM_TYPE(DDR)                          int64
# Display_type                           int64
# Processor_Speed(Ghz)                 float64
# Display_Tier                           int64
# GPU_Tier                               int64
# SSD(GB)                                int64
# HDD(GB)                                int64
# Processor_Category_AMD Athlon           bool
# Processor_Category_AMD Other            bool
# Processor_Category_AMD Ryzen 3          bool
# Processor_Category_AMD Ryzen 5          bool
# Processor_Category_AMD Ryzen 7          bool
# Processor_Category_AMD Ryzen 9          bool
# Processor_Category_Apple M-series       bool
# Processor_Category_Intel Celeron        bool
# Processor_Category_Intel I3             bool
# Processor_Category_Intel I5             bool
# Processor_Category_Intel I7             bool
# Processor_Category_Intel I9             bool
# Processor_Category_Intel Other          bool
# Processor_Category_Intel Pentium        bool
# Processor_Category_Intel Ultra 5        bool
# Processor_Category_Intel Ultra 7        bool
# Processor_Category_Intel Ultra 9        bool
# Brand_Acer                              bool
# Brand_Apple                             bool
# Brand_Dell                              bool
# Brand_HP                                bool
# Brand_Lenovo                            bool
# Brand_MSI                               bool
# Brand_Other                             bool
# Brand_Samsung                           bool
# Processor_Brand_Apple                   bool
# Processor_Brand_Intel                   bool
# GPU_Brand_Apple                         bool
# GPU_Brand_Intel                         bool
# GPU_Brand_NVIDIA                        bool
# dtype: object

# %% [markdown]
# #### Heat Map

# %%
#Separate features and target
feature_cols = [col for col in df_encoded.columns if col != 'Price'] 
X = df_encoded[feature_cols]  # 23 features
y = df_encoded['Price']       # 1 target

# %%
plt.figure(figsize=(20,18))
sns.heatmap(X.corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Correlation Matrix of Features")
plt.show()

# %%
# from statsmodels.stats.outliers_influence import variance_inflation_factor

# X_vif = X.copy()

# # # 2. Fill NaN in Processor_Tier for VIF calculation
# # X_vif['Processor_Tier'] = X_vif['Processor_Tier'].fillna(-1)

# # 3. Keep only numeric columns
# X_vif = X_vif.select_dtypes(include=['int64', 'float64', 'uint8', 'bool'])

# # 4. Convert all to float
# X_vif = X_vif.astype(float)

# # 5. Compute VIF
# from statsmodels.stats.outliers_influence import variance_inflation_factor
# import pandas as pd

# vif_data = pd.DataFrame()
# vif_data["Feature"] = X_vif.columns
# vif_data["VIF"] = [variance_inflation_factor(X_vif.values, i) for i in range(X_vif.shape[1])]

# print(vif_data.sort_values(by="VIF", ascending=False))

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3492 entries, 0 to 3635
# Data columns (total 40 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Price                              3492 non-null   float64
#  1   RAM_Expandable                     3492 non-null   int64
#  2   RAM_Capacity                       3492 non-null   int64
#  3   RAM_TYPE(DDR)                      3492 non-null   int64
#  4   Display_type                       3492 non-null   int64
#  5   Processor_Speed(Ghz)               3492 non-null   float64
#  6   Display_Tier                       3492 non-null   int64
#  7   GPU_Tier                           3492 non-null   int64
#  8   SSD(GB)                            3492 non-null   int64
#  9   HDD(GB)                            3492 non-null   int64
#  10  Processor_Category_AMD Athlon      3492 non-null   bool
#  11  Processor_Category_AMD Other       3492 non-null   bool
#  12  Processor_Category_AMD Ryzen 3     3492 non-null   bool
#  13  Processor_Category_AMD Ryzen 5     3492 non-null   bool
#  14  Processor_Category_AMD Ryzen 7     3492 non-null   bool
#  15  Processor_Category_AMD Ryzen 9     3492 non-null   bool
#  16  Processor_Category_Apple M-series  3492 non-null   bool
#  17  Processor_Category_Intel Celeron   3492 non-null   bool
#  18  Processor_Category_Intel I3        3492 non-null   bool
#  19  Processor_Category_Intel I5        3492 non-null   bool
#  20  Processor_Category_Intel I7        3492 non-null   bool
#  21  Processor_Category_Intel I9        3492 non-null   bool
#  22  Processor_Category_Intel Other     3492 non-null   bool
#  23  Processor_Category_Intel Pentium   3492 non-null   bool
#  24  Processor_Category_Intel Ultra 5   3492 non-null   bool
#  25  Processor_Category_Intel Ultra 7   3492 non-null   bool
#  26  Processor_Category_Intel Ultra 9   3492 non-null   bool
#  27  Brand_Acer                         3492 non-null   bool
#  28  Brand_Apple                        3492 non-null   bool
#  29  Brand_Dell                         3492 non-null   bool
#  30  Brand_HP                           3492 non-null   bool
#  31  Brand_Lenovo                       3492 non-null   bool
#  32  Brand_MSI                          3492 non-null   bool
#  33  Brand_Other                        3492 non-null   bool
#  34  Brand_Samsung                      3492 non-null   bool
#  35  Processor_Brand_Apple              3492 non-null   bool
#  36  Processor_Brand_Intel              3492 non-null   bool
#  37  GPU_Brand_Apple                    3492 non-null   bool
#  38  GPU_Brand_Intel                    3492 non-null   bool
#  39  GPU_Brand_NVIDIA                   3492 non-null   bool
# dtypes: bool(30), float64(2), int64(8)
# memory usage: 402.4 KB

# %%
df_cleaned = df_encoded.copy()
df_cleaned.to_csv("cleaned_data.csv", index=False)

# %%
# df_cleaned['Processor_Tier'].value_counts(dropna=False)

# %%
# print("Brand Unique Values:", df_cleaned['Brand'].nunique())
# print("Missing Brand values:", df_cleaned['Brand'].isna().sum())
# print(df_cleaned['Brand'].value_counts())
